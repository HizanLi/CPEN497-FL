# %% [markdown]
# # The notebook contains
# ### Code for Our attack and our aggregation algorithm
# ### Evaluation of our defense with different parameters in our attack

# %% [markdown]
# ## Import packages

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
from __future__ import print_function
import argparse, os, sys, csv, shutil, time, random, operator, pickle, ast, math
import numpy as np
import pandas as pd
from torch.optim import Optimizer
import torch.nn.functional as F
import torch
import pickle
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data as data
import torch.multiprocessing as mp
import math
sys.path.insert(0,'./../utils/')
from logger import *
from eval import *
from misc import *

from cifar10_normal_train import *
from cifar10_util import *
from adam import Adam
from sgd import SGD

# %% [markdown]
# ### Load Data
# Divide cifar10 data among 50 clients in Non-IID fashion using Dirichlet distribution

# %%
n_users = 50
user_tr_len = pickle.load(open('./data/user_tr_len.pkl','rb'))

user_train_data_tensors = pickle.load(open('./data/user_train_data_tensors.pkl','rb'))
user_train_label_tensors = pickle.load(open('./data/user_train_label_tensors.pkl','rb'))

val_data_tensor = pickle.load(open('./data/val_data_tensor.pkl','rb'))
val_label_tensor = pickle.load(open('./data/val_label_tensor.pkl','rb'))
te_data_tensor = pickle.load(open('./data/te_data_tensor.pkl','rb'))
te_label_tensor = pickle.load(open('./data/te_label_tensor.pkl','rb'))

# %% [markdown]
# ### Our Aggregation Function

# %%
def our_mean_defense(all_updates, n_attackers, history_updates):
    discarded_history = get_discarded_index(n_attackers, history_updates)

    mask = torch.ones(all_updates.size(0), dtype=torch.bool)
    mask[discarded_history] = False
    remaining_updates = all_updates[mask]

    print('discarded index', discarded_history)

    return torch.nanmean(remaining_updates, dim=0)

####
def euclidean_distance(row1, row2):
    return torch.sqrt(torch.sum((row1 - row2) ** 2))
####

def get_discarded_index(n_attackers, history_updates):
    n_users = history_updates.shape[0]

    ####
    distance_matrix = [[0 if i == j else euclidean_distance(history_updates[i, :], history_updates[j, :]) for j in range(n_users)] for i in range(n_users)]
    ####

    sum_of_distances = [sum(row) for row in distance_matrix]

    discarded_history = []
    for _ in range(n_attackers):
        max_distance = max(sum_of_distances)
        index_of_max_distance = sum_of_distances.index(max_distance)
        discarded_history.append(index_of_max_distance)

        for i in range(n_users):
            sum_of_distances[i] -= distance_matrix[i][index_of_max_distance]
        sum_of_distances[index_of_max_distance] = -1

    return discarded_history

# %% [markdown]
# ### Set nepochs

# %%
nepochs= 300

# %% [markdown]
# # our_attack & our defense

# %% [markdown]
# ## iteration 5
#
# 10 bisection; 5 iterations; 12 discarded

# %% [markdown]
# ### our_attack_mean
# $ argmin_\theta(\ -L(\theta_{attacker(s)}) + \lambda_1 |\bar{\theta_{abs\ mean\ benige\ users}} - \bar{\theta_{abs\ attacker(s)}}|$

# %%
device = 'cuda:0'
def check_condition(lambda1, prev_grad, loss_grad, history, all_updates, n_users, n_attacker, epoch_num):
    loss_grad = loss_grad.to(device)
    prev_grad = prev_grad.to(device)
    new_grad = lambda1 * (loss_grad + prev_grad)

    ####
    mal_updates = torch.stack([new_grad.clone().detach() for _ in range(n_attacker)])
    malicious_grads = torch.cat((mal_updates, all_updates[n_attacker:]), 0)

    history_updates = history.clone().detach()
    history_updates[:, epoch_num] = malicious_grads.abs().mean(dim=1, keepdim=True).squeeze()
    ####

    discarded_history = get_discarded_index(n_attacker+2, history_updates)

    detected_mal = len([item for item in discarded_history if item < 10])
    return detected_mal / len(discarded_history) <= n_attacker / n_users

def find_upper_bound(lambda1, prev_grad, loss_grad, history, all_updates, n_users, n_attacker, epoch_num):
    while check_condition(lambda1, prev_grad, loss_grad, history, all_updates, n_users, n_attacker, epoch_num):
        lambda1 *= 2  # Exponentially increase lambda
    return lambda1


def projection(prev_grad, loss_grad, history, all_updates, n_users, n_attacker, epoch_num):
    updates_abs_mean = all_updates.abs().mean(dim=1, keepdim=True)
    median_value = torch.median(updates_abs_mean).item()

    ####
    history_updates = history.clone().detach()
    history_updates[:, epoch_num] = updates_abs_mean.mean(dim=1, keepdim=True).squeeze()
    ####

    loss_grad = loss_grad.to(device)
    prev_grad = prev_grad.to(device)

    lambda_low = median_value/(prev_grad + loss_grad).abs().mean().item()
    lambda_high = find_upper_bound(lambda_low, prev_grad, loss_grad, history_updates, all_updates, n_users, n_attacker, epoch_num)
    if lambda_high < lambda_low:
        lambda_high = lambda_low
        print("SHOULD NEVER REACH THIS LINE")
        print('lambda_low: ', lambda_low, ' lambda_high: ', lambda_high)
    tolerance = 1e-6

    iterations_count = 0
    while lambda_high - lambda_low > tolerance and iterations_count < 10:
        lambda_mid = (lambda_low + lambda_high) / 2
        if check_condition(lambda_mid, prev_grad, loss_grad, history_updates, all_updates, n_users, n_attacker, epoch_num):
            lambda_low = lambda_mid
        else:
            lambda_high = lambda_mid
        iterations_count += 1

    lambda1 = lambda_low

    return lambda1 * (prev_grad + loss_grad)

def our_attack_mean(n_user, epoch_num, history_updates, all_updates, model_params, n_attacker, arch, criterion, user_train_data_tensors, user_train_label_tensors):
    attacker_tr_data_tensor = user_train_data_tensors[0].cuda()
    attacker_tr_label_tensor = user_train_label_tensors[0].cuda()

    fed_model, _ = return_model(arch, 0.1, 0.9, parallel=False)
    fed_model.eval()  # Ensure the model is in evaluation mode

    new_grad = -all_updates[0].clone().detach().requires_grad_(True)
    prev_grad = np.zeros(len(new_grad))
    new_grad = projection(torch.from_numpy(prev_grad), new_grad, history_updates, all_updates, n_user, n_attacker, epoch_num)

    for _ in range(5):
        outputs = fed_model(attacker_tr_data_tensor)
        loss = criterion(outputs, attacker_tr_label_tensor)

        loss.backward(retain_graph=True)
        param_grad = []
        for param in fed_model.parameters():
            param_grad.append(param.grad.view(-1).detach())

        param_grad = torch.cat(param_grad)
        prev_grad = new_grad
        new_grad = projection(prev_grad, param_grad, history_updates, all_updates, n_user, n_attacker, epoch_num)

        difference = torch.mean(torch.abs(new_grad - prev_grad)).item()
        if difference < 1e-6:
            # print("STOPPED! Difference is too small, stop finding best attack grad")
            break

        fed_model.zero_grad()

    result_attacker_grads = [new_grad.clone().detach() for _ in range(10)]
    return torch.stack(result_attacker_grads).cuda()

# %% [markdown]
# ### our attack (10 attacker) + our defense

# %%
batch_size=250
resume=0

schedule=[1000]

gamma=.5
opt = 'sgd'
fed_lr=0.5
criterion=nn.CrossEntropyLoss()
use_cuda = torch.cuda.is_available()

aggregation='bulyan'
multi_k = False
candidates = []

at_type='our-agr'
dev_type ='std'
n_attackers=[10]

arch='alexnet'
chkpt='./'+aggregation

past_mean = []
past_abs_sum = []
past_median = []
past_lower_quartile = []
past_upper_quartile = []
past_std = []

title = "our attack (10 attacker) + our defense"

for n_attacker in n_attackers:
    epoch_num = 0
    best_global_acc = 0
    best_global_te_acc = 0

    torch.cuda.empty_cache()

    fed_model, _ = return_model(arch, 0.1, 0.9, parallel=False)
    optimizer_fed = SGD(fed_model.parameters(), lr=fed_lr)

    df = pd.DataFrame(columns = ['epoch', 'loss', 'validation accuracy', 'best validation accuracy'])

    ####
    history = torch.zeros((n_users, nepochs + 1), dtype=torch.float32).cuda()
    ####

    model_grads = []
    flag = False
    while epoch_num <= nepochs:
        user_grads=[]

        for i in range(n_users): # 50
            nbatches = user_tr_len[i]//batch_size

            inputs = user_train_data_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]
            targets = user_train_label_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]

            targets = targets.type(torch.LongTensor)

            inputs, targets = inputs.cuda(), targets.cuda()
            inputs, targets = torch.autograd.Variable(inputs), torch.autograd.Variable(targets)

            outputs = fed_model(inputs)
            loss = criterion(outputs, targets)
            fed_model.zero_grad()
            loss.backward(retain_graph=True)

            param_grad=[]
            for param in fed_model.parameters():
                param_grad=param.grad.data.view(-1) if not len(param_grad) else torch.cat((param_grad,param.grad.view(-1)))


            user_grads=param_grad[None, :] if len(user_grads)==0 else torch.cat((user_grads,param_grad[None,:]), 0)

        if epoch_num in schedule:
            for param_group in optimizer_fed.param_groups:
                param_group['lr'] *= gamma
                print('New learnin rate ', param_group['lr'])

        updates_abs_mean = user_grads.abs().mean(dim=1, keepdim=True)

        if n_attacker > 0:
            model_params = torch.cat([p.data.view(-1) for p in fed_model.parameters()])
            mal_updates = our_attack_mean(n_users, epoch_num, history, user_grads, model_params, n_attacker, arch, criterion, user_train_data_tensors, user_train_label_tensors)
            malicious_grads = torch.cat((mal_updates, user_grads[n_attacker:]), 0) # torch.Size([50, 2472266])


        if not (malicious_grads.shape[0]==50):
            print(malicious_grads.shape)

        updates_abs_mean = malicious_grads.abs().mean(dim=1, keepdim=True)

        history[:, epoch_num] = updates_abs_mean.squeeze()
        agg_grads = our_mean_defense(malicious_grads, n_attacker, history)

        del user_grads

        start_idx=0

        optimizer_fed.zero_grad()

        model_grads=[]

        for i, param in enumerate(fed_model.parameters()):
            param_=agg_grads[start_idx:start_idx+len(param.data.view(-1))].reshape(param.data.shape)
            start_idx=start_idx+len(param.data.view(-1))
            param_=param_.cuda()
            model_grads.append(param_)

        optimizer_fed.step(model_grads)

        val_loss, val_acc = test(val_data_tensor,val_label_tensor,fed_model,criterion, use_cuda)
        te_loss, te_acc = test(te_data_tensor,te_label_tensor, fed_model, criterion, use_cuda)

        is_best = best_global_acc < val_acc

        best_global_acc = max(best_global_acc, val_acc)

        if is_best:
            best_global_te_acc = te_acc


        print('epoch: %d, %s: at %s n_at %d e %d | val loss %.4f val acc %.4f best val_acc %f'%(epoch_num, aggregation, at_type, n_attacker, epoch_num, val_loss, val_acc, best_global_acc))
        new_row = pd.DataFrame([{
            'epoch': epoch_num,
            'loss': val_loss,
            'validation accuracy': val_acc,
            'best validation accuracy': best_global_acc
            }])
        df = pd.concat([df, new_row], ignore_index=True)
        df.to_csv(f'{title}.csv', index=False)

        epoch_num+=1
# Out:
# discarded index [34, 37, 33, 25, 49, 43, 11, 24, 14, 44]
# epoch: 0, bulyan: at our-agr n_at 10 e 0 | val loss 2.3030 val acc 10.1461 best val_acc 10.146104
# c:\Users\Hizan\Desktop\CPEN497-FL\attack-defense\sgd.py:109: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\python_arg_parser.cpp:1630.)
#   p.data.add_(-group['lr'], d_p)
# C:\Users\Hizan\AppData\Local\Temp\ipykernel_15296\3893755665.py:131: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, new_row], ignore_index=True)
# discarded index [34, 37, 43, 25, 33, 49, 24, 11, 44, 28]
# epoch: 1, bulyan: at our-agr n_at 10 e 1 | val loss 2.3027 val acc 10.1461 best val_acc 10.146104
# discarded index [34, 15, 39, 37, 43, 25, 49, 24, 11, 33]
# epoch: 2, bulyan: at our-agr n_at 10 e 2 | val loss 2.3026 val acc 10.1461 best val_acc 10.146104
# discarded index [34, 15, 39, 43, 37, 25, 49, 33, 24, 11]
# epoch: 3, bulyan: at our-agr n_at 10 e 3 | val loss 2.3028 val acc 10.1461 best val_acc 10.146104
# discarded index [34, 15, 39, 37, 49, 43, 25, 24, 33, 11]
# epoch: 4, bulyan: at our-agr n_at 10 e 4 | val loss 2.3032 val acc 10.1461 best val_acc 10.146104
# discarded index [34, 15, 39, 43, 37, 25, 49, 24, 11, 33]
# epoch: 5, bulyan: at our-agr n_at 10 e 5 | val loss 2.3036 val acc 10.1461 best val_acc 10.146104
# discarded index [34, 15, 37, 43, 49, 25, 24, 33, 11, 44]
# epoch: 6, bulyan: at our-agr n_at 10 e 6 | val loss 2.3044 val acc 10.1461 best val_acc 10.146104
# discarded index [34, 15, 39, 0, 1, 2, 3, 4, 5, 6]
# epoch: 7, bulyan: at our-agr n_at 10 e 7 | val loss 2.3032 val acc 10.1461 best val_acc 10.146104
# discarded index [34, 15, 39, 43, 37, 25, 49, 24, 11, 33]
# epoch: 8, bulyan: at our-agr n_at 10 e 8 | val loss 2.3035 val acc 10.1461 best val_acc 10.146104
# discarded index [34, 15, 39, 43, 37, 49, 25, 24, 33, 11]
# epoch: 9, bulyan: at our-agr n_at 10 e 9 | val loss 2.3043 val acc 10.1461 best val_acc 10.146104
# discarded index [34, 15, 39, 43, 37, 49, 25, 24, 33, 11]
# epoch: 10, bulyan: at our-agr n_at 10 e 10 | val loss 2.3045 val acc 10.1461 best val_acc 10.146104
# discarded index [34, 15, 43, 39, 37, 49, 24, 25, 11, 33]
# epoch: 11, bulyan: at our-agr n_at 10 e 11 | val loss 2.3049 val acc 10.1461 best val_acc 10.146104
# discarded index [34, 15, 43, 37, 49, 24, 25, 33, 28, 11]
# epoch: 12, bulyan: at our-agr n_at 10 e 12 | val loss 2.3041 val acc 10.1461 best val_acc 10.146104
# discarded index [34, 43, 24, 37, 49, 25, 28, 40, 33, 11]
# epoch: 13, bulyan: at our-agr n_at 10 e 13 | val loss 2.3021 val acc 10.2273 best val_acc 10.227273
# discarded index [34, 43, 24, 25, 49, 37, 40, 33, 28, 16]
# epoch: 14, bulyan: at our-agr n_at 10 e 14 | val loss 2.2988 val acc 10.3490 best val_acc 10.349026
# discarded index [34, 43, 49, 33, 24, 25, 11, 40, 28, 37]
# epoch: 15, bulyan: at our-agr n_at 10 e 15 | val loss 2.3025 val acc 10.4708 best val_acc 10.470779
# discarded index [20, 47, 34, 45, 49, 43, 33, 0, 1, 2]
# epoch: 16, bulyan: at our-agr n_at 10 e 16 | val loss 2.3010 val acc 10.0446 best val_acc 10.470779
# discarded index [20, 47, 34, 45, 43, 49, 40, 32, 11, 33]
# epoch: 17, bulyan: at our-agr n_at 10 e 17 | val loss 2.3326 val acc 12.1550 best val_acc 12.155032
# discarded index [20, 47, 45, 22, 34, 43, 28, 49, 11, 40]
# epoch: 18, bulyan: at our-agr n_at 10 e 18 | val loss 2.3436 val acc 11.1404 best val_acc 12.155032
# discarded index [20, 47, 45, 34, 22, 43, 11, 49, 44, 28]
# epoch: 19, bulyan: at our-agr n_at 10 e 19 | val loss 2.3287 val acc 10.4302 best val_acc 12.155032
# discarded index [20, 47, 45, 34, 43, 49, 11, 22, 44, 40]
# epoch: 20, bulyan: at our-agr n_at 10 e 20 | val loss 2.4116 val acc 10.1867 best val_acc 12.155032
# discarded index [20, 47, 45, 22, 31, 10, 34, 37, 11, 49]
# epoch: 21, bulyan: at our-agr n_at 10 e 21 | val loss 2.3763 val acc 9.5779 best val_acc 12.155032
# discarded index [20, 47, 45, 22, 31, 34, 10, 11, 43, 49]
# epoch: 22, bulyan: at our-agr n_at 10 e 22 | val loss 2.6696 val acc 9.4359 best val_acc 12.155032
# discarded index [20, 47, 45, 27, 10, 31, 37, 22, 49, 21]
# epoch: 23, bulyan: at our-agr n_at 10 e 23 | val loss 2.4278 val acc 9.7200 best val_acc 12.155032
# discarded index [20, 47, 45, 27, 10, 31, 37, 22, 49, 21]
# epoch: 24, bulyan: at our-agr n_at 10 e 24 | val loss 2.4596 val acc 12.5812 best val_acc 12.581169
# discarded index [20, 47, 45, 27, 31, 10, 37, 22, 35, 13]
# epoch: 25, bulyan: at our-agr n_at 10 e 25 | val loss 2.3108 val acc 15.5235 best val_acc 15.523539
# discarded index [20, 47, 45, 27, 31, 10, 37, 22, 35, 13]
# epoch: 26, bulyan: at our-agr n_at 10 e 26 | val loss 2.4986 val acc 10.1664 best val_acc 15.523539
# discarded index [20, 47, 45, 31, 10, 27, 22, 37, 35, 21]
# epoch: 27, bulyan: at our-agr n_at 10 e 27 | val loss 2.3329 val acc 11.9927 best val_acc 15.523539
# discarded index [20, 47, 45, 31, 10, 27, 22, 37, 35, 21]
# epoch: 28, bulyan: at our-agr n_at 10 e 28 | val loss 2.5188 val acc 8.1981 best val_acc 15.523539
# discarded index [20, 47, 45, 31, 10, 27, 37, 22, 35, 18]
# epoch: 29, bulyan: at our-agr n_at 10 e 29 | val loss 2.3321 val acc 14.8742 best val_acc 15.523539
# discarded index [20, 47, 45, 31, 10, 27, 37, 22, 35, 18]
# epoch: 30, bulyan: at our-agr n_at 10 e 30 | val loss 2.8217 val acc 10.2476 best val_acc 15.523539
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 21, 34]
# epoch: 31, bulyan: at our-agr n_at 10 e 31 | val loss 2.5252 val acc 13.9002 best val_acc 15.523539
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 21, 34]
# epoch: 32, bulyan: at our-agr n_at 10 e 32 | val loss 2.7769 val acc 10.2273 best val_acc 15.523539
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 21, 37]
# epoch: 33, bulyan: at our-agr n_at 10 e 33 | val loss 2.3919 val acc 10.2476 best val_acc 15.523539
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 21, 37]
# epoch: 34, bulyan: at our-agr n_at 10 e 34 | val loss 2.3177 val acc 12.5000 best val_acc 15.523539
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 21, 37]
# epoch: 35, bulyan: at our-agr n_at 10 e 35 | val loss 2.2616 val acc 17.0252 best val_acc 17.025162
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 21, 37]
# epoch: 36, bulyan: at our-agr n_at 10 e 36 | val loss 2.7187 val acc 12.7841 best val_acc 17.025162
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 21, 34]
# epoch: 37, bulyan: at our-agr n_at 10 e 37 | val loss 2.8943 val acc 10.1461 best val_acc 17.025162
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 21, 34]
# epoch: 38, bulyan: at our-agr n_at 10 e 38 | val loss 2.6466 val acc 14.6916 best val_acc 17.025162
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 21, 37]
# epoch: 39, bulyan: at our-agr n_at 10 e 39 | val loss 2.4326 val acc 18.1006 best val_acc 18.100649
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 21, 28]
# epoch: 40, bulyan: at our-agr n_at 10 e 40 | val loss 2.2766 val acc 14.1234 best val_acc 18.100649
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 21, 37]
# epoch: 41, bulyan: at our-agr n_at 10 e 41 | val loss 2.7092 val acc 17.0049 best val_acc 18.100649
# discarded index [20, 47, 45, 31, 10, 35, 27, 18, 21, 28]
# epoch: 42, bulyan: at our-agr n_at 10 e 42 | val loss 2.5502 val acc 10.0244 best val_acc 18.100649
# discarded index [20, 47, 45, 31, 10, 35, 27, 18, 21, 28]
# epoch: 43, bulyan: at our-agr n_at 10 e 43 | val loss 11.0596 val acc 11.5463 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 27, 28, 37, 18, 35]
# epoch: 44, bulyan: at our-agr n_at 10 e 44 | val loss 5.3990 val acc 9.9229 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 37, 33, 17]
# epoch: 45, bulyan: at our-agr n_at 10 e 45 | val loss 3.6132 val acc 10.1461 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 37, 33, 17]
# epoch: 46, bulyan: at our-agr n_at 10 e 46 | val loss 3.1043 val acc 10.1461 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 37, 33, 17]
# epoch: 47, bulyan: at our-agr n_at 10 e 47 | val loss 4.1800 val acc 10.8157 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 48, bulyan: at our-agr n_at 10 e 48 | val loss 2.9957 val acc 10.1461 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 49, bulyan: at our-agr n_at 10 e 49 | val loss 2.8572 val acc 10.3084 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 50, bulyan: at our-agr n_at 10 e 50 | val loss 2.6866 val acc 10.3084 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 51, bulyan: at our-agr n_at 10 e 51 | val loss 2.6186 val acc 10.3084 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 52, bulyan: at our-agr n_at 10 e 52 | val loss 2.5081 val acc 10.3084 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 53, bulyan: at our-agr n_at 10 e 53 | val loss 2.4505 val acc 10.3084 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 54, bulyan: at our-agr n_at 10 e 54 | val loss 2.3931 val acc 10.3084 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 55, bulyan: at our-agr n_at 10 e 55 | val loss 2.3530 val acc 10.3084 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 56, bulyan: at our-agr n_at 10 e 56 | val loss 2.3207 val acc 9.7606 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 57, bulyan: at our-agr n_at 10 e 57 | val loss 2.3089 val acc 7.9748 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 58, bulyan: at our-agr n_at 10 e 58 | val loss 2.3045 val acc 8.3604 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 59, bulyan: at our-agr n_at 10 e 59 | val loss 2.3002 val acc 10.2881 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 60, bulyan: at our-agr n_at 10 e 60 | val loss 2.3089 val acc 9.3750 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 61, bulyan: at our-agr n_at 10 e 61 | val loss 2.2925 val acc 11.3433 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 62, bulyan: at our-agr n_at 10 e 62 | val loss 2.3125 val acc 10.2881 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 63, bulyan: at our-agr n_at 10 e 63 | val loss 2.2866 val acc 12.4391 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 64, bulyan: at our-agr n_at 10 e 64 | val loss 2.3331 val acc 12.4797 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 65, bulyan: at our-agr n_at 10 e 65 | val loss 2.2866 val acc 12.2362 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 66, bulyan: at our-agr n_at 10 e 66 | val loss 2.3186 val acc 11.9927 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 67, bulyan: at our-agr n_at 10 e 67 | val loss 2.2787 val acc 13.1696 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 68, bulyan: at our-agr n_at 10 e 68 | val loss 2.3355 val acc 12.5812 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 69, bulyan: at our-agr n_at 10 e 69 | val loss 2.2772 val acc 13.9813 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 70, bulyan: at our-agr n_at 10 e 70 | val loss 2.4110 val acc 10.7752 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 71, bulyan: at our-agr n_at 10 e 71 | val loss 2.2977 val acc 13.8596 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 72, bulyan: at our-agr n_at 10 e 72 | val loss 2.3432 val acc 13.3320 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 73, bulyan: at our-agr n_at 10 e 73 | val loss 2.2708 val acc 16.1323 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 74, bulyan: at our-agr n_at 10 e 74 | val loss 2.3434 val acc 13.9407 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 75, bulyan: at our-agr n_at 10 e 75 | val loss 2.2624 val acc 16.5584 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 76, bulyan: at our-agr n_at 10 e 76 | val loss 2.3516 val acc 14.1031 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 77, bulyan: at our-agr n_at 10 e 77 | val loss 2.2679 val acc 15.0974 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 78, bulyan: at our-agr n_at 10 e 78 | val loss 2.2980 val acc 11.5463 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 79, bulyan: at our-agr n_at 10 e 79 | val loss 2.2862 val acc 15.3815 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 80, bulyan: at our-agr n_at 10 e 80 | val loss 2.3341 val acc 13.7987 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 81, bulyan: at our-agr n_at 10 e 81 | val loss 2.2601 val acc 16.7817 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 82, bulyan: at our-agr n_at 10 e 82 | val loss 2.3676 val acc 14.0422 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 83, bulyan: at our-agr n_at 10 e 83 | val loss 2.2194 val acc 16.4976 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 84, bulyan: at our-agr n_at 10 e 84 | val loss 2.3478 val acc 12.8247 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 85, bulyan: at our-agr n_at 10 e 85 | val loss 2.3538 val acc 10.7143 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 86, bulyan: at our-agr n_at 10 e 86 | val loss 2.2627 val acc 14.2857 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 87, bulyan: at our-agr n_at 10 e 87 | val loss 2.8757 val acc 11.2216 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 88, bulyan: at our-agr n_at 10 e 88 | val loss 2.4530 val acc 12.9870 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 89, bulyan: at our-agr n_at 10 e 89 | val loss 2.2932 val acc 14.9351 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 90, bulyan: at our-agr n_at 10 e 90 | val loss 2.2667 val acc 15.1177 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 91, bulyan: at our-agr n_at 10 e 91 | val loss 2.3808 val acc 11.4651 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 92, bulyan: at our-agr n_at 10 e 92 | val loss 2.3647 val acc 12.7029 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 93, bulyan: at our-agr n_at 10 e 93 | val loss 2.4519 val acc 10.1664 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 94, bulyan: at our-agr n_at 10 e 94 | val loss 2.2445 val acc 14.7524 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 95, bulyan: at our-agr n_at 10 e 95 | val loss 2.4608 val acc 13.7378 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 96, bulyan: at our-agr n_at 10 e 96 | val loss 2.2660 val acc 17.1672 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 97, bulyan: at our-agr n_at 10 e 97 | val loss 2.4654 val acc 14.0828 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 98, bulyan: at our-agr n_at 10 e 98 | val loss 2.2415 val acc 15.7468 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 99, bulyan: at our-agr n_at 10 e 99 | val loss 2.5736 val acc 12.8044 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 100, bulyan: at our-agr n_at 10 e 100 | val loss 2.4934 val acc 10.2070 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 101, bulyan: at our-agr n_at 10 e 101 | val loss 2.2696 val acc 9.9026 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 102, bulyan: at our-agr n_at 10 e 102 | val loss 2.4968 val acc 12.1956 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 103, bulyan: at our-agr n_at 10 e 103 | val loss 2.3618 val acc 16.7411 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 104, bulyan: at our-agr n_at 10 e 104 | val loss 2.7699 val acc 13.5958 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 105, bulyan: at our-agr n_at 10 e 105 | val loss 2.3976 val acc 14.6307 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 106, bulyan: at our-agr n_at 10 e 106 | val loss 2.2695 val acc 15.1177 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 107, bulyan: at our-agr n_at 10 e 107 | val loss 2.3178 val acc 16.4570 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 108, bulyan: at our-agr n_at 10 e 108 | val loss 2.9281 val acc 13.1291 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 109, bulyan: at our-agr n_at 10 e 109 | val loss 2.4771 val acc 12.8856 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 110, bulyan: at our-agr n_at 10 e 110 | val loss 2.5268 val acc 12.9261 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 111, bulyan: at our-agr n_at 10 e 111 | val loss 2.5505 val acc 10.4302 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 112, bulyan: at our-agr n_at 10 e 112 | val loss 2.4465 val acc 11.5463 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 113, bulyan: at our-agr n_at 10 e 113 | val loss 2.5086 val acc 14.5901 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 17, 37, 33]
# epoch: 114, bulyan: at our-agr n_at 10 e 114 | val loss 5.9690 val acc 9.8011 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 37, 0, 1]
# epoch: 115, bulyan: at our-agr n_at 10 e 115 | val loss 3.7065 val acc 10.3084 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 37, 0, 1]
# epoch: 116, bulyan: at our-agr n_at 10 e 116 | val loss 3.0821 val acc 8.8474 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 27, 37, 0, 1]
# epoch: 117, bulyan: at our-agr n_at 10 e 117 | val loss 14.1426 val acc 10.3490 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 17, 18, 27, 35]
# epoch: 118, bulyan: at our-agr n_at 10 e 118 | val loss 5.8560 val acc 10.1461 best val_acc 18.100649
# discarded index [20, 47, 45, 10, 31, 28, 17, 18, 27, 35]
# epoch: 119, bulyan: at our-agr n_at 10 e 119 | val loss 189.2170 val acc 9.8620 best val_acc 18.100649
# discarded index [20, 31, 47, 18, 21, 17, 39, 45, 42, 25]
# epoch: 120, bulyan: at our-agr n_at 10 e 120 | val loss 8.6276 val acc 7.8328 best val_acc 18.100649
# discarded index [20, 31, 39, 17, 18, 21, 47, 45, 42, 15]
# epoch: 121, bulyan: at our-agr n_at 10 e 121 | val loss 160.7636 val acc 7.7719 best val_acc 18.100649
# discarded index [39, 15, 27, 46, 41, 29, 20, 31, 19, 42]
# epoch: 122, bulyan: at our-agr n_at 10 e 122 | val loss 21907.6200 val acc 9.8011 best val_acc 18.100649
# val loss 21907.620041 too high

# %%
import matplotlib.pyplot as plt

# Plotting the data
for col in ['loss', 'validation accuracy', 'best validation accuracy']:
    plt.plot(df['epoch'].tolist(), df[col].tolist())
    plt.title(f"{title} {col}")
    plt.show()
