# %% [markdown]
# # The notebook contains
# ### Code for _Bulyan_ aggregation algorithm, *when gradient updates of benign clients are unknown to adversary*
# ### Evaluation of all of the attacks (Fang, LIE, and our SOTA AGR-tailored and AGR-agnstic) on Bulyan

# %% [markdown]
# ## Import packages

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
from __future__ import print_function
import argparse, os, sys, csv, shutil, time, random, operator, pickle, ast, math
import numpy as np
import pandas as pd
from torch.optim import Optimizer
import torch.nn.functional as F
import torch
import pickle
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data as data
import torch.multiprocessing as mp
import math
sys.path.insert(0,'./../utils/')
from logger import *
from eval import *
from misc import *

from cifar10_normal_train import *
from cifar10_util import *
from adam import Adam
from sgd import SGD

# %% [markdown]
# ## Load Data
# Divide cifar10 data among 50 clients in Non-IID fashion using Dirichlet distribution

# %%
n_users = 50
user_tr_len = pickle.load(open('./data/user_tr_len.pkl','rb'))

user_train_data_tensors = pickle.load(open('./data/user_train_data_tensors.pkl','rb'))
user_train_label_tensors = pickle.load(open('./data/user_train_label_tensors.pkl','rb'))

val_data_tensor = pickle.load(open('./data/val_data_tensor.pkl','rb'))
val_label_tensor = pickle.load(open('./data/val_label_tensor.pkl','rb'))
te_data_tensor = pickle.load(open('./data/te_data_tensor.pkl','rb'))
te_label_tensor = pickle.load(open('./data/te_label_tensor.pkl','rb'))

# %% [markdown]
# ## Set nepochs

# %%
nepochs= 300

# %% [markdown]
# ## Code for Multi-krum aggregation algorithm

# %%
def multi_krum(all_updates, n_attackers, multi_k=False):

    candidates = []
    candidate_indices = []
    remaining_updates = all_updates
    all_indices = np.arange(len(all_updates))

    while len(remaining_updates) > 2 * n_attackers + 2:
        torch.cuda.empty_cache()
        distances = []
        for update in remaining_updates:
            distance = []
            for update_ in remaining_updates:
                distance.append(torch.norm((update - update_)) ** 2)
            distance = torch.Tensor(distance).float()
            distances = distance[None, :] if not len(distances) else torch.cat((distances, distance[None, :]), 0)

        distances = torch.sort(distances, dim=1)[0]
        scores = torch.sum(distances[:, :len(remaining_updates) - 2 - n_attackers], dim=1)
        indices = torch.argsort(scores)[:len(remaining_updates) - 2 - n_attackers]

        candidate_indices.append(all_indices[indices[0].cpu().numpy()])
        all_indices = np.delete(all_indices, indices[0].cpu().numpy())
        candidates = remaining_updates[indices[0]][None, :] if not len(candidates) else torch.cat((candidates, remaining_updates[indices[0]][None, :]), 0)
        remaining_updates = torch.cat((remaining_updates[:indices[0]], remaining_updates[indices[0] + 1:]), 0)
        if not multi_k:
            break
    # print(len(remaining_updates))

    aggregate = torch.mean(candidates, dim=0)

    return aggregate, np.array(candidate_indices)

# %% [markdown]
# ## LIE attack and multikrum defense

# %%
def lie_attack(all_updates, z):
    avg = torch.mean(all_updates, dim=0)
    std = torch.std(all_updates, dim=0)
    return avg + z * std

# %%
batch_size=250
resume=0

schedule=[1000]

gamma=.5
opt = 'sgd'
fed_lr=0.5
criterion=nn.CrossEntropyLoss()
use_cuda = torch.cuda.is_available()

at_type = 'multi-krum'

aggregation='bulyan'
multi_k = False
candidates = []

dev_type ='std'
n_attackers=[10]
z_values={3:0.69847, 5:0.7054, 8:0.71904, 10:0.72575, 12:0.73891}

arch='alexnet'
chkpt='./'+aggregation

past_mean = []
past_abs_sum = []
past_median = []
past_lower_quartile = []
past_upper_quartile = []
past_std = []

title = "LIE attack and multi-krum defense"

for n_attacker in n_attackers:
    epoch_num = 0
    best_global_acc = 0
    best_global_te_acc = 0

    torch.cuda.empty_cache()

    fed_model, _ = return_model(arch, 0.1, 0.9, parallel=False)
    optimizer_fed = SGD(fed_model.parameters(), lr=fed_lr)

    df = pd.DataFrame(columns = ['epoch', 'loss', 'validation accuracy', 'best validation accuracy'])

    ####
    history = torch.zeros((n_users, nepochs + 1), dtype=torch.float32).cuda()
    ####

    model_grads = []
    while epoch_num <= nepochs:
        user_grads=[]

        for i in range(n_users): # 50
            nbatches = user_tr_len[i]//batch_size

            inputs = user_train_data_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]
            targets = user_train_label_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]

            targets = targets.type(torch.LongTensor)

            inputs, targets = inputs.cuda(), targets.cuda()
            inputs, targets = torch.autograd.Variable(inputs), torch.autograd.Variable(targets)

            outputs = fed_model(inputs)
            loss = criterion(outputs, targets)
            fed_model.zero_grad()
            loss.backward(retain_graph=True)

            param_grad=[]
            for param in fed_model.parameters():
                param_grad=param.grad.data.view(-1) if not len(param_grad) else torch.cat((param_grad,param.grad.view(-1)))


            user_grads=param_grad[None, :] if len(user_grads)==0 else torch.cat((user_grads,param_grad[None,:]), 0)

        if epoch_num in schedule:
            for param_group in optimizer_fed.param_groups:
                param_group['lr'] *= gamma
                print('New learnin rate ', param_group['lr'])

        updates_abs_mean = user_grads.abs().mean(dim=1, keepdim=True)

        if n_attacker > 0:
            mal_update = lie_attack(user_grads, z_values[n_attacker])
            malicious_grads = torch.cat((torch.stack([mal_update]*n_attacker), user_grads[n_attacker:]))
        else:   # No attack
            malicious_grads = user_grads

        if not (malicious_grads.shape[0]==50):
            print(malicious_grads.shape)

        updates_abs_mean = malicious_grads.abs().mean(dim=1, keepdim=True)

        history[:, epoch_num] = updates_abs_mean.squeeze()
        agg_grads, _ = multi_krum(malicious_grads, n_attacker, multi_k=False)

        del user_grads

        start_idx=0

        optimizer_fed.zero_grad()

        model_grads=[]

        for i, param in enumerate(fed_model.parameters()):
            param_=agg_grads[start_idx:start_idx+len(param.data.view(-1))].reshape(param.data.shape)
            start_idx=start_idx+len(param.data.view(-1))
            param_=param_.cuda()
            model_grads.append(param_)

        optimizer_fed.step(model_grads)

        val_loss, val_acc = test(val_data_tensor,val_label_tensor,fed_model,criterion,use_cuda)
        te_loss, te_acc = test(te_data_tensor,te_label_tensor, fed_model, criterion, use_cuda)

        is_best = best_global_acc < val_acc

        best_global_acc = max(best_global_acc, val_acc)

        if is_best:
            best_global_te_acc = te_acc


        print('epoch: %d, %s: at %s n_at %d e %d | val loss %.4f val acc %.4f best val_acc %f'%(epoch_num, aggregation, at_type, n_attacker, epoch_num, val_loss, val_acc, best_global_acc))
        new_row = pd.DataFrame([{
            'epoch': epoch_num,
            'loss': val_loss,
            'validation accuracy': val_acc,
            'best validation accuracy': best_global_acc
            }])
        df = pd.concat([df, new_row], ignore_index=True)
        df.to_csv('lie_multi-krum.csv', index=False)

        if val_loss > 1000:
            print('val loss %f too high'%val_loss)
            break

        epoch_num+=1
# Out:
# c:\Users\tians\Desktop\CPEN499\CPEN497-FL\attack-defense\sgd.py:109: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at ..\torch\csrc\utils\python_arg_parser.cpp:1630.)
#   p.data.add_(-group['lr'], d_p)
# epoch: 0, bulyan: at multi-krum n_at 10 e 0 | val loss 2.3035 val acc 9.8823 best val_acc 9.882305
# C:\Users\tians\AppData\Local\Temp\ipykernel_24228\584266654.py:132: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, new_row], ignore_index=True)
# epoch: 1, bulyan: at multi-krum n_at 10 e 1 | val loss 2.3038 val acc 9.8823 best val_acc 9.882305
# epoch: 2, bulyan: at multi-krum n_at 10 e 2 | val loss 2.3053 val acc 9.8823 best val_acc 9.882305
# epoch: 3, bulyan: at multi-krum n_at 10 e 3 | val loss 2.3061 val acc 9.8823 best val_acc 9.882305
# epoch: 4, bulyan: at multi-krum n_at 10 e 4 | val loss 2.3081 val acc 9.8823 best val_acc 9.882305
# epoch: 5, bulyan: at multi-krum n_at 10 e 5 | val loss 2.3091 val acc 9.8823 best val_acc 9.882305
# epoch: 6, bulyan: at multi-krum n_at 10 e 6 | val loss 2.3117 val acc 9.8823 best val_acc 9.882305
# epoch: 7, bulyan: at multi-krum n_at 10 e 7 | val loss 2.3129 val acc 9.8823 best val_acc 9.882305
# epoch: 8, bulyan: at multi-krum n_at 10 e 8 | val loss 2.3159 val acc 9.8823 best val_acc 9.882305
# epoch: 9, bulyan: at multi-krum n_at 10 e 9 | val loss 2.3170 val acc 9.8823 best val_acc 9.882305
# epoch: 10, bulyan: at multi-krum n_at 10 e 10 | val loss 2.3205 val acc 9.8823 best val_acc 9.882305
# epoch: 11, bulyan: at multi-krum n_at 10 e 11 | val loss 2.3214 val acc 9.8823 best val_acc 9.882305
# epoch: 12, bulyan: at multi-krum n_at 10 e 12 | val loss 2.3254 val acc 9.8823 best val_acc 9.882305
# epoch: 13, bulyan: at multi-krum n_at 10 e 13 | val loss 2.3259 val acc 9.8823 best val_acc 9.882305
# epoch: 14, bulyan: at multi-krum n_at 10 e 14 | val loss 2.3300 val acc 9.8823 best val_acc 9.882305
# epoch: 15, bulyan: at multi-krum n_at 10 e 15 | val loss 2.3292 val acc 9.8823 best val_acc 9.882305
# epoch: 16, bulyan: at multi-krum n_at 10 e 16 | val loss 2.3118 val acc 9.8823 best val_acc 9.882305
# epoch: 17, bulyan: at multi-krum n_at 10 e 17 | val loss 2.3121 val acc 9.8823 best val_acc 9.882305
# epoch: 18, bulyan: at multi-krum n_at 10 e 18 | val loss 2.3151 val acc 9.8823 best val_acc 9.882305
# epoch: 19, bulyan: at multi-krum n_at 10 e 19 | val loss 2.3150 val acc 9.8823 best val_acc 9.882305
# epoch: 20, bulyan: at multi-krum n_at 10 e 20 | val loss 2.3077 val acc 9.8823 best val_acc 9.882305
# epoch: 21, bulyan: at multi-krum n_at 10 e 21 | val loss 2.3071 val acc 9.8823 best val_acc 9.882305
# epoch: 22, bulyan: at multi-krum n_at 10 e 22 | val loss 2.3098 val acc 9.8823 best val_acc 9.882305
# epoch: 23, bulyan: at multi-krum n_at 10 e 23 | val loss 2.3067 val acc 9.8823 best val_acc 9.882305
# epoch: 24, bulyan: at multi-krum n_at 10 e 24 | val loss 2.3010 val acc 9.8823 best val_acc 9.882305
# epoch: 25, bulyan: at multi-krum n_at 10 e 25 | val loss 2.2982 val acc 9.8823 best val_acc 9.882305
# epoch: 26, bulyan: at multi-krum n_at 10 e 26 | val loss 2.2951 val acc 10.0244 best val_acc 10.024351
# epoch: 27, bulyan: at multi-krum n_at 10 e 27 | val loss 2.2903 val acc 10.0041 best val_acc 10.024351
# epoch: 28, bulyan: at multi-krum n_at 10 e 28 | val loss 2.2879 val acc 10.9984 best val_acc 10.998377
# epoch: 29, bulyan: at multi-krum n_at 10 e 29 | val loss 2.2807 val acc 10.8563 best val_acc 10.998377
# epoch: 30, bulyan: at multi-krum n_at 10 e 30 | val loss 2.2841 val acc 11.9521 best val_acc 11.952110
# epoch: 31, bulyan: at multi-krum n_at 10 e 31 | val loss 2.2740 val acc 11.0390 best val_acc 11.952110
# epoch: 32, bulyan: at multi-krum n_at 10 e 32 | val loss 2.2749 val acc 11.9115 best val_acc 11.952110
# epoch: 33, bulyan: at multi-krum n_at 10 e 33 | val loss 2.2567 val acc 14.5698 best val_acc 14.569805
# epoch: 34, bulyan: at multi-krum n_at 10 e 34 | val loss 2.2540 val acc 16.4367 best val_acc 16.436688
# epoch: 35, bulyan: at multi-krum n_at 10 e 35 | val loss 2.2299 val acc 19.1558 best val_acc 19.155844
# epoch: 36, bulyan: at multi-krum n_at 10 e 36 | val loss 2.2384 val acc 18.9123 best val_acc 19.155844
# epoch: 37, bulyan: at multi-krum n_at 10 e 37 | val loss 2.2068 val acc 19.0341 best val_acc 19.155844
# epoch: 38, bulyan: at multi-krum n_at 10 e 38 | val loss 2.2652 val acc 14.9756 best val_acc 19.155844
# epoch: 39, bulyan: at multi-krum n_at 10 e 39 | val loss 2.2071 val acc 19.7443 best val_acc 19.744318
# epoch: 40, bulyan: at multi-krum n_at 10 e 40 | val loss 2.2382 val acc 13.8190 best val_acc 19.744318
# epoch: 41, bulyan: at multi-krum n_at 10 e 41 | val loss 2.3436 val acc 10.1867 best val_acc 19.744318
# epoch: 42, bulyan: at multi-krum n_at 10 e 42 | val loss 2.3133 val acc 10.9781 best val_acc 19.744318
# epoch: 43, bulyan: at multi-krum n_at 10 e 43 | val loss 2.3110 val acc 11.0593 best val_acc 19.744318
# epoch: 44, bulyan: at multi-krum n_at 10 e 44 | val loss 2.3070 val acc 11.1607 best val_acc 19.744318
# epoch: 45, bulyan: at multi-krum n_at 10 e 45 | val loss 2.3033 val acc 12.1550 best val_acc 19.744318
# epoch: 46, bulyan: at multi-krum n_at 10 e 46 | val loss 2.2997 val acc 13.3117 best val_acc 19.744318
# epoch: 47, bulyan: at multi-krum n_at 10 e 47 | val loss 2.2936 val acc 14.5089 best val_acc 19.744318
# epoch: 48, bulyan: at multi-krum n_at 10 e 48 | val loss 2.2889 val acc 15.4221 best val_acc 19.744318
# epoch: 49, bulyan: at multi-krum n_at 10 e 49 | val loss 2.2789 val acc 16.0308 best val_acc 19.744318
# epoch: 50, bulyan: at multi-krum n_at 10 e 50 | val loss 2.2720 val acc 16.3555 best val_acc 19.744318
# epoch: 51, bulyan: at multi-krum n_at 10 e 51 | val loss 2.2551 val acc 16.5990 best val_acc 19.744318
# epoch: 52, bulyan: at multi-krum n_at 10 e 52 | val loss 2.2471 val acc 16.4367 best val_acc 19.744318
# epoch: 53, bulyan: at multi-krum n_at 10 e 53 | val loss 2.2296 val acc 16.6599 best val_acc 19.744318
# epoch: 54, bulyan: at multi-krum n_at 10 e 54 | val loss 2.2301 val acc 16.9034 best val_acc 19.744318
# epoch: 55, bulyan: at multi-krum n_at 10 e 55 | val loss 2.2128 val acc 17.0049 best val_acc 19.744318
# epoch: 56, bulyan: at multi-krum n_at 10 e 56 | val loss 2.2144 val acc 16.5787 best val_acc 19.744318
# epoch: 57, bulyan: at multi-krum n_at 10 e 57 | val loss 2.1957 val acc 16.9034 best val_acc 19.744318
# epoch: 58, bulyan: at multi-krum n_at 10 e 58 | val loss 2.2024 val acc 16.8222 best val_acc 19.744318
# epoch: 59, bulyan: at multi-krum n_at 10 e 59 | val loss 2.1781 val acc 17.0252 best val_acc 19.744318
# epoch: 60, bulyan: at multi-krum n_at 10 e 60 | val loss 2.1823 val acc 16.8628 best val_acc 19.744318
# epoch: 61, bulyan: at multi-krum n_at 10 e 61 | val loss 2.1612 val acc 17.0657 best val_acc 19.744318
# epoch: 62, bulyan: at multi-krum n_at 10 e 62 | val loss 2.1672 val acc 16.9237 best val_acc 19.744318
# epoch: 63, bulyan: at multi-krum n_at 10 e 63 | val loss 2.1429 val acc 17.0049 best val_acc 19.744318
# epoch: 64, bulyan: at multi-krum n_at 10 e 64 | val loss 2.1719 val acc 14.0828 best val_acc 19.744318
# epoch: 65, bulyan: at multi-krum n_at 10 e 65 | val loss 2.1642 val acc 17.4107 best val_acc 19.744318
# epoch: 66, bulyan: at multi-krum n_at 10 e 66 | val loss 2.1546 val acc 19.1964 best val_acc 19.744318
# epoch: 67, bulyan: at multi-krum n_at 10 e 67 | val loss 2.1202 val acc 18.5877 best val_acc 19.744318
# epoch: 68, bulyan: at multi-krum n_at 10 e 68 | val loss 2.1937 val acc 16.0106 best val_acc 19.744318
# epoch: 69, bulyan: at multi-krum n_at 10 e 69 | val loss 2.1151 val acc 20.9416 best val_acc 20.941558
# epoch: 70, bulyan: at multi-krum n_at 10 e 70 | val loss 2.2239 val acc 14.0219 best val_acc 20.941558
# epoch: 71, bulyan: at multi-krum n_at 10 e 71 | val loss 2.3513 val acc 13.9610 best val_acc 20.941558
# epoch: 72, bulyan: at multi-krum n_at 10 e 72 | val loss 2.2701 val acc 15.3003 best val_acc 20.941558
# epoch: 73, bulyan: at multi-krum n_at 10 e 73 | val loss 2.2526 val acc 15.8685 best val_acc 20.941558
# epoch: 74, bulyan: at multi-krum n_at 10 e 74 | val loss 2.2585 val acc 15.2192 best val_acc 20.941558
# epoch: 75, bulyan: at multi-krum n_at 10 e 75 | val loss 2.2348 val acc 15.7062 best val_acc 20.941558
# epoch: 76, bulyan: at multi-krum n_at 10 e 76 | val loss 2.2493 val acc 14.8539 best val_acc 20.941558
# epoch: 77, bulyan: at multi-krum n_at 10 e 77 | val loss 2.2209 val acc 15.6250 best val_acc 20.941558
# epoch: 78, bulyan: at multi-krum n_at 10 e 78 | val loss 2.2425 val acc 14.8336 best val_acc 20.941558
# epoch: 79, bulyan: at multi-krum n_at 10 e 79 | val loss 2.2119 val acc 15.5844 best val_acc 20.941558
# epoch: 80, bulyan: at multi-krum n_at 10 e 80 | val loss 2.2383 val acc 14.0219 best val_acc 20.941558
# epoch: 81, bulyan: at multi-krum n_at 10 e 81 | val loss 2.2039 val acc 15.6453 best val_acc 20.941558
# epoch: 82, bulyan: at multi-krum n_at 10 e 82 | val loss 2.2088 val acc 15.5235 best val_acc 20.941558
# epoch: 83, bulyan: at multi-krum n_at 10 e 83 | val loss 2.1999 val acc 15.5438 best val_acc 20.941558
# epoch: 84, bulyan: at multi-krum n_at 10 e 84 | val loss 2.2529 val acc 12.3782 best val_acc 20.941558
# epoch: 85, bulyan: at multi-krum n_at 10 e 85 | val loss 2.1854 val acc 15.7873 best val_acc 20.941558
# epoch: 86, bulyan: at multi-krum n_at 10 e 86 | val loss 2.1524 val acc 15.5641 best val_acc 20.941558
# epoch: 87, bulyan: at multi-krum n_at 10 e 87 | val loss 2.1471 val acc 15.9091 best val_acc 20.941558
# epoch: 88, bulyan: at multi-krum n_at 10 e 88 | val loss 2.1540 val acc 18.5268 best val_acc 20.941558
# epoch: 89, bulyan: at multi-krum n_at 10 e 89 | val loss 2.1372 val acc 17.7963 best val_acc 20.941558
# epoch: 90, bulyan: at multi-krum n_at 10 e 90 | val loss 2.1390 val acc 15.6250 best val_acc 20.941558
# epoch: 91, bulyan: at multi-krum n_at 10 e 91 | val loss 2.1470 val acc 18.0398 best val_acc 20.941558
# epoch: 92, bulyan: at multi-krum n_at 10 e 92 | val loss 2.1355 val acc 15.8685 best val_acc 20.941558
# epoch: 93, bulyan: at multi-krum n_at 10 e 93 | val loss 2.1083 val acc 19.4602 best val_acc 20.941558
# epoch: 94, bulyan: at multi-krum n_at 10 e 94 | val loss 2.1526 val acc 18.2833 best val_acc 20.941558
# epoch: 95, bulyan: at multi-krum n_at 10 e 95 | val loss 2.2196 val acc 14.9554 best val_acc 20.941558
# epoch: 96, bulyan: at multi-krum n_at 10 e 96 | val loss 2.1543 val acc 17.9789 best val_acc 20.941558
# epoch: 97, bulyan: at multi-krum n_at 10 e 97 | val loss 2.1053 val acc 20.9213 best val_acc 20.941558
# epoch: 98, bulyan: at multi-krum n_at 10 e 98 | val loss 2.1861 val acc 16.0511 best val_acc 20.941558
# epoch: 99, bulyan: at multi-krum n_at 10 e 99 | val loss 2.1208 val acc 18.9732 best val_acc 20.941558
# epoch: 100, bulyan: at multi-krum n_at 10 e 100 | val loss 2.1676 val acc 16.5787 best val_acc 20.941558
# epoch: 101, bulyan: at multi-krum n_at 10 e 101 | val loss 2.1292 val acc 19.3385 best val_acc 20.941558
# epoch: 102, bulyan: at multi-krum n_at 10 e 102 | val loss 2.1226 val acc 15.1989 best val_acc 20.941558
# epoch: 103, bulyan: at multi-krum n_at 10 e 103 | val loss 2.0850 val acc 18.0804 best val_acc 20.941558
# epoch: 104, bulyan: at multi-krum n_at 10 e 104 | val loss 2.1311 val acc 17.8977 best val_acc 20.941558
# epoch: 105, bulyan: at multi-krum n_at 10 e 105 | val loss 2.0944 val acc 19.6834 best val_acc 20.941558
# epoch: 106, bulyan: at multi-krum n_at 10 e 106 | val loss 2.2328 val acc 14.1234 best val_acc 20.941558
# epoch: 107, bulyan: at multi-krum n_at 10 e 107 | val loss 2.1782 val acc 15.3206 best val_acc 20.941558
# epoch: 108, bulyan: at multi-krum n_at 10 e 108 | val loss 2.1401 val acc 16.8628 best val_acc 20.941558
# epoch: 109, bulyan: at multi-krum n_at 10 e 109 | val loss 2.0967 val acc 20.2922 best val_acc 20.941558
# epoch: 110, bulyan: at multi-krum n_at 10 e 110 | val loss 2.1832 val acc 15.6453 best val_acc 20.941558
# epoch: 111, bulyan: at multi-krum n_at 10 e 111 | val loss 2.0844 val acc 19.7240 best val_acc 20.941558
# epoch: 112, bulyan: at multi-krum n_at 10 e 112 | val loss 2.0766 val acc 19.4805 best val_acc 20.941558
# epoch: 113, bulyan: at multi-krum n_at 10 e 113 | val loss 2.0940 val acc 21.1648 best val_acc 21.164773
# epoch: 114, bulyan: at multi-krum n_at 10 e 114 | val loss 2.0830 val acc 17.8774 best val_acc 21.164773
# epoch: 115, bulyan: at multi-krum n_at 10 e 115 | val loss 2.1227 val acc 19.5617 best val_acc 21.164773
# epoch: 116, bulyan: at multi-krum n_at 10 e 116 | val loss 2.1432 val acc 17.4513 best val_acc 21.164773
# epoch: 117, bulyan: at multi-krum n_at 10 e 117 | val loss 2.0748 val acc 21.6315 best val_acc 21.631494
# epoch: 118, bulyan: at multi-krum n_at 10 e 118 | val loss 2.0614 val acc 21.4083 best val_acc 21.631494
# epoch: 119, bulyan: at multi-krum n_at 10 e 119 | val loss 2.0840 val acc 22.4432 best val_acc 22.443182
# epoch: 120, bulyan: at multi-krum n_at 10 e 120 | val loss 2.2431 val acc 12.3174 best val_acc 22.443182
# epoch: 121, bulyan: at multi-krum n_at 10 e 121 | val loss 2.1545 val acc 15.8076 best val_acc 22.443182
# epoch: 122, bulyan: at multi-krum n_at 10 e 122 | val loss 2.0883 val acc 20.9821 best val_acc 22.443182
# epoch: 123, bulyan: at multi-krum n_at 10 e 123 | val loss 2.0556 val acc 22.3417 best val_acc 22.443182
# epoch: 124, bulyan: at multi-krum n_at 10 e 124 | val loss 2.1424 val acc 17.8369 best val_acc 22.443182
# epoch: 125, bulyan: at multi-krum n_at 10 e 125 | val loss 2.0982 val acc 21.3068 best val_acc 22.443182
# epoch: 126, bulyan: at multi-krum n_at 10 e 126 | val loss 2.0387 val acc 21.7330 best val_acc 22.443182
# epoch: 127, bulyan: at multi-krum n_at 10 e 127 | val loss 2.0475 val acc 22.1997 best val_acc 22.443182
# epoch: 128, bulyan: at multi-krum n_at 10 e 128 | val loss 2.3144 val acc 15.7873 best val_acc 22.443182
# epoch: 129, bulyan: at multi-krum n_at 10 e 129 | val loss 2.2260 val acc 16.8222 best val_acc 22.443182
# epoch: 130, bulyan: at multi-krum n_at 10 e 130 | val loss 2.2923 val acc 12.6623 best val_acc 22.443182
# epoch: 131, bulyan: at multi-krum n_at 10 e 131 | val loss 2.2353 val acc 15.5032 best val_acc 22.443182
# epoch: 132, bulyan: at multi-krum n_at 10 e 132 | val loss 2.2324 val acc 14.3872 best val_acc 22.443182
# epoch: 133, bulyan: at multi-krum n_at 10 e 133 | val loss 2.1968 val acc 16.0308 best val_acc 22.443182
# epoch: 134, bulyan: at multi-krum n_at 10 e 134 | val loss 2.2849 val acc 11.3433 best val_acc 22.443182
# epoch: 135, bulyan: at multi-krum n_at 10 e 135 | val loss 2.1833 val acc 15.1989 best val_acc 22.443182
# epoch: 136, bulyan: at multi-krum n_at 10 e 136 | val loss 2.1653 val acc 16.0308 best val_acc 22.443182
# epoch: 137, bulyan: at multi-krum n_at 10 e 137 | val loss 2.1427 val acc 16.0106 best val_acc 22.443182
# epoch: 138, bulyan: at multi-krum n_at 10 e 138 | val loss 2.1695 val acc 15.2394 best val_acc 22.443182
# epoch: 139, bulyan: at multi-krum n_at 10 e 139 | val loss 2.1626 val acc 15.7670 best val_acc 22.443182
# epoch: 140, bulyan: at multi-krum n_at 10 e 140 | val loss 2.2725 val acc 13.9813 best val_acc 22.443182
# epoch: 141, bulyan: at multi-krum n_at 10 e 141 | val loss 2.0932 val acc 21.3271 best val_acc 22.443182
# epoch: 142, bulyan: at multi-krum n_at 10 e 142 | val loss 2.0785 val acc 18.3644 best val_acc 22.443182
# epoch: 143, bulyan: at multi-krum n_at 10 e 143 | val loss 2.0541 val acc 20.9416 best val_acc 22.443182
# epoch: 144, bulyan: at multi-krum n_at 10 e 144 | val loss 2.0759 val acc 22.2200 best val_acc 22.443182
# epoch: 145, bulyan: at multi-krum n_at 10 e 145 | val loss 2.0612 val acc 19.0950 best val_acc 22.443182
# epoch: 146, bulyan: at multi-krum n_at 10 e 146 | val loss 2.0633 val acc 19.6226 best val_acc 22.443182
# epoch: 147, bulyan: at multi-krum n_at 10 e 147 | val loss 2.0884 val acc 19.1153 best val_acc 22.443182
# epoch: 148, bulyan: at multi-krum n_at 10 e 148 | val loss 2.1763 val acc 18.1818 best val_acc 22.443182
# epoch: 149, bulyan: at multi-krum n_at 10 e 149 | val loss 2.2083 val acc 15.7265 best val_acc 22.443182
# epoch: 150, bulyan: at multi-krum n_at 10 e 150 | val loss 2.0535 val acc 20.4748 best val_acc 22.443182
# epoch: 151, bulyan: at multi-krum n_at 10 e 151 | val loss 2.0436 val acc 23.2549 best val_acc 23.254870
# epoch: 152, bulyan: at multi-krum n_at 10 e 152 | val loss 2.0116 val acc 23.9042 best val_acc 23.904221
# epoch: 153, bulyan: at multi-krum n_at 10 e 153 | val loss 2.0576 val acc 20.6169 best val_acc 23.904221
# epoch: 154, bulyan: at multi-krum n_at 10 e 154 | val loss 2.0047 val acc 22.7070 best val_acc 23.904221
# epoch: 155, bulyan: at multi-krum n_at 10 e 155 | val loss 2.0326 val acc 20.7589 best val_acc 23.904221
# epoch: 156, bulyan: at multi-krum n_at 10 e 156 | val loss 2.0040 val acc 23.3766 best val_acc 23.904221
# epoch: 157, bulyan: at multi-krum n_at 10 e 157 | val loss 2.0625 val acc 22.1185 best val_acc 23.904221
# epoch: 158, bulyan: at multi-krum n_at 10 e 158 | val loss 2.0803 val acc 19.6226 best val_acc 23.904221
# epoch: 159, bulyan: at multi-krum n_at 10 e 159 | val loss 2.1162 val acc 20.4545 best val_acc 23.904221
# epoch: 160, bulyan: at multi-krum n_at 10 e 160 | val loss 2.5370 val acc 13.3320 best val_acc 23.904221
# epoch: 161, bulyan: at multi-krum n_at 10 e 161 | val loss 2.2552 val acc 15.0568 best val_acc 23.904221
# epoch: 162, bulyan: at multi-krum n_at 10 e 162 | val loss 2.1692 val acc 18.3036 best val_acc 23.904221
# epoch: 163, bulyan: at multi-krum n_at 10 e 163 | val loss 2.0947 val acc 21.2256 best val_acc 23.904221
# epoch: 164, bulyan: at multi-krum n_at 10 e 164 | val loss 2.1508 val acc 18.5471 best val_acc 23.904221
# epoch: 165, bulyan: at multi-krum n_at 10 e 165 | val loss 2.0969 val acc 22.2606 best val_acc 23.904221
# epoch: 166, bulyan: at multi-krum n_at 10 e 166 | val loss 2.0756 val acc 21.0633 best val_acc 23.904221
# epoch: 167, bulyan: at multi-krum n_at 10 e 167 | val loss 2.1082 val acc 21.1039 best val_acc 23.904221
# epoch: 168, bulyan: at multi-krum n_at 10 e 168 | val loss 2.0362 val acc 22.3417 best val_acc 23.904221
# epoch: 169, bulyan: at multi-krum n_at 10 e 169 | val loss 2.1473 val acc 18.3644 best val_acc 23.904221
# epoch: 170, bulyan: at multi-krum n_at 10 e 170 | val loss 2.0438 val acc 20.6981 best val_acc 23.904221
# epoch: 171, bulyan: at multi-krum n_at 10 e 171 | val loss 2.0286 val acc 21.9359 best val_acc 23.904221
# epoch: 172, bulyan: at multi-krum n_at 10 e 172 | val loss 2.0413 val acc 22.2606 best val_acc 23.904221
# epoch: 173, bulyan: at multi-krum n_at 10 e 173 | val loss 2.0858 val acc 18.7906 best val_acc 23.904221
# epoch: 174, bulyan: at multi-krum n_at 10 e 174 | val loss 2.1066 val acc 22.6258 best val_acc 23.904221
# epoch: 175, bulyan: at multi-krum n_at 10 e 175 | val loss 2.3337 val acc 11.5057 best val_acc 23.904221
# epoch: 176, bulyan: at multi-krum n_at 10 e 176 | val loss 2.1455 val acc 16.2541 best val_acc 23.904221
# epoch: 177, bulyan: at multi-krum n_at 10 e 177 | val loss 2.0519 val acc 20.8198 best val_acc 23.904221
# epoch: 178, bulyan: at multi-krum n_at 10 e 178 | val loss 2.0218 val acc 23.9042 best val_acc 23.904221
# epoch: 179, bulyan: at multi-krum n_at 10 e 179 | val loss 2.0707 val acc 19.5414 best val_acc 23.904221
# epoch: 180, bulyan: at multi-krum n_at 10 e 180 | val loss 2.0947 val acc 23.1534 best val_acc 23.904221
# epoch: 181, bulyan: at multi-krum n_at 10 e 181 | val loss 2.4663 val acc 9.9635 best val_acc 23.904221
# epoch: 182, bulyan: at multi-krum n_at 10 e 182 | val loss 2.2988 val acc 13.2102 best val_acc 23.904221
# epoch: 183, bulyan: at multi-krum n_at 10 e 183 | val loss 2.1845 val acc 17.5731 best val_acc 23.904221
# epoch: 184, bulyan: at multi-krum n_at 10 e 184 | val loss 2.1012 val acc 19.7646 best val_acc 23.904221
# epoch: 185, bulyan: at multi-krum n_at 10 e 185 | val loss 2.0747 val acc 20.6372 best val_acc 23.904221
# epoch: 186, bulyan: at multi-krum n_at 10 e 186 | val loss 2.0506 val acc 21.3474 best val_acc 23.904221
# epoch: 187, bulyan: at multi-krum n_at 10 e 187 | val loss 2.0340 val acc 24.0463 best val_acc 24.046266
# epoch: 188, bulyan: at multi-krum n_at 10 e 188 | val loss 2.1244 val acc 19.4805 best val_acc 24.046266
# epoch: 189, bulyan: at multi-krum n_at 10 e 189 | val loss 2.0091 val acc 22.9505 best val_acc 24.046266
# epoch: 190, bulyan: at multi-krum n_at 10 e 190 | val loss 2.0435 val acc 23.1128 best val_acc 24.046266
# epoch: 191, bulyan: at multi-krum n_at 10 e 191 | val loss 2.0946 val acc 20.1705 best val_acc 24.046266
# epoch: 192, bulyan: at multi-krum n_at 10 e 192 | val loss 2.2026 val acc 18.1818 best val_acc 24.046266
# epoch: 193, bulyan: at multi-krum n_at 10 e 193 | val loss 2.0199 val acc 22.2403 best val_acc 24.046266
# epoch: 194, bulyan: at multi-krum n_at 10 e 194 | val loss 2.0050 val acc 21.1039 best val_acc 24.046266
# epoch: 195, bulyan: at multi-krum n_at 10 e 195 | val loss 2.0791 val acc 18.9123 best val_acc 24.046266
# epoch: 196, bulyan: at multi-krum n_at 10 e 196 | val loss 2.0139 val acc 24.6347 best val_acc 24.634740
# epoch: 197, bulyan: at multi-krum n_at 10 e 197 | val loss 2.3064 val acc 12.8450 best val_acc 24.634740
# epoch: 198, bulyan: at multi-krum n_at 10 e 198 | val loss 2.0950 val acc 19.6834 best val_acc 24.634740
# epoch: 199, bulyan: at multi-krum n_at 10 e 199 | val loss 2.0355 val acc 21.4894 best val_acc 24.634740
# epoch: 200, bulyan: at multi-krum n_at 10 e 200 | val loss 2.0703 val acc 20.0893 best val_acc 24.634740
# epoch: 201, bulyan: at multi-krum n_at 10 e 201 | val loss 1.9908 val acc 24.2492 best val_acc 24.634740
# epoch: 202, bulyan: at multi-krum n_at 10 e 202 | val loss 2.0271 val acc 22.0170 best val_acc 24.634740
# epoch: 203, bulyan: at multi-krum n_at 10 e 203 | val loss 2.0588 val acc 24.5942 best val_acc 24.634740
# epoch: 204, bulyan: at multi-krum n_at 10 e 204 | val loss 2.4277 val acc 11.0187 best val_acc 24.634740
# epoch: 205, bulyan: at multi-krum n_at 10 e 205 | val loss 2.3311 val acc 12.0536 best val_acc 24.634740
# epoch: 206, bulyan: at multi-krum n_at 10 e 206 | val loss 2.2499 val acc 14.0828 best val_acc 24.634740
# epoch: 207, bulyan: at multi-krum n_at 10 e 207 | val loss 2.1434 val acc 19.3791 best val_acc 24.634740
# epoch: 208, bulyan: at multi-krum n_at 10 e 208 | val loss 2.0328 val acc 23.1737 best val_acc 24.634740
# epoch: 209, bulyan: at multi-krum n_at 10 e 209 | val loss 1.9890 val acc 23.1534 best val_acc 24.634740
# epoch: 210, bulyan: at multi-krum n_at 10 e 210 | val loss 1.9626 val acc 24.5333 best val_acc 24.634740
# epoch: 211, bulyan: at multi-krum n_at 10 e 211 | val loss 1.9438 val acc 25.0609 best val_acc 25.060877
# epoch: 212, bulyan: at multi-krum n_at 10 e 212 | val loss 2.1673 val acc 22.1997 best val_acc 25.060877
# epoch: 213, bulyan: at multi-krum n_at 10 e 213 | val loss 2.6314 val acc 18.0398 best val_acc 25.060877
# epoch: 214, bulyan: at multi-krum n_at 10 e 214 | val loss 2.3297 val acc 12.1956 best val_acc 25.060877
# epoch: 215, bulyan: at multi-krum n_at 10 e 215 | val loss 2.2578 val acc 15.7670 best val_acc 25.060877
# epoch: 216, bulyan: at multi-krum n_at 10 e 216 | val loss 2.3495 val acc 9.7403 best val_acc 25.060877
# epoch: 217, bulyan: at multi-krum n_at 10 e 217 | val loss 2.2485 val acc 13.1088 best val_acc 25.060877
# epoch: 218, bulyan: at multi-krum n_at 10 e 218 | val loss 2.1396 val acc 16.7005 best val_acc 25.060877
# epoch: 219, bulyan: at multi-krum n_at 10 e 219 | val loss 2.0942 val acc 16.1932 best val_acc 25.060877
# epoch: 220, bulyan: at multi-krum n_at 10 e 220 | val loss 2.0792 val acc 19.1761 best val_acc 25.060877
# epoch: 221, bulyan: at multi-krum n_at 10 e 221 | val loss 2.0506 val acc 17.2687 best val_acc 25.060877
# epoch: 222, bulyan: at multi-krum n_at 10 e 222 | val loss 2.1952 val acc 13.9205 best val_acc 25.060877
# epoch: 223, bulyan: at multi-krum n_at 10 e 223 | val loss 2.0005 val acc 22.3214 best val_acc 25.060877
# epoch: 224, bulyan: at multi-krum n_at 10 e 224 | val loss 2.0124 val acc 22.1185 best val_acc 25.060877
# epoch: 225, bulyan: at multi-krum n_at 10 e 225 | val loss 2.0092 val acc 23.0317 best val_acc 25.060877
# epoch: 226, bulyan: at multi-krum n_at 10 e 226 | val loss 2.3241 val acc 10.7346 best val_acc 25.060877
# epoch: 227, bulyan: at multi-krum n_at 10 e 227 | val loss 2.1179 val acc 16.1120 best val_acc 25.060877
# epoch: 228, bulyan: at multi-krum n_at 10 e 228 | val loss 2.0586 val acc 19.8052 best val_acc 25.060877
# epoch: 229, bulyan: at multi-krum n_at 10 e 229 | val loss 2.0193 val acc 21.6518 best val_acc 25.060877
# epoch: 230, bulyan: at multi-krum n_at 10 e 230 | val loss 1.9866 val acc 23.0925 best val_acc 25.060877
# epoch: 231, bulyan: at multi-krum n_at 10 e 231 | val loss 2.0306 val acc 21.8344 best val_acc 25.060877
# epoch: 232, bulyan: at multi-krum n_at 10 e 232 | val loss 1.9793 val acc 21.7735 best val_acc 25.060877
# epoch: 233, bulyan: at multi-krum n_at 10 e 233 | val loss 2.0078 val acc 21.0836 best val_acc 25.060877
# epoch: 234, bulyan: at multi-krum n_at 10 e 234 | val loss 2.1335 val acc 16.6396 best val_acc 25.060877
# epoch: 235, bulyan: at multi-krum n_at 10 e 235 | val loss 2.0040 val acc 22.4432 best val_acc 25.060877
# epoch: 236, bulyan: at multi-krum n_at 10 e 236 | val loss 2.1144 val acc 16.4367 best val_acc 25.060877
# epoch: 237, bulyan: at multi-krum n_at 10 e 237 | val loss 2.0095 val acc 26.2175 best val_acc 26.217532
# epoch: 238, bulyan: at multi-krum n_at 10 e 238 | val loss 2.1647 val acc 12.9667 best val_acc 26.217532
# epoch: 239, bulyan: at multi-krum n_at 10 e 239 | val loss 1.9966 val acc 21.9359 best val_acc 26.217532
# epoch: 240, bulyan: at multi-krum n_at 10 e 240 | val loss 1.9617 val acc 24.3912 best val_acc 26.217532
# epoch: 241, bulyan: at multi-krum n_at 10 e 241 | val loss 2.0256 val acc 22.1388 best val_acc 26.217532
# epoch: 242, bulyan: at multi-krum n_at 10 e 242 | val loss 2.0044 val acc 21.4692 best val_acc 26.217532
# epoch: 243, bulyan: at multi-krum n_at 10 e 243 | val loss 2.1118 val acc 20.0893 best val_acc 26.217532
# epoch: 244, bulyan: at multi-krum n_at 10 e 244 | val loss 1.9693 val acc 23.6607 best val_acc 26.217532
# epoch: 245, bulyan: at multi-krum n_at 10 e 245 | val loss 1.9646 val acc 23.4375 best val_acc 26.217532
# epoch: 246, bulyan: at multi-krum n_at 10 e 246 | val loss 1.9926 val acc 21.3068 best val_acc 26.217532
# epoch: 247, bulyan: at multi-krum n_at 10 e 247 | val loss 2.0837 val acc 25.5885 best val_acc 26.217532
# epoch: 248, bulyan: at multi-krum n_at 10 e 248 | val loss 2.6247 val acc 10.2881 best val_acc 26.217532
# epoch: 249, bulyan: at multi-krum n_at 10 e 249 | val loss 2.3114 val acc 11.2013 best val_acc 26.217532
# epoch: 250, bulyan: at multi-krum n_at 10 e 250 | val loss 2.2013 val acc 16.2135 best val_acc 26.217532
# epoch: 251, bulyan: at multi-krum n_at 10 e 251 | val loss 2.1414 val acc 16.1526 best val_acc 26.217532
# epoch: 252, bulyan: at multi-krum n_at 10 e 252 | val loss 2.0582 val acc 19.1558 best val_acc 26.217532
# epoch: 253, bulyan: at multi-krum n_at 10 e 253 | val loss 2.1018 val acc 18.1006 best val_acc 26.217532
# epoch: 254, bulyan: at multi-krum n_at 10 e 254 | val loss 2.0006 val acc 20.3531 best val_acc 26.217532
# epoch: 255, bulyan: at multi-krum n_at 10 e 255 | val loss 2.0847 val acc 16.2744 best val_acc 26.217532
# epoch: 256, bulyan: at multi-krum n_at 10 e 256 | val loss 1.9910 val acc 19.3385 best val_acc 26.217532
# epoch: 257, bulyan: at multi-krum n_at 10 e 257 | val loss 2.0639 val acc 17.5122 best val_acc 26.217532
# epoch: 258, bulyan: at multi-krum n_at 10 e 258 | val loss 2.0299 val acc 18.2427 best val_acc 26.217532
# epoch: 259, bulyan: at multi-krum n_at 10 e 259 | val loss 2.0844 val acc 23.0519 best val_acc 26.217532
# epoch: 260, bulyan: at multi-krum n_at 10 e 260 | val loss 2.4158 val acc 9.7606 best val_acc 26.217532
# epoch: 261, bulyan: at multi-krum n_at 10 e 261 | val loss 2.2834 val acc 11.2622 best val_acc 26.217532
# epoch: 262, bulyan: at multi-krum n_at 10 e 262 | val loss 2.1283 val acc 15.6453 best val_acc 26.217532
# epoch: 263, bulyan: at multi-krum n_at 10 e 263 | val loss 2.0395 val acc 22.2403 best val_acc 26.217532
# epoch: 264, bulyan: at multi-krum n_at 10 e 264 | val loss 2.0093 val acc 21.1445 best val_acc 26.217532
# epoch: 265, bulyan: at multi-krum n_at 10 e 265 | val loss 2.1087 val acc 18.5065 best val_acc 26.217532
# epoch: 266, bulyan: at multi-krum n_at 10 e 266 | val loss 1.9636 val acc 22.4229 best val_acc 26.217532
# epoch: 267, bulyan: at multi-krum n_at 10 e 267 | val loss 2.0739 val acc 20.6169 best val_acc 26.217532
# epoch: 268, bulyan: at multi-krum n_at 10 e 268 | val loss 2.0122 val acc 22.8490 best val_acc 26.217532
# epoch: 269, bulyan: at multi-krum n_at 10 e 269 | val loss 2.2266 val acc 19.1558 best val_acc 26.217532
# epoch: 270, bulyan: at multi-krum n_at 10 e 270 | val loss 2.2526 val acc 14.5292 best val_acc 26.217532
# epoch: 271, bulyan: at multi-krum n_at 10 e 271 | val loss 1.9818 val acc 24.0869 best val_acc 26.217532
# epoch: 272, bulyan: at multi-krum n_at 10 e 272 | val loss 1.9930 val acc 22.5244 best val_acc 26.217532
# epoch: 273, bulyan: at multi-krum n_at 10 e 273 | val loss 1.9987 val acc 26.5828 best val_acc 26.582792
# epoch: 274, bulyan: at multi-krum n_at 10 e 274 | val loss 2.1744 val acc 16.1323 best val_acc 26.582792
# epoch: 275, bulyan: at multi-krum n_at 10 e 275 | val loss 1.9594 val acc 26.2784 best val_acc 26.582792
# epoch: 276, bulyan: at multi-krum n_at 10 e 276 | val loss 2.1072 val acc 20.1907 best val_acc 26.582792
# epoch: 277, bulyan: at multi-krum n_at 10 e 277 | val loss 2.0503 val acc 24.8580 best val_acc 26.582792
# epoch: 278, bulyan: at multi-krum n_at 10 e 278 | val loss 2.0504 val acc 20.2313 best val_acc 26.582792
# epoch: 279, bulyan: at multi-krum n_at 10 e 279 | val loss 1.9344 val acc 26.1769 best val_acc 26.582792
# epoch: 280, bulyan: at multi-krum n_at 10 e 280 | val loss 2.1981 val acc 20.7589 best val_acc 26.582792
# epoch: 281, bulyan: at multi-krum n_at 10 e 281 | val loss 2.3338 val acc 17.4716 best val_acc 26.582792
# epoch: 282, bulyan: at multi-krum n_at 10 e 282 | val loss 2.3182 val acc 15.0162 best val_acc 26.582792
# epoch: 283, bulyan: at multi-krum n_at 10 e 283 | val loss 2.1285 val acc 21.5097 best val_acc 26.582792
# epoch: 284, bulyan: at multi-krum n_at 10 e 284 | val loss 2.4082 val acc 13.5552 best val_acc 26.582792
# epoch: 285, bulyan: at multi-krum n_at 10 e 285 | val loss 2.2298 val acc 16.9237 best val_acc 26.582792
# epoch: 286, bulyan: at multi-krum n_at 10 e 286 | val loss 2.1209 val acc 20.0690 best val_acc 26.582792
# epoch: 287, bulyan: at multi-krum n_at 10 e 287 | val loss 2.0814 val acc 22.1185 best val_acc 26.582792
# epoch: 288, bulyan: at multi-krum n_at 10 e 288 | val loss 2.0221 val acc 24.7768 best val_acc 26.582792
# epoch: 289, bulyan: at multi-krum n_at 10 e 289 | val loss 1.9852 val acc 25.8523 best val_acc 26.582792
# epoch: 290, bulyan: at multi-krum n_at 10 e 290 | val loss 2.2092 val acc 20.0893 best val_acc 26.582792
# epoch: 291, bulyan: at multi-krum n_at 10 e 291 | val loss 2.0585 val acc 18.3847 best val_acc 26.582792
# epoch: 292, bulyan: at multi-krum n_at 10 e 292 | val loss 2.0006 val acc 19.9269 best val_acc 26.582792
# epoch: 293, bulyan: at multi-krum n_at 10 e 293 | val loss 2.0113 val acc 20.2719 best val_acc 26.582792
# epoch: 294, bulyan: at multi-krum n_at 10 e 294 | val loss 1.9907 val acc 21.7127 best val_acc 26.582792
# epoch: 295, bulyan: at multi-krum n_at 10 e 295 | val loss 2.0128 val acc 22.7476 best val_acc 26.582792
# epoch: 296, bulyan: at multi-krum n_at 10 e 296 | val loss 2.1946 val acc 19.0544 best val_acc 26.582792
# epoch: 297, bulyan: at multi-krum n_at 10 e 297 | val loss 2.2027 val acc 16.7614 best val_acc 26.582792
# epoch: 298, bulyan: at multi-krum n_at 10 e 298 | val loss 2.0400 val acc 22.9099 best val_acc 26.582792
# epoch: 299, bulyan: at multi-krum n_at 10 e 299 | val loss 1.9544 val acc 27.0089 best val_acc 27.008929
# epoch: 300, bulyan: at multi-krum n_at 10 e 300 | val loss 1.9737 val acc 24.5739 best val_acc 27.008929

# %%
import matplotlib.pyplot as plt

# Plotting the data
for col in ['loss', 'validation accuracy', 'best validation accuracy']:
    plt.plot(df['epoch'].tolist(), df[col].tolist())
    plt.title(f"{title} {col}")
    plt.show()
