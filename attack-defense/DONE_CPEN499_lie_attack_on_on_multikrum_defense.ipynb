# %% [markdown]
# # The notebook contains
# ### Code for _Bulyan_ aggregation algorithm, *when gradient updates of benign clients are unknown to adversary*
# ### Evaluation of all of the attacks (Fang, LIE, and our SOTA AGR-tailored and AGR-agnstic) on Bulyan

# %% [markdown]
# ## Import packages

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
from __future__ import print_function
import argparse, os, sys, csv, shutil, time, random, operator, pickle, ast, math
import numpy as np
import pandas as pd
from torch.optim import Optimizer
import torch.nn.functional as F
import torch
import pickle
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data as data
import torch.multiprocessing as mp
import math
sys.path.insert(0,'./../utils/')
from logger import *
from eval import *
from misc import *

from cifar10_normal_train import *
from cifar10_util import *
from adam import Adam
from sgd import SGD

# %% [markdown]
# ## Load Data
# Divide cifar10 data among 50 clients in Non-IID fashion using Dirichlet distribution

# %%
n_users = 50
user_tr_len = pickle.load(open('./data/user_tr_len.pkl','rb'))

user_train_data_tensors = pickle.load(open('./data/user_train_data_tensors.pkl','rb'))
user_train_label_tensors = pickle.load(open('./data/user_train_label_tensors.pkl','rb'))

val_data_tensor = pickle.load(open('./data/val_data_tensor.pkl','rb'))
val_label_tensor = pickle.load(open('./data/val_label_tensor.pkl','rb'))
te_data_tensor = pickle.load(open('./data/te_data_tensor.pkl','rb'))
te_label_tensor = pickle.load(open('./data/te_label_tensor.pkl','rb'))

# %% [markdown]
# ## Set nepochs

# %%
nepochs= 300

# %% [markdown]
# ## Code for Multi-krum aggregation algorithm

# %%
def multi_krum(all_updates, n_attackers, multi_k=False):

    candidates = []
    candidate_indices = []
    remaining_updates = all_updates
    all_indices = np.arange(len(all_updates))

    while len(remaining_updates) > 2 * n_attackers + 2:
        torch.cuda.empty_cache()
        distances = []
        for update in remaining_updates:
            distance = []
            for update_ in remaining_updates:
                distance.append(torch.norm((update - update_)) ** 2)
            distance = torch.Tensor(distance).float()
            distances = distance[None, :] if not len(distances) else torch.cat((distances, distance[None, :]), 0)

        distances = torch.sort(distances, dim=1)[0]
        scores = torch.sum(distances[:, :len(remaining_updates) - 2 - n_attackers], dim=1)
        indices = torch.argsort(scores)[:len(remaining_updates) - 2 - n_attackers]

        candidate_indices.append(all_indices[indices[0].cpu().numpy()])
        all_indices = np.delete(all_indices, indices[0].cpu().numpy())
        candidates = remaining_updates[indices[0]][None, :] if not len(candidates) else torch.cat((candidates, remaining_updates[indices[0]][None, :]), 0)
        remaining_updates = torch.cat((remaining_updates[:indices[0]], remaining_updates[indices[0] + 1:]), 0)
        if not multi_k:
            break
    # print(len(remaining_updates))

    aggregate = torch.mean(candidates, dim=0)

    return aggregate, np.array(candidate_indices)

# %% [markdown]
# ## LIE attack and multikrum defense

# %%
def lie_attack(all_updates, z):
    avg = torch.mean(all_updates, dim=0)
    std = torch.std(all_updates, dim=0)
    return avg + z * std

# %%
batch_size=250
resume=0

schedule=[1000]

gamma=.5
opt = 'sgd'
fed_lr=0.5
criterion=nn.CrossEntropyLoss()
use_cuda = torch.cuda.is_available()

at_type = 'multi-krum'

aggregation='bulyan'
multi_k = False
candidates = []

dev_type ='std'
n_attackers=[10]
z_values={3:0.69847, 5:0.7054, 8:0.71904, 10:0.72575, 12:0.73891}

arch='alexnet'
chkpt='./'+aggregation

past_mean = []
past_abs_sum = []
past_median = []
past_lower_quartile = []
past_upper_quartile = []
past_std = []

title = "LIE attack and multi-krum defense"

for n_attacker in n_attackers:
    epoch_num = 0
    best_global_acc = 0
    best_global_te_acc = 0

    torch.cuda.empty_cache()

    fed_model, _ = return_model(arch, 0.1, 0.9, parallel=False)
    optimizer_fed = SGD(fed_model.parameters(), lr=fed_lr)

    df = pd.DataFrame(columns = ['epoch', 'loss', 'validation accuracy', 'best validation accuracy'])

    ####
    history = torch.zeros((n_users, nepochs + 1), dtype=torch.float32).cuda()
    ####

    model_grads = []
    while epoch_num <= nepochs:
        user_grads=[]

        for i in range(n_users): # 50
            nbatches = user_tr_len[i]//batch_size

            inputs = user_train_data_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]
            targets = user_train_label_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]

            targets = targets.type(torch.LongTensor)

            inputs, targets = inputs.cuda(), targets.cuda()
            inputs, targets = torch.autograd.Variable(inputs), torch.autograd.Variable(targets)

            outputs = fed_model(inputs)
            loss = criterion(outputs, targets)
            fed_model.zero_grad()
            loss.backward(retain_graph=True)

            param_grad=[]
            for param in fed_model.parameters():
                param_grad=param.grad.data.view(-1) if not len(param_grad) else torch.cat((param_grad,param.grad.view(-1)))


            user_grads=param_grad[None, :] if len(user_grads)==0 else torch.cat((user_grads,param_grad[None,:]), 0)

        if epoch_num in schedule:
            for param_group in optimizer_fed.param_groups:
                param_group['lr'] *= gamma
                print('New learnin rate ', param_group['lr'])

        updates_abs_mean = user_grads.abs().mean(dim=1, keepdim=True)

        if n_attacker > 0:
            mal_update = lie_attack(user_grads, z_values[n_attacker])
            malicious_grads = torch.cat((torch.stack([mal_update]*n_attacker), user_grads[n_attacker:]))
        else:   # No attack
            malicious_grads = user_grads

        if not (malicious_grads.shape[0]==50):
            print(malicious_grads.shape)

        updates_abs_mean = malicious_grads.abs().mean(dim=1, keepdim=True)

        history[:, epoch_num] = updates_abs_mean.squeeze()
        agg_grads, _ = multi_krum(malicious_grads, n_attacker, multi_k=False)

        del user_grads

        start_idx=0

        optimizer_fed.zero_grad()

        model_grads=[]

        for i, param in enumerate(fed_model.parameters()):
            param_=agg_grads[start_idx:start_idx+len(param.data.view(-1))].reshape(param.data.shape)
            start_idx=start_idx+len(param.data.view(-1))
            param_=param_.cuda()
            model_grads.append(param_)

        optimizer_fed.step(model_grads)

        val_loss, val_acc = test(val_data_tensor,val_label_tensor,fed_model,criterion,use_cuda)
        te_loss, te_acc = test(te_data_tensor,te_label_tensor, fed_model, criterion, use_cuda)

        is_best = best_global_acc < val_acc

        best_global_acc = max(best_global_acc, val_acc)

        if is_best:
            best_global_te_acc = te_acc


        print('epoch: %d, %s: at %s n_at %d e %d | val loss %.4f val acc %.4f best val_acc %f'%(epoch_num, aggregation, at_type, n_attacker, epoch_num, val_loss, val_acc, best_global_acc))
        new_row = pd.DataFrame([{
            'epoch': epoch_num,
            'loss': val_loss,
            'validation accuracy': val_acc,
            'best validation accuracy': best_global_acc
            }])
        df = pd.concat([df, new_row], ignore_index=True)
        df.to_csv('lie_multi-krum.csv', index=False)

        if val_loss > 1000:
            print('val loss %f too high'%val_loss)
            break

        epoch_num+=1
# Out:
# c:\Users\Hizan\Desktop\CPEN497-FL\attack-defense\sgd.py:109: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\python_arg_parser.cpp:1630.)
#   p.data.add_(-group['lr'], d_p)
# C:\Users\Hizan\AppData\Local\Temp\ipykernel_12228\1966748630.py:132: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, new_row], ignore_index=True)
# epoch: 0, bulyan: at multi-krum n_at 10 e 0 | val loss 2.3029 val acc 10.1867 best val_acc 10.186688
# epoch: 1, bulyan: at multi-krum n_at 10 e 1 | val loss 2.3032 val acc 10.2070 best val_acc 10.206981
# epoch: 2, bulyan: at multi-krum n_at 10 e 2 | val loss 2.3039 val acc 13.6161 best val_acc 13.616071
# epoch: 3, bulyan: at multi-krum n_at 10 e 3 | val loss 2.3046 val acc 9.8823 best val_acc 13.616071
# epoch: 4, bulyan: at multi-krum n_at 10 e 4 | val loss 2.3060 val acc 9.8823 best val_acc 13.616071
# epoch: 5, bulyan: at multi-krum n_at 10 e 5 | val loss 2.3070 val acc 9.8823 best val_acc 13.616071
# epoch: 6, bulyan: at multi-krum n_at 10 e 6 | val loss 2.3090 val acc 9.8823 best val_acc 13.616071
# epoch: 7, bulyan: at multi-krum n_at 10 e 7 | val loss 2.3100 val acc 9.8823 best val_acc 13.616071
# epoch: 8, bulyan: at multi-krum n_at 10 e 8 | val loss 2.3126 val acc 9.8823 best val_acc 13.616071
# epoch: 9, bulyan: at multi-krum n_at 10 e 9 | val loss 2.3135 val acc 9.8823 best val_acc 13.616071
# epoch: 10, bulyan: at multi-krum n_at 10 e 10 | val loss 2.3167 val acc 9.8823 best val_acc 13.616071
# epoch: 11, bulyan: at multi-krum n_at 10 e 11 | val loss 2.3171 val acc 9.8823 best val_acc 13.616071
# epoch: 12, bulyan: at multi-krum n_at 10 e 12 | val loss 2.3112 val acc 9.8823 best val_acc 13.616071
# epoch: 13, bulyan: at multi-krum n_at 10 e 13 | val loss 2.3120 val acc 9.8823 best val_acc 13.616071
# epoch: 14, bulyan: at multi-krum n_at 10 e 14 | val loss 2.3146 val acc 9.8823 best val_acc 13.616071
# epoch: 15, bulyan: at multi-krum n_at 10 e 15 | val loss 2.3146 val acc 9.8823 best val_acc 13.616071
# epoch: 16, bulyan: at multi-krum n_at 10 e 16 | val loss 2.3095 val acc 9.8823 best val_acc 13.616071
# epoch: 17, bulyan: at multi-krum n_at 10 e 17 | val loss 2.3096 val acc 9.8823 best val_acc 13.616071
# epoch: 18, bulyan: at multi-krum n_at 10 e 18 | val loss 2.3070 val acc 9.8823 best val_acc 13.616071
# epoch: 19, bulyan: at multi-krum n_at 10 e 19 | val loss 2.3064 val acc 9.8823 best val_acc 13.616071
# epoch: 20, bulyan: at multi-krum n_at 10 e 20 | val loss 2.3043 val acc 9.8823 best val_acc 13.616071
# epoch: 21, bulyan: at multi-krum n_at 10 e 21 | val loss 2.3031 val acc 9.8823 best val_acc 13.616071
# epoch: 22, bulyan: at multi-krum n_at 10 e 22 | val loss 2.3016 val acc 9.8823 best val_acc 13.616071
# epoch: 23, bulyan: at multi-krum n_at 10 e 23 | val loss 2.2994 val acc 9.8823 best val_acc 13.616071
# epoch: 24, bulyan: at multi-krum n_at 10 e 24 | val loss 2.2981 val acc 9.8823 best val_acc 13.616071
# epoch: 25, bulyan: at multi-krum n_at 10 e 25 | val loss 2.2947 val acc 9.8823 best val_acc 13.616071
# epoch: 26, bulyan: at multi-krum n_at 10 e 26 | val loss 2.2938 val acc 10.0041 best val_acc 13.616071
# epoch: 27, bulyan: at multi-krum n_at 10 e 27 | val loss 2.2887 val acc 10.4302 best val_acc 13.616071
# epoch: 28, bulyan: at multi-krum n_at 10 e 28 | val loss 2.2875 val acc 13.5349 best val_acc 13.616071
# epoch: 29, bulyan: at multi-krum n_at 10 e 29 | val loss 2.2798 val acc 14.6307 best val_acc 14.630682
# epoch: 30, bulyan: at multi-krum n_at 10 e 30 | val loss 2.2784 val acc 16.3149 best val_acc 16.314935
# epoch: 31, bulyan: at multi-krum n_at 10 e 31 | val loss 2.2660 val acc 16.9034 best val_acc 16.903409
# epoch: 32, bulyan: at multi-krum n_at 10 e 32 | val loss 2.2638 val acc 17.1266 best val_acc 17.126623
# epoch: 33, bulyan: at multi-krum n_at 10 e 33 | val loss 2.2465 val acc 17.4310 best val_acc 17.431006
# epoch: 34, bulyan: at multi-krum n_at 10 e 34 | val loss 2.2462 val acc 16.7411 best val_acc 17.431006
# epoch: 35, bulyan: at multi-krum n_at 10 e 35 | val loss 2.2243 val acc 17.1266 best val_acc 17.431006
# epoch: 36, bulyan: at multi-krum n_at 10 e 36 | val loss 2.2266 val acc 16.5381 best val_acc 17.431006
# epoch: 37, bulyan: at multi-krum n_at 10 e 37 | val loss 2.2036 val acc 17.6136 best val_acc 17.613636
# epoch: 38, bulyan: at multi-krum n_at 10 e 38 | val loss 2.2117 val acc 16.5990 best val_acc 17.613636
# epoch: 39, bulyan: at multi-krum n_at 10 e 39 | val loss 2.1946 val acc 18.2833 best val_acc 18.283279
# epoch: 40, bulyan: at multi-krum n_at 10 e 40 | val loss 2.3001 val acc 14.8336 best val_acc 18.283279
# epoch: 41, bulyan: at multi-krum n_at 10 e 41 | val loss 2.3487 val acc 9.8620 best val_acc 18.283279
# epoch: 42, bulyan: at multi-krum n_at 10 e 42 | val loss 2.3177 val acc 9.8620 best val_acc 18.283279
# epoch: 43, bulyan: at multi-krum n_at 10 e 43 | val loss 2.3172 val acc 9.8620 best val_acc 18.283279
# epoch: 44, bulyan: at multi-krum n_at 10 e 44 | val loss 2.3144 val acc 9.8620 best val_acc 18.283279
# epoch: 45, bulyan: at multi-krum n_at 10 e 45 | val loss 2.3134 val acc 9.8620 best val_acc 18.283279
# epoch: 46, bulyan: at multi-krum n_at 10 e 46 | val loss 2.3115 val acc 9.8620 best val_acc 18.283279
# epoch: 47, bulyan: at multi-krum n_at 10 e 47 | val loss 2.3098 val acc 12.2159 best val_acc 18.283279
# epoch: 48, bulyan: at multi-krum n_at 10 e 48 | val loss 2.3080 val acc 10.8969 best val_acc 18.283279
# epoch: 49, bulyan: at multi-krum n_at 10 e 49 | val loss 2.3054 val acc 9.9026 best val_acc 18.283279
# epoch: 50, bulyan: at multi-krum n_at 10 e 50 | val loss 2.3038 val acc 10.0446 best val_acc 18.283279
# epoch: 51, bulyan: at multi-krum n_at 10 e 51 | val loss 2.3001 val acc 10.3490 best val_acc 18.283279
# epoch: 52, bulyan: at multi-krum n_at 10 e 52 | val loss 2.2986 val acc 12.0130 best val_acc 18.283279
# epoch: 53, bulyan: at multi-krum n_at 10 e 53 | val loss 2.2937 val acc 13.2914 best val_acc 18.283279
# epoch: 54, bulyan: at multi-krum n_at 10 e 54 | val loss 2.2914 val acc 15.1380 best val_acc 18.283279
# epoch: 55, bulyan: at multi-krum n_at 10 e 55 | val loss 2.2849 val acc 15.8076 best val_acc 18.283279
# epoch: 56, bulyan: at multi-krum n_at 10 e 56 | val loss 2.2832 val acc 16.5179 best val_acc 18.283279
# epoch: 57, bulyan: at multi-krum n_at 10 e 57 | val loss 2.2725 val acc 17.0049 best val_acc 18.283279
# epoch: 58, bulyan: at multi-krum n_at 10 e 58 | val loss 2.2699 val acc 16.9643 best val_acc 18.283279
# epoch: 59, bulyan: at multi-krum n_at 10 e 59 | val loss 2.2540 val acc 17.0252 best val_acc 18.283279
# epoch: 60, bulyan: at multi-krum n_at 10 e 60 | val loss 2.2506 val acc 16.7817 best val_acc 18.283279
# epoch: 61, bulyan: at multi-krum n_at 10 e 61 | val loss 2.2310 val acc 17.2484 best val_acc 18.283279
# epoch: 62, bulyan: at multi-krum n_at 10 e 62 | val loss 2.2355 val acc 16.7005 best val_acc 18.283279
# epoch: 63, bulyan: at multi-krum n_at 10 e 63 | val loss 2.2186 val acc 17.1875 best val_acc 18.283279
# epoch: 64, bulyan: at multi-krum n_at 10 e 64 | val loss 2.2305 val acc 17.0860 best val_acc 18.283279
# epoch: 65, bulyan: at multi-krum n_at 10 e 65 | val loss 2.2103 val acc 16.9237 best val_acc 18.283279
# epoch: 66, bulyan: at multi-krum n_at 10 e 66 | val loss 2.2229 val acc 17.1672 best val_acc 18.283279
# epoch: 67, bulyan: at multi-krum n_at 10 e 67 | val loss 2.2034 val acc 16.9440 best val_acc 18.283279
# epoch: 68, bulyan: at multi-krum n_at 10 e 68 | val loss 2.2217 val acc 17.0049 best val_acc 18.283279
# epoch: 69, bulyan: at multi-krum n_at 10 e 69 | val loss 2.1964 val acc 17.3701 best val_acc 18.283279
# epoch: 70, bulyan: at multi-krum n_at 10 e 70 | val loss 2.2117 val acc 17.3498 best val_acc 18.283279
# epoch: 71, bulyan: at multi-krum n_at 10 e 71 | val loss 2.1903 val acc 17.2078 best val_acc 18.283279
# epoch: 72, bulyan: at multi-krum n_at 10 e 72 | val loss 2.2103 val acc 17.2281 best val_acc 18.283279
# epoch: 73, bulyan: at multi-krum n_at 10 e 73 | val loss 2.1847 val acc 17.3498 best val_acc 18.283279
# epoch: 74, bulyan: at multi-krum n_at 10 e 74 | val loss 2.2044 val acc 17.5325 best val_acc 18.283279
# epoch: 75, bulyan: at multi-krum n_at 10 e 75 | val loss 2.1795 val acc 17.2890 best val_acc 18.283279
# epoch: 76, bulyan: at multi-krum n_at 10 e 76 | val loss 2.2012 val acc 17.4107 best val_acc 18.283279
# epoch: 77, bulyan: at multi-krum n_at 10 e 77 | val loss 2.1739 val acc 17.3701 best val_acc 18.283279
# epoch: 78, bulyan: at multi-krum n_at 10 e 78 | val loss 2.1985 val acc 17.5933 best val_acc 18.283279
# epoch: 79, bulyan: at multi-krum n_at 10 e 79 | val loss 2.1710 val acc 17.4310 best val_acc 18.283279
# epoch: 80, bulyan: at multi-krum n_at 10 e 80 | val loss 2.1925 val acc 17.3904 best val_acc 18.283279
# epoch: 81, bulyan: at multi-krum n_at 10 e 81 | val loss 2.1650 val acc 17.3093 best val_acc 18.283279
# epoch: 82, bulyan: at multi-krum n_at 10 e 82 | val loss 2.1925 val acc 17.4310 best val_acc 18.283279
# epoch: 83, bulyan: at multi-krum n_at 10 e 83 | val loss 2.1624 val acc 17.5933 best val_acc 18.283279
# epoch: 84, bulyan: at multi-krum n_at 10 e 84 | val loss 2.1887 val acc 16.9643 best val_acc 18.283279
# epoch: 85, bulyan: at multi-krum n_at 10 e 85 | val loss 2.1583 val acc 17.3093 best val_acc 18.283279
# epoch: 86, bulyan: at multi-krum n_at 10 e 86 | val loss 2.1974 val acc 16.4367 best val_acc 18.283279
# epoch: 87, bulyan: at multi-krum n_at 10 e 87 | val loss 2.1586 val acc 17.6136 best val_acc 18.283279
# epoch: 88, bulyan: at multi-krum n_at 10 e 88 | val loss 2.1822 val acc 15.1177 best val_acc 18.283279
# epoch: 89, bulyan: at multi-krum n_at 10 e 89 | val loss 2.1593 val acc 17.2281 best val_acc 18.283279
# epoch: 90, bulyan: at multi-krum n_at 10 e 90 | val loss 2.2428 val acc 14.0828 best val_acc 18.283279
# epoch: 91, bulyan: at multi-krum n_at 10 e 91 | val loss 2.1998 val acc 15.5438 best val_acc 18.283279
# epoch: 92, bulyan: at multi-krum n_at 10 e 92 | val loss 2.1763 val acc 16.1932 best val_acc 18.283279
# epoch: 93, bulyan: at multi-krum n_at 10 e 93 | val loss 2.1492 val acc 18.1615 best val_acc 18.283279
# epoch: 94, bulyan: at multi-krum n_at 10 e 94 | val loss 2.1790 val acc 17.3904 best val_acc 18.283279
# epoch: 95, bulyan: at multi-krum n_at 10 e 95 | val loss 2.1528 val acc 17.5122 best val_acc 18.283279
# epoch: 96, bulyan: at multi-krum n_at 10 e 96 | val loss 2.1926 val acc 13.9002 best val_acc 18.283279
# epoch: 97, bulyan: at multi-krum n_at 10 e 97 | val loss 2.1564 val acc 19.1761 best val_acc 19.176136
# epoch: 98, bulyan: at multi-krum n_at 10 e 98 | val loss 2.1652 val acc 17.4513 best val_acc 19.176136
# epoch: 99, bulyan: at multi-krum n_at 10 e 99 | val loss 2.1347 val acc 19.8052 best val_acc 19.805195
# epoch: 100, bulyan: at multi-krum n_at 10 e 100 | val loss 2.2439 val acc 14.7930 best val_acc 19.805195
# epoch: 101, bulyan: at multi-krum n_at 10 e 101 | val loss 2.1999 val acc 16.7817 best val_acc 19.805195
# epoch: 102, bulyan: at multi-krum n_at 10 e 102 | val loss 2.2105 val acc 16.1729 best val_acc 19.805195
# epoch: 103, bulyan: at multi-krum n_at 10 e 103 | val loss 2.1635 val acc 17.8166 best val_acc 19.805195
# epoch: 104, bulyan: at multi-krum n_at 10 e 104 | val loss 2.1758 val acc 17.9180 best val_acc 19.805195
# epoch: 105, bulyan: at multi-krum n_at 10 e 105 | val loss 2.1421 val acc 18.8109 best val_acc 19.805195
# epoch: 106, bulyan: at multi-krum n_at 10 e 106 | val loss 2.1869 val acc 17.8571 best val_acc 19.805195
# epoch: 107, bulyan: at multi-krum n_at 10 e 107 | val loss 2.1368 val acc 18.1006 best val_acc 19.805195
# epoch: 108, bulyan: at multi-krum n_at 10 e 108 | val loss 2.1591 val acc 17.1469 best val_acc 19.805195
# epoch: 109, bulyan: at multi-krum n_at 10 e 109 | val loss 2.1329 val acc 20.2516 best val_acc 20.251623
# epoch: 110, bulyan: at multi-krum n_at 10 e 110 | val loss 2.1784 val acc 17.0252 best val_acc 20.251623
# epoch: 111, bulyan: at multi-krum n_at 10 e 111 | val loss 2.1457 val acc 17.9383 best val_acc 20.251623
# epoch: 112, bulyan: at multi-krum n_at 10 e 112 | val loss 2.1914 val acc 15.3612 best val_acc 20.251623
# epoch: 113, bulyan: at multi-krum n_at 10 e 113 | val loss 2.1549 val acc 18.2224 best val_acc 20.251623
# epoch: 114, bulyan: at multi-krum n_at 10 e 114 | val loss 2.1641 val acc 16.2946 best val_acc 20.251623
# epoch: 115, bulyan: at multi-krum n_at 10 e 115 | val loss 2.1071 val acc 20.0081 best val_acc 20.251623
# epoch: 116, bulyan: at multi-krum n_at 10 e 116 | val loss 2.1614 val acc 15.8482 best val_acc 20.251623
# epoch: 117, bulyan: at multi-krum n_at 10 e 117 | val loss 2.1058 val acc 19.7646 best val_acc 20.251623
# epoch: 118, bulyan: at multi-krum n_at 10 e 118 | val loss 2.1775 val acc 15.3409 best val_acc 20.251623
# epoch: 119, bulyan: at multi-krum n_at 10 e 119 | val loss 2.1189 val acc 19.1356 best val_acc 20.251623
# epoch: 120, bulyan: at multi-krum n_at 10 e 120 | val loss 2.1697 val acc 17.4716 best val_acc 20.251623
# epoch: 121, bulyan: at multi-krum n_at 10 e 121 | val loss 2.1036 val acc 18.7906 best val_acc 20.251623
# epoch: 122, bulyan: at multi-krum n_at 10 e 122 | val loss 2.1572 val acc 17.4919 best val_acc 20.251623
# epoch: 123, bulyan: at multi-krum n_at 10 e 123 | val loss 2.1441 val acc 18.1412 best val_acc 20.251623
# epoch: 124, bulyan: at multi-krum n_at 10 e 124 | val loss 2.1380 val acc 16.9034 best val_acc 20.251623
# epoch: 125, bulyan: at multi-krum n_at 10 e 125 | val loss 2.1129 val acc 18.8718 best val_acc 20.251623
# epoch: 126, bulyan: at multi-krum n_at 10 e 126 | val loss 2.1914 val acc 13.4537 best val_acc 20.251623
# epoch: 127, bulyan: at multi-krum n_at 10 e 127 | val loss 2.1088 val acc 19.0138 best val_acc 20.251623
# epoch: 128, bulyan: at multi-krum n_at 10 e 128 | val loss 2.1159 val acc 18.6891 best val_acc 20.251623
# epoch: 129, bulyan: at multi-krum n_at 10 e 129 | val loss 2.1353 val acc 18.4456 best val_acc 20.251623
# epoch: 130, bulyan: at multi-krum n_at 10 e 130 | val loss 2.2487 val acc 13.5552 best val_acc 20.251623
# epoch: 131, bulyan: at multi-krum n_at 10 e 131 | val loss 2.1733 val acc 16.0308 best val_acc 20.251623
# epoch: 132, bulyan: at multi-krum n_at 10 e 132 | val loss 2.1322 val acc 17.3904 best val_acc 20.251623
# epoch: 133, bulyan: at multi-krum n_at 10 e 133 | val loss 2.1277 val acc 18.5877 best val_acc 20.251623
# epoch: 134, bulyan: at multi-krum n_at 10 e 134 | val loss 2.1300 val acc 18.0804 best val_acc 20.251623
# epoch: 135, bulyan: at multi-krum n_at 10 e 135 | val loss 2.1471 val acc 19.2776 best val_acc 20.251623
# epoch: 136, bulyan: at multi-krum n_at 10 e 136 | val loss 2.2189 val acc 13.2305 best val_acc 20.251623
# epoch: 137, bulyan: at multi-krum n_at 10 e 137 | val loss 2.1360 val acc 18.7094 best val_acc 20.251623
# epoch: 138, bulyan: at multi-krum n_at 10 e 138 | val loss 2.2537 val acc 15.7062 best val_acc 20.251623
# epoch: 139, bulyan: at multi-krum n_at 10 e 139 | val loss 2.1720 val acc 16.3352 best val_acc 20.251623
# epoch: 140, bulyan: at multi-krum n_at 10 e 140 | val loss 2.1309 val acc 15.5032 best val_acc 20.251623
# epoch: 141, bulyan: at multi-krum n_at 10 e 141 | val loss 2.0869 val acc 19.2167 best val_acc 20.251623
# epoch: 142, bulyan: at multi-krum n_at 10 e 142 | val loss 2.1691 val acc 13.5146 best val_acc 20.251623
# epoch: 143, bulyan: at multi-krum n_at 10 e 143 | val loss 2.0971 val acc 18.9529 best val_acc 20.251623
# epoch: 144, bulyan: at multi-krum n_at 10 e 144 | val loss 2.1703 val acc 15.6859 best val_acc 20.251623
# epoch: 145, bulyan: at multi-krum n_at 10 e 145 | val loss 2.0832 val acc 18.3036 best val_acc 20.251623
# epoch: 146, bulyan: at multi-krum n_at 10 e 146 | val loss 2.0645 val acc 20.8401 best val_acc 20.840097
# epoch: 147, bulyan: at multi-krum n_at 10 e 147 | val loss 2.1113 val acc 20.6372 best val_acc 20.840097
# epoch: 148, bulyan: at multi-krum n_at 10 e 148 | val loss 2.1666 val acc 17.6542 best val_acc 20.840097
# epoch: 149, bulyan: at multi-krum n_at 10 e 149 | val loss 2.1763 val acc 16.8222 best val_acc 20.840097
# epoch: 150, bulyan: at multi-krum n_at 10 e 150 | val loss 2.1555 val acc 15.6250 best val_acc 20.840097
# epoch: 151, bulyan: at multi-krum n_at 10 e 151 | val loss 2.1226 val acc 19.2573 best val_acc 20.840097
# epoch: 152, bulyan: at multi-krum n_at 10 e 152 | val loss 2.0833 val acc 18.8109 best val_acc 20.840097
# epoch: 153, bulyan: at multi-krum n_at 10 e 153 | val loss 2.1125 val acc 20.4343 best val_acc 20.840097
# epoch: 154, bulyan: at multi-krum n_at 10 e 154 | val loss 2.2604 val acc 14.5089 best val_acc 20.840097
# epoch: 155, bulyan: at multi-krum n_at 10 e 155 | val loss 2.1379 val acc 16.7614 best val_acc 20.840097
# epoch: 156, bulyan: at multi-krum n_at 10 e 156 | val loss 2.0635 val acc 18.6282 best val_acc 20.840097
# epoch: 157, bulyan: at multi-krum n_at 10 e 157 | val loss 2.1010 val acc 19.1558 best val_acc 20.840097
# epoch: 158, bulyan: at multi-krum n_at 10 e 158 | val loss 2.0696 val acc 21.0633 best val_acc 21.063312
# epoch: 159, bulyan: at multi-krum n_at 10 e 159 | val loss 2.1797 val acc 21.0836 best val_acc 21.083604
# epoch: 160, bulyan: at multi-krum n_at 10 e 160 | val loss 2.2758 val acc 13.4943 best val_acc 21.083604
# epoch: 161, bulyan: at multi-krum n_at 10 e 161 | val loss 2.2656 val acc 14.9148 best val_acc 21.083604
# epoch: 162, bulyan: at multi-krum n_at 10 e 162 | val loss 2.2158 val acc 16.7614 best val_acc 21.083604
# epoch: 163, bulyan: at multi-krum n_at 10 e 163 | val loss 2.2142 val acc 17.7760 best val_acc 21.083604
# epoch: 164, bulyan: at multi-krum n_at 10 e 164 | val loss 2.1931 val acc 18.3442 best val_acc 21.083604
# epoch: 165, bulyan: at multi-krum n_at 10 e 165 | val loss 2.1829 val acc 18.7906 best val_acc 21.083604
# epoch: 166, bulyan: at multi-krum n_at 10 e 166 | val loss 2.2399 val acc 14.8742 best val_acc 21.083604
# epoch: 167, bulyan: at multi-krum n_at 10 e 167 | val loss 2.1970 val acc 17.2484 best val_acc 21.083604
# epoch: 168, bulyan: at multi-krum n_at 10 e 168 | val loss 2.1396 val acc 19.3588 best val_acc 21.083604
# epoch: 169, bulyan: at multi-krum n_at 10 e 169 | val loss 2.1299 val acc 18.9326 best val_acc 21.083604
# epoch: 170, bulyan: at multi-krum n_at 10 e 170 | val loss 2.1272 val acc 18.9123 best val_acc 21.083604
# epoch: 171, bulyan: at multi-krum n_at 10 e 171 | val loss 2.1071 val acc 19.3994 best val_acc 21.083604
# epoch: 172, bulyan: at multi-krum n_at 10 e 172 | val loss 2.2095 val acc 15.8279 best val_acc 21.083604
# epoch: 173, bulyan: at multi-krum n_at 10 e 173 | val loss 2.1329 val acc 18.4253 best val_acc 21.083604
# epoch: 174, bulyan: at multi-krum n_at 10 e 174 | val loss 2.0448 val acc 22.4635 best val_acc 22.463474
# epoch: 175, bulyan: at multi-krum n_at 10 e 175 | val loss 2.0569 val acc 21.0430 best val_acc 22.463474
# epoch: 176, bulyan: at multi-krum n_at 10 e 176 | val loss 2.2037 val acc 16.7614 best val_acc 22.463474
# epoch: 177, bulyan: at multi-krum n_at 10 e 177 | val loss 2.1226 val acc 19.0544 best val_acc 22.463474
# epoch: 178, bulyan: at multi-krum n_at 10 e 178 | val loss 2.1181 val acc 18.6282 best val_acc 22.463474
# epoch: 179, bulyan: at multi-krum n_at 10 e 179 | val loss 2.0755 val acc 18.9732 best val_acc 22.463474
# epoch: 180, bulyan: at multi-krum n_at 10 e 180 | val loss 2.1559 val acc 17.5731 best val_acc 22.463474
# epoch: 181, bulyan: at multi-krum n_at 10 e 181 | val loss 2.0443 val acc 19.9269 best val_acc 22.463474
# epoch: 182, bulyan: at multi-krum n_at 10 e 182 | val loss 2.1073 val acc 20.9213 best val_acc 22.463474
# epoch: 183, bulyan: at multi-krum n_at 10 e 183 | val loss 2.0503 val acc 20.3734 best val_acc 22.463474
# epoch: 184, bulyan: at multi-krum n_at 10 e 184 | val loss 2.0824 val acc 19.4602 best val_acc 22.463474
# epoch: 185, bulyan: at multi-krum n_at 10 e 185 | val loss 2.0353 val acc 24.2492 best val_acc 24.249188
# epoch: 186, bulyan: at multi-krum n_at 10 e 186 | val loss 2.3606 val acc 14.6104 best val_acc 24.249188
# epoch: 187, bulyan: at multi-krum n_at 10 e 187 | val loss 2.1599 val acc 15.3409 best val_acc 24.249188
# epoch: 188, bulyan: at multi-krum n_at 10 e 188 | val loss 2.0798 val acc 18.7297 best val_acc 24.249188
# epoch: 189, bulyan: at multi-krum n_at 10 e 189 | val loss 2.0996 val acc 18.9123 best val_acc 24.249188
# epoch: 190, bulyan: at multi-krum n_at 10 e 190 | val loss 2.1141 val acc 16.5584 best val_acc 24.249188
# epoch: 191, bulyan: at multi-krum n_at 10 e 191 | val loss 2.1556 val acc 15.7265 best val_acc 24.249188
# epoch: 192, bulyan: at multi-krum n_at 10 e 192 | val loss 2.0654 val acc 19.0747 best val_acc 24.249188
# epoch: 193, bulyan: at multi-krum n_at 10 e 193 | val loss 2.1078 val acc 17.8166 best val_acc 24.249188
# epoch: 194, bulyan: at multi-krum n_at 10 e 194 | val loss 2.0429 val acc 20.5560 best val_acc 24.249188
# epoch: 195, bulyan: at multi-krum n_at 10 e 195 | val loss 2.1092 val acc 19.5820 best val_acc 24.249188
# epoch: 196, bulyan: at multi-krum n_at 10 e 196 | val loss 2.0588 val acc 19.1964 best val_acc 24.249188
# epoch: 197, bulyan: at multi-krum n_at 10 e 197 | val loss 2.1971 val acc 18.7297 best val_acc 24.249188
# epoch: 198, bulyan: at multi-krum n_at 10 e 198 | val loss 2.0967 val acc 20.0081 best val_acc 24.249188
# epoch: 199, bulyan: at multi-krum n_at 10 e 199 | val loss 2.0395 val acc 21.0836 best val_acc 24.249188
# epoch: 200, bulyan: at multi-krum n_at 10 e 200 | val loss 2.1364 val acc 18.4456 best val_acc 24.249188
# epoch: 201, bulyan: at multi-krum n_at 10 e 201 | val loss 2.0242 val acc 22.8693 best val_acc 24.249188
# epoch: 202, bulyan: at multi-krum n_at 10 e 202 | val loss 2.0227 val acc 22.5852 best val_acc 24.249188
# epoch: 203, bulyan: at multi-krum n_at 10 e 203 | val loss 2.0251 val acc 22.8287 best val_acc 24.249188
# epoch: 204, bulyan: at multi-krum n_at 10 e 204 | val loss 2.0102 val acc 22.7273 best val_acc 24.249188
# epoch: 205, bulyan: at multi-krum n_at 10 e 205 | val loss 2.0852 val acc 19.7240 best val_acc 24.249188
# epoch: 206, bulyan: at multi-krum n_at 10 e 206 | val loss 2.1106 val acc 19.2573 best val_acc 24.249188
# epoch: 207, bulyan: at multi-krum n_at 10 e 207 | val loss 2.2335 val acc 14.7321 best val_acc 24.249188
# epoch: 208, bulyan: at multi-krum n_at 10 e 208 | val loss 2.0719 val acc 19.3588 best val_acc 24.249188
# epoch: 209, bulyan: at multi-krum n_at 10 e 209 | val loss 2.0271 val acc 21.0836 best val_acc 24.249188
# epoch: 210, bulyan: at multi-krum n_at 10 e 210 | val loss 2.0446 val acc 22.6461 best val_acc 24.249188
# epoch: 211, bulyan: at multi-krum n_at 10 e 211 | val loss 2.0052 val acc 23.5795 best val_acc 24.249188
# epoch: 212, bulyan: at multi-krum n_at 10 e 212 | val loss 2.1512 val acc 20.2922 best val_acc 24.249188
# epoch: 213, bulyan: at multi-krum n_at 10 e 213 | val loss 2.0000 val acc 23.2752 best val_acc 24.249188
# epoch: 214, bulyan: at multi-krum n_at 10 e 214 | val loss 1.9919 val acc 25.4464 best val_acc 25.446429
# epoch: 215, bulyan: at multi-krum n_at 10 e 215 | val loss 2.1327 val acc 17.2078 best val_acc 25.446429
# epoch: 216, bulyan: at multi-krum n_at 10 e 216 | val loss 2.0106 val acc 22.9708 best val_acc 25.446429
# epoch: 217, bulyan: at multi-krum n_at 10 e 217 | val loss 2.1084 val acc 20.9416 best val_acc 25.446429
# epoch: 218, bulyan: at multi-krum n_at 10 e 218 | val loss 2.0314 val acc 21.0227 best val_acc 25.446429
# epoch: 219, bulyan: at multi-krum n_at 10 e 219 | val loss 2.0447 val acc 21.4692 best val_acc 25.446429
# epoch: 220, bulyan: at multi-krum n_at 10 e 220 | val loss 2.0077 val acc 21.9765 best val_acc 25.446429
# epoch: 221, bulyan: at multi-krum n_at 10 e 221 | val loss 2.1059 val acc 20.6169 best val_acc 25.446429
# epoch: 222, bulyan: at multi-krum n_at 10 e 222 | val loss 2.0037 val acc 22.5041 best val_acc 25.446429
# epoch: 223, bulyan: at multi-krum n_at 10 e 223 | val loss 2.0156 val acc 21.4286 best val_acc 25.446429
# epoch: 224, bulyan: at multi-krum n_at 10 e 224 | val loss 2.0002 val acc 25.5682 best val_acc 25.568182
# epoch: 225, bulyan: at multi-krum n_at 10 e 225 | val loss 2.2335 val acc 19.0950 best val_acc 25.568182
# epoch: 226, bulyan: at multi-krum n_at 10 e 226 | val loss 2.0750 val acc 25.0406 best val_acc 25.568182
# epoch: 227, bulyan: at multi-krum n_at 10 e 227 | val loss 2.0586 val acc 22.7070 best val_acc 25.568182
# epoch: 228, bulyan: at multi-krum n_at 10 e 228 | val loss 1.9731 val acc 25.2638 best val_acc 25.568182
# epoch: 229, bulyan: at multi-krum n_at 10 e 229 | val loss 2.1273 val acc 20.1299 best val_acc 25.568182
# epoch: 230, bulyan: at multi-krum n_at 10 e 230 | val loss 1.9904 val acc 23.9448 best val_acc 25.568182
# epoch: 231, bulyan: at multi-krum n_at 10 e 231 | val loss 2.0458 val acc 22.5244 best val_acc 25.568182
# epoch: 232, bulyan: at multi-krum n_at 10 e 232 | val loss 1.9602 val acc 27.1510 best val_acc 27.150974
# epoch: 233, bulyan: at multi-krum n_at 10 e 233 | val loss 2.1450 val acc 17.4919 best val_acc 27.150974
# epoch: 234, bulyan: at multi-krum n_at 10 e 234 | val loss 2.0018 val acc 24.8782 best val_acc 27.150974
# epoch: 235, bulyan: at multi-krum n_at 10 e 235 | val loss 2.1944 val acc 20.9010 best val_acc 27.150974
# epoch: 236, bulyan: at multi-krum n_at 10 e 236 | val loss 2.1579 val acc 19.2167 best val_acc 27.150974
# epoch: 237, bulyan: at multi-krum n_at 10 e 237 | val loss 2.0039 val acc 24.1477 best val_acc 27.150974
# epoch: 238, bulyan: at multi-krum n_at 10 e 238 | val loss 2.0259 val acc 22.8287 best val_acc 27.150974
# epoch: 239, bulyan: at multi-krum n_at 10 e 239 | val loss 1.9901 val acc 24.2492 best val_acc 27.150974
# epoch: 240, bulyan: at multi-krum n_at 10 e 240 | val loss 1.9458 val acc 26.9075 best val_acc 27.150974
# epoch: 241, bulyan: at multi-krum n_at 10 e 241 | val loss 2.0995 val acc 24.6956 best val_acc 27.150974
# epoch: 242, bulyan: at multi-krum n_at 10 e 242 | val loss 2.3218 val acc 16.0714 best val_acc 27.150974
# epoch: 243, bulyan: at multi-krum n_at 10 e 243 | val loss 2.2170 val acc 17.1469 best val_acc 27.150974
# epoch: 244, bulyan: at multi-krum n_at 10 e 244 | val loss 2.2743 val acc 12.6218 best val_acc 27.150974
# epoch: 245, bulyan: at multi-krum n_at 10 e 245 | val loss 2.0854 val acc 20.8401 best val_acc 27.150974
# epoch: 246, bulyan: at multi-krum n_at 10 e 246 | val loss 2.1619 val acc 16.9643 best val_acc 27.150974
# epoch: 247, bulyan: at multi-krum n_at 10 e 247 | val loss 2.0606 val acc 19.0747 best val_acc 27.150974
# epoch: 248, bulyan: at multi-krum n_at 10 e 248 | val loss 2.0725 val acc 19.9067 best val_acc 27.150974
# epoch: 249, bulyan: at multi-krum n_at 10 e 249 | val loss 2.0225 val acc 22.9911 best val_acc 27.150974
# epoch: 250, bulyan: at multi-krum n_at 10 e 250 | val loss 2.1570 val acc 19.0747 best val_acc 27.150974
# epoch: 251, bulyan: at multi-krum n_at 10 e 251 | val loss 2.0085 val acc 23.5795 best val_acc 27.150974
# epoch: 252, bulyan: at multi-krum n_at 10 e 252 | val loss 1.9809 val acc 26.3799 best val_acc 27.150974
# epoch: 253, bulyan: at multi-krum n_at 10 e 253 | val loss 2.1031 val acc 24.1071 best val_acc 27.150974
# epoch: 254, bulyan: at multi-krum n_at 10 e 254 | val loss 2.0114 val acc 26.6640 best val_acc 27.150974
# epoch: 255, bulyan: at multi-krum n_at 10 e 255 | val loss 2.0697 val acc 18.1412 best val_acc 27.150974
# epoch: 256, bulyan: at multi-krum n_at 10 e 256 | val loss 1.9742 val acc 26.3393 best val_acc 27.150974
# epoch: 257, bulyan: at multi-krum n_at 10 e 257 | val loss 2.4940 val acc 12.1347 best val_acc 27.150974
# epoch: 258, bulyan: at multi-krum n_at 10 e 258 | val loss 2.2727 val acc 16.2744 best val_acc 27.150974
# epoch: 259, bulyan: at multi-krum n_at 10 e 259 | val loss 2.1546 val acc 19.6226 best val_acc 27.150974
# epoch: 260, bulyan: at multi-krum n_at 10 e 260 | val loss 2.0390 val acc 22.5244 best val_acc 27.150974
# epoch: 261, bulyan: at multi-krum n_at 10 e 261 | val loss 2.0426 val acc 21.6721 best val_acc 27.150974
# epoch: 262, bulyan: at multi-krum n_at 10 e 262 | val loss 2.0498 val acc 21.0227 best val_acc 27.150974
# epoch: 263, bulyan: at multi-krum n_at 10 e 263 | val loss 2.0278 val acc 23.0925 best val_acc 27.150974
# epoch: 264, bulyan: at multi-krum n_at 10 e 264 | val loss 1.9774 val acc 25.7102 best val_acc 27.150974
# epoch: 265, bulyan: at multi-krum n_at 10 e 265 | val loss 2.2061 val acc 18.8515 best val_acc 27.150974
# epoch: 266, bulyan: at multi-krum n_at 10 e 266 | val loss 2.0363 val acc 23.7825 best val_acc 27.150974
# epoch: 267, bulyan: at multi-krum n_at 10 e 267 | val loss 1.9763 val acc 24.6347 best val_acc 27.150974
# epoch: 268, bulyan: at multi-krum n_at 10 e 268 | val loss 2.0456 val acc 24.0260 best val_acc 27.150974
# epoch: 269, bulyan: at multi-krum n_at 10 e 269 | val loss 1.9479 val acc 27.9627 best val_acc 27.962662
# epoch: 270, bulyan: at multi-krum n_at 10 e 270 | val loss 1.9843 val acc 26.1161 best val_acc 27.962662
# epoch: 271, bulyan: at multi-krum n_at 10 e 271 | val loss 1.9408 val acc 28.0032 best val_acc 28.003247
# epoch: 272, bulyan: at multi-krum n_at 10 e 272 | val loss 1.9218 val acc 28.5917 best val_acc 28.591721
# epoch: 273, bulyan: at multi-krum n_at 10 e 273 | val loss 2.0239 val acc 22.4432 best val_acc 28.591721
# epoch: 274, bulyan: at multi-krum n_at 10 e 274 | val loss 2.1339 val acc 27.5365 best val_acc 28.591721
# epoch: 275, bulyan: at multi-krum n_at 10 e 275 | val loss 2.3164 val acc 16.3758 best val_acc 28.591721
# epoch: 276, bulyan: at multi-krum n_at 10 e 276 | val loss 2.2960 val acc 15.7062 best val_acc 28.591721
# epoch: 277, bulyan: at multi-krum n_at 10 e 277 | val loss 2.1851 val acc 19.9878 best val_acc 28.591721
# epoch: 278, bulyan: at multi-krum n_at 10 e 278 | val loss 2.1436 val acc 21.5909 best val_acc 28.591721
# epoch: 279, bulyan: at multi-krum n_at 10 e 279 | val loss 2.0993 val acc 22.5041 best val_acc 28.591721
# epoch: 280, bulyan: at multi-krum n_at 10 e 280 | val loss 2.0666 val acc 22.3823 best val_acc 28.591721
# epoch: 281, bulyan: at multi-krum n_at 10 e 281 | val loss 2.0462 val acc 18.2630 best val_acc 28.591721
# epoch: 282, bulyan: at multi-krum n_at 10 e 282 | val loss 2.0302 val acc 21.9765 best val_acc 28.591721
# epoch: 283, bulyan: at multi-krum n_at 10 e 283 | val loss 1.9909 val acc 24.6550 best val_acc 28.591721
# epoch: 284, bulyan: at multi-krum n_at 10 e 284 | val loss 2.0620 val acc 21.2459 best val_acc 28.591721
# epoch: 285, bulyan: at multi-krum n_at 10 e 285 | val loss 2.0167 val acc 22.1185 best val_acc 28.591721
# epoch: 286, bulyan: at multi-krum n_at 10 e 286 | val loss 2.3030 val acc 13.1494 best val_acc 28.591721
# epoch: 287, bulyan: at multi-krum n_at 10 e 287 | val loss 2.1585 val acc 18.8515 best val_acc 28.591721
# epoch: 288, bulyan: at multi-krum n_at 10 e 288 | val loss 2.0442 val acc 21.8141 best val_acc 28.591721
# epoch: 289, bulyan: at multi-krum n_at 10 e 289 | val loss 2.0159 val acc 21.0227 best val_acc 28.591721
# epoch: 290, bulyan: at multi-krum n_at 10 e 290 | val loss 2.0370 val acc 21.4083 best val_acc 28.591721
# epoch: 291, bulyan: at multi-krum n_at 10 e 291 | val loss 1.9892 val acc 23.9448 best val_acc 28.591721
# epoch: 292, bulyan: at multi-krum n_at 10 e 292 | val loss 1.9854 val acc 23.7216 best val_acc 28.591721
# epoch: 293, bulyan: at multi-krum n_at 10 e 293 | val loss 1.9875 val acc 24.1274 best val_acc 28.591721
# epoch: 294, bulyan: at multi-krum n_at 10 e 294 | val loss 2.0360 val acc 21.6721 best val_acc 28.591721
# epoch: 295, bulyan: at multi-krum n_at 10 e 295 | val loss 2.1112 val acc 25.1623 best val_acc 28.591721
# epoch: 296, bulyan: at multi-krum n_at 10 e 296 | val loss 2.3267 val acc 15.5235 best val_acc 28.591721
# epoch: 297, bulyan: at multi-krum n_at 10 e 297 | val loss 2.2125 val acc 18.4456 best val_acc 28.591721
# epoch: 298, bulyan: at multi-krum n_at 10 e 298 | val loss 2.2378 val acc 17.1266 best val_acc 28.591721
# epoch: 299, bulyan: at multi-krum n_at 10 e 299 | val loss 2.1761 val acc 19.5820 best val_acc 28.591721
# epoch: 300, bulyan: at multi-krum n_at 10 e 300 | val loss 2.1535 val acc 19.3791 best val_acc 28.591721

# %%
import matplotlib.pyplot as plt

# Plotting the data
for col in ['loss', 'validation accuracy', 'best validation accuracy']:
    plt.plot(df['epoch'].tolist(), df[col].tolist())
    plt.title(f"{title} {col}")
    plt.show()
