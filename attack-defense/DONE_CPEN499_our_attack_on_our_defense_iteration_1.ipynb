# %% [markdown]
# # The notebook contains
# ### Code for Our attack and our aggregation algorithm
# ### Evaluation of our defense with different parameters in our attack

# %% [markdown]
# ## Import packages

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
from __future__ import print_function
import argparse, os, sys, csv, shutil, time, random, operator, pickle, ast, math
import numpy as np
import pandas as pd
from torch.optim import Optimizer
import torch.nn.functional as F
import torch
import pickle
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data as data
import torch.multiprocessing as mp
import math
sys.path.insert(0,'./../utils/')
from logger import *
from eval import *
from misc import *

from cifar10_normal_train import *
from cifar10_util import *
from adam import Adam
from sgd import SGD

# %% [markdown]
# ### Load Data
# Divide cifar10 data among 50 clients in Non-IID fashion using Dirichlet distribution

# %%
n_users = 50
user_tr_len = pickle.load(open('./data/user_tr_len.pkl','rb'))

user_train_data_tensors = pickle.load(open('./data/user_train_data_tensors.pkl','rb'))
user_train_label_tensors = pickle.load(open('./data/user_train_label_tensors.pkl','rb'))

val_data_tensor = pickle.load(open('./data/val_data_tensor.pkl','rb'))
val_label_tensor = pickle.load(open('./data/val_label_tensor.pkl','rb'))
te_data_tensor = pickle.load(open('./data/te_data_tensor.pkl','rb'))
te_label_tensor = pickle.load(open('./data/te_label_tensor.pkl','rb'))

# %% [markdown]
# ### Our Aggregation Function

# %%
def our_mean_defense(all_updates, n_attackers, history_updates):
    discarded_history = get_discarded_index(n_attackers, history_updates)

    mask = torch.ones(all_updates.size(0), dtype=torch.bool)
    mask[discarded_history] = False
    remaining_updates = all_updates[mask]

    print('discarded index', discarded_history)

    return torch.nanmean(remaining_updates, dim=0)

####
def euclidean_distance(row1, row2):
    return torch.sqrt(torch.sum((row1 - row2) ** 2))
####

def get_discarded_index(n_attackers, history_updates):
    n_users = history_updates.shape[0]

    ####
    distance_matrix = [[0 if i == j else euclidean_distance(history_updates[i, :], history_updates[j, :]) for j in range(n_users)] for i in range(n_users)]
    ####

    sum_of_distances = [sum(row) for row in distance_matrix]

    discarded_history = []
    for _ in range(n_attackers):
        max_distance = max(sum_of_distances)
        index_of_max_distance = sum_of_distances.index(max_distance)
        discarded_history.append(index_of_max_distance)

        for i in range(n_users):
            sum_of_distances[i] -= distance_matrix[i][index_of_max_distance]
        sum_of_distances[index_of_max_distance] = -1

    return discarded_history

# %% [markdown]
# ### Set nepochs

# %%
nepochs= 300

# %% [markdown]
# # our_attack & our defense

# %% [markdown]
# ## iteration 1
#
# 10 bisection; 1 iterations; 12 discarded

# %% [markdown]
# ### our_attack_mean
# $ argmin_\theta(\ -L(\theta_{attacker(s)}) + \lambda_1 |\bar{\theta_{abs\ mean\ benige\ users}} - \bar{\theta_{abs\ attacker(s)}}|$

# %%
device = 'cuda:0'
def check_condition(lambda1, prev_grad, loss_grad, history, all_updates, n_users, n_attacker, epoch_num):
    loss_grad = loss_grad.to(device)
    prev_grad = prev_grad.to(device)
    new_grad = lambda1 * (loss_grad + prev_grad)

    ####
    mal_updates = torch.stack([new_grad.clone().detach() for _ in range(n_attacker)])
    malicious_grads = torch.cat((mal_updates, all_updates[n_attacker:]), 0)

    history_updates = history.clone().detach()
    history_updates[:, epoch_num] = malicious_grads.abs().mean(dim=1, keepdim=True).squeeze()
    ####

    discarded_history = get_discarded_index(n_attacker+2, history_updates)

    detected_mal = len([item for item in discarded_history if item < 10])
    return detected_mal / len(discarded_history) <= n_attacker / n_users

def find_upper_bound(lambda1, prev_grad, loss_grad, history, all_updates, n_users, n_attacker, epoch_num):
    while check_condition(lambda1, prev_grad, loss_grad, history, all_updates, n_users, n_attacker, epoch_num):
        lambda1 *= 2  # Exponentially increase lambda
    return lambda1


def projection(prev_grad, loss_grad, history, all_updates, n_users, n_attacker, epoch_num):
    updates_abs_mean = all_updates.abs().mean(dim=1, keepdim=True)
    median_value = torch.median(updates_abs_mean).item()

    ####
    history_updates = history.clone().detach()
    history_updates[:, epoch_num] = updates_abs_mean.mean(dim=1, keepdim=True).squeeze()
    ####

    loss_grad = loss_grad.to(device)
    prev_grad = prev_grad.to(device)

    lambda_low = median_value/(prev_grad + loss_grad).abs().mean().item()
    lambda_high = find_upper_bound(lambda_low, prev_grad, loss_grad, history_updates, all_updates, n_users, n_attacker, epoch_num)
    if lambda_high < lambda_low:
        lambda_high = lambda_low
        print("SHOULD NEVER REACH THIS LINE")
        print('lambda_low: ', lambda_low, ' lambda_high: ', lambda_high)
    tolerance = 1e-6

    iterations_count = 0
    while lambda_high - lambda_low > tolerance and iterations_count < 10:
        lambda_mid = (lambda_low + lambda_high) / 2
        if check_condition(lambda_mid, prev_grad, loss_grad, history_updates, all_updates, n_users, n_attacker, epoch_num):
            lambda_low = lambda_mid
        else:
            lambda_high = lambda_mid
        iterations_count += 1

    lambda1 = lambda_low

    return lambda1 * (prev_grad + loss_grad)

def our_attack_mean(n_user, epoch_num, history_updates, all_updates, model_params, n_attacker, arch, criterion, user_train_data_tensors, user_train_label_tensors):
    attacker_tr_data_tensor = user_train_data_tensors[0].cuda()
    attacker_tr_label_tensor = user_train_label_tensors[0].cuda()

    fed_model, _ = return_model(arch, 0.1, 0.9, parallel=False)
    fed_model.eval()  # Ensure the model is in evaluation mode

    new_grad = -all_updates[0].clone().detach().requires_grad_(True)
    prev_grad = np.zeros(len(new_grad))
    new_grad = projection(torch.from_numpy(prev_grad), new_grad, history_updates, all_updates, n_user, n_attacker, epoch_num)

    for _ in range(1):
        outputs = fed_model(attacker_tr_data_tensor)
        loss = criterion(outputs, attacker_tr_label_tensor)

        loss.backward(retain_graph=True)
        param_grad = []
        for param in fed_model.parameters():
            param_grad.append(param.grad.view(-1).detach())

        param_grad = torch.cat(param_grad)
        prev_grad = new_grad
        new_grad = projection(prev_grad, param_grad, history_updates, all_updates, n_user, n_attacker, epoch_num)

        difference = torch.mean(torch.abs(new_grad - prev_grad)).item()
        if difference < 1e-6:
            # print("STOPPED! Difference is too small, stop finding best attack grad")
            break

        fed_model.zero_grad()

    result_attacker_grads = [new_grad.clone().detach() for _ in range(10)]
    return torch.stack(result_attacker_grads).cuda()

# %% [markdown]
# ### our attack (10 attacker) + our defense

# %%
batch_size=250
resume=0

schedule=[1000]

gamma=.5
opt = 'sgd'
fed_lr=0.5
criterion=nn.CrossEntropyLoss()
use_cuda = torch.cuda.is_available()

aggregation='bulyan'
multi_k = False
candidates = []

at_type='our-agr'
dev_type ='std'
n_attackers=[10]

arch='alexnet'
chkpt='./'+aggregation

past_mean = []
past_abs_sum = []
past_median = []
past_lower_quartile = []
past_upper_quartile = []
past_std = []

title = "our attack (10 attacker) + our defense"

for n_attacker in n_attackers:
    epoch_num = 0
    best_global_acc = 0
    best_global_te_acc = 0

    torch.cuda.empty_cache()

    fed_model, _ = return_model(arch, 0.1, 0.9, parallel=False)
    optimizer_fed = SGD(fed_model.parameters(), lr=fed_lr)

    df = pd.DataFrame(columns = ['epoch', 'loss', 'validation accuracy', 'best validation accuracy'])

    ####
    history = torch.zeros((n_users, nepochs + 1), dtype=torch.float32).cuda()
    ####

    model_grads = []
    flag = False
    while epoch_num <= nepochs:
        user_grads=[]

        for i in range(n_users): # 50
            nbatches = user_tr_len[i]//batch_size

            inputs = user_train_data_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]
            targets = user_train_label_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]

            targets = targets.type(torch.LongTensor)

            inputs, targets = inputs.cuda(), targets.cuda()
            inputs, targets = torch.autograd.Variable(inputs), torch.autograd.Variable(targets)

            outputs = fed_model(inputs)
            loss = criterion(outputs, targets)
            fed_model.zero_grad()
            loss.backward(retain_graph=True)

            param_grad=[]
            for param in fed_model.parameters():
                param_grad=param.grad.data.view(-1) if not len(param_grad) else torch.cat((param_grad,param.grad.view(-1)))


            user_grads=param_grad[None, :] if len(user_grads)==0 else torch.cat((user_grads,param_grad[None,:]), 0)

        if epoch_num in schedule:
            for param_group in optimizer_fed.param_groups:
                param_group['lr'] *= gamma
                print('New learnin rate ', param_group['lr'])

        updates_abs_mean = user_grads.abs().mean(dim=1, keepdim=True)

        if n_attacker > 0:
            model_params = torch.cat([p.data.view(-1) for p in fed_model.parameters()])
            mal_updates = our_attack_mean(n_users, epoch_num, history, user_grads, model_params, n_attacker, arch, criterion, user_train_data_tensors, user_train_label_tensors)
            malicious_grads = torch.cat((mal_updates, user_grads[n_attacker:]), 0) # torch.Size([50, 2472266])


        if not (malicious_grads.shape[0]==50):
            print(malicious_grads.shape)

        updates_abs_mean = malicious_grads.abs().mean(dim=1, keepdim=True)

        history[:, epoch_num] = updates_abs_mean.squeeze()
        agg_grads = our_mean_defense(malicious_grads, n_attacker, history)

        del user_grads

        start_idx=0

        optimizer_fed.zero_grad()

        model_grads=[]

        for i, param in enumerate(fed_model.parameters()):
            param_=agg_grads[start_idx:start_idx+len(param.data.view(-1))].reshape(param.data.shape)
            start_idx=start_idx+len(param.data.view(-1))
            param_=param_.cuda()
            model_grads.append(param_)

        optimizer_fed.step(model_grads)

        val_loss, val_acc = test(val_data_tensor,val_label_tensor,fed_model,criterion, use_cuda)
        te_loss, te_acc = test(te_data_tensor,te_label_tensor, fed_model, criterion, use_cuda)

        is_best = best_global_acc < val_acc

        best_global_acc = max(best_global_acc, val_acc)

        if is_best:
            best_global_te_acc = te_acc


        print('epoch: %d, %s: at %s n_at %d e %d | val loss %.4f val acc %.4f best val_acc %f'%(epoch_num, aggregation, at_type, n_attacker, epoch_num, val_loss, val_acc, best_global_acc))
        new_row = pd.DataFrame([{
            'epoch': epoch_num,
            'loss': val_loss,
            'validation accuracy': val_acc,
            'best validation accuracy': best_global_acc
            }])
        df = pd.concat([df, new_row], ignore_index=True)
        df.to_csv('iteration_1.csv', index=False)

        if val_loss > 1000:
            print('val loss %f too high'%val_loss)
            break

        epoch_num+=1
# Out:
# discarded index [34, 20, 37, 47, 49, 25, 24, 33, 11, 43]
# c:\Users\Hizan\Desktop\CPEN497-FL\attack-defense\sgd.py:109: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\python_arg_parser.cpp:1630.)
#   p.data.add_(-group['lr'], d_p)
# epoch: 0, bulyan: at our-agr n_at 10 e 0 | val loss 2.3029 val acc 10.0244 best val_acc 10.024351
# C:\Users\Hizan\AppData\Local\Temp\ipykernel_20584\2005063417.py:131: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, new_row], ignore_index=True)
# discarded index [34, 20, 47, 37, 25, 43, 49, 24, 11, 33]
# epoch: 1, bulyan: at our-agr n_at 10 e 1 | val loss 2.3029 val acc 10.0244 best val_acc 10.024351
# discarded index [34, 20, 37, 47, 25, 32, 49, 43, 24, 11]
# epoch: 2, bulyan: at our-agr n_at 10 e 2 | val loss 2.3030 val acc 10.0244 best val_acc 10.024351
# discarded index [34, 20, 47, 37, 25, 43, 49, 32, 24, 11]
# epoch: 3, bulyan: at our-agr n_at 10 e 3 | val loss 2.3033 val acc 10.0244 best val_acc 10.024351
# discarded index [34, 20, 47, 37, 49, 25, 43, 32, 24, 33]
# epoch: 4, bulyan: at our-agr n_at 10 e 4 | val loss 2.3037 val acc 10.0244 best val_acc 10.024351
# discarded index [34, 20, 47, 43, 37, 25, 49, 32, 24, 33]
# epoch: 5, bulyan: at our-agr n_at 10 e 5 | val loss 2.3043 val acc 10.0244 best val_acc 10.024351
# discarded index [34, 20, 47, 43, 37, 49, 25, 32, 24, 33]
# epoch: 6, bulyan: at our-agr n_at 10 e 6 | val loss 2.3052 val acc 10.0244 best val_acc 10.024351
# discarded index [20, 34, 47, 43, 37, 49, 25, 32, 33, 24]
# epoch: 7, bulyan: at our-agr n_at 10 e 7 | val loss 2.3063 val acc 10.0244 best val_acc 10.024351
# discarded index [20, 47, 34, 43, 45, 49, 32, 25, 37, 33]
# epoch: 8, bulyan: at our-agr n_at 10 e 8 | val loss 2.3088 val acc 10.0244 best val_acc 10.024351
# discarded index [20, 47, 34, 45, 43, 22, 49, 18, 31, 0]
# epoch: 9, bulyan: at our-agr n_at 10 e 9 | val loss 2.3092 val acc 10.0244 best val_acc 10.024351
# discarded index [20, 47, 34, 45, 49, 43, 32, 22, 33, 18]
# epoch: 10, bulyan: at our-agr n_at 10 e 10 | val loss 2.3149 val acc 10.0244 best val_acc 10.024351
# discarded index [47, 20, 34, 45, 43, 49, 32, 11, 33, 44]
# epoch: 11, bulyan: at our-agr n_at 10 e 11 | val loss 2.3208 val acc 10.0244 best val_acc 10.024351
# discarded index [20, 47, 45, 34, 22, 31, 43, 49, 32, 11]
# epoch: 12, bulyan: at our-agr n_at 10 e 12 | val loss 2.3286 val acc 13.9407 best val_acc 13.940747
# discarded index [20, 47, 45, 34, 22, 31, 43, 49, 32, 11]
# epoch: 13, bulyan: at our-agr n_at 10 e 13 | val loss 2.3479 val acc 14.3669 best val_acc 14.366883
# discarded index [20, 47, 45, 34, 31, 22, 49, 11, 44, 43]
# epoch: 14, bulyan: at our-agr n_at 10 e 14 | val loss 2.3618 val acc 9.8011 best val_acc 14.366883
# discarded index [20, 47, 45, 22, 31, 34, 11, 10, 37, 16]
# epoch: 15, bulyan: at our-agr n_at 10 e 15 | val loss 2.3962 val acc 9.8011 best val_acc 14.366883
# discarded index [20, 47, 45, 31, 22, 10, 34, 11, 16, 37]
# epoch: 16, bulyan: at our-agr n_at 10 e 16 | val loss 2.4354 val acc 9.8011 best val_acc 14.366883
# discarded index [20, 47, 45, 31, 10, 22, 37, 11, 34, 16]
# epoch: 17, bulyan: at our-agr n_at 10 e 17 | val loss 2.4403 val acc 12.2565 best val_acc 14.366883
# discarded index [20, 47, 45, 31, 10, 22, 37, 11, 16, 28]
# epoch: 18, bulyan: at our-agr n_at 10 e 18 | val loss 2.4667 val acc 9.8011 best val_acc 14.366883
# discarded index [20, 47, 45, 31, 10, 22, 37, 16, 11, 34]
# epoch: 19, bulyan: at our-agr n_at 10 e 19 | val loss 2.4475 val acc 10.2273 best val_acc 14.366883
# discarded index [20, 47, 45, 31, 10, 37, 22, 11, 16, 28]
# epoch: 20, bulyan: at our-agr n_at 10 e 20 | val loss 2.5437 val acc 9.8011 best val_acc 14.366883
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 13, 11]
# epoch: 21, bulyan: at our-agr n_at 10 e 21 | val loss 2.4557 val acc 14.1640 best val_acc 14.366883
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 11, 13]
# epoch: 22, bulyan: at our-agr n_at 10 e 22 | val loss 2.4371 val acc 11.3839 best val_acc 14.366883
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 11, 0]
# epoch: 23, bulyan: at our-agr n_at 10 e 23 | val loss 2.3178 val acc 18.4456 best val_acc 18.445617
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 11, 13]
# epoch: 24, bulyan: at our-agr n_at 10 e 24 | val loss 2.3400 val acc 14.2451 best val_acc 18.445617
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 11, 39]
# epoch: 25, bulyan: at our-agr n_at 10 e 25 | val loss 2.3630 val acc 14.6307 best val_acc 18.445617
# discarded index [20, 47, 45, 10, 31, 37, 22, 39, 16, 24]
# epoch: 26, bulyan: at our-agr n_at 10 e 26 | val loss 2.3834 val acc 12.7232 best val_acc 18.445617
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 39, 16]
# epoch: 27, bulyan: at our-agr n_at 10 e 27 | val loss 2.4172 val acc 18.1818 best val_acc 18.445617
# discarded index [20, 47, 45, 10, 31, 37, 22, 39, 16, 24]
# epoch: 28, bulyan: at our-agr n_at 10 e 28 | val loss 2.5613 val acc 12.4594 best val_acc 18.445617
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 39, 24]
# epoch: 29, bulyan: at our-agr n_at 10 e 29 | val loss 2.4845 val acc 15.2192 best val_acc 18.445617
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 39, 13]
# epoch: 30, bulyan: at our-agr n_at 10 e 30 | val loss 2.4236 val acc 16.9440 best val_acc 18.445617
# discarded index [20, 47, 45, 10, 31, 37, 22, 39, 27, 13]
# epoch: 31, bulyan: at our-agr n_at 10 e 31 | val loss 2.3552 val acc 21.1242 best val_acc 21.124188
# discarded index [20, 47, 45, 10, 31, 37, 39, 22, 24, 0]
# epoch: 32, bulyan: at our-agr n_at 10 e 32 | val loss 2.3430 val acc 17.0657 best val_acc 21.124188
# discarded index [20, 47, 45, 10, 31, 37, 22, 39, 24, 16]
# epoch: 33, bulyan: at our-agr n_at 10 e 33 | val loss 2.3481 val acc 21.1851 best val_acc 21.185065
# discarded index [20, 47, 45, 10, 31, 37, 22, 39, 24, 28]
# epoch: 34, bulyan: at our-agr n_at 10 e 34 | val loss 2.7654 val acc 13.2508 best val_acc 21.185065
# discarded index [20, 47, 45, 10, 31, 37, 27, 13, 49, 39]
# epoch: 35, bulyan: at our-agr n_at 10 e 35 | val loss 2.4995 val acc 9.9026 best val_acc 21.185065
# discarded index [20, 47, 45, 10, 31, 37, 27, 13, 49, 11]
# epoch: 36, bulyan: at our-agr n_at 10 e 36 | val loss 2.3345 val acc 10.6940 best val_acc 21.185065
# discarded index [20, 47, 45, 10, 31, 37, 27, 13, 49, 11]
# epoch: 37, bulyan: at our-agr n_at 10 e 37 | val loss 2.3337 val acc 14.6307 best val_acc 21.185065
# discarded index [20, 47, 45, 10, 31, 37, 27, 13, 49, 11]
# epoch: 38, bulyan: at our-agr n_at 10 e 38 | val loss 2.3381 val acc 15.1583 best val_acc 21.185065
# discarded index [20, 47, 45, 10, 31, 37, 27, 13, 49, 11]
# epoch: 39, bulyan: at our-agr n_at 10 e 39 | val loss 2.3398 val acc 15.6453 best val_acc 21.185065
# discarded index [20, 47, 45, 10, 31, 37, 27, 13, 49, 11]
# epoch: 40, bulyan: at our-agr n_at 10 e 40 | val loss 2.3370 val acc 17.0252 best val_acc 21.185065
# discarded index [20, 47, 45, 10, 31, 37, 27, 13, 49, 11]
# epoch: 41, bulyan: at our-agr n_at 10 e 41 | val loss 2.3531 val acc 18.8920 best val_acc 21.185065
# discarded index [20, 47, 45, 10, 31, 37, 27, 13, 49, 11]
# epoch: 42, bulyan: at our-agr n_at 10 e 42 | val loss 2.3282 val acc 21.9156 best val_acc 21.915584
# discarded index [20, 47, 45, 10, 31, 37, 27, 13, 49, 11]
# epoch: 43, bulyan: at our-agr n_at 10 e 43 | val loss 2.3512 val acc 21.3068 best val_acc 21.915584
# discarded index [20, 47, 45, 10, 31, 37, 27, 13, 49, 11]
# epoch: 44, bulyan: at our-agr n_at 10 e 44 | val loss 2.4011 val acc 23.5998 best val_acc 23.599838
# discarded index [20, 47, 45, 10, 31, 37, 27, 22, 0, 1]
# epoch: 45, bulyan: at our-agr n_at 10 e 45 | val loss 2.2143 val acc 21.0836 best val_acc 23.599838
# discarded index [20, 47, 45, 10, 31, 37, 27, 22, 0, 1]
# epoch: 46, bulyan: at our-agr n_at 10 e 46 | val loss 2.3693 val acc 20.5763 best val_acc 23.599838
# discarded index [20, 47, 45, 10, 31, 37, 27, 22, 39, 24]
# epoch: 47, bulyan: at our-agr n_at 10 e 47 | val loss 2.3545 val acc 18.1615 best val_acc 23.599838
# discarded index [20, 47, 45, 10, 31, 37, 27, 39, 22, 24]
# epoch: 48, bulyan: at our-agr n_at 10 e 48 | val loss 2.4398 val acc 17.0455 best val_acc 23.599838
# discarded index [20, 47, 45, 10, 31, 37, 27, 13, 22, 39]
# epoch: 49, bulyan: at our-agr n_at 10 e 49 | val loss 2.4508 val acc 16.8425 best val_acc 23.599838
# discarded index [20, 47, 45, 10, 31, 37, 27, 39, 13, 22]
# epoch: 50, bulyan: at our-agr n_at 10 e 50 | val loss 2.2519 val acc 21.1445 best val_acc 23.599838
# discarded index [20, 47, 45, 10, 31, 37, 27, 39, 13, 22]
# epoch: 51, bulyan: at our-agr n_at 10 e 51 | val loss 2.2787 val acc 24.1477 best val_acc 24.147727
# discarded index [20, 47, 45, 10, 31, 37, 39, 27, 13, 22]
# epoch: 52, bulyan: at our-agr n_at 10 e 52 | val loss 2.3579 val acc 23.4375 best val_acc 24.147727
# discarded index [20, 47, 45, 10, 31, 37, 39, 27, 13, 49]
# epoch: 53, bulyan: at our-agr n_at 10 e 53 | val loss 2.2075 val acc 22.0576 best val_acc 24.147727
# discarded index [20, 47, 45, 10, 31, 37, 39, 27, 13, 49]
# epoch: 54, bulyan: at our-agr n_at 10 e 54 | val loss 2.2832 val acc 24.3709 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 39, 27, 49, 13]
# epoch: 55, bulyan: at our-agr n_at 10 e 55 | val loss 2.2281 val acc 23.3969 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 39, 27, 49, 13]
# epoch: 56, bulyan: at our-agr n_at 10 e 56 | val loss 2.5955 val acc 16.8425 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 39, 27, 49]
# epoch: 57, bulyan: at our-agr n_at 10 e 57 | val loss 3.0505 val acc 12.6826 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 39, 11, 27]
# epoch: 58, bulyan: at our-agr n_at 10 e 58 | val loss 3.6480 val acc 10.3896 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 39, 27, 49]
# epoch: 59, bulyan: at our-agr n_at 10 e 59 | val loss 2.3821 val acc 10.1461 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 39, 27, 49]
# epoch: 60, bulyan: at our-agr n_at 10 e 60 | val loss 2.3643 val acc 10.4505 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 39, 27, 49]
# epoch: 61, bulyan: at our-agr n_at 10 e 61 | val loss 2.3507 val acc 10.1258 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 39, 27, 49]
# epoch: 62, bulyan: at our-agr n_at 10 e 62 | val loss 2.3387 val acc 10.3084 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 39, 27, 49]
# epoch: 63, bulyan: at our-agr n_at 10 e 63 | val loss 2.3305 val acc 10.3084 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 39, 27, 49]
# epoch: 64, bulyan: at our-agr n_at 10 e 64 | val loss 2.3261 val acc 10.3084 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 39, 27, 49]
# epoch: 65, bulyan: at our-agr n_at 10 e 65 | val loss 2.3297 val acc 10.2070 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 39, 27, 49]
# epoch: 66, bulyan: at our-agr n_at 10 e 66 | val loss 2.3331 val acc 10.7143 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 39, 27, 49]
# epoch: 67, bulyan: at our-agr n_at 10 e 67 | val loss 2.3360 val acc 11.9115 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 39, 27, 49]
# epoch: 68, bulyan: at our-agr n_at 10 e 68 | val loss 2.3351 val acc 12.5406 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 39, 27, 49]
# epoch: 69, bulyan: at our-agr n_at 10 e 69 | val loss 2.3353 val acc 13.0885 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 39, 27, 49]
# epoch: 70, bulyan: at our-agr n_at 10 e 70 | val loss 2.3369 val acc 13.2711 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 39, 27, 49]
# epoch: 71, bulyan: at our-agr n_at 10 e 71 | val loss 2.3306 val acc 13.0479 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 39, 27, 49]
# epoch: 72, bulyan: at our-agr n_at 10 e 72 | val loss 2.3467 val acc 13.2305 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 39, 27, 49]
# epoch: 73, bulyan: at our-agr n_at 10 e 73 | val loss 2.3353 val acc 12.6623 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 39, 27, 49]
# epoch: 74, bulyan: at our-agr n_at 10 e 74 | val loss 2.3253 val acc 12.3377 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 39, 27, 49]
# epoch: 75, bulyan: at our-agr n_at 10 e 75 | val loss 2.3469 val acc 11.4448 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 39, 27, 49]
# epoch: 76, bulyan: at our-agr n_at 10 e 76 | val loss 2.3313 val acc 12.6826 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 39, 27, 49]
# epoch: 77, bulyan: at our-agr n_at 10 e 77 | val loss 2.3195 val acc 13.4740 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 39, 27, 49]
# epoch: 78, bulyan: at our-agr n_at 10 e 78 | val loss 2.3426 val acc 11.2622 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 39, 27, 49]
# epoch: 79, bulyan: at our-agr n_at 10 e 79 | val loss 2.3245 val acc 12.3174 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 39, 0, 1]
# epoch: 80, bulyan: at our-agr n_at 10 e 80 | val loss 2.2948 val acc 15.2800 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 39, 27, 49]
# epoch: 81, bulyan: at our-agr n_at 10 e 81 | val loss 2.3218 val acc 11.9115 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 39, 28, 0]
# epoch: 82, bulyan: at our-agr n_at 10 e 82 | val loss 2.2899 val acc 12.6826 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 39, 28, 0]
# epoch: 83, bulyan: at our-agr n_at 10 e 83 | val loss 2.3183 val acc 12.0333 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 39, 28, 0]
# epoch: 84, bulyan: at our-agr n_at 10 e 84 | val loss 2.2781 val acc 13.2102 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 39, 28, 0]
# epoch: 85, bulyan: at our-agr n_at 10 e 85 | val loss 2.3561 val acc 12.1956 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 39, 28, 0]
# epoch: 86, bulyan: at our-agr n_at 10 e 86 | val loss 2.2825 val acc 12.2159 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 39, 28, 0]
# epoch: 87, bulyan: at our-agr n_at 10 e 87 | val loss 2.3648 val acc 11.8709 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 39, 28, 0]
# epoch: 88, bulyan: at our-agr n_at 10 e 88 | val loss 2.2781 val acc 11.3839 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 39, 28, 0]
# epoch: 89, bulyan: at our-agr n_at 10 e 89 | val loss 2.3438 val acc 12.6826 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 39, 28, 0]
# epoch: 90, bulyan: at our-agr n_at 10 e 90 | val loss 2.2706 val acc 12.3174 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 39, 28, 0]
# epoch: 91, bulyan: at our-agr n_at 10 e 91 | val loss 2.3440 val acc 12.6826 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 28, 39, 0]
# epoch: 92, bulyan: at our-agr n_at 10 e 92 | val loss 2.2668 val acc 13.0885 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 28, 39, 0]
# epoch: 93, bulyan: at our-agr n_at 10 e 93 | val loss 2.3439 val acc 13.3929 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 28, 39, 0]
# epoch: 94, bulyan: at our-agr n_at 10 e 94 | val loss 2.2629 val acc 12.5000 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 28, 39, 0]
# epoch: 95, bulyan: at our-agr n_at 10 e 95 | val loss 2.3569 val acc 12.6015 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 28, 39, 24]
# epoch: 96, bulyan: at our-agr n_at 10 e 96 | val loss 2.2969 val acc 15.5641 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 26, 28, 39, 24]
# epoch: 97, bulyan: at our-agr n_at 10 e 97 | val loss 2.4426 val acc 13.9407 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 26, 39, 24]
# epoch: 98, bulyan: at our-agr n_at 10 e 98 | val loss 2.3738 val acc 17.2281 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 26, 39, 24]
# epoch: 99, bulyan: at our-agr n_at 10 e 99 | val loss 2.4800 val acc 16.3352 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 26, 39, 24]
# epoch: 100, bulyan: at our-agr n_at 10 e 100 | val loss 2.4757 val acc 11.7289 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 26, 39, 24]
# epoch: 101, bulyan: at our-agr n_at 10 e 101 | val loss 2.5253 val acc 17.8977 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 26, 39, 24]
# epoch: 102, bulyan: at our-agr n_at 10 e 102 | val loss 2.4412 val acc 15.0974 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 39, 26, 24]
# epoch: 103, bulyan: at our-agr n_at 10 e 103 | val loss 2.6345 val acc 15.5032 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 39, 24, 0]
# epoch: 104, bulyan: at our-agr n_at 10 e 104 | val loss 2.3635 val acc 15.2800 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 39, 24, 0]
# epoch: 105, bulyan: at our-agr n_at 10 e 105 | val loss 2.3306 val acc 15.9294 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 39, 24, 0]
# epoch: 106, bulyan: at our-agr n_at 10 e 106 | val loss 2.2830 val acc 16.3149 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 39, 24, 0]
# epoch: 107, bulyan: at our-agr n_at 10 e 107 | val loss 2.2592 val acc 20.6981 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 39, 24, 0]
# epoch: 108, bulyan: at our-agr n_at 10 e 108 | val loss 2.2656 val acc 15.3815 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 39, 24, 0]
# epoch: 109, bulyan: at our-agr n_at 10 e 109 | val loss 3.2972 val acc 11.6883 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 26, 39, 24]
# epoch: 110, bulyan: at our-agr n_at 10 e 110 | val loss 2.3477 val acc 14.4075 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 26, 39, 24]
# epoch: 111, bulyan: at our-agr n_at 10 e 111 | val loss 2.3230 val acc 12.1753 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 26, 39, 24]
# epoch: 112, bulyan: at our-agr n_at 10 e 112 | val loss 2.2856 val acc 11.5463 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 26, 39, 24]
# epoch: 113, bulyan: at our-agr n_at 10 e 113 | val loss 2.2703 val acc 11.8506 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 26, 39, 24]
# epoch: 114, bulyan: at our-agr n_at 10 e 114 | val loss 2.2859 val acc 11.5057 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 26, 39, 24]
# epoch: 115, bulyan: at our-agr n_at 10 e 115 | val loss 2.2648 val acc 12.2362 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 26, 39, 24]
# epoch: 116, bulyan: at our-agr n_at 10 e 116 | val loss 2.2797 val acc 13.5349 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 26, 39, 24]
# epoch: 117, bulyan: at our-agr n_at 10 e 117 | val loss 2.3002 val acc 16.8425 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 26, 39, 24]
# epoch: 118, bulyan: at our-agr n_at 10 e 118 | val loss 2.3217 val acc 15.8076 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 26, 39, 24]
# epoch: 119, bulyan: at our-agr n_at 10 e 119 | val loss 2.3018 val acc 18.3644 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 26, 39, 24]
# epoch: 120, bulyan: at our-agr n_at 10 e 120 | val loss 2.3628 val acc 19.3791 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 39, 0]
# epoch: 121, bulyan: at our-agr n_at 10 e 121 | val loss 2.2254 val acc 15.5235 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 39, 0]
# epoch: 122, bulyan: at our-agr n_at 10 e 122 | val loss 2.3217 val acc 17.7760 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 39, 0]
# epoch: 123, bulyan: at our-agr n_at 10 e 123 | val loss 2.2319 val acc 18.9529 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 39, 0]
# epoch: 124, bulyan: at our-agr n_at 10 e 124 | val loss 2.3141 val acc 20.2516 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 39, 0]
# epoch: 125, bulyan: at our-agr n_at 10 e 125 | val loss 2.1830 val acc 19.1356 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 39, 0]
# epoch: 126, bulyan: at our-agr n_at 10 e 126 | val loss 2.3135 val acc 16.2338 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 39, 0]
# epoch: 127, bulyan: at our-agr n_at 10 e 127 | val loss 2.2222 val acc 18.8515 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 39, 0]
# epoch: 128, bulyan: at our-agr n_at 10 e 128 | val loss 2.3119 val acc 19.4805 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 39, 22]
# epoch: 129, bulyan: at our-agr n_at 10 e 129 | val loss 2.4953 val acc 20.7183 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 39, 22]
# epoch: 130, bulyan: at our-agr n_at 10 e 130 | val loss 2.5407 val acc 14.4886 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 39, 22]
# epoch: 131, bulyan: at our-agr n_at 10 e 131 | val loss 2.6991 val acc 10.5114 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 39, 22]
# epoch: 132, bulyan: at our-agr n_at 10 e 132 | val loss 2.5535 val acc 11.9318 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 39, 22]
# epoch: 133, bulyan: at our-agr n_at 10 e 133 | val loss 2.3736 val acc 13.4740 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 39, 22]
# epoch: 134, bulyan: at our-agr n_at 10 e 134 | val loss 2.4314 val acc 10.9781 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 39, 22]
# epoch: 135, bulyan: at our-agr n_at 10 e 135 | val loss 2.6500 val acc 11.4854 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 39, 22]
# epoch: 136, bulyan: at our-agr n_at 10 e 136 | val loss 2.3064 val acc 15.8482 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 39, 22]
# epoch: 137, bulyan: at our-agr n_at 10 e 137 | val loss 2.3801 val acc 15.9091 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 39, 22]
# epoch: 138, bulyan: at our-agr n_at 10 e 138 | val loss 2.6164 val acc 16.1526 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 39, 22]
# epoch: 139, bulyan: at our-agr n_at 10 e 139 | val loss 2.2662 val acc 18.5268 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 39, 22]
# epoch: 140, bulyan: at our-agr n_at 10 e 140 | val loss 2.3901 val acc 17.3904 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 39, 22]
# epoch: 141, bulyan: at our-agr n_at 10 e 141 | val loss 2.6348 val acc 18.2630 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 39, 22]
# epoch: 142, bulyan: at our-agr n_at 10 e 142 | val loss 2.2564 val acc 19.0138 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 39, 22]
# epoch: 143, bulyan: at our-agr n_at 10 e 143 | val loss 2.3016 val acc 18.7500 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 39, 22]
# epoch: 144, bulyan: at our-agr n_at 10 e 144 | val loss 2.8080 val acc 17.9180 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 39, 22]
# epoch: 145, bulyan: at our-agr n_at 10 e 145 | val loss 2.2584 val acc 16.5584 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 39, 22]
# epoch: 146, bulyan: at our-agr n_at 10 e 146 | val loss 2.3888 val acc 19.3588 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 39, 22]
# epoch: 147, bulyan: at our-agr n_at 10 e 147 | val loss 2.7051 val acc 20.5763 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 39]
# epoch: 148, bulyan: at our-agr n_at 10 e 148 | val loss 2.6772 val acc 21.4692 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 39, 0]
# epoch: 149, bulyan: at our-agr n_at 10 e 149 | val loss 2.1893 val acc 14.1437 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 39, 0]
# epoch: 150, bulyan: at our-agr n_at 10 e 150 | val loss 2.3674 val acc 17.8166 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 39]
# epoch: 151, bulyan: at our-agr n_at 10 e 151 | val loss 2.7234 val acc 14.3263 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 39]
# epoch: 152, bulyan: at our-agr n_at 10 e 152 | val loss 2.7965 val acc 12.3377 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 39]
# epoch: 153, bulyan: at our-agr n_at 10 e 153 | val loss 2.3993 val acc 11.4448 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 39]
# epoch: 154, bulyan: at our-agr n_at 10 e 154 | val loss 2.7140 val acc 15.9091 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 39]
# epoch: 155, bulyan: at our-agr n_at 10 e 155 | val loss 2.3186 val acc 17.9992 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 39]
# epoch: 156, bulyan: at our-agr n_at 10 e 156 | val loss 2.4325 val acc 18.7094 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 39]
# epoch: 157, bulyan: at our-agr n_at 10 e 157 | val loss 2.2351 val acc 22.0576 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 39]
# epoch: 158, bulyan: at our-agr n_at 10 e 158 | val loss 2.4062 val acc 18.9326 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 39]
# epoch: 159, bulyan: at our-agr n_at 10 e 159 | val loss 2.2529 val acc 22.5649 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 39]
# epoch: 160, bulyan: at our-agr n_at 10 e 160 | val loss 2.4136 val acc 19.7240 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 39]
# epoch: 161, bulyan: at our-agr n_at 10 e 161 | val loss 2.3624 val acc 18.7297 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 39]
# epoch: 162, bulyan: at our-agr n_at 10 e 162 | val loss 2.8774 val acc 15.9091 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 39]
# epoch: 163, bulyan: at our-agr n_at 10 e 163 | val loss 2.2123 val acc 14.1437 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 39]
# epoch: 164, bulyan: at our-agr n_at 10 e 164 | val loss 2.2096 val acc 19.7849 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 39]
# epoch: 165, bulyan: at our-agr n_at 10 e 165 | val loss 2.2698 val acc 24.3101 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 39]
# epoch: 166, bulyan: at our-agr n_at 10 e 166 | val loss 2.3663 val acc 20.1907 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 39]
# epoch: 167, bulyan: at our-agr n_at 10 e 167 | val loss 2.1847 val acc 21.7330 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 39]
# epoch: 168, bulyan: at our-agr n_at 10 e 168 | val loss 2.2301 val acc 23.0519 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 39]
# epoch: 169, bulyan: at our-agr n_at 10 e 169 | val loss 2.2125 val acc 21.0836 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 39]
# epoch: 170, bulyan: at our-agr n_at 10 e 170 | val loss 2.5031 val acc 20.3125 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 39]
# epoch: 171, bulyan: at our-agr n_at 10 e 171 | val loss 2.7055 val acc 14.9959 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 39]
# epoch: 172, bulyan: at our-agr n_at 10 e 172 | val loss 2.2439 val acc 13.0885 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 39]
# epoch: 173, bulyan: at our-agr n_at 10 e 173 | val loss 2.6649 val acc 18.1209 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 21]
# epoch: 174, bulyan: at our-agr n_at 10 e 174 | val loss 2.2076 val acc 20.0284 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 21]
# epoch: 175, bulyan: at our-agr n_at 10 e 175 | val loss 2.1883 val acc 21.2054 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 21]
# epoch: 176, bulyan: at our-agr n_at 10 e 176 | val loss 2.1319 val acc 21.5706 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 21]
# epoch: 177, bulyan: at our-agr n_at 10 e 177 | val loss 2.2358 val acc 21.1039 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 21]
# epoch: 178, bulyan: at our-agr n_at 10 e 178 | val loss 2.1027 val acc 22.6461 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 21]
# epoch: 179, bulyan: at our-agr n_at 10 e 179 | val loss 2.1597 val acc 23.5390 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 22]
# epoch: 180, bulyan: at our-agr n_at 10 e 180 | val loss 2.2126 val acc 20.5763 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 21]
# epoch: 181, bulyan: at our-agr n_at 10 e 181 | val loss 2.2118 val acc 20.6575 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 21]
# epoch: 182, bulyan: at our-agr n_at 10 e 182 | val loss 3.3180 val acc 10.5519 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 21]
# epoch: 183, bulyan: at our-agr n_at 10 e 183 | val loss 2.3579 val acc 17.9789 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 21]
# epoch: 184, bulyan: at our-agr n_at 10 e 184 | val loss 2.3885 val acc 12.6420 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 21]
# epoch: 185, bulyan: at our-agr n_at 10 e 185 | val loss 2.3110 val acc 17.3295 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 21]
# epoch: 186, bulyan: at our-agr n_at 10 e 186 | val loss 2.3292 val acc 20.3328 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 21]
# epoch: 187, bulyan: at our-agr n_at 10 e 187 | val loss 2.2024 val acc 22.1794 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 21]
# epoch: 188, bulyan: at our-agr n_at 10 e 188 | val loss 2.2465 val acc 21.6721 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 21]
# epoch: 189, bulyan: at our-agr n_at 10 e 189 | val loss 2.1773 val acc 22.0576 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 21]
# epoch: 190, bulyan: at our-agr n_at 10 e 190 | val loss 2.2474 val acc 19.5414 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 21]
# epoch: 191, bulyan: at our-agr n_at 10 e 191 | val loss 2.2184 val acc 20.5966 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 21]
# epoch: 192, bulyan: at our-agr n_at 10 e 192 | val loss 2.3693 val acc 23.1128 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 21]
# epoch: 193, bulyan: at our-agr n_at 10 e 193 | val loss 2.0882 val acc 19.5008 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 21]
# epoch: 194, bulyan: at our-agr n_at 10 e 194 | val loss 2.7916 val acc 19.3791 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 22]
# epoch: 195, bulyan: at our-agr n_at 10 e 195 | val loss 2.4182 val acc 18.9326 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 22]
# epoch: 196, bulyan: at our-agr n_at 10 e 196 | val loss 2.5101 val acc 19.6023 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 22]
# epoch: 197, bulyan: at our-agr n_at 10 e 197 | val loss 2.3005 val acc 18.1615 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 22]
# epoch: 198, bulyan: at our-agr n_at 10 e 198 | val loss 2.2210 val acc 21.4894 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 21]
# epoch: 199, bulyan: at our-agr n_at 10 e 199 | val loss 2.2146 val acc 21.8344 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 21]
# epoch: 200, bulyan: at our-agr n_at 10 e 200 | val loss 2.2217 val acc 20.3734 best val_acc 24.370942
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 22]
# epoch: 201, bulyan: at our-agr n_at 10 e 201 | val loss 2.4781 val acc 27.2524 best val_acc 27.252435
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 21]
# epoch: 202, bulyan: at our-agr n_at 10 e 202 | val loss 2.0836 val acc 22.9099 best val_acc 27.252435
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 21]
# epoch: 203, bulyan: at our-agr n_at 10 e 203 | val loss 2.3685 val acc 22.4026 best val_acc 27.252435
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 22]
# epoch: 204, bulyan: at our-agr n_at 10 e 204 | val loss 2.7777 val acc 21.3068 best val_acc 27.252435
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 22]
# epoch: 205, bulyan: at our-agr n_at 10 e 205 | val loss 2.3198 val acc 15.6453 best val_acc 27.252435
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 22]
# epoch: 206, bulyan: at our-agr n_at 10 e 206 | val loss 2.1149 val acc 20.7386 best val_acc 27.252435
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 22]
# epoch: 207, bulyan: at our-agr n_at 10 e 207 | val loss 2.5039 val acc 24.4521 best val_acc 27.252435
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 35]
# epoch: 208, bulyan: at our-agr n_at 10 e 208 | val loss 2.1027 val acc 21.4286 best val_acc 27.252435
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 35]
# epoch: 209, bulyan: at our-agr n_at 10 e 209 | val loss 2.3151 val acc 25.7508 best val_acc 27.252435
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 22]
# epoch: 210, bulyan: at our-agr n_at 10 e 210 | val loss 2.6116 val acc 23.3157 best val_acc 27.252435
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 35]
# epoch: 211, bulyan: at our-agr n_at 10 e 211 | val loss 2.2808 val acc 21.4286 best val_acc 27.252435
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 35]
# epoch: 212, bulyan: at our-agr n_at 10 e 212 | val loss 2.7070 val acc 19.1761 best val_acc 27.252435
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 35]
# epoch: 213, bulyan: at our-agr n_at 10 e 213 | val loss 2.2683 val acc 16.9237 best val_acc 27.252435
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 35]
# epoch: 214, bulyan: at our-agr n_at 10 e 214 | val loss 2.1426 val acc 21.0836 best val_acc 27.252435
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 35]
# epoch: 215, bulyan: at our-agr n_at 10 e 215 | val loss 2.0405 val acc 27.6177 best val_acc 27.617695
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 35]
# epoch: 216, bulyan: at our-agr n_at 10 e 216 | val loss 2.4795 val acc 26.0146 best val_acc 27.617695
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 35]
# epoch: 217, bulyan: at our-agr n_at 10 e 217 | val loss 2.1841 val acc 23.5187 best val_acc 27.617695
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 35]
# epoch: 218, bulyan: at our-agr n_at 10 e 218 | val loss 2.2658 val acc 28.3076 best val_acc 28.307630
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 35]
# epoch: 219, bulyan: at our-agr n_at 10 e 219 | val loss 2.3969 val acc 22.6664 best val_acc 28.307630
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 35]
# epoch: 220, bulyan: at our-agr n_at 10 e 220 | val loss 2.3481 val acc 21.4286 best val_acc 28.307630
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 35]
# epoch: 221, bulyan: at our-agr n_at 10 e 221 | val loss 2.1927 val acc 22.7881 best val_acc 28.307630
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 35]
# epoch: 222, bulyan: at our-agr n_at 10 e 222 | val loss 2.4540 val acc 22.0170 best val_acc 28.307630
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 35]
# epoch: 223, bulyan: at our-agr n_at 10 e 223 | val loss 2.1450 val acc 23.4375 best val_acc 28.307630
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 35]
# epoch: 224, bulyan: at our-agr n_at 10 e 224 | val loss 2.2546 val acc 25.8726 best val_acc 28.307630
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 35]
# epoch: 225, bulyan: at our-agr n_at 10 e 225 | val loss 2.3547 val acc 24.9797 best val_acc 28.307630
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 35]
# epoch: 226, bulyan: at our-agr n_at 10 e 226 | val loss 2.1144 val acc 22.7679 best val_acc 28.307630
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 35]
# epoch: 227, bulyan: at our-agr n_at 10 e 227 | val loss 2.7448 val acc 26.0958 best val_acc 28.307630
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 35]
# epoch: 228, bulyan: at our-agr n_at 10 e 228 | val loss 2.3013 val acc 23.2143 best val_acc 28.307630
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 35]
# epoch: 229, bulyan: at our-agr n_at 10 e 229 | val loss 2.2628 val acc 28.4903 best val_acc 28.490260
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 35]
# epoch: 230, bulyan: at our-agr n_at 10 e 230 | val loss 2.0364 val acc 30.2354 best val_acc 30.235390
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 35]
# epoch: 231, bulyan: at our-agr n_at 10 e 231 | val loss 2.3119 val acc 26.9278 best val_acc 30.235390
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 35]
# epoch: 232, bulyan: at our-agr n_at 10 e 232 | val loss 2.1685 val acc 29.8295 best val_acc 30.235390
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 35]
# epoch: 233, bulyan: at our-agr n_at 10 e 233 | val loss 2.5908 val acc 23.2752 best val_acc 30.235390
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 22]
# epoch: 234, bulyan: at our-agr n_at 10 e 234 | val loss 2.6327 val acc 21.0633 best val_acc 30.235390
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 35]
# epoch: 235, bulyan: at our-agr n_at 10 e 235 | val loss 2.4501 val acc 23.3766 best val_acc 30.235390
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 35]
# epoch: 236, bulyan: at our-agr n_at 10 e 236 | val loss 2.2529 val acc 28.3482 best val_acc 30.235390
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 35]
# epoch: 237, bulyan: at our-agr n_at 10 e 237 | val loss 2.3557 val acc 24.2086 best val_acc 30.235390
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 35]
# epoch: 238, bulyan: at our-agr n_at 10 e 238 | val loss 2.2995 val acc 25.3044 best val_acc 30.235390
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 35]
# epoch: 239, bulyan: at our-agr n_at 10 e 239 | val loss 2.1029 val acc 23.6201 best val_acc 30.235390
# discarded index [20, 47, 45, 10, 31, 37, 28, 24, 27, 35]
# epoch: 240, bulyan: at our-agr n_at 10 e 240 | val loss 2.8274 val acc 22.9911 best val_acc 30.235390
# discarded index [20, 47, 45, 10, 31, 37, 28, 27, 24, 35]
# epoch: 241, bulyan: at our-agr n_at 10 e 241 | val loss 2.4188 val acc 19.8052 best val_acc 30.235390
# discarded index [20, 47, 45, 10, 31, 37, 28, 27, 24, 35]
# epoch: 242, bulyan: at our-agr n_at 10 e 242 | val loss 2.7618 val acc 25.6088 best val_acc 30.235390
# discarded index [20, 47, 45, 10, 31, 37, 28, 27, 24, 35]
# epoch: 243, bulyan: at our-agr n_at 10 e 243 | val loss 2.1872 val acc 23.0519 best val_acc 30.235390
# discarded index [20, 47, 45, 10, 31, 37, 28, 27, 24, 35]
# epoch: 244, bulyan: at our-agr n_at 10 e 244 | val loss 3.2732 val acc 22.1185 best val_acc 30.235390
# discarded index [20, 47, 45, 10, 31, 37, 28, 27, 18, 35]
# epoch: 245, bulyan: at our-agr n_at 10 e 245 | val loss 4.7853 val acc 19.8052 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 246, bulyan: at our-agr n_at 10 e 246 | val loss 2.6881 val acc 12.8247 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 247, bulyan: at our-agr n_at 10 e 247 | val loss 3.4370 val acc 10.6737 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 248, bulyan: at our-agr n_at 10 e 248 | val loss 2.5625 val acc 10.2273 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 249, bulyan: at our-agr n_at 10 e 249 | val loss 2.3690 val acc 16.1120 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 250, bulyan: at our-agr n_at 10 e 250 | val loss 2.3347 val acc 15.5641 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 251, bulyan: at our-agr n_at 10 e 251 | val loss 2.2352 val acc 17.3904 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 252, bulyan: at our-agr n_at 10 e 252 | val loss 2.2525 val acc 18.7094 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 253, bulyan: at our-agr n_at 10 e 253 | val loss 2.1379 val acc 20.1096 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 254, bulyan: at our-agr n_at 10 e 254 | val loss 2.2984 val acc 18.8515 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 255, bulyan: at our-agr n_at 10 e 255 | val loss 2.2291 val acc 15.5032 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 256, bulyan: at our-agr n_at 10 e 256 | val loss 2.3916 val acc 19.6429 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 257, bulyan: at our-agr n_at 10 e 257 | val loss 2.3995 val acc 18.4659 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 258, bulyan: at our-agr n_at 10 e 258 | val loss 2.4815 val acc 11.5463 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 259, bulyan: at our-agr n_at 10 e 259 | val loss 2.2809 val acc 14.8539 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 260, bulyan: at our-agr n_at 10 e 260 | val loss 2.2887 val acc 13.1494 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 261, bulyan: at our-agr n_at 10 e 261 | val loss 2.1469 val acc 17.7557 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 262, bulyan: at our-agr n_at 10 e 262 | val loss 2.1980 val acc 21.9562 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 263, bulyan: at our-agr n_at 10 e 263 | val loss 2.0750 val acc 20.2516 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 264, bulyan: at our-agr n_at 10 e 264 | val loss 2.1878 val acc 20.7792 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 265, bulyan: at our-agr n_at 10 e 265 | val loss 2.4957 val acc 14.3466 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 266, bulyan: at our-agr n_at 10 e 266 | val loss 2.4064 val acc 13.9813 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 267, bulyan: at our-agr n_at 10 e 267 | val loss 2.1600 val acc 18.5877 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 268, bulyan: at our-agr n_at 10 e 268 | val loss 2.2174 val acc 17.6745 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 269, bulyan: at our-agr n_at 10 e 269 | val loss 2.0685 val acc 22.4026 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 270, bulyan: at our-agr n_at 10 e 270 | val loss 2.1723 val acc 20.6169 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 271, bulyan: at our-agr n_at 10 e 271 | val loss 2.0854 val acc 21.4286 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 272, bulyan: at our-agr n_at 10 e 272 | val loss 2.1605 val acc 22.1388 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 273, bulyan: at our-agr n_at 10 e 273 | val loss 2.1623 val acc 21.1242 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 274, bulyan: at our-agr n_at 10 e 274 | val loss 2.0956 val acc 22.3620 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 275, bulyan: at our-agr n_at 10 e 275 | val loss 2.2425 val acc 25.5073 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 276, bulyan: at our-agr n_at 10 e 276 | val loss 2.1414 val acc 21.3677 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 277, bulyan: at our-agr n_at 10 e 277 | val loss 2.0620 val acc 24.6347 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 278, bulyan: at our-agr n_at 10 e 278 | val loss 1.9886 val acc 24.3304 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 279, bulyan: at our-agr n_at 10 e 279 | val loss 1.9510 val acc 27.4148 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 280, bulyan: at our-agr n_at 10 e 280 | val loss 2.1312 val acc 26.0755 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 281, bulyan: at our-agr n_at 10 e 281 | val loss 2.0931 val acc 19.7240 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 282, bulyan: at our-agr n_at 10 e 282 | val loss 2.4260 val acc 22.9505 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 283, bulyan: at our-agr n_at 10 e 283 | val loss 2.0366 val acc 20.6169 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 284, bulyan: at our-agr n_at 10 e 284 | val loss 2.2548 val acc 22.4229 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 285, bulyan: at our-agr n_at 10 e 285 | val loss 2.4058 val acc 16.7005 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 286, bulyan: at our-agr n_at 10 e 286 | val loss 2.2658 val acc 16.6396 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 287, bulyan: at our-agr n_at 10 e 287 | val loss 2.0677 val acc 18.3442 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 288, bulyan: at our-agr n_at 10 e 288 | val loss 2.0097 val acc 28.2062 best val_acc 30.235390
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 289, bulyan: at our-agr n_at 10 e 289 | val loss 1.9883 val acc 30.7224 best val_acc 30.722403
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 290, bulyan: at our-agr n_at 10 e 290 | val loss 1.9956 val acc 28.4091 best val_acc 30.722403
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 291, bulyan: at our-agr n_at 10 e 291 | val loss 2.2155 val acc 25.5073 best val_acc 30.722403
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 292, bulyan: at our-agr n_at 10 e 292 | val loss 2.0218 val acc 25.9537 best val_acc 30.722403
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 293, bulyan: at our-agr n_at 10 e 293 | val loss 2.0164 val acc 27.9221 best val_acc 30.722403
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 294, bulyan: at our-agr n_at 10 e 294 | val loss 1.9377 val acc 28.9773 best val_acc 30.722403
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 295, bulyan: at our-agr n_at 10 e 295 | val loss 2.0418 val acc 29.2005 best val_acc 30.722403
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 296, bulyan: at our-agr n_at 10 e 296 | val loss 1.9336 val acc 27.1307 best val_acc 30.722403
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 0, 1]
# epoch: 297, bulyan: at our-agr n_at 10 e 297 | val loss 2.1844 val acc 26.5828 best val_acc 30.722403
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 22, 0]
# epoch: 298, bulyan: at our-agr n_at 10 e 298 | val loss 2.0235 val acc 25.4261 best val_acc 30.722403
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 22, 0]
# epoch: 299, bulyan: at our-agr n_at 10 e 299 | val loss 2.1599 val acc 28.8758 best val_acc 30.722403
# discarded index [20, 47, 45, 31, 10, 37, 28, 24, 22, 0]
# epoch: 300, bulyan: at our-agr n_at 10 e 300 | val loss 2.0582 val acc 28.5511 best val_acc 30.722403

# %%
import matplotlib.pyplot as plt

# Plotting the data
for col in ['loss', 'validation accuracy', 'best validation accuracy']:
    plt.plot(df['epoch'].tolist(), df[col].tolist())
    plt.title(f"{title} {col}")
    plt.show()
