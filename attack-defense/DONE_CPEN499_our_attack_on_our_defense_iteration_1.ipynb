# %% [markdown]
# # The notebook contains
# ### Code for Our attack and our aggregation algorithm
# ### Evaluation of our defense with different parameters in our attack

# %% [markdown]
# ## Import packages

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
from __future__ import print_function
import argparse, os, sys, csv, shutil, time, random, operator, pickle, ast, math
import numpy as np
import pandas as pd
from torch.optim import Optimizer
import torch.nn.functional as F
import torch
import pickle
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data as data
import torch.multiprocessing as mp
import math
sys.path.insert(0,'./../utils/')
from logger import *
from eval import *
from misc import *

from cifar10_normal_train import *
from cifar10_util import *
from adam import Adam
from sgd import SGD

# %% [markdown]
# ### Load Data
# Divide cifar10 data among 50 clients in Non-IID fashion using Dirichlet distribution

# %%
n_users = 50
user_tr_len = pickle.load(open('./data/user_tr_len.pkl','rb'))

user_train_data_tensors = pickle.load(open('./data/user_train_data_tensors.pkl','rb'))
user_train_label_tensors = pickle.load(open('./data/user_train_label_tensors.pkl','rb'))

val_data_tensor = pickle.load(open('./data/val_data_tensor.pkl','rb'))
val_label_tensor = pickle.load(open('./data/val_label_tensor.pkl','rb'))
te_data_tensor = pickle.load(open('./data/te_data_tensor.pkl','rb'))
te_label_tensor = pickle.load(open('./data/te_label_tensor.pkl','rb'))

# %% [markdown]
# ### Our Aggregation Function

# %%
def our_mean_defense(all_updates, n_attackers, history_updates):
    discarded_history = get_discarded_index(n_attackers, history_updates)

    mask = torch.ones(all_updates.size(0), dtype=torch.bool)
    mask[discarded_history] = False
    remaining_updates = all_updates[mask]

    print('discarded index', discarded_history)

    return torch.nanmean(remaining_updates, dim=0)

####
def euclidean_distance(row1, row2):
    return torch.sqrt(torch.sum((row1 - row2) ** 2))
####

def get_discarded_index(n_attackers, history_updates):
    n_users = history_updates.shape[0]

    ####
    distance_matrix = [[0 if i == j else euclidean_distance(history_updates[i, :], history_updates[j, :]) for j in range(n_users)] for i in range(n_users)]
    ####

    sum_of_distances = [sum(row) for row in distance_matrix]

    discarded_history = []
    for _ in range(n_attackers):
        max_distance = max(sum_of_distances)
        index_of_max_distance = sum_of_distances.index(max_distance)
        discarded_history.append(index_of_max_distance)

        for i in range(n_users):
            sum_of_distances[i] -= distance_matrix[i][index_of_max_distance]
        sum_of_distances[index_of_max_distance] = -1

    return discarded_history

# %% [markdown]
# ### Set nepochs

# %%
nepochs= 300

# %% [markdown]
# # our_attack & our defense

# %% [markdown]
# ## iteration 1
#
# 10 bisection; 1 iterations; 12 discarded

# %% [markdown]
# ### our_attack_mean
# $ argmin_\theta(\ -L(\theta_{attacker(s)}) + \lambda_1 |\bar{\theta_{abs\ mean\ benige\ users}} - \bar{\theta_{abs\ attacker(s)}}|$

# %%
device = 'cuda:0'
def check_condition(lambda1, prev_grad, loss_grad, history, all_updates, n_users, n_attacker, epoch_num):
    loss_grad = loss_grad.to(device)
    prev_grad = prev_grad.to(device)
    new_grad = lambda1 * (loss_grad + prev_grad)

    ####
    mal_updates = torch.stack([new_grad.clone().detach() for _ in range(n_attacker)])
    malicious_grads = torch.cat((mal_updates, all_updates[n_attacker:]), 0)

    history_updates = history.clone().detach()
    history_updates[:, epoch_num] = malicious_grads.abs().mean(dim=1, keepdim=True).squeeze()
    ####

    discarded_history = get_discarded_index(n_attacker+2, history_updates)

    detected_mal = len([item for item in discarded_history if item < 10])
    return detected_mal / len(discarded_history) <= n_attacker / n_users

def find_upper_bound(lambda1, prev_grad, loss_grad, history, all_updates, n_users, n_attacker, epoch_num):
    while check_condition(lambda1, prev_grad, loss_grad, history, all_updates, n_users, n_attacker, epoch_num):
        lambda1 *= 2  # Exponentially increase lambda
    return lambda1


def projection(prev_grad, loss_grad, history, all_updates, n_users, n_attacker, epoch_num):
    updates_abs_mean = all_updates.abs().mean(dim=1, keepdim=True)
    median_value = torch.median(updates_abs_mean).item()

    ####
    history_updates = history.clone().detach()
    history_updates[:, epoch_num] = updates_abs_mean.mean(dim=1, keepdim=True).squeeze()
    ####

    loss_grad = loss_grad.to(device)
    prev_grad = prev_grad.to(device)

    lambda_low = median_value/(prev_grad + loss_grad).abs().mean().item()
    lambda_high = find_upper_bound(lambda_low, prev_grad, loss_grad, history_updates, all_updates, n_users, n_attacker, epoch_num)
    if lambda_high < lambda_low:
        lambda_high = lambda_low
        print("SHOULD NEVER REACH THIS LINE")
        print('lambda_low: ', lambda_low, ' lambda_high: ', lambda_high)
    tolerance = 1e-6

    iterations_count = 0
    while lambda_high - lambda_low > tolerance and iterations_count < 10:
        lambda_mid = (lambda_low + lambda_high) / 2
        if check_condition(lambda_mid, prev_grad, loss_grad, history_updates, all_updates, n_users, n_attacker, epoch_num):
            lambda_low = lambda_mid
        else:
            lambda_high = lambda_mid
        iterations_count += 1

    lambda1 = lambda_low

    return lambda1 * (prev_grad + loss_grad)

def our_attack_mean(n_user, epoch_num, history_updates, all_updates, model_params, n_attacker, arch, criterion, user_train_data_tensors, user_train_label_tensors):
    attacker_tr_data_tensor = user_train_data_tensors[0].cuda()
    attacker_tr_label_tensor = user_train_label_tensors[0].cuda()

    fed_model, _ = return_model(arch, 0.1, 0.9, parallel=False)
    fed_model.eval()  # Ensure the model is in evaluation mode

    new_grad = -all_updates[0].clone().detach().requires_grad_(True)
    prev_grad = np.zeros(len(new_grad))
    new_grad = projection(torch.from_numpy(prev_grad), new_grad, history_updates, all_updates, n_user, n_attacker, epoch_num)

    for _ in range(1):
        outputs = fed_model(attacker_tr_data_tensor)
        loss = criterion(outputs, attacker_tr_label_tensor)

        loss.backward(retain_graph=True)
        param_grad = []
        for param in fed_model.parameters():
            param_grad.append(param.grad.view(-1).detach())

        param_grad = torch.cat(param_grad)
        prev_grad = new_grad
        new_grad = projection(prev_grad, param_grad, history_updates, all_updates, n_user, n_attacker, epoch_num)

        difference = torch.mean(torch.abs(new_grad - prev_grad)).item()
        if difference < 1e-6:
            # print("STOPPED! Difference is too small, stop finding best attack grad")
            break

        fed_model.zero_grad()

    result_attacker_grads = [new_grad.clone().detach() for _ in range(10)]
    return torch.stack(result_attacker_grads).cuda()

# %% [markdown]
# ### our attack (10 attacker) + our defense

# %%
batch_size=250
resume=0

schedule=[1000]

gamma=.5
opt = 'sgd'
fed_lr=0.5
criterion=nn.CrossEntropyLoss()
use_cuda = torch.cuda.is_available()

aggregation='bulyan'
multi_k = False
candidates = []

at_type='our-agr'
dev_type ='std'
n_attackers=[10]

arch='alexnet'
chkpt='./'+aggregation

past_mean = []
past_abs_sum = []
past_median = []
past_lower_quartile = []
past_upper_quartile = []
past_std = []

title = "our attack (10 attacker) + our defense"

for n_attacker in n_attackers:
    epoch_num = 0
    best_global_acc = 0
    best_global_te_acc = 0

    torch.cuda.empty_cache()

    fed_model, _ = return_model(arch, 0.1, 0.9, parallel=False)
    optimizer_fed = SGD(fed_model.parameters(), lr=fed_lr)

    df = pd.DataFrame(columns = ['epoch', 'loss', 'validation accuracy', 'best validation accuracy'])

    ####
    history = torch.zeros((n_users, nepochs + 1), dtype=torch.float32).cuda()
    ####

    model_grads = []
    flag = False
    while epoch_num <= nepochs:
        user_grads=[]

        for i in range(n_users): # 50
            nbatches = user_tr_len[i]//batch_size

            inputs = user_train_data_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]
            targets = user_train_label_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]

            targets = targets.type(torch.LongTensor)

            inputs, targets = inputs.cuda(), targets.cuda()
            inputs, targets = torch.autograd.Variable(inputs), torch.autograd.Variable(targets)

            outputs = fed_model(inputs)
            loss = criterion(outputs, targets)
            fed_model.zero_grad()
            loss.backward(retain_graph=True)

            param_grad=[]
            for param in fed_model.parameters():
                param_grad=param.grad.data.view(-1) if not len(param_grad) else torch.cat((param_grad,param.grad.view(-1)))


            user_grads=param_grad[None, :] if len(user_grads)==0 else torch.cat((user_grads,param_grad[None,:]), 0)

        if epoch_num in schedule:
            for param_group in optimizer_fed.param_groups:
                param_group['lr'] *= gamma
                print('New learnin rate ', param_group['lr'])

        updates_abs_mean = user_grads.abs().mean(dim=1, keepdim=True)

        if n_attacker > 0:
            model_params = torch.cat([p.data.view(-1) for p in fed_model.parameters()])
            mal_updates = our_attack_mean(n_users, epoch_num, history, user_grads, model_params, n_attacker, arch, criterion, user_train_data_tensors, user_train_label_tensors)
            malicious_grads = torch.cat((mal_updates, user_grads[n_attacker:]), 0) # torch.Size([50, 2472266])


        if not (malicious_grads.shape[0]==50):
            print(malicious_grads.shape)

        updates_abs_mean = malicious_grads.abs().mean(dim=1, keepdim=True)

        history[:, epoch_num] = updates_abs_mean.squeeze()
        agg_grads = our_mean_defense(malicious_grads, n_attacker, history)

        del user_grads

        start_idx=0

        optimizer_fed.zero_grad()

        model_grads=[]

        for i, param in enumerate(fed_model.parameters()):
            param_=agg_grads[start_idx:start_idx+len(param.data.view(-1))].reshape(param.data.shape)
            start_idx=start_idx+len(param.data.view(-1))
            param_=param_.cuda()
            model_grads.append(param_)

        optimizer_fed.step(model_grads)

        val_loss, val_acc = test(val_data_tensor,val_label_tensor,fed_model,criterion, use_cuda)
        te_loss, te_acc = test(te_data_tensor,te_label_tensor, fed_model, criterion, use_cuda)

        is_best = best_global_acc < val_acc

        best_global_acc = max(best_global_acc, val_acc)

        if is_best:
            best_global_te_acc = te_acc


        print('epoch: %d, %s: at %s n_at %d e %d | val loss %.4f val acc %.4f best val_acc %f'%(epoch_num, aggregation, at_type, n_attacker, epoch_num, val_loss, val_acc, best_global_acc))
        new_row = pd.DataFrame([{
            'epoch': epoch_num,
            'loss': val_loss,
            'validation accuracy': val_acc,
            'best validation accuracy': best_global_acc
            }])
        df = pd.concat([df, new_row], ignore_index=True)
        df.to_csv(f'{title}.csv', index=False)

        if val_loss > 1000:
            print('val loss %f too high'%val_loss)
            break

        epoch_num+=1
# Out:
# discarded index [34, 20, 37, 24, 33, 28, 11, 49, 25, 43]
# epoch: 0, bulyan: at our-agr n_at 10 e 0 | val loss 2.3030 val acc 9.8620 best val_acc 9.862013
# c:\Users\Hizan\Desktop\CPEN497-FL\attack-defense\sgd.py:109: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\python_arg_parser.cpp:1630.)
#   p.data.add_(-group['lr'], d_p)
# C:\Users\Hizan\AppData\Local\Temp\ipykernel_12080\3893755665.py:131: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, new_row], ignore_index=True)
# discarded index [34, 20, 37, 24, 28, 33, 25, 43, 11, 49]
# epoch: 1, bulyan: at our-agr n_at 10 e 1 | val loss 2.3030 val acc 9.8620 best val_acc 9.862013
# discarded index [34, 20, 45, 47, 37, 24, 0, 1, 2, 3]
# epoch: 2, bulyan: at our-agr n_at 10 e 2 | val loss 2.3030 val acc 9.8620 best val_acc 9.862013
# discarded index [34, 20, 47, 45, 24, 37, 25, 43, 28, 33]
# epoch: 3, bulyan: at our-agr n_at 10 e 3 | val loss 2.3034 val acc 11.3231 best val_acc 11.323052
# discarded index [20, 34, 45, 47, 37, 24, 49, 25, 43, 28]
# epoch: 4, bulyan: at our-agr n_at 10 e 4 | val loss 2.3038 val acc 12.8653 best val_acc 12.865260
# discarded index [34, 20, 47, 45, 24, 37, 25, 43, 49, 28]
# epoch: 5, bulyan: at our-agr n_at 10 e 5 | val loss 2.3043 val acc 12.5609 best val_acc 12.865260
# discarded index [20, 34, 47, 45, 37, 24, 49, 25, 43, 33]
# epoch: 6, bulyan: at our-agr n_at 10 e 6 | val loss 2.3048 val acc 13.2914 best val_acc 13.291396
# discarded index [20, 34, 47, 45, 24, 37, 43, 25, 49, 33]
# epoch: 7, bulyan: at our-agr n_at 10 e 7 | val loss 2.3057 val acc 13.4740 best val_acc 13.474026
# discarded index [20, 34, 47, 45, 24, 37, 43, 25, 49, 33]
# epoch: 8, bulyan: at our-agr n_at 10 e 8 | val loss 2.3065 val acc 12.7841 best val_acc 13.474026
# discarded index [20, 34, 47, 45, 24, 43, 49, 37, 25, 33]
# epoch: 9, bulyan: at our-agr n_at 10 e 9 | val loss 2.3078 val acc 12.6218 best val_acc 13.474026
# discarded index [20, 47, 34, 45, 24, 49, 43, 33, 37, 25]
# epoch: 10, bulyan: at our-agr n_at 10 e 10 | val loss 2.3095 val acc 12.6826 best val_acc 13.474026
# discarded index [20, 47, 45, 34, 43, 49, 24, 11, 33, 32]
# epoch: 11, bulyan: at our-agr n_at 10 e 11 | val loss 2.3118 val acc 11.0390 best val_acc 13.474026
# discarded index [20, 47, 45, 34, 43, 49, 24, 33, 11, 32]
# epoch: 12, bulyan: at our-agr n_at 10 e 12 | val loss 2.3162 val acc 10.0649 best val_acc 13.474026
# discarded index [20, 47, 45, 34, 43, 49, 40, 33, 32, 11]
# epoch: 13, bulyan: at our-agr n_at 10 e 13 | val loss 2.3212 val acc 12.3985 best val_acc 13.474026
# discarded index [20, 47, 45, 34, 49, 43, 11, 32, 40, 33]
# epoch: 14, bulyan: at our-agr n_at 10 e 14 | val loss 2.3297 val acc 12.1347 best val_acc 13.474026
# discarded index [20, 47, 45, 34, 22, 49, 11, 43, 44, 32]
# epoch: 15, bulyan: at our-agr n_at 10 e 15 | val loss 2.3383 val acc 14.6104 best val_acc 14.610390
# discarded index [20, 47, 45, 34, 49, 11, 22, 43, 44, 32]
# epoch: 16, bulyan: at our-agr n_at 10 e 16 | val loss 2.3547 val acc 12.2768 best val_acc 14.610390
# discarded index [20, 47, 45, 34, 49, 11, 43, 44, 22, 31]
# epoch: 17, bulyan: at our-agr n_at 10 e 17 | val loss 2.3585 val acc 11.0795 best val_acc 14.610390
# discarded index [20, 47, 45, 22, 34, 11, 31, 10, 49, 37]
# epoch: 18, bulyan: at our-agr n_at 10 e 18 | val loss 2.3881 val acc 9.8011 best val_acc 14.610390
# discarded index [20, 47, 45, 34, 22, 10, 31, 11, 37, 49]
# epoch: 19, bulyan: at our-agr n_at 10 e 19 | val loss 2.3941 val acc 10.0244 best val_acc 14.610390
# discarded index [20, 47, 45, 31, 10, 22, 11, 34, 49, 37]
# epoch: 20, bulyan: at our-agr n_at 10 e 20 | val loss 2.4584 val acc 9.8011 best val_acc 14.610390
# discarded index [20, 47, 45, 31, 10, 22, 37, 11, 34, 16]
# epoch: 21, bulyan: at our-agr n_at 10 e 21 | val loss 2.4207 val acc 12.2362 best val_acc 14.610390
# discarded index [20, 47, 45, 10, 31, 22, 37, 11, 16, 34]
# epoch: 22, bulyan: at our-agr n_at 10 e 22 | val loss 2.4237 val acc 10.0244 best val_acc 14.610390
# discarded index [20, 47, 45, 31, 10, 22, 37, 11, 16, 34]
# epoch: 23, bulyan: at our-agr n_at 10 e 23 | val loss 2.4387 val acc 14.5901 best val_acc 14.610390
# discarded index [20, 47, 45, 10, 31, 22, 37, 11, 16, 28]
# epoch: 24, bulyan: at our-agr n_at 10 e 24 | val loss 2.4709 val acc 9.8214 best val_acc 14.610390
# discarded index [20, 47, 45, 31, 10, 22, 37, 16, 11, 24]
# epoch: 25, bulyan: at our-agr n_at 10 e 25 | val loss 2.4564 val acc 10.2881 best val_acc 14.610390
# discarded index [20, 47, 45, 10, 31, 37, 22, 11, 16, 28]
# epoch: 26, bulyan: at our-agr n_at 10 e 26 | val loss 2.5190 val acc 9.8214 best val_acc 14.610390
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 11, 13]
# epoch: 27, bulyan: at our-agr n_at 10 e 27 | val loss 2.4734 val acc 12.5406 best val_acc 14.610390
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 11, 13]
# epoch: 28, bulyan: at our-agr n_at 10 e 28 | val loss 2.4105 val acc 12.2565 best val_acc 14.610390
# discarded index [20, 47, 45, 10, 31, 37, 22, 11, 27, 13]
# epoch: 29, bulyan: at our-agr n_at 10 e 29 | val loss 2.3858 val acc 16.0511 best val_acc 16.051136
# discarded index [20, 47, 45, 10, 31, 37, 22, 11, 27, 0]
# epoch: 30, bulyan: at our-agr n_at 10 e 30 | val loss 2.3225 val acc 16.6396 best val_acc 16.639610
# discarded index [20, 47, 45, 10, 31, 37, 22, 11, 27, 16]
# epoch: 31, bulyan: at our-agr n_at 10 e 31 | val loss 2.3797 val acc 11.7086 best val_acc 16.639610
# discarded index [20, 47, 45, 10, 31, 37, 22, 11, 27, 49]
# epoch: 32, bulyan: at our-agr n_at 10 e 32 | val loss 2.3947 val acc 14.8539 best val_acc 16.639610
# discarded index [20, 47, 45, 10, 31, 37, 22, 16, 24, 0]
# epoch: 33, bulyan: at our-agr n_at 10 e 33 | val loss 2.3165 val acc 18.6688 best val_acc 18.668831
# discarded index [20, 47, 45, 10, 31, 37, 22, 11, 16, 24]
# epoch: 34, bulyan: at our-agr n_at 10 e 34 | val loss 2.6126 val acc 10.4302 best val_acc 18.668831
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 13, 11]
# epoch: 35, bulyan: at our-agr n_at 10 e 35 | val loss 2.4056 val acc 11.4042 best val_acc 18.668831
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 13, 11]
# epoch: 36, bulyan: at our-agr n_at 10 e 36 | val loss 2.3709 val acc 17.8571 best val_acc 18.668831
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 13, 11]
# epoch: 37, bulyan: at our-agr n_at 10 e 37 | val loss 2.3488 val acc 13.1291 best val_acc 18.668831
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 0, 1]
# epoch: 38, bulyan: at our-agr n_at 10 e 38 | val loss 2.2818 val acc 20.2110 best val_acc 20.211039
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 24, 0]
# epoch: 39, bulyan: at our-agr n_at 10 e 39 | val loss 2.3068 val acc 19.5617 best val_acc 20.211039
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 24, 16]
# epoch: 40, bulyan: at our-agr n_at 10 e 40 | val loss 2.3942 val acc 18.3442 best val_acc 20.211039
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 49, 11]
# epoch: 41, bulyan: at our-agr n_at 10 e 41 | val loss 2.3673 val acc 23.0114 best val_acc 23.011364
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 11, 49]
# epoch: 42, bulyan: at our-agr n_at 10 e 42 | val loss 2.5644 val acc 15.2800 best val_acc 23.011364
# discarded index [20, 47, 45, 10, 31, 37, 27, 22, 13, 49]
# epoch: 43, bulyan: at our-agr n_at 10 e 43 | val loss 2.4962 val acc 9.9026 best val_acc 23.011364
# discarded index [20, 47, 45, 10, 31, 37, 27, 13, 22, 49]
# epoch: 44, bulyan: at our-agr n_at 10 e 44 | val loss 2.3224 val acc 16.7614 best val_acc 23.011364
# discarded index [20, 47, 45, 10, 31, 37, 27, 13, 22, 49]
# epoch: 45, bulyan: at our-agr n_at 10 e 45 | val loss 2.3685 val acc 12.4594 best val_acc 23.011364
# discarded index [20, 47, 45, 10, 31, 37, 27, 22, 13, 49]
# epoch: 46, bulyan: at our-agr n_at 10 e 46 | val loss 2.3420 val acc 17.0049 best val_acc 23.011364
# discarded index [20, 47, 45, 10, 31, 37, 27, 22, 13, 49]
# epoch: 47, bulyan: at our-agr n_at 10 e 47 | val loss 2.3833 val acc 14.0625 best val_acc 23.011364
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 13, 11]
# epoch: 48, bulyan: at our-agr n_at 10 e 48 | val loss 2.3396 val acc 21.8141 best val_acc 23.011364
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 13, 11]
# epoch: 49, bulyan: at our-agr n_at 10 e 49 | val loss 2.5113 val acc 14.1437 best val_acc 23.011364
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 13, 49]
# epoch: 50, bulyan: at our-agr n_at 10 e 50 | val loss 2.4014 val acc 19.0950 best val_acc 23.011364
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 13, 49]
# epoch: 51, bulyan: at our-agr n_at 10 e 51 | val loss 2.3281 val acc 21.7735 best val_acc 23.011364
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 13, 49]
# epoch: 52, bulyan: at our-agr n_at 10 e 52 | val loss 2.4441 val acc 23.3766 best val_acc 23.376623
# discarded index [20, 47, 45, 10, 31, 37, 27, 22, 13, 49]
# epoch: 53, bulyan: at our-agr n_at 10 e 53 | val loss 2.2742 val acc 22.4635 best val_acc 23.376623
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 13, 49]
# epoch: 54, bulyan: at our-agr n_at 10 e 54 | val loss 2.6849 val acc 18.9529 best val_acc 23.376623
# discarded index [20, 47, 45, 10, 31, 37, 27, 22, 13, 49]
# epoch: 55, bulyan: at our-agr n_at 10 e 55 | val loss 2.5118 val acc 11.4042 best val_acc 23.376623
# discarded index [20, 47, 45, 10, 31, 37, 27, 22, 26, 13]
# epoch: 56, bulyan: at our-agr n_at 10 e 56 | val loss 2.3189 val acc 17.1469 best val_acc 23.376623
# discarded index [20, 47, 45, 10, 31, 37, 27, 22, 26, 13]
# epoch: 57, bulyan: at our-agr n_at 10 e 57 | val loss 2.3342 val acc 18.5471 best val_acc 23.376623
# discarded index [20, 47, 45, 10, 31, 37, 27, 22, 13, 26]
# epoch: 58, bulyan: at our-agr n_at 10 e 58 | val loss 2.2979 val acc 17.3093 best val_acc 23.376623
# discarded index [20, 47, 45, 10, 31, 37, 27, 22, 13, 26]
# epoch: 59, bulyan: at our-agr n_at 10 e 59 | val loss 2.2493 val acc 18.5268 best val_acc 23.376623
# discarded index [20, 47, 45, 10, 31, 37, 27, 22, 26, 13]
# epoch: 60, bulyan: at our-agr n_at 10 e 60 | val loss 2.3134 val acc 19.1964 best val_acc 23.376623
# discarded index [20, 47, 45, 10, 31, 37, 27, 22, 13, 26]
# epoch: 61, bulyan: at our-agr n_at 10 e 61 | val loss 2.2191 val acc 21.1445 best val_acc 23.376623
# discarded index [20, 47, 45, 10, 31, 37, 27, 22, 13, 26]
# epoch: 62, bulyan: at our-agr n_at 10 e 62 | val loss 2.4106 val acc 17.1063 best val_acc 23.376623
# discarded index [20, 47, 45, 10, 31, 37, 27, 22, 13, 21]
# epoch: 63, bulyan: at our-agr n_at 10 e 63 | val loss 2.2602 val acc 13.9002 best val_acc 23.376623
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 13, 21]
# epoch: 64, bulyan: at our-agr n_at 10 e 64 | val loss 2.2612 val acc 18.2224 best val_acc 23.376623
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 13, 21]
# epoch: 65, bulyan: at our-agr n_at 10 e 65 | val loss 2.1993 val acc 21.5909 best val_acc 23.376623
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 13, 49]
# epoch: 66, bulyan: at our-agr n_at 10 e 66 | val loss 2.4013 val acc 19.4399 best val_acc 23.376623
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 13, 21]
# epoch: 67, bulyan: at our-agr n_at 10 e 67 | val loss 2.3495 val acc 18.9326 best val_acc 23.376623
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 13, 49]
# epoch: 68, bulyan: at our-agr n_at 10 e 68 | val loss 2.3631 val acc 18.6688 best val_acc 23.376623
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 13, 49]
# epoch: 69, bulyan: at our-agr n_at 10 e 69 | val loss 2.2417 val acc 21.2459 best val_acc 23.376623
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 13, 49]
# epoch: 70, bulyan: at our-agr n_at 10 e 70 | val loss 2.1826 val acc 24.3101 best val_acc 24.310065
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 13, 49]
# epoch: 71, bulyan: at our-agr n_at 10 e 71 | val loss 2.2662 val acc 19.9067 best val_acc 24.310065
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 13, 49]
# epoch: 72, bulyan: at our-agr n_at 10 e 72 | val loss 2.2429 val acc 16.2338 best val_acc 24.310065
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 13, 49]
# epoch: 73, bulyan: at our-agr n_at 10 e 73 | val loss 2.8136 val acc 16.4367 best val_acc 24.310065
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 21, 49]
# epoch: 74, bulyan: at our-agr n_at 10 e 74 | val loss 2.3009 val acc 12.8247 best val_acc 24.310065
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 21, 49]
# epoch: 75, bulyan: at our-agr n_at 10 e 75 | val loss 2.2498 val acc 18.7297 best val_acc 24.310065
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 21, 49]
# epoch: 76, bulyan: at our-agr n_at 10 e 76 | val loss 2.4592 val acc 17.4107 best val_acc 24.310065
# discarded index [20, 47, 45, 10, 31, 37, 27, 22, 21, 49]
# epoch: 77, bulyan: at our-agr n_at 10 e 77 | val loss 2.2053 val acc 17.3498 best val_acc 24.310065
# discarded index [20, 47, 45, 10, 31, 37, 27, 22, 21, 49]
# epoch: 78, bulyan: at our-agr n_at 10 e 78 | val loss 2.3394 val acc 21.0227 best val_acc 24.310065
# discarded index [20, 47, 45, 10, 31, 37, 27, 22, 21, 49]
# epoch: 79, bulyan: at our-agr n_at 10 e 79 | val loss 2.2203 val acc 22.2808 best val_acc 24.310065
# discarded index [20, 47, 45, 10, 31, 37, 27, 22, 21, 49]
# epoch: 80, bulyan: at our-agr n_at 10 e 80 | val loss 2.4438 val acc 22.7679 best val_acc 24.310065
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 0, 1]
# epoch: 81, bulyan: at our-agr n_at 10 e 81 | val loss 2.2365 val acc 19.5414 best val_acc 24.310065
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 0, 1]
# epoch: 82, bulyan: at our-agr n_at 10 e 82 | val loss 2.1998 val acc 20.0081 best val_acc 24.310065
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 21, 49]
# epoch: 83, bulyan: at our-agr n_at 10 e 83 | val loss 2.1351 val acc 18.2427 best val_acc 24.310065
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 21, 49]
# epoch: 84, bulyan: at our-agr n_at 10 e 84 | val loss 2.1841 val acc 24.5739 best val_acc 24.573864
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 21, 49]
# epoch: 85, bulyan: at our-agr n_at 10 e 85 | val loss 2.1127 val acc 23.4781 best val_acc 24.573864
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 21, 49]
# epoch: 86, bulyan: at our-agr n_at 10 e 86 | val loss 2.4468 val acc 19.7037 best val_acc 24.573864
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 21, 35]
# epoch: 87, bulyan: at our-agr n_at 10 e 87 | val loss 2.8221 val acc 12.3377 best val_acc 24.573864
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 21, 35]
# epoch: 88, bulyan: at our-agr n_at 10 e 88 | val loss 2.3275 val acc 19.6023 best val_acc 24.573864
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 21, 35]
# epoch: 89, bulyan: at our-agr n_at 10 e 89 | val loss 2.4949 val acc 15.2800 best val_acc 24.573864
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 21, 18]
# epoch: 90, bulyan: at our-agr n_at 10 e 90 | val loss 2.2932 val acc 17.2078 best val_acc 24.573864
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 21, 18]
# epoch: 91, bulyan: at our-agr n_at 10 e 91 | val loss 2.4222 val acc 17.0252 best val_acc 24.573864
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 21, 18]
# epoch: 92, bulyan: at our-agr n_at 10 e 92 | val loss 2.2530 val acc 18.2224 best val_acc 24.573864
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 21, 18]
# epoch: 93, bulyan: at our-agr n_at 10 e 93 | val loss 2.2283 val acc 18.6485 best val_acc 24.573864
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 0, 1]
# epoch: 94, bulyan: at our-agr n_at 10 e 94 | val loss 2.1156 val acc 19.5820 best val_acc 24.573864
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 21, 18]
# epoch: 95, bulyan: at our-agr n_at 10 e 95 | val loss 2.2108 val acc 21.4894 best val_acc 24.573864
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 21, 35]
# epoch: 96, bulyan: at our-agr n_at 10 e 96 | val loss 2.1650 val acc 19.4602 best val_acc 24.573864
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 21, 18]
# epoch: 97, bulyan: at our-agr n_at 10 e 97 | val loss 2.6142 val acc 17.7963 best val_acc 24.573864
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 21, 18]
# epoch: 98, bulyan: at our-agr n_at 10 e 98 | val loss 2.4664 val acc 12.4391 best val_acc 24.573864
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 21, 18]
# epoch: 99, bulyan: at our-agr n_at 10 e 99 | val loss 2.3053 val acc 16.3555 best val_acc 24.573864
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 0, 1]
# epoch: 100, bulyan: at our-agr n_at 10 e 100 | val loss 2.2700 val acc 23.0114 best val_acc 24.573864
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 21, 18]
# epoch: 101, bulyan: at our-agr n_at 10 e 101 | val loss 2.1736 val acc 25.4261 best val_acc 25.426136
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 0, 1]
# epoch: 102, bulyan: at our-agr n_at 10 e 102 | val loss 2.0392 val acc 25.8726 best val_acc 25.872565
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 21, 35]
# epoch: 103, bulyan: at our-agr n_at 10 e 103 | val loss 2.4059 val acc 26.1567 best val_acc 26.156656
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 21, 18]
# epoch: 104, bulyan: at our-agr n_at 10 e 104 | val loss 2.1025 val acc 22.5852 best val_acc 26.156656
# discarded index [20, 47, 45, 10, 31, 37, 22, 27, 21, 18]
# epoch: 105, bulyan: at our-agr n_at 10 e 105 | val loss 2.6364 val acc 22.1591 best val_acc 26.156656
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 21]
# epoch: 106, bulyan: at our-agr n_at 10 e 106 | val loss 2.5448 val acc 12.7435 best val_acc 26.156656
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 21]
# epoch: 107, bulyan: at our-agr n_at 10 e 107 | val loss 2.1974 val acc 18.2833 best val_acc 26.156656
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 21]
# epoch: 108, bulyan: at our-agr n_at 10 e 108 | val loss 2.2215 val acc 20.2110 best val_acc 26.156656
# discarded index [20, 47, 45, 10, 31, 37, 27, 22, 18, 21]
# epoch: 109, bulyan: at our-agr n_at 10 e 109 | val loss 2.0836 val acc 23.4172 best val_acc 26.156656
# discarded index [20, 47, 45, 10, 31, 37, 27, 22, 18, 21]
# epoch: 110, bulyan: at our-agr n_at 10 e 110 | val loss 2.9755 val acc 19.1153 best val_acc 26.156656
# discarded index [20, 47, 45, 10, 31, 37, 27, 18, 35, 21]
# epoch: 111, bulyan: at our-agr n_at 10 e 111 | val loss 2.4111 val acc 18.1006 best val_acc 26.156656
# discarded index [20, 47, 45, 31, 10, 37, 27, 18, 35, 21]
# epoch: 112, bulyan: at our-agr n_at 10 e 112 | val loss 2.2507 val acc 20.1705 best val_acc 26.156656
# discarded index [20, 47, 45, 31, 10, 37, 27, 18, 35, 21]
# epoch: 113, bulyan: at our-agr n_at 10 e 113 | val loss 2.2387 val acc 23.2955 best val_acc 26.156656
# discarded index [20, 47, 45, 31, 10, 37, 27, 18, 35, 21]
# epoch: 114, bulyan: at our-agr n_at 10 e 114 | val loss 2.1502 val acc 24.3912 best val_acc 26.156656
# discarded index [20, 47, 45, 31, 10, 37, 27, 18, 35, 21]
# epoch: 115, bulyan: at our-agr n_at 10 e 115 | val loss 2.1981 val acc 26.6437 best val_acc 26.643669
# discarded index [20, 47, 45, 31, 10, 37, 0, 1, 2, 3]
# epoch: 116, bulyan: at our-agr n_at 10 e 116 | val loss 2.0589 val acc 25.5682 best val_acc 26.643669
# discarded index [20, 47, 45, 31, 10, 37, 27, 18, 35, 21]
# epoch: 117, bulyan: at our-agr n_at 10 e 117 | val loss 2.2902 val acc 25.1826 best val_acc 26.643669
# discarded index [20, 47, 45, 31, 10, 37, 22, 0, 1, 2]
# epoch: 118, bulyan: at our-agr n_at 10 e 118 | val loss 2.1757 val acc 19.8458 best val_acc 26.643669
# discarded index [20, 47, 45, 31, 10, 37, 22, 0, 1, 2]
# epoch: 119, bulyan: at our-agr n_at 10 e 119 | val loss 2.5021 val acc 23.2955 best val_acc 26.643669
# discarded index [20, 47, 45, 31, 10, 37, 22, 0, 1, 2]
# epoch: 120, bulyan: at our-agr n_at 10 e 120 | val loss 2.4450 val acc 17.3701 best val_acc 26.643669
# discarded index [20, 47, 45, 31, 10, 37, 22, 0, 1, 2]
# epoch: 121, bulyan: at our-agr n_at 10 e 121 | val loss 2.1777 val acc 21.6721 best val_acc 26.643669
# discarded index [20, 47, 45, 31, 10, 37, 22, 0, 1, 2]
# epoch: 122, bulyan: at our-agr n_at 10 e 122 | val loss 2.2822 val acc 21.0633 best val_acc 26.643669
# discarded index [20, 47, 45, 31, 10, 37, 22, 0, 1, 2]
# epoch: 123, bulyan: at our-agr n_at 10 e 123 | val loss 2.1936 val acc 20.8198 best val_acc 26.643669
# discarded index [20, 47, 45, 31, 10, 37, 22, 0, 1, 2]
# epoch: 124, bulyan: at our-agr n_at 10 e 124 | val loss 2.1888 val acc 24.5739 best val_acc 26.643669
# discarded index [20, 47, 45, 31, 10, 37, 22, 0, 1, 2]
# epoch: 125, bulyan: at our-agr n_at 10 e 125 | val loss 2.0683 val acc 21.0430 best val_acc 26.643669
# discarded index [20, 47, 45, 31, 10, 37, 22, 0, 1, 2]
# epoch: 126, bulyan: at our-agr n_at 10 e 126 | val loss 2.0666 val acc 25.7305 best val_acc 26.643669
# discarded index [20, 47, 45, 31, 10, 37, 22, 0, 1, 2]
# epoch: 127, bulyan: at our-agr n_at 10 e 127 | val loss 1.9577 val acc 25.6899 best val_acc 26.643669
# discarded index [20, 47, 45, 31, 10, 37, 22, 0, 1, 2]
# epoch: 128, bulyan: at our-agr n_at 10 e 128 | val loss 2.2246 val acc 25.2232 best val_acc 26.643669
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 129, bulyan: at our-agr n_at 10 e 129 | val loss 2.3105 val acc 20.7792 best val_acc 26.643669
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 130, bulyan: at our-agr n_at 10 e 130 | val loss 2.2857 val acc 19.3994 best val_acc 26.643669
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 131, bulyan: at our-agr n_at 10 e 131 | val loss 2.0710 val acc 22.6664 best val_acc 26.643669
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 132, bulyan: at our-agr n_at 10 e 132 | val loss 2.1334 val acc 27.2727 best val_acc 27.272727
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 133, bulyan: at our-agr n_at 10 e 133 | val loss 2.0078 val acc 26.9886 best val_acc 27.272727
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 134, bulyan: at our-agr n_at 10 e 134 | val loss 1.9940 val acc 29.9107 best val_acc 29.910714
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 135, bulyan: at our-agr n_at 10 e 135 | val loss 2.1175 val acc 28.2670 best val_acc 29.910714
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 136, bulyan: at our-agr n_at 10 e 136 | val loss 2.0817 val acc 26.1567 best val_acc 29.910714
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 137, bulyan: at our-agr n_at 10 e 137 | val loss 2.5333 val acc 23.5593 best val_acc 29.910714
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 21]
# epoch: 138, bulyan: at our-agr n_at 10 e 138 | val loss 2.4822 val acc 14.5698 best val_acc 29.910714
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 21]
# epoch: 139, bulyan: at our-agr n_at 10 e 139 | val loss 2.2383 val acc 20.7183 best val_acc 29.910714
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 21]
# epoch: 140, bulyan: at our-agr n_at 10 e 140 | val loss 2.1295 val acc 27.0089 best val_acc 29.910714
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 21]
# epoch: 141, bulyan: at our-agr n_at 10 e 141 | val loss 2.0864 val acc 27.1713 best val_acc 29.910714
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 21]
# epoch: 142, bulyan: at our-agr n_at 10 e 142 | val loss 2.0704 val acc 27.6989 best val_acc 29.910714
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 21]
# epoch: 143, bulyan: at our-agr n_at 10 e 143 | val loss 1.9768 val acc 28.2062 best val_acc 29.910714
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 21]
# epoch: 144, bulyan: at our-agr n_at 10 e 144 | val loss 2.2690 val acc 29.4237 best val_acc 29.910714
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 145, bulyan: at our-agr n_at 10 e 145 | val loss 1.9999 val acc 25.1623 best val_acc 29.910714
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 146, bulyan: at our-agr n_at 10 e 146 | val loss 2.6392 val acc 30.2963 best val_acc 30.296266
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 147, bulyan: at our-agr n_at 10 e 147 | val loss 2.1720 val acc 18.6485 best val_acc 30.296266
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 148, bulyan: at our-agr n_at 10 e 148 | val loss 2.2600 val acc 26.4610 best val_acc 30.296266
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 149, bulyan: at our-agr n_at 10 e 149 | val loss 2.3904 val acc 19.9472 best val_acc 30.296266
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 150, bulyan: at our-agr n_at 10 e 150 | val loss 2.2040 val acc 23.9245 best val_acc 30.296266
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 151, bulyan: at our-agr n_at 10 e 151 | val loss 2.1042 val acc 27.1916 best val_acc 30.296266
# discarded index [20, 47, 45, 31, 10, 37, 22, 0, 1, 2]
# epoch: 152, bulyan: at our-agr n_at 10 e 152 | val loss 1.9935 val acc 26.6031 best val_acc 30.296266
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 153, bulyan: at our-agr n_at 10 e 153 | val loss 2.6625 val acc 27.4554 best val_acc 30.296266
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 154, bulyan: at our-agr n_at 10 e 154 | val loss 2.2990 val acc 23.2143 best val_acc 30.296266
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 155, bulyan: at our-agr n_at 10 e 155 | val loss 2.0345 val acc 29.5455 best val_acc 30.296266
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 156, bulyan: at our-agr n_at 10 e 156 | val loss 2.0813 val acc 31.4123 best val_acc 31.412338
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 157, bulyan: at our-agr n_at 10 e 157 | val loss 2.1398 val acc 30.3977 best val_acc 31.412338
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 158, bulyan: at our-agr n_at 10 e 158 | val loss 2.2946 val acc 24.2289 best val_acc 31.412338
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 159, bulyan: at our-agr n_at 10 e 159 | val loss 2.3623 val acc 26.0958 best val_acc 31.412338
# discarded index [20, 47, 45, 31, 10, 37, 27, 18, 35, 21]
# epoch: 160, bulyan: at our-agr n_at 10 e 160 | val loss 2.6681 val acc 28.4091 best val_acc 31.412338
# discarded index [20, 47, 45, 31, 10, 37, 27, 18, 35, 21]
# epoch: 161, bulyan: at our-agr n_at 10 e 161 | val loss 2.1471 val acc 22.6258 best val_acc 31.412338
# discarded index [20, 47, 45, 31, 10, 37, 27, 18, 35, 21]
# epoch: 162, bulyan: at our-agr n_at 10 e 162 | val loss 2.7151 val acc 27.0698 best val_acc 31.412338
# discarded index [20, 47, 45, 31, 10, 37, 27, 18, 35, 21]
# epoch: 163, bulyan: at our-agr n_at 10 e 163 | val loss 2.1635 val acc 27.8612 best val_acc 31.412338
# discarded index [20, 47, 45, 31, 10, 37, 27, 18, 35, 21]
# epoch: 164, bulyan: at our-agr n_at 10 e 164 | val loss 2.0742 val acc 30.6615 best val_acc 31.412338
# discarded index [20, 47, 45, 31, 10, 37, 27, 18, 35, 21]
# epoch: 165, bulyan: at our-agr n_at 10 e 165 | val loss 2.0939 val acc 30.8036 best val_acc 31.412338
# discarded index [20, 47, 45, 31, 10, 37, 27, 18, 35, 21]
# epoch: 166, bulyan: at our-agr n_at 10 e 166 | val loss 2.0859 val acc 29.8093 best val_acc 31.412338
# discarded index [20, 47, 45, 31, 10, 37, 27, 18, 35, 21]
# epoch: 167, bulyan: at our-agr n_at 10 e 167 | val loss 2.2138 val acc 25.1826 best val_acc 31.412338
# discarded index [20, 47, 45, 31, 10, 37, 27, 18, 35, 21]
# epoch: 168, bulyan: at our-agr n_at 10 e 168 | val loss 2.0858 val acc 30.8644 best val_acc 31.412338
# discarded index [20, 47, 45, 31, 10, 37, 27, 18, 35, 21]
# epoch: 169, bulyan: at our-agr n_at 10 e 169 | val loss 1.9410 val acc 30.1339 best val_acc 31.412338
# discarded index [20, 47, 45, 31, 10, 37, 27, 18, 35, 21]
# epoch: 170, bulyan: at our-agr n_at 10 e 170 | val loss 2.4182 val acc 29.4034 best val_acc 31.412338
# discarded index [20, 47, 45, 31, 10, 37, 22, 0, 1, 2]
# epoch: 171, bulyan: at our-agr n_at 10 e 171 | val loss 2.4361 val acc 18.4862 best val_acc 31.412338
# discarded index [20, 47, 45, 31, 10, 37, 22, 0, 1, 2]
# epoch: 172, bulyan: at our-agr n_at 10 e 172 | val loss 2.5154 val acc 19.7849 best val_acc 31.412338
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 0, 1]
# epoch: 173, bulyan: at our-agr n_at 10 e 173 | val loss 2.3562 val acc 18.4862 best val_acc 31.412338
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 0, 1]
# epoch: 174, bulyan: at our-agr n_at 10 e 174 | val loss 2.2452 val acc 17.2484 best val_acc 31.412338
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 0, 1]
# epoch: 175, bulyan: at our-agr n_at 10 e 175 | val loss 2.0990 val acc 22.8693 best val_acc 31.412338
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 0, 1]
# epoch: 176, bulyan: at our-agr n_at 10 e 176 | val loss 2.1079 val acc 25.9740 best val_acc 31.412338
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 0, 1]
# epoch: 177, bulyan: at our-agr n_at 10 e 177 | val loss 2.0304 val acc 26.1567 best val_acc 31.412338
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 0, 1]
# epoch: 178, bulyan: at our-agr n_at 10 e 178 | val loss 2.0968 val acc 26.0755 best val_acc 31.412338
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 179, bulyan: at our-agr n_at 10 e 179 | val loss 2.0521 val acc 24.7362 best val_acc 31.412338
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 180, bulyan: at our-agr n_at 10 e 180 | val loss 2.0474 val acc 28.7946 best val_acc 31.412338
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 181, bulyan: at our-agr n_at 10 e 181 | val loss 1.9003 val acc 29.0787 best val_acc 31.412338
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 182, bulyan: at our-agr n_at 10 e 182 | val loss 2.1171 val acc 31.3515 best val_acc 31.412338
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 183, bulyan: at our-agr n_at 10 e 183 | val loss 2.0901 val acc 26.1972 best val_acc 31.412338
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 184, bulyan: at our-agr n_at 10 e 184 | val loss 2.1958 val acc 27.4756 best val_acc 31.412338
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 185, bulyan: at our-agr n_at 10 e 185 | val loss 2.0850 val acc 28.3482 best val_acc 31.412338
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 186, bulyan: at our-agr n_at 10 e 186 | val loss 2.1567 val acc 27.9018 best val_acc 31.412338
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 187, bulyan: at our-agr n_at 10 e 187 | val loss 1.9750 val acc 30.8644 best val_acc 31.412338
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 188, bulyan: at our-agr n_at 10 e 188 | val loss 1.9833 val acc 33.8068 best val_acc 33.806818
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 189, bulyan: at our-agr n_at 10 e 189 | val loss 2.2669 val acc 28.2468 best val_acc 33.806818
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 190, bulyan: at our-agr n_at 10 e 190 | val loss 1.9839 val acc 30.7021 best val_acc 33.806818
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 191, bulyan: at our-agr n_at 10 e 191 | val loss 2.1118 val acc 33.6851 best val_acc 33.806818
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 192, bulyan: at our-agr n_at 10 e 192 | val loss 1.9993 val acc 30.1745 best val_acc 33.806818
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 193, bulyan: at our-agr n_at 10 e 193 | val loss 2.4546 val acc 31.3109 best val_acc 33.806818
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 194, bulyan: at our-agr n_at 10 e 194 | val loss 2.0749 val acc 26.8466 best val_acc 33.806818
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 195, bulyan: at our-agr n_at 10 e 195 | val loss 1.9608 val acc 32.4878 best val_acc 33.806818
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 196, bulyan: at our-agr n_at 10 e 196 | val loss 2.0126 val acc 31.1891 best val_acc 33.806818
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 197, bulyan: at our-agr n_at 10 e 197 | val loss 2.2490 val acc 27.1916 best val_acc 33.806818
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 198, bulyan: at our-agr n_at 10 e 198 | val loss 2.5680 val acc 26.7857 best val_acc 33.806818
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 199, bulyan: at our-agr n_at 10 e 199 | val loss 2.1177 val acc 23.3157 best val_acc 33.806818
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 200, bulyan: at our-agr n_at 10 e 200 | val loss 2.8157 val acc 27.4351 best val_acc 33.806818
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 201, bulyan: at our-agr n_at 10 e 201 | val loss 2.1171 val acc 25.0000 best val_acc 33.806818
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 202, bulyan: at our-agr n_at 10 e 202 | val loss 2.2506 val acc 31.4326 best val_acc 33.806818
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 203, bulyan: at our-agr n_at 10 e 203 | val loss 1.9902 val acc 31.3515 best val_acc 33.806818
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 204, bulyan: at our-agr n_at 10 e 204 | val loss 2.1573 val acc 32.3864 best val_acc 33.806818
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 205, bulyan: at our-agr n_at 10 e 205 | val loss 2.0759 val acc 30.3571 best val_acc 33.806818
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 206, bulyan: at our-agr n_at 10 e 206 | val loss 2.0514 val acc 29.8904 best val_acc 33.806818
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 207, bulyan: at our-agr n_at 10 e 207 | val loss 2.0875 val acc 30.7833 best val_acc 33.806818
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 208, bulyan: at our-agr n_at 10 e 208 | val loss 1.8433 val acc 36.0390 best val_acc 36.038961
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 209, bulyan: at our-agr n_at 10 e 209 | val loss 2.2275 val acc 33.7865 best val_acc 36.038961
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 210, bulyan: at our-agr n_at 10 e 210 | val loss 2.1461 val acc 27.5162 best val_acc 36.038961
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 211, bulyan: at our-agr n_at 10 e 211 | val loss 1.9737 val acc 31.5341 best val_acc 36.038961
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 212, bulyan: at our-agr n_at 10 e 212 | val loss 1.8595 val acc 35.2881 best val_acc 36.038961
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 213, bulyan: at our-agr n_at 10 e 213 | val loss 2.1660 val acc 33.8677 best val_acc 36.038961
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 214, bulyan: at our-agr n_at 10 e 214 | val loss 1.9881 val acc 30.0731 best val_acc 36.038961
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 215, bulyan: at our-agr n_at 10 e 215 | val loss 1.9827 val acc 35.1258 best val_acc 36.038961
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 216, bulyan: at our-agr n_at 10 e 216 | val loss 1.8903 val acc 32.0617 best val_acc 36.038961
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 217, bulyan: at our-agr n_at 10 e 217 | val loss 2.2748 val acc 33.5227 best val_acc 36.038961
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 218, bulyan: at our-agr n_at 10 e 218 | val loss 2.0364 val acc 24.5942 best val_acc 36.038961
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 219, bulyan: at our-agr n_at 10 e 219 | val loss 2.1880 val acc 30.3977 best val_acc 36.038961
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 220, bulyan: at our-agr n_at 10 e 220 | val loss 2.1569 val acc 31.8791 best val_acc 36.038961
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 221, bulyan: at our-agr n_at 10 e 221 | val loss 1.9877 val acc 25.8117 best val_acc 36.038961
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 222, bulyan: at our-agr n_at 10 e 222 | val loss 2.1013 val acc 35.1461 best val_acc 36.038961
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 223, bulyan: at our-agr n_at 10 e 223 | val loss 1.9047 val acc 30.6818 best val_acc 36.038961
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 18, 35]
# epoch: 224, bulyan: at our-agr n_at 10 e 224 | val loss 3.4180 val acc 32.0211 best val_acc 36.038961
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 225, bulyan: at our-agr n_at 10 e 225 | val loss 2.8507 val acc 17.0049 best val_acc 36.038961
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 226, bulyan: at our-agr n_at 10 e 226 | val loss 3.2384 val acc 20.6372 best val_acc 36.038961
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 227, bulyan: at our-agr n_at 10 e 227 | val loss 2.3230 val acc 21.6112 best val_acc 36.038961
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 228, bulyan: at our-agr n_at 10 e 228 | val loss 2.1713 val acc 23.3766 best val_acc 36.038961
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 229, bulyan: at our-agr n_at 10 e 229 | val loss 2.0406 val acc 29.8295 best val_acc 36.038961
# discarded index [20, 47, 45, 31, 10, 37, 22, 0, 1, 2]
# epoch: 230, bulyan: at our-agr n_at 10 e 230 | val loss 1.8995 val acc 32.2443 best val_acc 36.038961
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 231, bulyan: at our-agr n_at 10 e 231 | val loss 2.0749 val acc 35.3693 best val_acc 36.038961
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 232, bulyan: at our-agr n_at 10 e 232 | val loss 1.9575 val acc 32.4878 best val_acc 36.038961
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 233, bulyan: at our-agr n_at 10 e 233 | val loss 2.1032 val acc 35.3693 best val_acc 36.038961
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 234, bulyan: at our-agr n_at 10 e 234 | val loss 2.0922 val acc 32.8125 best val_acc 36.038961
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 235, bulyan: at our-agr n_at 10 e 235 | val loss 2.2366 val acc 28.7338 best val_acc 36.038961
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 236, bulyan: at our-agr n_at 10 e 236 | val loss 1.8456 val acc 33.8068 best val_acc 36.038961
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 237, bulyan: at our-agr n_at 10 e 237 | val loss 2.4952 val acc 34.7403 best val_acc 36.038961
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 238, bulyan: at our-agr n_at 10 e 238 | val loss 1.9183 val acc 30.9862 best val_acc 36.038961
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 239, bulyan: at our-agr n_at 10 e 239 | val loss 2.4134 val acc 35.7143 best val_acc 36.038961
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 240, bulyan: at our-agr n_at 10 e 240 | val loss 2.1229 val acc 27.9018 best val_acc 36.038961
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 241, bulyan: at our-agr n_at 10 e 241 | val loss 2.0843 val acc 30.8036 best val_acc 36.038961
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 242, bulyan: at our-agr n_at 10 e 242 | val loss 1.9202 val acc 35.9984 best val_acc 36.038961
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 243, bulyan: at our-agr n_at 10 e 243 | val loss 1.9995 val acc 36.0593 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 244, bulyan: at our-agr n_at 10 e 244 | val loss 2.1432 val acc 34.2127 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 245, bulyan: at our-agr n_at 10 e 245 | val loss 2.6376 val acc 27.9018 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 246, bulyan: at our-agr n_at 10 e 246 | val loss 2.2797 val acc 28.2062 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 247, bulyan: at our-agr n_at 10 e 247 | val loss 2.5061 val acc 31.4326 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 248, bulyan: at our-agr n_at 10 e 248 | val loss 1.9878 val acc 31.1080 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 249, bulyan: at our-agr n_at 10 e 249 | val loss 3.8509 val acc 31.4326 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 28, 0]
# epoch: 250, bulyan: at our-agr n_at 10 e 250 | val loss 2.5031 val acc 19.6429 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 27, 22, 28, 0]
# epoch: 251, bulyan: at our-agr n_at 10 e 251 | val loss 2.8704 val acc 21.0633 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 28, 0]
# epoch: 252, bulyan: at our-agr n_at 10 e 252 | val loss 2.1427 val acc 19.1964 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 28, 0]
# epoch: 253, bulyan: at our-agr n_at 10 e 253 | val loss 2.0548 val acc 29.4643 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 28, 0]
# epoch: 254, bulyan: at our-agr n_at 10 e 254 | val loss 1.9100 val acc 32.3458 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 28, 0]
# epoch: 255, bulyan: at our-agr n_at 10 e 255 | val loss 1.8889 val acc 34.8214 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 28, 0]
# epoch: 256, bulyan: at our-agr n_at 10 e 256 | val loss 1.9070 val acc 33.7256 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 28, 0]
# epoch: 257, bulyan: at our-agr n_at 10 e 257 | val loss 2.1148 val acc 28.4091 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 28, 0]
# epoch: 258, bulyan: at our-agr n_at 10 e 258 | val loss 1.9748 val acc 32.3052 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 28, 0]
# epoch: 259, bulyan: at our-agr n_at 10 e 259 | val loss 1.8834 val acc 33.1981 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 28, 0]
# epoch: 260, bulyan: at our-agr n_at 10 e 260 | val loss 2.1688 val acc 31.4732 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 28, 0]
# epoch: 261, bulyan: at our-agr n_at 10 e 261 | val loss 2.2009 val acc 22.7881 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 28, 0]
# epoch: 262, bulyan: at our-agr n_at 10 e 262 | val loss 2.2020 val acc 26.0349 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 28, 0]
# epoch: 263, bulyan: at our-agr n_at 10 e 263 | val loss 1.9760 val acc 28.6526 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 28, 0]
# epoch: 264, bulyan: at our-agr n_at 10 e 264 | val loss 1.9467 val acc 34.3750 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 28, 0]
# epoch: 265, bulyan: at our-agr n_at 10 e 265 | val loss 1.8523 val acc 34.8823 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 28, 18]
# epoch: 266, bulyan: at our-agr n_at 10 e 266 | val loss 2.1692 val acc 35.0244 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 28, 18]
# epoch: 267, bulyan: at our-agr n_at 10 e 267 | val loss 2.3770 val acc 31.2094 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 28, 18]
# epoch: 268, bulyan: at our-agr n_at 10 e 268 | val loss 3.1642 val acc 26.4813 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 27, 18, 35]
# epoch: 269, bulyan: at our-agr n_at 10 e 269 | val loss 4.9870 val acc 24.6347 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 28, 0, 1]
# epoch: 270, bulyan: at our-agr n_at 10 e 270 | val loss 2.7750 val acc 10.0244 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 28, 0, 1]
# epoch: 271, bulyan: at our-agr n_at 10 e 271 | val loss 3.1306 val acc 11.0390 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 28, 0, 1]
# epoch: 272, bulyan: at our-agr n_at 10 e 272 | val loss 2.5574 val acc 10.7143 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 28, 0, 1]
# epoch: 273, bulyan: at our-agr n_at 10 e 273 | val loss 2.3252 val acc 16.0106 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 28, 0, 1]
# epoch: 274, bulyan: at our-agr n_at 10 e 274 | val loss 3.3002 val acc 10.8766 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 28, 0, 1]
# epoch: 275, bulyan: at our-agr n_at 10 e 275 | val loss 2.4607 val acc 10.4302 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 28, 0, 1]
# epoch: 276, bulyan: at our-agr n_at 10 e 276 | val loss 2.5050 val acc 10.1867 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 28, 0, 1]
# epoch: 277, bulyan: at our-agr n_at 10 e 277 | val loss 2.3132 val acc 19.0138 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 28, 0, 1]
# epoch: 278, bulyan: at our-agr n_at 10 e 278 | val loss 2.3004 val acc 20.6575 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 28, 0, 1]
# epoch: 279, bulyan: at our-agr n_at 10 e 279 | val loss 2.2277 val acc 21.8141 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 28, 0, 1]
# epoch: 280, bulyan: at our-agr n_at 10 e 280 | val loss 2.1968 val acc 18.6891 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 28, 0, 1]
# epoch: 281, bulyan: at our-agr n_at 10 e 281 | val loss 2.0864 val acc 24.1071 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 28, 0, 1]
# epoch: 282, bulyan: at our-agr n_at 10 e 282 | val loss 2.5118 val acc 20.7183 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 28, 0, 1]
# epoch: 283, bulyan: at our-agr n_at 10 e 283 | val loss 2.3371 val acc 12.0739 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 28, 0, 1]
# epoch: 284, bulyan: at our-agr n_at 10 e 284 | val loss 2.5768 val acc 16.7411 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 28, 0, 1]
# epoch: 285, bulyan: at our-agr n_at 10 e 285 | val loss 2.3457 val acc 15.9294 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 28, 0, 1]
# epoch: 286, bulyan: at our-agr n_at 10 e 286 | val loss 2.2159 val acc 25.5276 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 28, 0, 1]
# epoch: 287, bulyan: at our-agr n_at 10 e 287 | val loss 2.0844 val acc 25.5479 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 28, 0, 1]
# epoch: 288, bulyan: at our-agr n_at 10 e 288 | val loss 1.9897 val acc 29.4034 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 28, 0, 1]
# epoch: 289, bulyan: at our-agr n_at 10 e 289 | val loss 1.9054 val acc 32.5487 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 28, 0, 1]
# epoch: 290, bulyan: at our-agr n_at 10 e 290 | val loss 2.2674 val acc 25.1218 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 28, 0, 1]
# epoch: 291, bulyan: at our-agr n_at 10 e 291 | val loss 3.0896 val acc 13.3523 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 28, 0, 1]
# epoch: 292, bulyan: at our-agr n_at 10 e 292 | val loss 2.7227 val acc 10.1461 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 28, 0, 1]
# epoch: 293, bulyan: at our-agr n_at 10 e 293 | val loss 6.1925 val acc 13.3523 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 28, 0, 1]
# epoch: 294, bulyan: at our-agr n_at 10 e 294 | val loss 2.7715 val acc 12.8653 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 28, 0, 1]
# epoch: 295, bulyan: at our-agr n_at 10 e 295 | val loss 3.1087 val acc 10.3084 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 28, 0, 1]
# epoch: 296, bulyan: at our-agr n_at 10 e 296 | val loss 2.6574 val acc 7.2240 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 28, 0, 1]
# epoch: 297, bulyan: at our-agr n_at 10 e 297 | val loss 2.5529 val acc 10.2273 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 28, 0, 1]
# epoch: 298, bulyan: at our-agr n_at 10 e 298 | val loss 2.4523 val acc 11.8709 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 28, 0, 1]
# epoch: 299, bulyan: at our-agr n_at 10 e 299 | val loss 2.3881 val acc 14.3060 best val_acc 36.059253
# discarded index [20, 47, 45, 31, 10, 37, 22, 28, 0, 1]
# epoch: 300, bulyan: at our-agr n_at 10 e 300 | val loss 2.3477 val acc 18.6282 best val_acc 36.059253

# %%
import matplotlib.pyplot as plt

# Plotting the data
for col in ['loss', 'validation accuracy', 'best validation accuracy']:
    plt.plot(df['epoch'].tolist(), df[col].tolist())
    plt.title(f"{title} {col}")
    plt.show()
