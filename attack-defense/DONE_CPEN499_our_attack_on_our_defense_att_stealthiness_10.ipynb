# %% [markdown]
# # The notebook contains
# ### Code for Our attack and our aggregation algorithm
# ### Evaluation of our defense with different parameters in our attack

# %% [markdown]
# ## Import packages

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
from __future__ import print_function
import argparse, os, sys, csv, shutil, time, random, operator, pickle, ast, math
import numpy as np
import pandas as pd
from torch.optim import Optimizer
import torch.nn.functional as F
import torch
import pickle
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data as data
import torch.multiprocessing as mp
import math
sys.path.insert(0,'./../utils/')
from logger import *
from eval import *
from misc import *

from cifar10_normal_train import *
from cifar10_util import *
from adam import Adam
from sgd import SGD

# %% [markdown]
# ### Load Data
# Divide cifar10 data among 50 clients in Non-IID fashion using Dirichlet distribution

# %%
n_users = 50
user_tr_len = pickle.load(open('./data/user_tr_len.pkl','rb'))

user_train_data_tensors = pickle.load(open('./data/user_train_data_tensors.pkl','rb'))
user_train_label_tensors = pickle.load(open('./data/user_train_label_tensors.pkl','rb'))

val_data_tensor = pickle.load(open('./data/val_data_tensor.pkl','rb'))
val_label_tensor = pickle.load(open('./data/val_label_tensor.pkl','rb'))
te_data_tensor = pickle.load(open('./data/te_data_tensor.pkl','rb'))
te_label_tensor = pickle.load(open('./data/te_label_tensor.pkl','rb'))

# %% [markdown]
# ### Our Aggregation Function

# %%
def our_mean_defense(all_updates, n_attackers, history_updates):
    discarded_history = get_discarded_index(n_attackers, history_updates)

    mask = torch.ones(all_updates.size(0), dtype=torch.bool)
    mask[discarded_history] = False
    remaining_updates = all_updates[mask]

    print('discarded index', discarded_history)

    return torch.nanmean(remaining_updates, dim=0)

####
def euclidean_distance(row1, row2):
    return torch.sqrt(torch.sum((row1 - row2) ** 2))
####

def get_discarded_index(n_attackers, history_updates):
    n_users = history_updates.shape[0]

    ####
    distance_matrix = [[0 if i == j else euclidean_distance(history_updates[i, :], history_updates[j, :]) for j in range(n_users)] for i in range(n_users)]
    ####

    sum_of_distances = [sum(row) for row in distance_matrix]

    discarded_history = []
    for _ in range(n_attackers):
        max_distance = max(sum_of_distances)
        index_of_max_distance = sum_of_distances.index(max_distance)
        discarded_history.append(index_of_max_distance)

        for i in range(n_users):
            sum_of_distances[i] -= distance_matrix[i][index_of_max_distance]
        sum_of_distances[index_of_max_distance] = -1

    return discarded_history

# %% [markdown]
# ### Code for no defense aggregation algorithm

# %%
def no_defense_aggregation(user_grads):
    return torch.nanmean(user_grads, dim=0)

# %% [markdown]
# ### Set nepochs

# %%
nepochs= 300

# %% [markdown]
# # our_attack & our defense

# %% [markdown]
# ## attacker stealthiness: discard 20
#
# 10 bisection; 10 iterations; 20 discarded

# %% [markdown]
# ### our_attack_mean
# $ argmin_\theta(\ -L(\theta_{attacker(s)}) + \lambda_1 |\bar{\theta_{abs\ mean\ benige\ users}} - \bar{\theta_{abs\ attacker(s)}}|$

# %%
device = 'cuda:0'
def check_condition(lambda1, prev_grad, loss_grad, history, all_updates, n_users, n_attacker, epoch_num):
    loss_grad = loss_grad.to(device)
    prev_grad = prev_grad.to(device)
    new_grad = lambda1 * (loss_grad + prev_grad)

    ####
    mal_updates = torch.stack([new_grad.clone().detach() for _ in range(n_attacker)])
    malicious_grads = torch.cat((mal_updates, all_updates[n_attacker:]), 0)

    history_updates = history.clone().detach()
    history_updates[:, epoch_num] = malicious_grads.abs().mean(dim=1, keepdim=True).squeeze()
    ####

    discarded_history = get_discarded_index(n_attacker*2, history_updates)

    detected_mal = len([item for item in discarded_history if item < 10])
    return detected_mal / len(discarded_history) <= n_attacker / n_users

def find_upper_bound(lambda1, prev_grad, loss_grad, history, all_updates, n_users, n_attacker, epoch_num):
    while check_condition(lambda1, prev_grad, loss_grad, history, all_updates, n_users, n_attacker, epoch_num):
        lambda1 *= 2  # Exponentially increase lambda
    return lambda1


def projection(prev_grad, loss_grad, history, all_updates, n_users, n_attacker, epoch_num):
    updates_abs_mean = all_updates.abs().mean(dim=1, keepdim=True)
    median_value = torch.median(updates_abs_mean).item()

    ####
    history_updates = history.clone().detach()
    history_updates[:, epoch_num] = updates_abs_mean.mean(dim=1, keepdim=True).squeeze()
    ####

    loss_grad = loss_grad.to(device)
    prev_grad = prev_grad.to(device)

    lambda_low = median_value/(prev_grad + loss_grad).abs().mean().item()
    lambda_high = find_upper_bound(lambda_low, prev_grad, loss_grad, history_updates, all_updates, n_users, n_attacker, epoch_num)
    if lambda_high < lambda_low:
        lambda_high = lambda_low
        print("SHOULD NEVER REACH THIS LINE")
        print('lambda_low: ', lambda_low, ' lambda_high: ', lambda_high)
    tolerance = 1e-6

    iterations_count = 0
    while lambda_high - lambda_low > tolerance and iterations_count < 10:
        lambda_mid = (lambda_low + lambda_high) / 2
        if check_condition(lambda_mid, prev_grad, loss_grad, history_updates, all_updates, n_users, n_attacker, epoch_num):
            lambda_low = lambda_mid
        else:
            lambda_high = lambda_mid
        iterations_count += 1

    lambda1 = lambda_low

    return lambda1 * (prev_grad + loss_grad)

def our_attack_mean(n_user, epoch_num, history_updates, all_updates, model_params, n_attacker, arch, criterion, user_train_data_tensors, user_train_label_tensors):
    attacker_tr_data_tensor = user_train_data_tensors[0].cuda()
    attacker_tr_label_tensor = user_train_label_tensors[0].cuda()

    fed_model, _ = return_model(arch, 0.1, 0.9, parallel=False)
    fed_model.eval()  # Ensure the model is in evaluation mode

    new_grad = -all_updates[0].clone().detach().requires_grad_(True)
    prev_grad = np.zeros(len(new_grad))
    new_grad = projection(torch.from_numpy(prev_grad), new_grad, history_updates, all_updates, n_user, n_attacker, epoch_num)

    for _ in range(10):
        outputs = fed_model(attacker_tr_data_tensor)
        loss = criterion(outputs, attacker_tr_label_tensor)

        loss.backward(retain_graph=True)
        param_grad = []
        for param in fed_model.parameters():
            param_grad.append(param.grad.view(-1).detach())

        param_grad = torch.cat(param_grad)
        prev_grad = new_grad
        new_grad = projection(prev_grad, param_grad, history_updates, all_updates, n_user, n_attacker, epoch_num)

        difference = torch.mean(torch.abs(new_grad - prev_grad)).item()
        if difference < 1e-6:
            # print("STOPPED! Difference is too small, stop finding best attack grad")
            break

        fed_model.zero_grad()

    result_attacker_grads = [new_grad.clone().detach() for _ in range(10)]
    return torch.stack(result_attacker_grads).cuda()

# %%
batch_size=250
resume=0

schedule=[1000]

gamma=.5
opt = 'sgd'
fed_lr=0.5
criterion=nn.CrossEntropyLoss()
use_cuda = torch.cuda.is_available()

aggregation='bulyan'
multi_k = False
candidates = []

at_type='our-agr'
dev_type ='std'
n_attackers=[10]

arch='alexnet'
chkpt='./'+aggregation

past_mean = []
past_abs_sum = []
past_median = []
past_lower_quartile = []
past_upper_quartile = []
past_std = []

title = "our attack (10 attacker) + our aggregation defense"

for n_attacker in n_attackers:
    epoch_num = 0
    best_global_acc = 0
    best_global_te_acc = 0

    torch.cuda.empty_cache()

    fed_model, _ = return_model(arch, 0.1, 0.9, parallel=False)
    optimizer_fed = SGD(fed_model.parameters(), lr=fed_lr)

    df = pd.DataFrame(columns = ['epoch', 'loss', 'validation accuracy', 'best validation accuracy'])

    ####
    history = torch.zeros((n_users, nepochs + 1), dtype=torch.float32).cuda()
    ####

    model_grads = []
    while epoch_num <= nepochs:
        user_grads=[]

        for i in range(n_users): # 50
            nbatches = user_tr_len[i]//batch_size

            inputs = user_train_data_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]
            targets = user_train_label_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]

            targets = targets.type(torch.LongTensor)

            inputs, targets = inputs.cuda(), targets.cuda()
            inputs, targets = torch.autograd.Variable(inputs), torch.autograd.Variable(targets)

            outputs = fed_model(inputs)
            loss = criterion(outputs, targets)
            fed_model.zero_grad()
            loss.backward(retain_graph=True)

            param_grad=[]
            for param in fed_model.parameters():
                param_grad=param.grad.data.view(-1) if not len(param_grad) else torch.cat((param_grad,param.grad.view(-1)))


            user_grads=param_grad[None, :] if len(user_grads)==0 else torch.cat((user_grads,param_grad[None,:]), 0)

        if epoch_num in schedule:
            for param_group in optimizer_fed.param_groups:
                param_group['lr'] *= gamma
                print('New learnin rate ', param_group['lr'])

        updates_abs_mean = user_grads.abs().mean(dim=1, keepdim=True)

        if n_attacker > 0:
            model_params = torch.cat([p.data.view(-1) for p in fed_model.parameters()])
            mal_updates = our_attack_mean(n_users, epoch_num, history, user_grads, model_params, n_attacker, arch, criterion, user_train_data_tensors, user_train_label_tensors)
            malicious_grads = torch.cat((mal_updates, user_grads[n_attacker:]), 0) # torch.Size([50, 2472266])

        if not (malicious_grads.shape[0]==50):
            print(malicious_grads.shape)

        updates_abs_mean = malicious_grads.abs().mean(dim=1, keepdim=True)

        history[:, epoch_num] = updates_abs_mean.squeeze()
        agg_grads = our_mean_defense(malicious_grads, n_attacker, history)

        del user_grads

        start_idx=0

        optimizer_fed.zero_grad()

        model_grads=[]

        for i, param in enumerate(fed_model.parameters()):
            param_=agg_grads[start_idx:start_idx+len(param.data.view(-1))].reshape(param.data.shape)
            start_idx=start_idx+len(param.data.view(-1))
            param_=param_.cuda()
            model_grads.append(param_)

        optimizer_fed.step(model_grads)

        val_loss, val_acc = test(val_data_tensor,val_label_tensor,fed_model,criterion,use_cuda)
        te_loss, te_acc = test(te_data_tensor,te_label_tensor, fed_model, criterion, use_cuda)

        is_best = best_global_acc < val_acc

        best_global_acc = max(best_global_acc, val_acc)

        if is_best:
            best_global_te_acc = te_acc


        print('epoch: %d, %s: at %s n_at %d e %d | val loss %.4f val acc %.4f best val_acc %f'%(epoch_num, aggregation, at_type, n_attacker, epoch_num, val_loss, val_acc, best_global_acc))
        new_row = pd.DataFrame([{
            'epoch': epoch_num,
            'loss': val_loss,
            'validation accuracy': val_acc,
            'best validation accuracy': best_global_acc
            }])
        df = pd.concat([df, new_row], ignore_index=True)
        df.to_csv('our_attack_stealthiness_discard_20.csv', index=False)

        if val_loss > 1000:
            print('val loss %f too high'%val_loss)
            break

        epoch_num+=1
# Out:
# discarded index [34, 37, 20, 33, 25, 11, 49, 24, 28, 43]
# epoch: 0, bulyan: at our-agr n_at 10 e 0 | val loss 2.3026 val acc 10.1867 best val_acc 10.186688
# c:\Users\Hizan\Desktop\CPEN497-FL\attack-defense\sgd.py:109: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\python_arg_parser.cpp:1630.)
#   p.data.add_(-group['lr'], d_p)
# C:\Users\Hizan\AppData\Local\Temp\ipykernel_14612\2761079156.py:129: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, new_row], ignore_index=True)
# discarded index [34, 20, 37, 25, 11, 43, 28, 49, 33, 24]
# epoch: 1, bulyan: at our-agr n_at 10 e 1 | val loss 2.3021 val acc 11.5463 best val_acc 11.546266
# discarded index [34, 20, 37, 11, 25, 32, 49, 43, 24, 44]
# epoch: 2, bulyan: at our-agr n_at 10 e 2 | val loss 2.3019 val acc 10.1461 best val_acc 11.546266
# discarded index [34, 20, 37, 11, 25, 49, 43, 32, 24, 33]
# epoch: 3, bulyan: at our-agr n_at 10 e 3 | val loss 2.3020 val acc 10.1461 best val_acc 11.546266
# discarded index [34, 20, 37, 11, 49, 25, 32, 43, 24, 28]
# epoch: 4, bulyan: at our-agr n_at 10 e 4 | val loss 2.3021 val acc 10.1461 best val_acc 11.546266
# discarded index [34, 20, 37, 25, 11, 49, 32, 28, 43, 24]
# epoch: 5, bulyan: at our-agr n_at 10 e 5 | val loss 2.3025 val acc 10.1461 best val_acc 11.546266
# discarded index [34, 20, 37, 11, 25, 49, 32, 24, 43, 33]
# epoch: 6, bulyan: at our-agr n_at 10 e 6 | val loss 2.3030 val acc 10.1461 best val_acc 11.546266
# discarded index [34, 20, 37, 11, 25, 49, 24, 43, 32, 28]
# epoch: 7, bulyan: at our-agr n_at 10 e 7 | val loss 2.3041 val acc 10.1461 best val_acc 11.546266
# discarded index [34, 20, 37, 11, 25, 49, 32, 24, 28, 43]
# epoch: 8, bulyan: at our-agr n_at 10 e 8 | val loss 2.3046 val acc 10.1461 best val_acc 11.546266
# discarded index [34, 20, 37, 11, 25, 49, 24, 28, 43, 32]
# epoch: 9, bulyan: at our-agr n_at 10 e 9 | val loss 2.3055 val acc 10.1461 best val_acc 11.546266
# discarded index [34, 20, 37, 11, 49, 24, 25, 28, 32, 43]
# epoch: 10, bulyan: at our-agr n_at 10 e 10 | val loss 2.3064 val acc 10.1461 best val_acc 11.546266
# discarded index [34, 37, 20, 11, 24, 49, 25, 32, 28, 43]
# epoch: 11, bulyan: at our-agr n_at 10 e 11 | val loss 2.3080 val acc 10.1461 best val_acc 11.546266
# discarded index [34, 37, 20, 24, 11, 49, 25, 28, 33, 32]
# epoch: 12, bulyan: at our-agr n_at 10 e 12 | val loss 2.3094 val acc 10.1461 best val_acc 11.546266
# discarded index [34, 37, 20, 24, 28, 11, 49, 25, 43, 33]
# epoch: 13, bulyan: at our-agr n_at 10 e 13 | val loss 2.3117 val acc 10.1461 best val_acc 11.546266
# discarded index [34, 37, 24, 11, 49, 25, 28, 32, 43, 33]
# epoch: 14, bulyan: at our-agr n_at 10 e 14 | val loss 2.3132 val acc 10.1461 best val_acc 11.546266
# discarded index [34, 24, 37, 49, 11, 25, 28, 33, 43, 32]
# epoch: 15, bulyan: at our-agr n_at 10 e 15 | val loss 2.3146 val acc 10.1461 best val_acc 11.546266
# discarded index [34, 24, 37, 49, 28, 25, 33, 11, 43, 32]
# epoch: 16, bulyan: at our-agr n_at 10 e 16 | val loss 2.3150 val acc 10.1461 best val_acc 11.546266
# discarded index [34, 24, 37, 28, 25, 49, 33, 32, 43, 11]
# epoch: 17, bulyan: at our-agr n_at 10 e 17 | val loss 2.3119 val acc 10.1461 best val_acc 11.546266
# discarded index [34, 24, 37, 49, 33, 25, 28, 43, 11, 32]
# epoch: 18, bulyan: at our-agr n_at 10 e 18 | val loss 2.3041 val acc 11.3636 best val_acc 11.546266
# discarded index [34, 20, 24, 37, 33, 49, 25, 28, 43, 11]
# epoch: 19, bulyan: at our-agr n_at 10 e 19 | val loss 2.3089 val acc 11.8709 best val_acc 11.870942
# discarded index [20, 47, 45, 34, 24, 49, 37, 28, 33, 43]
# epoch: 20, bulyan: at our-agr n_at 10 e 20 | val loss 2.3524 val acc 9.3344 best val_acc 11.870942
# discarded index [47, 20, 45, 22, 34, 37, 11, 49, 43, 31]
# epoch: 21, bulyan: at our-agr n_at 10 e 21 | val loss 2.3113 val acc 10.7549 best val_acc 11.870942
# discarded index [20, 47, 45, 22, 34, 37, 49, 11, 43, 33]
# epoch: 22, bulyan: at our-agr n_at 10 e 22 | val loss 2.5304 val acc 9.9838 best val_acc 11.870942
# discarded index [20, 47, 45, 27, 21, 18, 35, 49, 12, 34]
# epoch: 23, bulyan: at our-agr n_at 10 e 23 | val loss 2.5040 val acc 10.1461 best val_acc 11.870942
# discarded index [20, 47, 45, 27, 21, 18, 35, 49, 12, 34]
# epoch: 24, bulyan: at our-agr n_at 10 e 24 | val loss 2.4871 val acc 13.2914 best val_acc 13.291396
# discarded index [20, 47, 45, 31, 27, 10, 21, 18, 35, 12]
# epoch: 25, bulyan: at our-agr n_at 10 e 25 | val loss 2.4007 val acc 10.3896 best val_acc 13.291396
# discarded index [20, 47, 45, 31, 27, 10, 18, 21, 35, 12]
# epoch: 26, bulyan: at our-agr n_at 10 e 26 | val loss 2.7246 val acc 10.2070 best val_acc 13.291396
# discarded index [20, 47, 45, 31, 35, 27, 18, 21, 12, 34]
# epoch: 27, bulyan: at our-agr n_at 10 e 27 | val loss 2.6087 val acc 9.8214 best val_acc 13.291396
# discarded index [20, 47, 45, 31, 35, 27, 18, 21, 12, 34]
# epoch: 28, bulyan: at our-agr n_at 10 e 28 | val loss 2.7224 val acc 13.1494 best val_acc 13.291396
# discarded index [20, 47, 45, 31, 10, 37, 35, 27, 18, 21]
# epoch: 29, bulyan: at our-agr n_at 10 e 29 | val loss 2.7658 val acc 10.1461 best val_acc 13.291396
# discarded index [20, 47, 45, 31, 10, 37, 35, 27, 18, 21]
# epoch: 30, bulyan: at our-agr n_at 10 e 30 | val loss 2.4639 val acc 10.4302 best val_acc 13.291396
# discarded index [20, 47, 45, 31, 10, 37, 35, 27, 18, 21]
# epoch: 31, bulyan: at our-agr n_at 10 e 31 | val loss 2.7730 val acc 10.1461 best val_acc 13.291396
# discarded index [20, 47, 45, 31, 10, 37, 35, 27, 18, 21]
# epoch: 32, bulyan: at our-agr n_at 10 e 32 | val loss 2.6234 val acc 7.3458 best val_acc 13.291396
# discarded index [20, 47, 45, 31, 10, 37, 24, 22, 28, 35]
# epoch: 33, bulyan: at our-agr n_at 10 e 33 | val loss 2.8124 val acc 10.1461 best val_acc 13.291396
# discarded index [20, 47, 45, 31, 10, 37, 24, 22, 28, 35]
# epoch: 34, bulyan: at our-agr n_at 10 e 34 | val loss 3.3015 val acc 10.1461 best val_acc 13.291396
# discarded index [20, 47, 45, 10, 31, 18, 35, 37, 21, 27]
# epoch: 35, bulyan: at our-agr n_at 10 e 35 | val loss 3.1989 val acc 10.1461 best val_acc 13.291396
# discarded index [20, 47, 45, 31, 10, 18, 35, 37, 21, 27]
# epoch: 36, bulyan: at our-agr n_at 10 e 36 | val loss 2.7529 val acc 9.8417 best val_acc 13.291396
# discarded index [20, 47, 45, 31, 10, 18, 35, 37, 21, 27]
# epoch: 37, bulyan: at our-agr n_at 10 e 37 | val loss 2.7378 val acc 10.8766 best val_acc 13.291396
# discarded index [20, 47, 45, 31, 10, 18, 35, 37, 21, 27]
# epoch: 38, bulyan: at our-agr n_at 10 e 38 | val loss 2.5555 val acc 7.9343 best val_acc 13.291396
# discarded index [20, 47, 45, 31, 10, 18, 35, 37, 21, 27]
# epoch: 39, bulyan: at our-agr n_at 10 e 39 | val loss 3.4894 val acc 9.8011 best val_acc 13.291396
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 21, 24]
# epoch: 40, bulyan: at our-agr n_at 10 e 40 | val loss 3.1599 val acc 10.1461 best val_acc 13.291396
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 21, 24]
# epoch: 41, bulyan: at our-agr n_at 10 e 41 | val loss 2.6630 val acc 10.2273 best val_acc 13.291396
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 21, 24]
# epoch: 42, bulyan: at our-agr n_at 10 e 42 | val loss 2.5184 val acc 10.3490 best val_acc 13.291396
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 21, 24]
# epoch: 43, bulyan: at our-agr n_at 10 e 43 | val loss 2.3983 val acc 12.0130 best val_acc 13.291396
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 21, 24]
# epoch: 44, bulyan: at our-agr n_at 10 e 44 | val loss 2.3414 val acc 13.4740 best val_acc 13.474026
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 21, 24]
# epoch: 45, bulyan: at our-agr n_at 10 e 45 | val loss 2.2990 val acc 13.9002 best val_acc 13.900162
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 21, 24]
# epoch: 46, bulyan: at our-agr n_at 10 e 46 | val loss 2.3472 val acc 12.3580 best val_acc 13.900162
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 24, 37]
# epoch: 47, bulyan: at our-agr n_at 10 e 47 | val loss 2.4395 val acc 11.2216 best val_acc 13.900162
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 24, 37]
# epoch: 48, bulyan: at our-agr n_at 10 e 48 | val loss 2.7628 val acc 9.7808 best val_acc 13.900162
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 24, 21]
# epoch: 49, bulyan: at our-agr n_at 10 e 49 | val loss 2.5698 val acc 10.3084 best val_acc 13.900162
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 24, 21]
# epoch: 50, bulyan: at our-agr n_at 10 e 50 | val loss 2.4355 val acc 14.0625 best val_acc 14.062500
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 24, 37]
# epoch: 51, bulyan: at our-agr n_at 10 e 51 | val loss 2.3327 val acc 11.4651 best val_acc 14.062500
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 24, 37]
# epoch: 52, bulyan: at our-agr n_at 10 e 52 | val loss 2.3128 val acc 11.3028 best val_acc 14.062500
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 24, 37]
# epoch: 53, bulyan: at our-agr n_at 10 e 53 | val loss 2.2878 val acc 12.5609 best val_acc 14.062500
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 24, 37]
# epoch: 54, bulyan: at our-agr n_at 10 e 54 | val loss 2.3013 val acc 12.5609 best val_acc 14.062500
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 24, 37]
# epoch: 55, bulyan: at our-agr n_at 10 e 55 | val loss 2.2738 val acc 12.5000 best val_acc 14.062500
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 24, 37]
# epoch: 56, bulyan: at our-agr n_at 10 e 56 | val loss 2.3162 val acc 9.1315 best val_acc 14.062500
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 24, 37]
# epoch: 57, bulyan: at our-agr n_at 10 e 57 | val loss 2.2988 val acc 17.1063 best val_acc 17.106331
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 24, 37]
# epoch: 58, bulyan: at our-agr n_at 10 e 58 | val loss 2.6058 val acc 9.8011 best val_acc 17.106331
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 24, 21]
# epoch: 59, bulyan: at our-agr n_at 10 e 59 | val loss 2.4427 val acc 11.3028 best val_acc 17.106331
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 24, 21]
# epoch: 60, bulyan: at our-agr n_at 10 e 60 | val loss 2.5532 val acc 16.7817 best val_acc 17.106331
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 24, 21]
# epoch: 61, bulyan: at our-agr n_at 10 e 61 | val loss 2.3333 val acc 14.7119 best val_acc 17.106331
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 24, 21]
# epoch: 62, bulyan: at our-agr n_at 10 e 62 | val loss 2.3560 val acc 15.7265 best val_acc 17.106331
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 24, 21]
# epoch: 63, bulyan: at our-agr n_at 10 e 63 | val loss 2.3731 val acc 15.2394 best val_acc 17.106331
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 24, 21]
# epoch: 64, bulyan: at our-agr n_at 10 e 64 | val loss 3.4280 val acc 14.9756 best val_acc 17.106331
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 24, 21]
# epoch: 65, bulyan: at our-agr n_at 10 e 65 | val loss 2.8753 val acc 11.2419 best val_acc 17.106331
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 24, 21]
# epoch: 66, bulyan: at our-agr n_at 10 e 66 | val loss 2.4183 val acc 9.8823 best val_acc 17.106331
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 24, 21]
# epoch: 67, bulyan: at our-agr n_at 10 e 67 | val loss 2.2953 val acc 15.7265 best val_acc 17.106331
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 24, 21]
# epoch: 68, bulyan: at our-agr n_at 10 e 68 | val loss 2.3035 val acc 16.2946 best val_acc 17.106331
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 24, 21]
# epoch: 69, bulyan: at our-agr n_at 10 e 69 | val loss 2.2950 val acc 13.7175 best val_acc 17.106331
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 24, 21]
# epoch: 70, bulyan: at our-agr n_at 10 e 70 | val loss 2.7917 val acc 13.0682 best val_acc 17.106331
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 24, 21]
# epoch: 71, bulyan: at our-agr n_at 10 e 71 | val loss 2.6912 val acc 15.8279 best val_acc 17.106331
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 24, 37]
# epoch: 72, bulyan: at our-agr n_at 10 e 72 | val loss 2.9184 val acc 10.5722 best val_acc 17.106331
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 24, 21]
# epoch: 73, bulyan: at our-agr n_at 10 e 73 | val loss 2.6123 val acc 10.6128 best val_acc 17.106331
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 24, 37]
# epoch: 74, bulyan: at our-agr n_at 10 e 74 | val loss 2.3773 val acc 17.4513 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 24, 37]
# epoch: 75, bulyan: at our-agr n_at 10 e 75 | val loss 2.3652 val acc 15.1583 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 10, 27, 35, 18, 24, 37]
# epoch: 76, bulyan: at our-agr n_at 10 e 76 | val loss 5.7545 val acc 13.3320 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 77, bulyan: at our-agr n_at 10 e 77 | val loss 3.5133 val acc 9.8620 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 78, bulyan: at our-agr n_at 10 e 78 | val loss 2.8335 val acc 10.2273 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 79, bulyan: at our-agr n_at 10 e 79 | val loss 2.5742 val acc 9.4765 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 80, bulyan: at our-agr n_at 10 e 80 | val loss 2.4910 val acc 10.7549 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 37, 24]
# epoch: 81, bulyan: at our-agr n_at 10 e 81 | val loss 3.8612 val acc 10.0244 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 82, bulyan: at our-agr n_at 10 e 82 | val loss 3.1487 val acc 11.7695 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 83, bulyan: at our-agr n_at 10 e 83 | val loss 2.7973 val acc 9.8620 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 84, bulyan: at our-agr n_at 10 e 84 | val loss 2.6919 val acc 10.1461 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 85, bulyan: at our-agr n_at 10 e 85 | val loss 4.3738 val acc 9.8011 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 86, bulyan: at our-agr n_at 10 e 86 | val loss 3.3842 val acc 10.2273 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 87, bulyan: at our-agr n_at 10 e 87 | val loss 2.7475 val acc 9.8620 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 88, bulyan: at our-agr n_at 10 e 88 | val loss 2.4478 val acc 10.2273 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 89, bulyan: at our-agr n_at 10 e 89 | val loss 2.5451 val acc 13.4334 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 90, bulyan: at our-agr n_at 10 e 90 | val loss 2.8154 val acc 10.1461 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 91, bulyan: at our-agr n_at 10 e 91 | val loss 4.8544 val acc 9.8011 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 92, bulyan: at our-agr n_at 10 e 92 | val loss 3.6308 val acc 11.8912 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 93, bulyan: at our-agr n_at 10 e 93 | val loss 2.9228 val acc 9.8620 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 94, bulyan: at our-agr n_at 10 e 94 | val loss 2.6363 val acc 10.7752 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 95, bulyan: at our-agr n_at 10 e 95 | val loss 2.4782 val acc 11.6680 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 96, bulyan: at our-agr n_at 10 e 96 | val loss 2.3723 val acc 12.4797 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 97, bulyan: at our-agr n_at 10 e 97 | val loss 3.0180 val acc 12.2159 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 98, bulyan: at our-agr n_at 10 e 98 | val loss 3.0198 val acc 10.0852 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 99, bulyan: at our-agr n_at 10 e 99 | val loss 4.7063 val acc 9.8011 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 100, bulyan: at our-agr n_at 10 e 100 | val loss 3.6302 val acc 9.6591 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 101, bulyan: at our-agr n_at 10 e 101 | val loss 3.1039 val acc 9.8620 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 102, bulyan: at our-agr n_at 10 e 102 | val loss 3.1890 val acc 10.1461 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 103, bulyan: at our-agr n_at 10 e 103 | val loss 6.2836 val acc 10.0244 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 17]
# epoch: 104, bulyan: at our-agr n_at 10 e 104 | val loss 3.8293 val acc 10.2273 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 105, bulyan: at our-agr n_at 10 e 105 | val loss 2.9719 val acc 10.3084 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 106, bulyan: at our-agr n_at 10 e 106 | val loss 2.6832 val acc 10.1867 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 107, bulyan: at our-agr n_at 10 e 107 | val loss 2.7226 val acc 10.1461 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 108, bulyan: at our-agr n_at 10 e 108 | val loss 5.9619 val acc 9.8011 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 109, bulyan: at our-agr n_at 10 e 109 | val loss 3.8416 val acc 5.9862 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 110, bulyan: at our-agr n_at 10 e 110 | val loss 4.2584 val acc 9.8620 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 111, bulyan: at our-agr n_at 10 e 111 | val loss 3.4307 val acc 10.3084 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 112, bulyan: at our-agr n_at 10 e 112 | val loss 2.7365 val acc 9.8620 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 113, bulyan: at our-agr n_at 10 e 113 | val loss 2.7545 val acc 10.1461 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 114, bulyan: at our-agr n_at 10 e 114 | val loss 5.2423 val acc 10.0244 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 115, bulyan: at our-agr n_at 10 e 115 | val loss 3.5666 val acc 10.3084 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 116, bulyan: at our-agr n_at 10 e 116 | val loss 3.6244 val acc 9.8620 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 117, bulyan: at our-agr n_at 10 e 117 | val loss 2.9389 val acc 10.3693 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 118, bulyan: at our-agr n_at 10 e 118 | val loss 2.6990 val acc 9.8823 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 119, bulyan: at our-agr n_at 10 e 119 | val loss 2.9243 val acc 10.1461 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 120, bulyan: at our-agr n_at 10 e 120 | val loss 4.7452 val acc 9.8011 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 121, bulyan: at our-agr n_at 10 e 121 | val loss 3.3097 val acc 15.2394 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 122, bulyan: at our-agr n_at 10 e 122 | val loss 2.8044 val acc 9.8620 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 123, bulyan: at our-agr n_at 10 e 123 | val loss 2.5063 val acc 15.0974 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 124, bulyan: at our-agr n_at 10 e 124 | val loss 2.5690 val acc 10.2273 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 125, bulyan: at our-agr n_at 10 e 125 | val loss 2.6178 val acc 10.1055 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 126, bulyan: at our-agr n_at 10 e 126 | val loss 3.6332 val acc 12.9667 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 127, bulyan: at our-agr n_at 10 e 127 | val loss 2.7760 val acc 15.1380 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 128, bulyan: at our-agr n_at 10 e 128 | val loss 2.4833 val acc 10.2273 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 129, bulyan: at our-agr n_at 10 e 129 | val loss 2.3738 val acc 15.6047 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 130, bulyan: at our-agr n_at 10 e 130 | val loss 2.8409 val acc 15.0974 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 131, bulyan: at our-agr n_at 10 e 131 | val loss 2.5511 val acc 11.8101 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 132, bulyan: at our-agr n_at 10 e 132 | val loss 2.6875 val acc 13.9205 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 133, bulyan: at our-agr n_at 10 e 133 | val loss 2.5534 val acc 13.6972 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 134, bulyan: at our-agr n_at 10 e 134 | val loss 3.3945 val acc 13.5958 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 135, bulyan: at our-agr n_at 10 e 135 | val loss 2.7262 val acc 14.5698 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 136, bulyan: at our-agr n_at 10 e 136 | val loss 2.4275 val acc 10.4302 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 137, bulyan: at our-agr n_at 10 e 137 | val loss 2.2853 val acc 16.2541 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 138, bulyan: at our-agr n_at 10 e 138 | val loss 2.5299 val acc 15.0974 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 139, bulyan: at our-agr n_at 10 e 139 | val loss 2.4861 val acc 14.4886 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 140, bulyan: at our-agr n_at 10 e 140 | val loss 3.1044 val acc 12.5000 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 141, bulyan: at our-agr n_at 10 e 141 | val loss 2.5511 val acc 14.3263 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 142, bulyan: at our-agr n_at 10 e 142 | val loss 2.4849 val acc 15.3612 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 143, bulyan: at our-agr n_at 10 e 143 | val loss 2.3654 val acc 13.4334 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 144, bulyan: at our-agr n_at 10 e 144 | val loss 2.4522 val acc 14.9554 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 145, bulyan: at our-agr n_at 10 e 145 | val loss 2.3861 val acc 14.4075 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 146, bulyan: at our-agr n_at 10 e 146 | val loss 3.3987 val acc 15.3206 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 147, bulyan: at our-agr n_at 10 e 147 | val loss 2.6801 val acc 14.5901 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 148, bulyan: at our-agr n_at 10 e 148 | val loss 2.4307 val acc 15.1786 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 149, bulyan: at our-agr n_at 10 e 149 | val loss 2.2661 val acc 16.3758 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 150, bulyan: at our-agr n_at 10 e 150 | val loss 2.6437 val acc 15.5438 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 151, bulyan: at our-agr n_at 10 e 151 | val loss 2.5212 val acc 13.3320 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 152, bulyan: at our-agr n_at 10 e 152 | val loss 2.7257 val acc 15.7265 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 153, bulyan: at our-agr n_at 10 e 153 | val loss 2.4418 val acc 15.3206 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 154, bulyan: at our-agr n_at 10 e 154 | val loss 3.2472 val acc 15.2394 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 155, bulyan: at our-agr n_at 10 e 155 | val loss 2.5792 val acc 13.0073 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 156, bulyan: at our-agr n_at 10 e 156 | val loss 2.2667 val acc 15.2597 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 157, bulyan: at our-agr n_at 10 e 157 | val loss 2.1592 val acc 17.0049 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 158, bulyan: at our-agr n_at 10 e 158 | val loss 2.1486 val acc 15.9700 best val_acc 17.451299
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 159, bulyan: at our-agr n_at 10 e 159 | val loss 2.1364 val acc 18.0195 best val_acc 18.019481
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 160, bulyan: at our-agr n_at 10 e 160 | val loss 2.2451 val acc 16.3758 best val_acc 18.019481
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 161, bulyan: at our-agr n_at 10 e 161 | val loss 2.2631 val acc 18.5674 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 162, bulyan: at our-agr n_at 10 e 162 | val loss 3.3464 val acc 15.9091 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 163, bulyan: at our-agr n_at 10 e 163 | val loss 3.0458 val acc 10.2273 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 164, bulyan: at our-agr n_at 10 e 164 | val loss 2.9716 val acc 9.8620 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 165, bulyan: at our-agr n_at 10 e 165 | val loss 2.4122 val acc 9.8011 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 166, bulyan: at our-agr n_at 10 e 166 | val loss 2.2932 val acc 17.4716 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 167, bulyan: at our-agr n_at 10 e 167 | val loss 2.8255 val acc 14.6307 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 168, bulyan: at our-agr n_at 10 e 168 | val loss 2.9281 val acc 13.6769 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 169, bulyan: at our-agr n_at 10 e 169 | val loss 4.0901 val acc 16.4570 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 170, bulyan: at our-agr n_at 10 e 170 | val loss 3.2229 val acc 9.8620 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 171, bulyan: at our-agr n_at 10 e 171 | val loss 2.6487 val acc 10.8360 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 172, bulyan: at our-agr n_at 10 e 172 | val loss 2.3905 val acc 13.7378 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 173, bulyan: at our-agr n_at 10 e 173 | val loss 3.1969 val acc 14.7119 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 174, bulyan: at our-agr n_at 10 e 174 | val loss 2.8730 val acc 13.0885 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 175, bulyan: at our-agr n_at 10 e 175 | val loss 2.7381 val acc 10.1867 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 176, bulyan: at our-agr n_at 10 e 176 | val loss 2.6295 val acc 10.2273 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 177, bulyan: at our-agr n_at 10 e 177 | val loss 2.5407 val acc 13.8393 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 178, bulyan: at our-agr n_at 10 e 178 | val loss 2.3796 val acc 14.7119 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 179, bulyan: at our-agr n_at 10 e 179 | val loss 2.6404 val acc 14.4683 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 180, bulyan: at our-agr n_at 10 e 180 | val loss 2.3924 val acc 15.3206 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 181, bulyan: at our-agr n_at 10 e 181 | val loss 2.2950 val acc 14.5901 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 182, bulyan: at our-agr n_at 10 e 182 | val loss 2.2621 val acc 16.8425 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 183, bulyan: at our-agr n_at 10 e 183 | val loss 2.4762 val acc 15.6859 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 184, bulyan: at our-agr n_at 10 e 184 | val loss 2.3878 val acc 14.4278 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 185, bulyan: at our-agr n_at 10 e 185 | val loss 2.3482 val acc 16.7817 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 186, bulyan: at our-agr n_at 10 e 186 | val loss 2.2097 val acc 15.8076 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 187, bulyan: at our-agr n_at 10 e 187 | val loss 2.4145 val acc 16.0308 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 188, bulyan: at our-agr n_at 10 e 188 | val loss 2.3246 val acc 17.1063 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 189, bulyan: at our-agr n_at 10 e 189 | val loss 2.4685 val acc 16.0917 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 190, bulyan: at our-agr n_at 10 e 190 | val loss 2.3256 val acc 16.2135 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 191, bulyan: at our-agr n_at 10 e 191 | val loss 2.4010 val acc 16.4164 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 192, bulyan: at our-agr n_at 10 e 192 | val loss 2.2706 val acc 15.9091 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 193, bulyan: at our-agr n_at 10 e 193 | val loss 2.4558 val acc 16.3961 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 194, bulyan: at our-agr n_at 10 e 194 | val loss 2.2596 val acc 16.4164 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 195, bulyan: at our-agr n_at 10 e 195 | val loss 2.3417 val acc 16.2338 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 196, bulyan: at our-agr n_at 10 e 196 | val loss 2.2360 val acc 17.3295 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 197, bulyan: at our-agr n_at 10 e 197 | val loss 2.4518 val acc 16.4773 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 198, bulyan: at our-agr n_at 10 e 198 | val loss 2.3079 val acc 16.9643 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 199, bulyan: at our-agr n_at 10 e 199 | val loss 2.3540 val acc 16.4570 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 200, bulyan: at our-agr n_at 10 e 200 | val loss 2.3281 val acc 15.7265 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 201, bulyan: at our-agr n_at 10 e 201 | val loss 2.7868 val acc 14.7727 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 202, bulyan: at our-agr n_at 10 e 202 | val loss 2.4750 val acc 15.5641 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 203, bulyan: at our-agr n_at 10 e 203 | val loss 2.2939 val acc 11.6680 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 204, bulyan: at our-agr n_at 10 e 204 | val loss 2.2307 val acc 17.2687 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 205, bulyan: at our-agr n_at 10 e 205 | val loss 2.1798 val acc 18.2630 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 206, bulyan: at our-agr n_at 10 e 206 | val loss 2.2647 val acc 15.5438 best val_acc 18.567370
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 207, bulyan: at our-agr n_at 10 e 207 | val loss 2.2997 val acc 18.6080 best val_acc 18.607955
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 208, bulyan: at our-agr n_at 10 e 208 | val loss 2.5707 val acc 16.9846 best val_acc 18.607955
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 209, bulyan: at our-agr n_at 10 e 209 | val loss 2.4240 val acc 16.4570 best val_acc 18.607955
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 210, bulyan: at our-agr n_at 10 e 210 | val loss 2.5071 val acc 16.5787 best val_acc 18.607955
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 211, bulyan: at our-agr n_at 10 e 211 | val loss 2.3094 val acc 16.8222 best val_acc 18.607955
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 212, bulyan: at our-agr n_at 10 e 212 | val loss 2.2963 val acc 16.7208 best val_acc 18.607955
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 213, bulyan: at our-agr n_at 10 e 213 | val loss 2.3153 val acc 18.3239 best val_acc 18.607955
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 214, bulyan: at our-agr n_at 10 e 214 | val loss 2.7340 val acc 16.3149 best val_acc 18.607955
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 215, bulyan: at our-agr n_at 10 e 215 | val loss 2.4976 val acc 16.5179 best val_acc 18.607955
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 216, bulyan: at our-agr n_at 10 e 216 | val loss 2.2902 val acc 16.9846 best val_acc 18.607955
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 217, bulyan: at our-agr n_at 10 e 217 | val loss 2.1494 val acc 17.4716 best val_acc 18.607955
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 218, bulyan: at our-agr n_at 10 e 218 | val loss 2.6313 val acc 16.0308 best val_acc 18.607955
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 219, bulyan: at our-agr n_at 10 e 219 | val loss 2.4054 val acc 16.4570 best val_acc 18.607955
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 220, bulyan: at our-agr n_at 10 e 220 | val loss 2.2816 val acc 16.7614 best val_acc 18.607955
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 221, bulyan: at our-agr n_at 10 e 221 | val loss 2.2091 val acc 18.4862 best val_acc 18.607955
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 222, bulyan: at our-agr n_at 10 e 222 | val loss 2.8136 val acc 17.4716 best val_acc 18.607955
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 223, bulyan: at our-agr n_at 10 e 223 | val loss 2.5709 val acc 16.2338 best val_acc 18.607955
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 224, bulyan: at our-agr n_at 10 e 224 | val loss 2.3511 val acc 14.7119 best val_acc 18.607955
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 225, bulyan: at our-agr n_at 10 e 225 | val loss 2.4112 val acc 16.8222 best val_acc 18.607955
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 226, bulyan: at our-agr n_at 10 e 226 | val loss 2.3270 val acc 11.5260 best val_acc 18.607955
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 227, bulyan: at our-agr n_at 10 e 227 | val loss 2.2591 val acc 15.8279 best val_acc 18.607955
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 228, bulyan: at our-agr n_at 10 e 228 | val loss 2.1773 val acc 16.3961 best val_acc 18.607955
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 229, bulyan: at our-agr n_at 10 e 229 | val loss 2.3099 val acc 14.2248 best val_acc 18.607955
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 230, bulyan: at our-agr n_at 10 e 230 | val loss 2.2636 val acc 14.8336 best val_acc 18.607955
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 231, bulyan: at our-agr n_at 10 e 231 | val loss 2.3266 val acc 17.1469 best val_acc 18.607955
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 232, bulyan: at our-agr n_at 10 e 232 | val loss 2.1766 val acc 14.8336 best val_acc 18.607955
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 233, bulyan: at our-agr n_at 10 e 233 | val loss 2.1901 val acc 17.3904 best val_acc 18.607955
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 234, bulyan: at our-agr n_at 10 e 234 | val loss 2.1369 val acc 15.4018 best val_acc 18.607955
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 235, bulyan: at our-agr n_at 10 e 235 | val loss 2.1377 val acc 18.2833 best val_acc 18.607955
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 236, bulyan: at our-agr n_at 10 e 236 | val loss 2.2693 val acc 14.7727 best val_acc 18.607955
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 237, bulyan: at our-agr n_at 10 e 237 | val loss 2.4282 val acc 19.3588 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 238, bulyan: at our-agr n_at 10 e 238 | val loss 2.5391 val acc 17.3093 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 239, bulyan: at our-agr n_at 10 e 239 | val loss 2.3246 val acc 18.7906 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 240, bulyan: at our-agr n_at 10 e 240 | val loss 2.5939 val acc 16.4570 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 241, bulyan: at our-agr n_at 10 e 241 | val loss 2.3783 val acc 17.2890 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 242, bulyan: at our-agr n_at 10 e 242 | val loss 2.2820 val acc 17.1063 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 243, bulyan: at our-agr n_at 10 e 243 | val loss 2.4195 val acc 18.2630 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 244, bulyan: at our-agr n_at 10 e 244 | val loss 3.0280 val acc 16.3149 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 245, bulyan: at our-agr n_at 10 e 245 | val loss 2.7529 val acc 17.3498 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 246, bulyan: at our-agr n_at 10 e 246 | val loss 2.4195 val acc 16.4164 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 247, bulyan: at our-agr n_at 10 e 247 | val loss 2.3375 val acc 18.0398 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 248, bulyan: at our-agr n_at 10 e 248 | val loss 2.7632 val acc 16.9643 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 249, bulyan: at our-agr n_at 10 e 249 | val loss 2.4868 val acc 17.3093 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 250, bulyan: at our-agr n_at 10 e 250 | val loss 2.3030 val acc 16.7817 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 251, bulyan: at our-agr n_at 10 e 251 | val loss 2.2995 val acc 18.1615 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 252, bulyan: at our-agr n_at 10 e 252 | val loss 2.9827 val acc 17.1469 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 253, bulyan: at our-agr n_at 10 e 253 | val loss 2.6101 val acc 16.8222 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 254, bulyan: at our-agr n_at 10 e 254 | val loss 2.2107 val acc 16.3555 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 255, bulyan: at our-agr n_at 10 e 255 | val loss 2.2061 val acc 18.7906 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 256, bulyan: at our-agr n_at 10 e 256 | val loss 2.8437 val acc 16.8425 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 257, bulyan: at our-agr n_at 10 e 257 | val loss 2.5694 val acc 17.6948 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 258, bulyan: at our-agr n_at 10 e 258 | val loss 2.2410 val acc 17.0657 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 259, bulyan: at our-agr n_at 10 e 259 | val loss 2.3555 val acc 18.7500 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 260, bulyan: at our-agr n_at 10 e 260 | val loss 2.6491 val acc 15.2394 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 261, bulyan: at our-agr n_at 10 e 261 | val loss 2.4419 val acc 13.1088 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 262, bulyan: at our-agr n_at 10 e 262 | val loss 2.3118 val acc 16.2338 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 263, bulyan: at our-agr n_at 10 e 263 | val loss 2.2610 val acc 16.9440 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 264, bulyan: at our-agr n_at 10 e 264 | val loss 2.2464 val acc 13.3726 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 265, bulyan: at our-agr n_at 10 e 265 | val loss 2.3043 val acc 18.6485 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 266, bulyan: at our-agr n_at 10 e 266 | val loss 2.2242 val acc 15.0568 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 267, bulyan: at our-agr n_at 10 e 267 | val loss 2.2989 val acc 17.6948 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 268, bulyan: at our-agr n_at 10 e 268 | val loss 2.2611 val acc 13.7987 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 269, bulyan: at our-agr n_at 10 e 269 | val loss 2.4621 val acc 18.4253 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 270, bulyan: at our-agr n_at 10 e 270 | val loss 2.3762 val acc 16.2338 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 271, bulyan: at our-agr n_at 10 e 271 | val loss 2.2621 val acc 17.0049 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 272, bulyan: at our-agr n_at 10 e 272 | val loss 2.5606 val acc 16.5584 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 273, bulyan: at our-agr n_at 10 e 273 | val loss 2.4486 val acc 18.2833 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 274, bulyan: at our-agr n_at 10 e 274 | val loss 2.3295 val acc 17.2687 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 275, bulyan: at our-agr n_at 10 e 275 | val loss 2.2446 val acc 18.2427 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 276, bulyan: at our-agr n_at 10 e 276 | val loss 2.9899 val acc 16.6396 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 277, bulyan: at our-agr n_at 10 e 277 | val loss 2.8009 val acc 10.6534 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 278, bulyan: at our-agr n_at 10 e 278 | val loss 2.5572 val acc 16.1526 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 279, bulyan: at our-agr n_at 10 e 279 | val loss 2.1218 val acc 17.7963 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 280, bulyan: at our-agr n_at 10 e 280 | val loss 2.3322 val acc 17.2281 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 281, bulyan: at our-agr n_at 10 e 281 | val loss 2.3528 val acc 17.4716 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 282, bulyan: at our-agr n_at 10 e 282 | val loss 2.8040 val acc 18.2833 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 283, bulyan: at our-agr n_at 10 e 283 | val loss 2.4028 val acc 17.7354 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 284, bulyan: at our-agr n_at 10 e 284 | val loss 2.4038 val acc 17.8166 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 285, bulyan: at our-agr n_at 10 e 285 | val loss 2.4753 val acc 18.0601 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 286, bulyan: at our-agr n_at 10 e 286 | val loss 3.2491 val acc 16.9237 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 287, bulyan: at our-agr n_at 10 e 287 | val loss 3.0445 val acc 13.1494 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 24]
# epoch: 288, bulyan: at our-agr n_at 10 e 288 | val loss 2.8834 val acc 10.9578 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 289, bulyan: at our-agr n_at 10 e 289 | val loss 2.5944 val acc 14.1234 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 290, bulyan: at our-agr n_at 10 e 290 | val loss 2.8963 val acc 18.5268 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 291, bulyan: at our-agr n_at 10 e 291 | val loss 3.0450 val acc 17.5325 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 292, bulyan: at our-agr n_at 10 e 292 | val loss 2.6279 val acc 10.9984 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 293, bulyan: at our-agr n_at 10 e 293 | val loss 2.3759 val acc 14.0016 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 294, bulyan: at our-agr n_at 10 e 294 | val loss 2.1765 val acc 15.8482 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 295, bulyan: at our-agr n_at 10 e 295 | val loss 2.3472 val acc 16.4164 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 296, bulyan: at our-agr n_at 10 e 296 | val loss 2.2696 val acc 17.7963 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 297, bulyan: at our-agr n_at 10 e 297 | val loss 2.2972 val acc 18.4659 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 298, bulyan: at our-agr n_at 10 e 298 | val loss 2.5517 val acc 16.5381 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 299, bulyan: at our-agr n_at 10 e 299 | val loss 2.6456 val acc 19.2979 best val_acc 19.358766
# discarded index [20, 47, 45, 31, 18, 35, 27, 10, 21, 37]
# epoch: 300, bulyan: at our-agr n_at 10 e 300 | val loss 2.9488 val acc 17.1063 best val_acc 19.358766

# %%
import matplotlib.pyplot as plt

# Plotting the data
for col in ['loss', 'validation accuracy', 'best validation accuracy']:
    plt.plot(df['epoch'].tolist(), df[col].tolist())
    plt.title(f"{title} {col}")
    plt.show()
