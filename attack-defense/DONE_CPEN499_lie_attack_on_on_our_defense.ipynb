# %% [markdown]
# # The notebook contains
# ### Code for _Bulyan_ aggregation algorithm, *when gradient updates of benign clients are unknown to adversary*
# ### Evaluation of all of the attacks (Fang, LIE, and our SOTA AGR-tailored and AGR-agnstic) on Bulyan

# %% [markdown]
# ## Import packages

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
from __future__ import print_function
import argparse, os, sys, csv, shutil, time, random, operator, pickle, ast, math
import numpy as np
import pandas as pd
from torch.optim import Optimizer
import torch.nn.functional as F
import torch
import pickle
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data as data
import torch.multiprocessing as mp
import math
sys.path.insert(0,'./../utils/')
from logger import *
from eval import *
from misc import *

from cifar10_normal_train import *
from cifar10_util import *
from adam import Adam
from sgd import SGD

# %% [markdown]
# ## Load Data
# Divide cifar10 data among 50 clients in Non-IID fashion using Dirichlet distribution

# %%
n_users = 50
user_tr_len = pickle.load(open('./data/user_tr_len.pkl','rb'))

user_train_data_tensors = pickle.load(open('./data/user_train_data_tensors.pkl','rb'))
user_train_label_tensors = pickle.load(open('./data/user_train_label_tensors.pkl','rb'))

val_data_tensor = pickle.load(open('./data/val_data_tensor.pkl','rb'))
val_label_tensor = pickle.load(open('./data/val_label_tensor.pkl','rb'))
te_data_tensor = pickle.load(open('./data/te_data_tensor.pkl','rb'))
te_label_tensor = pickle.load(open('./data/te_label_tensor.pkl','rb'))

# %% [markdown]
# ## Our Aggregation Function

# %%
def our_mean_defense(all_updates, n_attackers, history_updates):
    discarded_history = get_discarded_index(n_attackers, history_updates)

    mask = torch.ones(all_updates.size(0), dtype=torch.bool)
    mask[discarded_history] = False
    remaining_updates = all_updates[mask]

    print('discarded index', discarded_history)

    return torch.nanmean(remaining_updates, dim=0)

####
def euclidean_distance(row1, row2):
    return torch.sqrt(torch.sum((row1 - row2) ** 2))
####

def get_discarded_index(n_attackers, history_updates):
    n_users = history_updates.shape[0]

    ####
    distance_matrix = [[0 if i == j else euclidean_distance(history_updates[i, :], history_updates[j, :]) for j in range(n_users)] for i in range(n_users)]
    ####

    sum_of_distances = [sum(row) for row in distance_matrix]

    discarded_history = []
    for _ in range(n_attackers):
        max_distance = max(sum_of_distances)
        index_of_max_distance = sum_of_distances.index(max_distance)
        discarded_history.append(index_of_max_distance)

        for i in range(n_users):
            sum_of_distances[i] -= distance_matrix[i][index_of_max_distance]
        sum_of_distances[index_of_max_distance] = -1

    return discarded_history

# %% [markdown]
# ## Set nepochs

# %%
nepochs= 300

# %% [markdown]
# ## LIE attack and our defense

# %%
def lie_attack(all_updates, z):
    avg = torch.mean(all_updates, dim=0)
    std = torch.std(all_updates, dim=0)
    return avg + z * std

# %%
batch_size=250
resume=0

schedule=[1000]

gamma=.5
opt = 'sgd'
fed_lr=0.5
criterion=nn.CrossEntropyLoss()
use_cuda = torch.cuda.is_available()

at_type = 'multi-krum'

aggregation='bulyan'
multi_k = False
candidates = []

dev_type ='std'
n_attackers=[10]
z_values={3:0.69847, 5:0.7054, 8:0.71904, 10:0.72575, 12:0.73891}

arch='alexnet'
chkpt='./'+aggregation

past_mean = []
past_abs_sum = []
past_median = []
past_lower_quartile = []
past_upper_quartile = []
past_std = []

title = "LIE attack and our defense"

for n_attacker in n_attackers:
    epoch_num = 0
    best_global_acc = 0
    best_global_te_acc = 0

    torch.cuda.empty_cache()

    fed_model, _ = return_model(arch, 0.1, 0.9, parallel=False)
    optimizer_fed = SGD(fed_model.parameters(), lr=fed_lr)

    df = pd.DataFrame(columns = ['epoch', 'loss', 'validation accuracy', 'best validation accuracy'])

    ####
    history = torch.zeros((n_users, nepochs + 1), dtype=torch.float32).cuda()
    ####

    model_grads = []
    while epoch_num <= nepochs:
        user_grads=[]

        for i in range(n_users): # 50
            nbatches = user_tr_len[i]//batch_size

            inputs = user_train_data_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]
            targets = user_train_label_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]

            targets = targets.type(torch.LongTensor)

            inputs, targets = inputs.cuda(), targets.cuda()
            inputs, targets = torch.autograd.Variable(inputs), torch.autograd.Variable(targets)

            outputs = fed_model(inputs)
            loss = criterion(outputs, targets)
            fed_model.zero_grad()
            loss.backward(retain_graph=True)

            param_grad=[]
            for param in fed_model.parameters():
                param_grad=param.grad.data.view(-1) if not len(param_grad) else torch.cat((param_grad,param.grad.view(-1)))


            user_grads=param_grad[None, :] if len(user_grads)==0 else torch.cat((user_grads,param_grad[None,:]), 0)

        if epoch_num in schedule:
            for param_group in optimizer_fed.param_groups:
                param_group['lr'] *= gamma
                print('New learnin rate ', param_group['lr'])

        updates_abs_mean = user_grads.abs().mean(dim=1, keepdim=True)

        if n_attacker > 0:
            mal_update = lie_attack(user_grads, z_values[n_attacker])
            malicious_grads = torch.cat((torch.stack([mal_update]*n_attacker), user_grads[n_attacker:]))
        else:   # No attack
            malicious_grads = user_grads

        if not (malicious_grads.shape[0]==50):
            print(malicious_grads.shape)

        updates_abs_mean = malicious_grads.abs().mean(dim=1, keepdim=True)

        history[:, epoch_num] = updates_abs_mean.squeeze()
        agg_grads = our_mean_defense(malicious_grads, n_attacker, history)

        del user_grads

        start_idx=0

        optimizer_fed.zero_grad()

        model_grads=[]

        for i, param in enumerate(fed_model.parameters()):
            param_=agg_grads[start_idx:start_idx+len(param.data.view(-1))].reshape(param.data.shape)
            start_idx=start_idx+len(param.data.view(-1))
            param_=param_.cuda()
            model_grads.append(param_)

        optimizer_fed.step(model_grads)

        val_loss, val_acc = test(val_data_tensor,val_label_tensor,fed_model,criterion,use_cuda)
        te_loss, te_acc = test(te_data_tensor,te_label_tensor, fed_model, criterion, use_cuda)

        is_best = best_global_acc < val_acc

        best_global_acc = max(best_global_acc, val_acc)

        if is_best:
            best_global_te_acc = te_acc


        print('epoch: %d, %s: at %s n_at %d e %d | val loss %.4f val acc %.4f best val_acc %f'%(epoch_num, aggregation, at_type, n_attacker, epoch_num, val_loss, val_acc, best_global_acc))
        new_row = pd.DataFrame([{
            'epoch': epoch_num,
            'loss': val_loss,
            'validation accuracy': val_acc,
            'best validation accuracy': best_global_acc
            }])
        df = pd.concat([df, new_row], ignore_index=True)
        df.to_csv('lie_our-defense.csv', index=False)

        if val_loss > 1000:
            print('val loss %f too high'%val_loss)
            break

        epoch_num+=1
# Out:
# discarded index [20, 34, 15, 31, 39, 47, 37, 22, 29, 42]
# c:\Users\tians\Desktop\CPEN499\CPEN497-FL\attack-defense\sgd.py:109: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at ..\torch\csrc\utils\python_arg_parser.cpp:1630.)
#   p.data.add_(-group['lr'], d_p)
# epoch: 0, bulyan: at multi-krum n_at 10 e 0 | val loss 2.3026 val acc 14.9554 best val_acc 14.955357
# C:\Users\tians\AppData\Local\Temp\ipykernel_12176\1010853095.py:132: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, new_row], ignore_index=True)
# discarded index [20, 34, 15, 39, 31, 47, 22, 42, 18, 29]
# epoch: 1, bulyan: at multi-krum n_at 10 e 1 | val loss 2.3023 val acc 14.7119 best val_acc 14.955357
# discarded index [20, 34, 15, 39, 31, 47, 18, 42, 22, 29]
# epoch: 2, bulyan: at multi-krum n_at 10 e 2 | val loss 2.3022 val acc 15.5641 best val_acc 15.564123
# discarded index [20, 34, 15, 39, 31, 47, 22, 42, 18, 26]
# epoch: 3, bulyan: at multi-krum n_at 10 e 3 | val loss 2.3021 val acc 15.1380 best val_acc 15.564123
# discarded index [20, 34, 15, 39, 31, 47, 42, 22, 18, 26]
# epoch: 4, bulyan: at multi-krum n_at 10 e 4 | val loss 2.3020 val acc 15.8279 best val_acc 15.827922
# discarded index [20, 34, 15, 39, 31, 47, 42, 18, 22, 29]
# epoch: 5, bulyan: at multi-krum n_at 10 e 5 | val loss 2.3019 val acc 16.2744 best val_acc 16.274351
# discarded index [20, 34, 15, 39, 31, 47, 18, 42, 22, 26]
# epoch: 6, bulyan: at multi-krum n_at 10 e 6 | val loss 2.3018 val acc 14.4886 best val_acc 16.274351
# discarded index [20, 34, 15, 39, 31, 47, 18, 42, 26, 22]
# epoch: 7, bulyan: at multi-krum n_at 10 e 7 | val loss 2.3016 val acc 15.7265 best val_acc 16.274351
# discarded index [20, 15, 34, 39, 31, 47, 26, 42, 18, 22]
# epoch: 8, bulyan: at multi-krum n_at 10 e 8 | val loss 2.3015 val acc 14.7524 best val_acc 16.274351
# discarded index [20, 34, 15, 39, 31, 47, 18, 26, 42, 22]
# epoch: 9, bulyan: at multi-krum n_at 10 e 9 | val loss 2.3013 val acc 15.9700 best val_acc 16.274351
# discarded index [20, 15, 34, 39, 31, 47, 18, 42, 26, 22]
# epoch: 10, bulyan: at multi-krum n_at 10 e 10 | val loss 2.3011 val acc 16.3758 best val_acc 16.375812
# discarded index [20, 34, 15, 39, 31, 47, 26, 18, 42, 22]
# epoch: 11, bulyan: at multi-krum n_at 10 e 11 | val loss 2.3007 val acc 14.9554 best val_acc 16.375812
# discarded index [20, 34, 15, 39, 31, 47, 26, 18, 42, 22]
# epoch: 12, bulyan: at multi-krum n_at 10 e 12 | val loss 2.3004 val acc 15.4221 best val_acc 16.375812
# discarded index [20, 34, 15, 39, 31, 47, 26, 18, 42, 22]
# epoch: 13, bulyan: at multi-krum n_at 10 e 13 | val loss 2.2999 val acc 16.9846 best val_acc 16.984578
# discarded index [20, 34, 15, 39, 31, 47, 26, 18, 42, 46]
# epoch: 14, bulyan: at multi-krum n_at 10 e 14 | val loss 2.2995 val acc 14.9148 best val_acc 16.984578
# discarded index [20, 34, 15, 39, 31, 47, 26, 18, 42, 46]
# epoch: 15, bulyan: at multi-krum n_at 10 e 15 | val loss 2.2989 val acc 15.7670 best val_acc 16.984578
# discarded index [20, 34, 15, 39, 31, 47, 26, 18, 42, 46]
# epoch: 16, bulyan: at multi-krum n_at 10 e 16 | val loss 2.2981 val acc 16.4367 best val_acc 16.984578
# discarded index [20, 34, 15, 39, 31, 47, 26, 18, 46, 42]
# epoch: 17, bulyan: at multi-krum n_at 10 e 17 | val loss 2.2971 val acc 17.1266 best val_acc 17.126623
# discarded index [20, 34, 15, 31, 47, 39, 26, 18, 46, 42]
# epoch: 18, bulyan: at multi-krum n_at 10 e 18 | val loss 2.2961 val acc 16.2338 best val_acc 17.126623
# discarded index [20, 34, 15, 47, 31, 39, 26, 46, 18, 42]
# epoch: 19, bulyan: at multi-krum n_at 10 e 19 | val loss 2.2947 val acc 17.4310 best val_acc 17.431006
# discarded index [20, 34, 15, 47, 31, 39, 26, 46, 18, 42]
# epoch: 20, bulyan: at multi-krum n_at 10 e 20 | val loss 2.2928 val acc 18.7703 best val_acc 18.770292
# discarded index [20, 34, 15, 47, 31, 39, 26, 46, 18, 13]
# epoch: 21, bulyan: at multi-krum n_at 10 e 21 | val loss 2.2905 val acc 18.6282 best val_acc 18.770292
# discarded index [20, 34, 47, 15, 26, 31, 39, 46, 13, 18]
# epoch: 22, bulyan: at multi-krum n_at 10 e 22 | val loss 2.2875 val acc 18.5471 best val_acc 18.770292
# discarded index [20, 47, 34, 15, 31, 26, 46, 39, 13, 18]
# epoch: 23, bulyan: at multi-krum n_at 10 e 23 | val loss 2.2838 val acc 17.4513 best val_acc 18.770292
# discarded index [20, 47, 34, 15, 31, 46, 26, 39, 13, 18]
# epoch: 24, bulyan: at multi-krum n_at 10 e 24 | val loss 2.2788 val acc 19.0341 best val_acc 19.034091
# discarded index [20, 47, 34, 46, 31, 15, 26, 13, 39, 12]
# epoch: 25, bulyan: at multi-krum n_at 10 e 25 | val loss 2.2723 val acc 19.9675 best val_acc 19.967532
# discarded index [20, 47, 46, 31, 26, 15, 13, 34, 39, 12]
# epoch: 26, bulyan: at multi-krum n_at 10 e 26 | val loss 2.2639 val acc 18.9732 best val_acc 19.967532
# discarded index [20, 47, 26, 46, 31, 13, 15, 34, 39, 32]
# epoch: 27, bulyan: at multi-krum n_at 10 e 27 | val loss 2.2552 val acc 19.4399 best val_acc 19.967532
# discarded index [20, 47, 46, 26, 13, 31, 15, 34, 39, 19]
# epoch: 28, bulyan: at multi-krum n_at 10 e 28 | val loss 2.2423 val acc 17.9789 best val_acc 19.967532
# discarded index [20, 47, 46, 26, 13, 31, 15, 19, 12, 34]
# epoch: 29, bulyan: at multi-krum n_at 10 e 29 | val loss 2.2338 val acc 20.0284 best val_acc 20.028409
# discarded index [20, 47, 46, 13, 31, 26, 15, 19, 12, 32]
# epoch: 30, bulyan: at multi-krum n_at 10 e 30 | val loss 2.2220 val acc 18.5065 best val_acc 20.028409
# discarded index [20, 47, 46, 13, 26, 31, 19, 15, 12, 48]
# epoch: 31, bulyan: at multi-krum n_at 10 e 31 | val loss 2.2142 val acc 21.3271 best val_acc 21.327110
# discarded index [20, 47, 46, 26, 13, 31, 19, 15, 12, 48]
# epoch: 32, bulyan: at multi-krum n_at 10 e 32 | val loss 2.2016 val acc 19.9878 best val_acc 21.327110
# discarded index [20, 47, 46, 26, 13, 19, 31, 15, 12, 45]
# epoch: 33, bulyan: at multi-krum n_at 10 e 33 | val loss 2.2168 val acc 21.7330 best val_acc 21.732955
# discarded index [20, 47, 46, 13, 26, 31, 19, 12, 15, 27]
# epoch: 34, bulyan: at multi-krum n_at 10 e 34 | val loss 2.2054 val acc 18.1615 best val_acc 21.732955
# discarded index [20, 47, 46, 19, 13, 26, 31, 12, 32, 10]
# epoch: 35, bulyan: at multi-krum n_at 10 e 35 | val loss 2.2763 val acc 12.8450 best val_acc 21.732955
# discarded index [20, 47, 46, 19, 13, 26, 31, 32, 12, 27]
# epoch: 36, bulyan: at multi-krum n_at 10 e 36 | val loss 2.2136 val acc 21.0836 best val_acc 21.732955
# discarded index [20, 47, 46, 19, 13, 26, 31, 12, 32, 10]
# epoch: 37, bulyan: at multi-krum n_at 10 e 37 | val loss 2.1730 val acc 19.6631 best val_acc 21.732955
# discarded index [20, 47, 46, 19, 13, 26, 31, 12, 32, 10]
# epoch: 38, bulyan: at multi-krum n_at 10 e 38 | val loss 2.1651 val acc 21.7938 best val_acc 21.793831
# discarded index [20, 47, 46, 19, 13, 26, 31, 12, 32, 10]
# epoch: 39, bulyan: at multi-krum n_at 10 e 39 | val loss 2.1441 val acc 21.7330 best val_acc 21.793831
# discarded index [20, 47, 46, 19, 13, 26, 31, 12, 32, 10]
# epoch: 40, bulyan: at multi-krum n_at 10 e 40 | val loss 2.1333 val acc 22.9911 best val_acc 22.991071
# discarded index [20, 47, 46, 13, 19, 26, 31, 12, 10, 48]
# epoch: 41, bulyan: at multi-krum n_at 10 e 41 | val loss 2.1172 val acc 20.9010 best val_acc 22.991071
# discarded index [20, 47, 46, 19, 13, 26, 31, 12, 10, 27]
# epoch: 42, bulyan: at multi-krum n_at 10 e 42 | val loss 2.2322 val acc 15.4830 best val_acc 22.991071
# discarded index [20, 47, 19, 46, 26, 13, 31, 12, 32, 10]
# epoch: 43, bulyan: at multi-krum n_at 10 e 43 | val loss 2.3624 val acc 12.1753 best val_acc 22.991071
# discarded index [20, 47, 19, 26, 46, 13, 31, 32, 12, 30]
# epoch: 44, bulyan: at multi-krum n_at 10 e 44 | val loss 2.3198 val acc 10.1867 best val_acc 22.991071
# discarded index [20, 47, 19, 26, 46, 13, 31, 32, 12, 30]
# epoch: 45, bulyan: at multi-krum n_at 10 e 45 | val loss 2.3164 val acc 10.3287 best val_acc 22.991071
# discarded index [20, 47, 19, 26, 46, 13, 31, 32, 12, 30]
# epoch: 46, bulyan: at multi-krum n_at 10 e 46 | val loss 2.3130 val acc 10.8766 best val_acc 22.991071
# discarded index [20, 47, 19, 26, 46, 13, 31, 32, 12, 30]
# epoch: 47, bulyan: at multi-krum n_at 10 e 47 | val loss 2.3095 val acc 11.3231 best val_acc 22.991071
# discarded index [20, 47, 19, 26, 46, 13, 31, 32, 12, 30]
# epoch: 48, bulyan: at multi-krum n_at 10 e 48 | val loss 2.3058 val acc 11.3636 best val_acc 22.991071
# discarded index [20, 47, 19, 26, 46, 13, 31, 32, 12, 30]
# epoch: 49, bulyan: at multi-krum n_at 10 e 49 | val loss 2.3017 val acc 10.9172 best val_acc 22.991071
# discarded index [20, 47, 19, 26, 46, 13, 31, 32, 12, 30]
# epoch: 50, bulyan: at multi-krum n_at 10 e 50 | val loss 2.2972 val acc 11.2825 best val_acc 22.991071
# discarded index [20, 47, 19, 26, 46, 13, 31, 32, 12, 30]
# epoch: 51, bulyan: at multi-krum n_at 10 e 51 | val loss 2.2922 val acc 11.2622 best val_acc 22.991071
# discarded index [20, 47, 19, 26, 46, 13, 31, 32, 12, 30]
# epoch: 52, bulyan: at multi-krum n_at 10 e 52 | val loss 2.2867 val acc 11.0795 best val_acc 22.991071
# discarded index [20, 47, 19, 26, 46, 13, 31, 32, 12, 30]
# epoch: 53, bulyan: at multi-krum n_at 10 e 53 | val loss 2.2808 val acc 11.0998 best val_acc 22.991071
# discarded index [20, 47, 19, 26, 46, 13, 31, 32, 12, 30]
# epoch: 54, bulyan: at multi-krum n_at 10 e 54 | val loss 2.2741 val acc 10.9578 best val_acc 22.991071
# discarded index [20, 47, 19, 26, 46, 13, 31, 32, 12, 30]
# epoch: 55, bulyan: at multi-krum n_at 10 e 55 | val loss 2.2677 val acc 11.1607 best val_acc 22.991071
# discarded index [20, 47, 19, 26, 46, 13, 31, 32, 12, 30]
# epoch: 56, bulyan: at multi-krum n_at 10 e 56 | val loss 2.2615 val acc 11.7695 best val_acc 22.991071
# discarded index [20, 47, 19, 26, 46, 13, 31, 32, 12, 30]
# epoch: 57, bulyan: at multi-krum n_at 10 e 57 | val loss 2.2537 val acc 12.4391 best val_acc 22.991071
# discarded index [20, 47, 19, 26, 46, 13, 31, 32, 12, 30]
# epoch: 58, bulyan: at multi-krum n_at 10 e 58 | val loss 2.2466 val acc 13.6972 best val_acc 22.991071
# discarded index [20, 47, 19, 26, 46, 13, 31, 32, 12, 15]
# epoch: 59, bulyan: at multi-krum n_at 10 e 59 | val loss 2.2390 val acc 15.1583 best val_acc 22.991071
# discarded index [20, 47, 19, 26, 46, 13, 31, 32, 12, 15]
# epoch: 60, bulyan: at multi-krum n_at 10 e 60 | val loss 2.2300 val acc 16.4367 best val_acc 22.991071
# discarded index [20, 47, 19, 26, 46, 13, 31, 32, 12, 15]
# epoch: 61, bulyan: at multi-krum n_at 10 e 61 | val loss 2.2196 val acc 17.6745 best val_acc 22.991071
# discarded index [20, 47, 19, 26, 46, 13, 31, 32, 12, 15]
# epoch: 62, bulyan: at multi-krum n_at 10 e 62 | val loss 2.2077 val acc 18.6485 best val_acc 22.991071
# discarded index [20, 47, 19, 26, 46, 13, 31, 32, 12, 15]
# epoch: 63, bulyan: at multi-krum n_at 10 e 63 | val loss 2.1932 val acc 18.2021 best val_acc 22.991071
# discarded index [20, 47, 19, 26, 46, 13, 31, 32, 12, 48]
# epoch: 64, bulyan: at multi-krum n_at 10 e 64 | val loss 2.1793 val acc 19.2573 best val_acc 22.991071
# discarded index [20, 47, 19, 26, 46, 13, 31, 32, 12, 48]
# epoch: 65, bulyan: at multi-krum n_at 10 e 65 | val loss 2.1607 val acc 18.7703 best val_acc 22.991071
# discarded index [20, 47, 19, 26, 46, 13, 31, 32, 48, 15]
# epoch: 66, bulyan: at multi-krum n_at 10 e 66 | val loss 2.1463 val acc 19.4196 best val_acc 22.991071
# discarded index [20, 47, 19, 26, 46, 13, 31, 48, 15, 39]
# epoch: 67, bulyan: at multi-krum n_at 10 e 67 | val loss 2.1346 val acc 19.8255 best val_acc 22.991071
# discarded index [20, 47, 19, 46, 26, 13, 31, 48, 15, 39]
# epoch: 68, bulyan: at multi-krum n_at 10 e 68 | val loss 2.1218 val acc 19.3385 best val_acc 22.991071
# discarded index [20, 47, 19, 46, 26, 13, 31, 48, 15, 41]
# epoch: 69, bulyan: at multi-krum n_at 10 e 69 | val loss 2.1075 val acc 19.6226 best val_acc 22.991071
# discarded index [20, 47, 19, 46, 13, 26, 31, 48, 15, 41]
# epoch: 70, bulyan: at multi-krum n_at 10 e 70 | val loss 2.1013 val acc 17.0049 best val_acc 22.991071
# discarded index [20, 47, 19, 46, 13, 26, 31, 48, 41, 15]
# epoch: 71, bulyan: at multi-krum n_at 10 e 71 | val loss 2.0905 val acc 20.2922 best val_acc 22.991071
# discarded index [20, 47, 19, 46, 13, 26, 31, 48, 41, 15]
# epoch: 72, bulyan: at multi-krum n_at 10 e 72 | val loss 2.0852 val acc 19.0747 best val_acc 22.991071
# discarded index [20, 47, 19, 46, 13, 26, 31, 48, 41, 15]
# epoch: 73, bulyan: at multi-krum n_at 10 e 73 | val loss 2.1198 val acc 21.6112 best val_acc 22.991071
# discarded index [20, 47, 19, 46, 13, 31, 26, 48, 41, 15]
# epoch: 74, bulyan: at multi-krum n_at 10 e 74 | val loss 2.1712 val acc 14.3872 best val_acc 22.991071
# discarded index [20, 47, 19, 46, 13, 31, 26, 41, 48, 15]
# epoch: 75, bulyan: at multi-krum n_at 10 e 75 | val loss 2.1811 val acc 17.7760 best val_acc 22.991071
# discarded index [20, 47, 19, 46, 13, 31, 26, 41, 48, 15]
# epoch: 76, bulyan: at multi-krum n_at 10 e 76 | val loss 2.1565 val acc 18.4253 best val_acc 22.991071
# discarded index [20, 47, 19, 46, 13, 31, 26, 41, 48, 15]
# epoch: 77, bulyan: at multi-krum n_at 10 e 77 | val loss 2.1011 val acc 19.0950 best val_acc 22.991071
# discarded index [20, 47, 19, 46, 13, 31, 26, 41, 48, 15]
# epoch: 78, bulyan: at multi-krum n_at 10 e 78 | val loss 2.0721 val acc 19.5211 best val_acc 22.991071
# discarded index [20, 47, 19, 46, 13, 31, 26, 48, 41, 15]
# epoch: 79, bulyan: at multi-krum n_at 10 e 79 | val loss 2.0601 val acc 18.7703 best val_acc 22.991071
# discarded index [20, 47, 19, 46, 31, 13, 26, 48, 41, 15]
# epoch: 80, bulyan: at multi-krum n_at 10 e 80 | val loss 2.0675 val acc 18.4050 best val_acc 22.991071
# discarded index [20, 47, 19, 46, 31, 13, 26, 41, 48, 15]
# epoch: 81, bulyan: at multi-krum n_at 10 e 81 | val loss 2.0756 val acc 19.9067 best val_acc 22.991071
# discarded index [20, 47, 19, 46, 13, 31, 26, 48, 41, 15]
# epoch: 82, bulyan: at multi-krum n_at 10 e 82 | val loss 2.1135 val acc 17.8977 best val_acc 22.991071
# discarded index [20, 47, 19, 46, 31, 13, 26, 41, 48, 15]
# epoch: 83, bulyan: at multi-krum n_at 10 e 83 | val loss 2.1489 val acc 17.0860 best val_acc 22.991071
# discarded index [20, 47, 19, 46, 31, 13, 26, 41, 48, 15]
# epoch: 84, bulyan: at multi-krum n_at 10 e 84 | val loss 2.1028 val acc 19.7037 best val_acc 22.991071
# discarded index [20, 47, 19, 46, 31, 13, 26, 41, 48, 15]
# epoch: 85, bulyan: at multi-krum n_at 10 e 85 | val loss 2.0423 val acc 21.4489 best val_acc 22.991071
# discarded index [20, 47, 19, 31, 46, 13, 26, 41, 48, 15]
# epoch: 86, bulyan: at multi-krum n_at 10 e 86 | val loss 2.0706 val acc 20.1502 best val_acc 22.991071
# discarded index [20, 47, 19, 31, 46, 13, 26, 41, 15, 48]
# epoch: 87, bulyan: at multi-krum n_at 10 e 87 | val loss 2.0739 val acc 19.5211 best val_acc 22.991071
# discarded index [20, 47, 19, 46, 31, 13, 26, 41, 15, 48]
# epoch: 88, bulyan: at multi-krum n_at 10 e 88 | val loss 2.1393 val acc 17.6948 best val_acc 22.991071
# discarded index [20, 47, 19, 31, 46, 13, 26, 41, 15, 48]
# epoch: 89, bulyan: at multi-krum n_at 10 e 89 | val loss 2.0905 val acc 19.4602 best val_acc 22.991071
# discarded index [20, 47, 19, 46, 31, 13, 26, 15, 41, 48]
# epoch: 90, bulyan: at multi-krum n_at 10 e 90 | val loss 2.0358 val acc 19.6023 best val_acc 22.991071
# discarded index [20, 47, 19, 31, 46, 13, 26, 15, 41, 48]
# epoch: 91, bulyan: at multi-krum n_at 10 e 91 | val loss 2.0449 val acc 20.6981 best val_acc 22.991071
# discarded index [20, 47, 19, 46, 31, 13, 26, 15, 41, 48]
# epoch: 92, bulyan: at multi-krum n_at 10 e 92 | val loss 2.0198 val acc 21.4692 best val_acc 22.991071
# discarded index [20, 47, 19, 31, 46, 26, 13, 15, 41, 39]
# epoch: 93, bulyan: at multi-krum n_at 10 e 93 | val loss 2.0533 val acc 20.7386 best val_acc 22.991071
# discarded index [20, 47, 19, 31, 46, 26, 13, 41, 15, 39]
# epoch: 94, bulyan: at multi-krum n_at 10 e 94 | val loss 2.0813 val acc 17.1875 best val_acc 22.991071
# discarded index [20, 47, 19, 31, 46, 26, 13, 15, 41, 39]
# epoch: 95, bulyan: at multi-krum n_at 10 e 95 | val loss 2.1100 val acc 19.3588 best val_acc 22.991071
# discarded index [20, 47, 19, 31, 26, 46, 13, 41, 15, 48]
# epoch: 96, bulyan: at multi-krum n_at 10 e 96 | val loss 2.1367 val acc 17.3093 best val_acc 22.991071
# discarded index [20, 47, 31, 26, 46, 19, 13, 41, 15, 48]
# epoch: 97, bulyan: at multi-krum n_at 10 e 97 | val loss 2.1177 val acc 18.2021 best val_acc 22.991071
# discarded index [20, 47, 31, 26, 46, 19, 13, 41, 15, 39]
# epoch: 98, bulyan: at multi-krum n_at 10 e 98 | val loss 2.0468 val acc 20.5966 best val_acc 22.991071
# discarded index [20, 47, 31, 26, 46, 19, 13, 41, 15, 39]
# epoch: 99, bulyan: at multi-krum n_at 10 e 99 | val loss 2.0200 val acc 22.4838 best val_acc 22.991071
# discarded index [20, 47, 31, 26, 19, 46, 13, 41, 15, 39]
# epoch: 100, bulyan: at multi-krum n_at 10 e 100 | val loss 2.0332 val acc 20.1299 best val_acc 22.991071
# discarded index [20, 47, 31, 26, 19, 46, 13, 41, 15, 48]
# epoch: 101, bulyan: at multi-krum n_at 10 e 101 | val loss 2.0989 val acc 20.4748 best val_acc 22.991071
# discarded index [20, 47, 31, 26, 46, 19, 13, 41, 15, 48]
# epoch: 102, bulyan: at multi-krum n_at 10 e 102 | val loss 2.0602 val acc 21.9562 best val_acc 22.991071
# discarded index [20, 47, 31, 26, 19, 46, 13, 41, 15, 39]
# epoch: 103, bulyan: at multi-krum n_at 10 e 103 | val loss 2.0068 val acc 21.4083 best val_acc 22.991071
# discarded index [20, 47, 31, 26, 46, 19, 13, 41, 15, 39]
# epoch: 104, bulyan: at multi-krum n_at 10 e 104 | val loss 2.0366 val acc 19.4602 best val_acc 22.991071
# discarded index [20, 47, 31, 26, 19, 46, 13, 41, 15, 39]
# epoch: 105, bulyan: at multi-krum n_at 10 e 105 | val loss 2.0830 val acc 19.8052 best val_acc 22.991071
# discarded index [20, 47, 31, 26, 19, 46, 13, 41, 15, 39]
# epoch: 106, bulyan: at multi-krum n_at 10 e 106 | val loss 2.1202 val acc 19.1356 best val_acc 22.991071
# discarded index [20, 47, 31, 26, 19, 46, 13, 41, 15, 39]
# epoch: 107, bulyan: at multi-krum n_at 10 e 107 | val loss 2.0508 val acc 21.9562 best val_acc 22.991071
# discarded index [20, 47, 31, 26, 19, 46, 13, 41, 15, 39]
# epoch: 108, bulyan: at multi-krum n_at 10 e 108 | val loss 1.9997 val acc 23.4172 best val_acc 23.417208
# discarded index [20, 47, 31, 26, 19, 46, 13, 41, 15, 39]
# epoch: 109, bulyan: at multi-krum n_at 10 e 109 | val loss 1.9958 val acc 21.9765 best val_acc 23.417208
# discarded index [20, 47, 31, 26, 19, 46, 13, 41, 15, 39]
# epoch: 110, bulyan: at multi-krum n_at 10 e 110 | val loss 2.1080 val acc 17.8977 best val_acc 23.417208
# discarded index [20, 47, 31, 26, 46, 19, 13, 15, 39, 41]
# epoch: 111, bulyan: at multi-krum n_at 10 e 111 | val loss 2.0978 val acc 19.3182 best val_acc 23.417208
# discarded index [20, 47, 31, 26, 46, 19, 13, 15, 39, 41]
# epoch: 112, bulyan: at multi-krum n_at 10 e 112 | val loss 2.1250 val acc 17.9789 best val_acc 23.417208
# discarded index [20, 47, 31, 26, 46, 19, 13, 41, 15, 39]
# epoch: 113, bulyan: at multi-krum n_at 10 e 113 | val loss 2.0700 val acc 20.6575 best val_acc 23.417208
# discarded index [20, 47, 31, 26, 46, 19, 13, 41, 15, 39]
# epoch: 114, bulyan: at multi-krum n_at 10 e 114 | val loss 2.0337 val acc 17.8571 best val_acc 23.417208
# discarded index [20, 47, 31, 26, 46, 19, 13, 41, 15, 39]
# epoch: 115, bulyan: at multi-krum n_at 10 e 115 | val loss 2.1072 val acc 20.4545 best val_acc 23.417208
# discarded index [20, 47, 31, 26, 46, 19, 13, 41, 10, 15]
# epoch: 116, bulyan: at multi-krum n_at 10 e 116 | val loss 2.0812 val acc 18.3644 best val_acc 23.417208
# discarded index [20, 47, 31, 26, 46, 19, 13, 41, 15, 39]
# epoch: 117, bulyan: at multi-krum n_at 10 e 117 | val loss 2.0925 val acc 20.0487 best val_acc 23.417208
# discarded index [20, 47, 31, 26, 46, 19, 13, 41, 10, 15]
# epoch: 118, bulyan: at multi-krum n_at 10 e 118 | val loss 2.0075 val acc 21.6112 best val_acc 23.417208
# discarded index [20, 47, 31, 26, 46, 19, 13, 41, 10, 15]
# epoch: 119, bulyan: at multi-krum n_at 10 e 119 | val loss 1.9659 val acc 24.1477 best val_acc 24.147727
# discarded index [20, 47, 31, 26, 46, 19, 13, 41, 10, 15]
# epoch: 120, bulyan: at multi-krum n_at 10 e 120 | val loss 2.0078 val acc 20.4343 best val_acc 24.147727
# discarded index [20, 47, 31, 26, 46, 19, 13, 41, 15, 39]
# epoch: 121, bulyan: at multi-krum n_at 10 e 121 | val loss 1.9883 val acc 22.7070 best val_acc 24.147727
# discarded index [20, 47, 31, 26, 46, 19, 13, 41, 15, 39]
# epoch: 122, bulyan: at multi-krum n_at 10 e 122 | val loss 2.0703 val acc 18.1006 best val_acc 24.147727
# discarded index [20, 47, 31, 26, 46, 19, 13, 41, 39, 15]
# epoch: 123, bulyan: at multi-krum n_at 10 e 123 | val loss 2.0035 val acc 25.0000 best val_acc 25.000000
# discarded index [20, 47, 31, 26, 46, 19, 13, 41, 39, 15]
# epoch: 124, bulyan: at multi-krum n_at 10 e 124 | val loss 2.0023 val acc 23.1128 best val_acc 25.000000
# discarded index [20, 47, 31, 26, 46, 19, 13, 41, 39, 15]
# epoch: 125, bulyan: at multi-krum n_at 10 e 125 | val loss 2.1350 val acc 21.1648 best val_acc 25.000000
# discarded index [20, 47, 31, 26, 19, 46, 13, 41, 39, 15]
# epoch: 126, bulyan: at multi-krum n_at 10 e 126 | val loss 2.1360 val acc 15.6453 best val_acc 25.000000
# discarded index [20, 47, 31, 26, 19, 46, 13, 41, 39, 15]
# epoch: 127, bulyan: at multi-krum n_at 10 e 127 | val loss 2.1122 val acc 18.9732 best val_acc 25.000000
# discarded index [20, 47, 31, 26, 19, 46, 13, 41, 39, 15]
# epoch: 128, bulyan: at multi-krum n_at 10 e 128 | val loss 2.0638 val acc 22.1185 best val_acc 25.000000
# discarded index [20, 47, 31, 26, 46, 19, 13, 41, 15, 39]
# epoch: 129, bulyan: at multi-krum n_at 10 e 129 | val loss 2.0571 val acc 22.3823 best val_acc 25.000000
# discarded index [20, 47, 31, 26, 46, 19, 13, 41, 15, 39]
# epoch: 130, bulyan: at multi-krum n_at 10 e 130 | val loss 2.0328 val acc 22.6867 best val_acc 25.000000
# discarded index [20, 47, 31, 26, 46, 19, 13, 15, 39, 41]
# epoch: 131, bulyan: at multi-krum n_at 10 e 131 | val loss 2.1035 val acc 19.8458 best val_acc 25.000000
# discarded index [20, 47, 31, 26, 46, 19, 13, 41, 15, 39]
# epoch: 132, bulyan: at multi-krum n_at 10 e 132 | val loss 2.1233 val acc 18.3442 best val_acc 25.000000
# discarded index [20, 47, 31, 26, 46, 19, 13, 41, 15, 39]
# epoch: 133, bulyan: at multi-krum n_at 10 e 133 | val loss 2.0166 val acc 23.1737 best val_acc 25.000000
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 134, bulyan: at multi-krum n_at 10 e 134 | val loss 1.9625 val acc 23.1128 best val_acc 25.000000
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 135, bulyan: at multi-krum n_at 10 e 135 | val loss 1.9832 val acc 21.7938 best val_acc 25.000000
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 136, bulyan: at multi-krum n_at 10 e 136 | val loss 1.9928 val acc 21.1648 best val_acc 25.000000
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 137, bulyan: at multi-krum n_at 10 e 137 | val loss 2.0558 val acc 21.3677 best val_acc 25.000000
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 138, bulyan: at multi-krum n_at 10 e 138 | val loss 2.0392 val acc 22.5041 best val_acc 25.000000
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 139, bulyan: at multi-krum n_at 10 e 139 | val loss 1.9296 val acc 24.5739 best val_acc 25.000000
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 41, 15]
# epoch: 140, bulyan: at multi-krum n_at 10 e 140 | val loss 1.9308 val acc 24.0666 best val_acc 25.000000
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 141, bulyan: at multi-krum n_at 10 e 141 | val loss 1.9383 val acc 25.9131 best val_acc 25.913149
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 41, 15]
# epoch: 142, bulyan: at multi-krum n_at 10 e 142 | val loss 2.1255 val acc 21.5097 best val_acc 25.913149
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 143, bulyan: at multi-krum n_at 10 e 143 | val loss 2.0919 val acc 18.7906 best val_acc 25.913149
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 144, bulyan: at multi-krum n_at 10 e 144 | val loss 2.0352 val acc 23.3563 best val_acc 25.913149
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 145, bulyan: at multi-krum n_at 10 e 145 | val loss 2.0118 val acc 22.3417 best val_acc 25.913149
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 146, bulyan: at multi-krum n_at 10 e 146 | val loss 2.0016 val acc 24.1071 best val_acc 25.913149
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 147, bulyan: at multi-krum n_at 10 e 147 | val loss 2.1162 val acc 20.6981 best val_acc 25.913149
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 148, bulyan: at multi-krum n_at 10 e 148 | val loss 2.0464 val acc 20.6778 best val_acc 25.913149
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 149, bulyan: at multi-krum n_at 10 e 149 | val loss 1.9993 val acc 24.4927 best val_acc 25.913149
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 150, bulyan: at multi-krum n_at 10 e 150 | val loss 2.0185 val acc 24.3101 best val_acc 25.913149
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 151, bulyan: at multi-krum n_at 10 e 151 | val loss 1.9280 val acc 25.5885 best val_acc 25.913149
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 152, bulyan: at multi-krum n_at 10 e 152 | val loss 1.9550 val acc 21.7938 best val_acc 25.913149
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 153, bulyan: at multi-krum n_at 10 e 153 | val loss 2.0346 val acc 23.4375 best val_acc 25.913149
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 154, bulyan: at multi-krum n_at 10 e 154 | val loss 1.9822 val acc 23.0722 best val_acc 25.913149
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 155, bulyan: at multi-krum n_at 10 e 155 | val loss 1.9190 val acc 26.6843 best val_acc 26.684253
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 156, bulyan: at multi-krum n_at 10 e 156 | val loss 1.9015 val acc 26.3596 best val_acc 26.684253
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 157, bulyan: at multi-krum n_at 10 e 157 | val loss 2.0504 val acc 22.0576 best val_acc 26.684253
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 158, bulyan: at multi-krum n_at 10 e 158 | val loss 2.1233 val acc 17.6339 best val_acc 26.684253
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 159, bulyan: at multi-krum n_at 10 e 159 | val loss 2.1199 val acc 21.4286 best val_acc 26.684253
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 160, bulyan: at multi-krum n_at 10 e 160 | val loss 2.0390 val acc 21.8547 best val_acc 26.684253
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 161, bulyan: at multi-krum n_at 10 e 161 | val loss 2.0319 val acc 22.2606 best val_acc 26.684253
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 162, bulyan: at multi-krum n_at 10 e 162 | val loss 1.9882 val acc 24.2695 best val_acc 26.684253
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 163, bulyan: at multi-krum n_at 10 e 163 | val loss 2.0684 val acc 20.8604 best val_acc 26.684253
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 164, bulyan: at multi-krum n_at 10 e 164 | val loss 1.9661 val acc 24.6144 best val_acc 26.684253
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 165, bulyan: at multi-krum n_at 10 e 165 | val loss 1.9378 val acc 24.0057 best val_acc 26.684253
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 166, bulyan: at multi-krum n_at 10 e 166 | val loss 1.9597 val acc 23.6201 best val_acc 26.684253
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 167, bulyan: at multi-krum n_at 10 e 167 | val loss 2.1398 val acc 19.0341 best val_acc 26.684253
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 168, bulyan: at multi-krum n_at 10 e 168 | val loss 2.0652 val acc 21.4894 best val_acc 26.684253
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 169, bulyan: at multi-krum n_at 10 e 169 | val loss 2.0225 val acc 23.9245 best val_acc 26.684253
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 170, bulyan: at multi-krum n_at 10 e 170 | val loss 1.9846 val acc 22.2403 best val_acc 26.684253
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 171, bulyan: at multi-krum n_at 10 e 171 | val loss 2.0541 val acc 21.5706 best val_acc 26.684253
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 172, bulyan: at multi-krum n_at 10 e 172 | val loss 1.9686 val acc 24.8985 best val_acc 26.684253
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 15, 39]
# epoch: 173, bulyan: at multi-krum n_at 10 e 173 | val loss 1.9119 val acc 25.8929 best val_acc 26.684253
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 39, 15]
# epoch: 174, bulyan: at multi-krum n_at 10 e 174 | val loss 1.9146 val acc 24.5130 best val_acc 26.684253
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 39, 15]
# epoch: 175, bulyan: at multi-krum n_at 10 e 175 | val loss 1.9893 val acc 22.4635 best val_acc 26.684253
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 39, 15]
# epoch: 176, bulyan: at multi-krum n_at 10 e 176 | val loss 2.0389 val acc 22.9708 best val_acc 26.684253
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 39, 15]
# epoch: 177, bulyan: at multi-krum n_at 10 e 177 | val loss 2.0475 val acc 21.8547 best val_acc 26.684253
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 39, 15]
# epoch: 178, bulyan: at multi-krum n_at 10 e 178 | val loss 1.9315 val acc 25.3856 best val_acc 26.684253
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 39, 15]
# epoch: 179, bulyan: at multi-krum n_at 10 e 179 | val loss 1.9695 val acc 26.1769 best val_acc 26.684253
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 39, 15]
# epoch: 180, bulyan: at multi-krum n_at 10 e 180 | val loss 1.9680 val acc 26.2987 best val_acc 26.684253
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 39, 15]
# epoch: 181, bulyan: at multi-krum n_at 10 e 181 | val loss 2.1374 val acc 18.9326 best val_acc 26.684253
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 39, 15]
# epoch: 182, bulyan: at multi-krum n_at 10 e 182 | val loss 2.0998 val acc 20.6169 best val_acc 26.684253
# discarded index [20, 47, 31, 26, 46, 19, 13, 10, 39, 15]
# epoch: 183, bulyan: at multi-krum n_at 10 e 183 | val loss 2.0096 val acc 24.2289 best val_acc 26.684253
# discarded index [20, 47, 31, 26, 46, 19, 10, 13, 39, 15]
# epoch: 184, bulyan: at multi-krum n_at 10 e 184 | val loss 1.9293 val acc 26.9683 best val_acc 26.968344
# discarded index [20, 47, 31, 26, 46, 19, 10, 13, 39, 15]
# epoch: 185, bulyan: at multi-krum n_at 10 e 185 | val loss 1.9015 val acc 26.8669 best val_acc 26.968344
# discarded index [20, 47, 31, 26, 46, 19, 10, 13, 39, 15]
# epoch: 186, bulyan: at multi-krum n_at 10 e 186 | val loss 1.9574 val acc 25.0812 best val_acc 26.968344
# discarded index [20, 47, 31, 26, 46, 19, 10, 13, 39, 15]
# epoch: 187, bulyan: at multi-krum n_at 10 e 187 | val loss 2.0412 val acc 22.7476 best val_acc 26.968344
# discarded index [20, 47, 31, 26, 46, 19, 10, 13, 39, 15]
# epoch: 188, bulyan: at multi-krum n_at 10 e 188 | val loss 1.9745 val acc 25.2232 best val_acc 26.968344
# discarded index [20, 47, 31, 26, 46, 19, 10, 13, 39, 15]
# epoch: 189, bulyan: at multi-krum n_at 10 e 189 | val loss 1.9790 val acc 26.5219 best val_acc 26.968344
# discarded index [20, 47, 31, 26, 46, 19, 10, 13, 39, 15]
# epoch: 190, bulyan: at multi-krum n_at 10 e 190 | val loss 1.9374 val acc 25.5479 best val_acc 26.968344
# discarded index [20, 47, 31, 26, 46, 19, 10, 13, 39, 15]
# epoch: 191, bulyan: at multi-krum n_at 10 e 191 | val loss 2.0457 val acc 21.2662 best val_acc 26.968344
# discarded index [20, 47, 31, 26, 46, 19, 10, 13, 39, 15]
# epoch: 192, bulyan: at multi-krum n_at 10 e 192 | val loss 1.9882 val acc 26.6640 best val_acc 26.968344
# discarded index [20, 47, 31, 26, 46, 19, 10, 13, 39, 15]
# epoch: 193, bulyan: at multi-krum n_at 10 e 193 | val loss 1.8740 val acc 29.4237 best val_acc 29.423701
# discarded index [20, 47, 31, 26, 46, 19, 10, 13, 39, 15]
# epoch: 194, bulyan: at multi-krum n_at 10 e 194 | val loss 1.8933 val acc 26.1161 best val_acc 29.423701
# discarded index [20, 47, 31, 26, 46, 19, 10, 39, 15, 45]
# epoch: 195, bulyan: at multi-krum n_at 10 e 195 | val loss 1.9454 val acc 26.4610 best val_acc 29.423701
# discarded index [20, 47, 31, 26, 46, 19, 10, 39, 15, 45]
# epoch: 196, bulyan: at multi-krum n_at 10 e 196 | val loss 1.9376 val acc 26.6031 best val_acc 29.423701
# discarded index [20, 47, 31, 26, 46, 19, 10, 39, 15, 45]
# epoch: 197, bulyan: at multi-krum n_at 10 e 197 | val loss 1.9143 val acc 25.3450 best val_acc 29.423701
# discarded index [20, 47, 31, 26, 46, 19, 10, 39, 15, 45]
# epoch: 198, bulyan: at multi-krum n_at 10 e 198 | val loss 1.9896 val acc 23.0722 best val_acc 29.423701
# discarded index [20, 47, 31, 26, 46, 19, 10, 39, 15, 45]
# epoch: 199, bulyan: at multi-krum n_at 10 e 199 | val loss 1.9284 val acc 25.7711 best val_acc 29.423701
# discarded index [20, 47, 31, 26, 46, 19, 10, 39, 15, 45]
# epoch: 200, bulyan: at multi-krum n_at 10 e 200 | val loss 1.9895 val acc 22.9911 best val_acc 29.423701
# discarded index [20, 47, 31, 26, 46, 19, 10, 39, 15, 45]
# epoch: 201, bulyan: at multi-krum n_at 10 e 201 | val loss 1.8982 val acc 28.0032 best val_acc 29.423701
# discarded index [20, 47, 31, 26, 46, 19, 10, 39, 15, 45]
# epoch: 202, bulyan: at multi-krum n_at 10 e 202 | val loss 1.9103 val acc 27.6177 best val_acc 29.423701
# discarded index [20, 47, 31, 26, 46, 19, 10, 39, 15, 45]
# epoch: 203, bulyan: at multi-krum n_at 10 e 203 | val loss 1.8731 val acc 27.2321 best val_acc 29.423701
# discarded index [20, 47, 31, 26, 46, 19, 10, 39, 45, 15]
# epoch: 204, bulyan: at multi-krum n_at 10 e 204 | val loss 2.0256 val acc 25.1826 best val_acc 29.423701
# discarded index [20, 47, 31, 26, 46, 19, 10, 39, 45, 15]
# epoch: 205, bulyan: at multi-krum n_at 10 e 205 | val loss 1.9706 val acc 26.8466 best val_acc 29.423701
# discarded index [20, 47, 31, 26, 46, 19, 10, 39, 45, 15]
# epoch: 206, bulyan: at multi-krum n_at 10 e 206 | val loss 1.9286 val acc 26.8669 best val_acc 29.423701
# discarded index [20, 47, 31, 26, 46, 19, 10, 39, 45, 15]
# epoch: 207, bulyan: at multi-krum n_at 10 e 207 | val loss 1.8424 val acc 29.1193 best val_acc 29.423701
# discarded index [20, 47, 31, 26, 46, 19, 10, 39, 45, 15]
# epoch: 208, bulyan: at multi-krum n_at 10 e 208 | val loss 1.9560 val acc 24.9391 best val_acc 29.423701
# discarded index [20, 47, 31, 26, 46, 10, 19, 45, 39, 15]
# epoch: 209, bulyan: at multi-krum n_at 10 e 209 | val loss 2.0108 val acc 24.8377 best val_acc 29.423701
# discarded index [20, 47, 31, 26, 46, 10, 19, 45, 39, 15]
# epoch: 210, bulyan: at multi-krum n_at 10 e 210 | val loss 1.9817 val acc 26.9481 best val_acc 29.423701
# discarded index [20, 47, 31, 26, 46, 10, 19, 45, 39, 15]
# epoch: 211, bulyan: at multi-krum n_at 10 e 211 | val loss 1.9257 val acc 25.8726 best val_acc 29.423701
# discarded index [20, 47, 31, 26, 46, 10, 19, 45, 39, 15]
# epoch: 212, bulyan: at multi-krum n_at 10 e 212 | val loss 1.8506 val acc 30.6209 best val_acc 30.620942
# discarded index [20, 47, 31, 26, 46, 10, 19, 45, 39, 15]
# epoch: 213, bulyan: at multi-krum n_at 10 e 213 | val loss 1.8467 val acc 30.5195 best val_acc 30.620942
# discarded index [20, 47, 31, 26, 46, 10, 19, 45, 39, 15]
# epoch: 214, bulyan: at multi-krum n_at 10 e 214 | val loss 1.8969 val acc 28.1453 best val_acc 30.620942
# discarded index [20, 47, 31, 26, 46, 10, 19, 45, 39, 15]
# epoch: 215, bulyan: at multi-krum n_at 10 e 215 | val loss 2.0741 val acc 21.8141 best val_acc 30.620942
# discarded index [20, 47, 31, 26, 46, 10, 19, 45, 39, 15]
# epoch: 216, bulyan: at multi-krum n_at 10 e 216 | val loss 1.9968 val acc 24.9594 best val_acc 30.620942
# discarded index [20, 47, 31, 26, 46, 10, 19, 45, 39, 15]
# epoch: 217, bulyan: at multi-krum n_at 10 e 217 | val loss 1.9130 val acc 29.0787 best val_acc 30.620942
# discarded index [20, 47, 31, 26, 46, 10, 19, 45, 39, 15]
# epoch: 218, bulyan: at multi-krum n_at 10 e 218 | val loss 1.8833 val acc 28.1047 best val_acc 30.620942
# discarded index [20, 47, 31, 26, 46, 10, 19, 45, 39, 15]
# epoch: 219, bulyan: at multi-krum n_at 10 e 219 | val loss 1.8927 val acc 27.3742 best val_acc 30.620942
# discarded index [20, 47, 31, 26, 46, 10, 45, 19, 39, 15]
# epoch: 220, bulyan: at multi-krum n_at 10 e 220 | val loss 1.8739 val acc 27.0495 best val_acc 30.620942
# discarded index [20, 47, 31, 26, 46, 10, 45, 19, 39, 15]
# epoch: 221, bulyan: at multi-krum n_at 10 e 221 | val loss 1.8662 val acc 30.2557 best val_acc 30.620942
# discarded index [20, 47, 31, 26, 46, 10, 45, 19, 39, 15]
# epoch: 222, bulyan: at multi-krum n_at 10 e 222 | val loss 1.9472 val acc 26.0146 best val_acc 30.620942
# discarded index [20, 47, 31, 26, 46, 10, 45, 19, 39, 15]
# epoch: 223, bulyan: at multi-krum n_at 10 e 223 | val loss 1.9346 val acc 25.8320 best val_acc 30.620942
# discarded index [20, 47, 31, 26, 46, 10, 45, 19, 39, 15]
# epoch: 224, bulyan: at multi-krum n_at 10 e 224 | val loss 1.9205 val acc 27.4554 best val_acc 30.620942
# discarded index [20, 47, 31, 26, 46, 10, 45, 19, 39, 15]
# epoch: 225, bulyan: at multi-krum n_at 10 e 225 | val loss 1.9017 val acc 26.9481 best val_acc 30.620942
# discarded index [20, 47, 31, 26, 46, 10, 45, 19, 39, 15]
# epoch: 226, bulyan: at multi-krum n_at 10 e 226 | val loss 1.8638 val acc 29.3831 best val_acc 30.620942
# discarded index [20, 47, 31, 26, 46, 10, 45, 19, 39, 15]
# epoch: 227, bulyan: at multi-krum n_at 10 e 227 | val loss 1.8984 val acc 27.1510 best val_acc 30.620942
# discarded index [20, 47, 31, 26, 46, 10, 45, 19, 39, 15]
# epoch: 228, bulyan: at multi-krum n_at 10 e 228 | val loss 1.8623 val acc 28.5511 best val_acc 30.620942
# discarded index [20, 47, 31, 26, 46, 10, 45, 19, 39, 15]
# epoch: 229, bulyan: at multi-krum n_at 10 e 229 | val loss 1.8889 val acc 28.2670 best val_acc 30.620942
# discarded index [20, 47, 31, 26, 46, 10, 45, 19, 39, 15]
# epoch: 230, bulyan: at multi-krum n_at 10 e 230 | val loss 1.8927 val acc 27.8409 best val_acc 30.620942
# discarded index [20, 47, 31, 26, 46, 10, 45, 19, 39, 15]
# epoch: 231, bulyan: at multi-krum n_at 10 e 231 | val loss 1.8888 val acc 27.0901 best val_acc 30.620942
# discarded index [20, 47, 31, 26, 46, 10, 45, 39, 19, 15]
# epoch: 232, bulyan: at multi-krum n_at 10 e 232 | val loss 1.8966 val acc 28.5714 best val_acc 30.620942
# discarded index [20, 47, 31, 26, 46, 10, 45, 39, 19, 15]
# epoch: 233, bulyan: at multi-krum n_at 10 e 233 | val loss 1.9048 val acc 26.8872 best val_acc 30.620942
# discarded index [20, 47, 31, 26, 46, 10, 45, 39, 19, 15]
# epoch: 234, bulyan: at multi-krum n_at 10 e 234 | val loss 1.9279 val acc 28.9773 best val_acc 30.620942
# discarded index [20, 47, 31, 26, 46, 10, 45, 39, 19, 15]
# epoch: 235, bulyan: at multi-krum n_at 10 e 235 | val loss 1.8382 val acc 32.1429 best val_acc 32.142857
# discarded index [20, 47, 31, 26, 46, 10, 45, 39, 19, 15]
# epoch: 236, bulyan: at multi-krum n_at 10 e 236 | val loss 1.8388 val acc 28.9976 best val_acc 32.142857
# discarded index [20, 47, 31, 26, 46, 10, 45, 39, 19, 15]
# epoch: 237, bulyan: at multi-krum n_at 10 e 237 | val loss 1.8951 val acc 29.4643 best val_acc 32.142857
# discarded index [20, 47, 31, 26, 46, 10, 45, 39, 19, 15]
# epoch: 238, bulyan: at multi-krum n_at 10 e 238 | val loss 1.9056 val acc 26.3393 best val_acc 32.142857
# discarded index [20, 47, 31, 26, 46, 10, 45, 39, 19, 15]
# epoch: 239, bulyan: at multi-krum n_at 10 e 239 | val loss 1.8736 val acc 30.2760 best val_acc 32.142857
# discarded index [20, 47, 31, 26, 46, 10, 45, 39, 19, 15]
# epoch: 240, bulyan: at multi-krum n_at 10 e 240 | val loss 1.8295 val acc 29.9310 best val_acc 32.142857
# discarded index [20, 47, 31, 26, 46, 10, 45, 39, 19, 15]
# epoch: 241, bulyan: at multi-krum n_at 10 e 241 | val loss 1.8853 val acc 32.0211 best val_acc 32.142857
# discarded index [20, 47, 31, 26, 46, 10, 45, 39, 19, 15]
# epoch: 242, bulyan: at multi-krum n_at 10 e 242 | val loss 1.8482 val acc 27.1916 best val_acc 32.142857
# discarded index [20, 47, 31, 26, 10, 46, 45, 39, 15, 19]
# epoch: 243, bulyan: at multi-krum n_at 10 e 243 | val loss 1.9255 val acc 28.5308 best val_acc 32.142857
# discarded index [20, 47, 31, 26, 10, 46, 45, 39, 15, 19]
# epoch: 244, bulyan: at multi-krum n_at 10 e 244 | val loss 1.9110 val acc 27.1713 best val_acc 32.142857
# discarded index [20, 47, 31, 26, 10, 46, 45, 39, 15, 19]
# epoch: 245, bulyan: at multi-krum n_at 10 e 245 | val loss 1.8091 val acc 31.6356 best val_acc 32.142857
# discarded index [20, 47, 31, 26, 10, 46, 45, 39, 15, 19]
# epoch: 246, bulyan: at multi-krum n_at 10 e 246 | val loss 1.8147 val acc 31.4935 best val_acc 32.142857
# discarded index [20, 47, 31, 26, 10, 46, 45, 39, 15, 19]
# epoch: 247, bulyan: at multi-krum n_at 10 e 247 | val loss 2.0045 val acc 23.9245 best val_acc 32.142857
# discarded index [20, 47, 31, 26, 10, 46, 45, 39, 15, 19]
# epoch: 248, bulyan: at multi-krum n_at 10 e 248 | val loss 1.9667 val acc 26.7045 best val_acc 32.142857
# discarded index [20, 47, 31, 26, 10, 45, 46, 39, 15, 29]
# epoch: 249, bulyan: at multi-krum n_at 10 e 249 | val loss 1.8662 val acc 30.6209 best val_acc 32.142857
# discarded index [20, 47, 31, 26, 10, 45, 46, 39, 29, 15]
# epoch: 250, bulyan: at multi-krum n_at 10 e 250 | val loss 1.8391 val acc 31.7776 best val_acc 32.142857
# discarded index [20, 47, 31, 26, 10, 45, 46, 39, 29, 15]
# epoch: 251, bulyan: at multi-krum n_at 10 e 251 | val loss 1.8940 val acc 28.7946 best val_acc 32.142857
# discarded index [20, 47, 31, 26, 45, 10, 46, 39, 29, 15]
# epoch: 252, bulyan: at multi-krum n_at 10 e 252 | val loss 2.0098 val acc 25.8523 best val_acc 32.142857
# discarded index [20, 47, 31, 26, 45, 10, 46, 39, 29, 15]
# epoch: 253, bulyan: at multi-krum n_at 10 e 253 | val loss 1.9480 val acc 32.2646 best val_acc 32.264610
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 254, bulyan: at multi-krum n_at 10 e 254 | val loss 1.8879 val acc 30.4992 best val_acc 32.264610
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 255, bulyan: at multi-krum n_at 10 e 255 | val loss 1.8775 val acc 31.3515 best val_acc 32.264610
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 256, bulyan: at multi-krum n_at 10 e 256 | val loss 1.8281 val acc 29.9919 best val_acc 32.264610
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 257, bulyan: at multi-krum n_at 10 e 257 | val loss 1.8788 val acc 30.1745 best val_acc 32.264610
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 258, bulyan: at multi-krum n_at 10 e 258 | val loss 1.9112 val acc 26.4205 best val_acc 32.264610
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 259, bulyan: at multi-krum n_at 10 e 259 | val loss 1.8450 val acc 30.1745 best val_acc 32.264610
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 260, bulyan: at multi-krum n_at 10 e 260 | val loss 1.7587 val acc 34.3344 best val_acc 34.334416
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 261, bulyan: at multi-krum n_at 10 e 261 | val loss 1.7833 val acc 31.7167 best val_acc 34.334416
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 262, bulyan: at multi-krum n_at 10 e 262 | val loss 1.7865 val acc 32.7110 best val_acc 34.334416
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 263, bulyan: at multi-krum n_at 10 e 263 | val loss 2.0467 val acc 23.4984 best val_acc 34.334416
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 264, bulyan: at multi-krum n_at 10 e 264 | val loss 1.9630 val acc 27.7394 best val_acc 34.334416
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 265, bulyan: at multi-krum n_at 10 e 265 | val loss 1.8481 val acc 29.5657 best val_acc 34.334416
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 266, bulyan: at multi-krum n_at 10 e 266 | val loss 1.8298 val acc 31.6558 best val_acc 34.334416
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 267, bulyan: at multi-krum n_at 10 e 267 | val loss 1.7770 val acc 32.4269 best val_acc 34.334416
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 268, bulyan: at multi-krum n_at 10 e 268 | val loss 1.8317 val acc 33.0560 best val_acc 34.334416
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 269, bulyan: at multi-krum n_at 10 e 269 | val loss 1.8592 val acc 30.0528 best val_acc 34.334416
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 270, bulyan: at multi-krum n_at 10 e 270 | val loss 1.8804 val acc 29.9919 best val_acc 34.334416
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 271, bulyan: at multi-krum n_at 10 e 271 | val loss 1.7994 val acc 31.8588 best val_acc 34.334416
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 272, bulyan: at multi-krum n_at 10 e 272 | val loss 1.9240 val acc 28.1047 best val_acc 34.334416
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 273, bulyan: at multi-krum n_at 10 e 273 | val loss 1.8469 val acc 30.8644 best val_acc 34.334416
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 274, bulyan: at multi-krum n_at 10 e 274 | val loss 1.9442 val acc 26.0552 best val_acc 34.334416
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 275, bulyan: at multi-krum n_at 10 e 275 | val loss 1.9066 val acc 29.7281 best val_acc 34.334416
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 276, bulyan: at multi-krum n_at 10 e 276 | val loss 1.8860 val acc 30.6006 best val_acc 34.334416
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 277, bulyan: at multi-krum n_at 10 e 277 | val loss 1.8330 val acc 31.6356 best val_acc 34.334416
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 278, bulyan: at multi-krum n_at 10 e 278 | val loss 1.7959 val acc 33.4416 best val_acc 34.334416
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 279, bulyan: at multi-krum n_at 10 e 279 | val loss 1.8797 val acc 29.9716 best val_acc 34.334416
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 280, bulyan: at multi-krum n_at 10 e 280 | val loss 1.8899 val acc 29.6469 best val_acc 34.334416
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 281, bulyan: at multi-krum n_at 10 e 281 | val loss 1.9133 val acc 28.8758 best val_acc 34.334416
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 282, bulyan: at multi-krum n_at 10 e 282 | val loss 1.8937 val acc 28.7744 best val_acc 34.334416
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 283, bulyan: at multi-krum n_at 10 e 283 | val loss 1.8313 val acc 30.9253 best val_acc 34.334416
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 284, bulyan: at multi-krum n_at 10 e 284 | val loss 1.7756 val acc 35.5925 best val_acc 35.592532
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 285, bulyan: at multi-krum n_at 10 e 285 | val loss 1.7513 val acc 34.4156 best val_acc 35.592532
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 286, bulyan: at multi-krum n_at 10 e 286 | val loss 1.7460 val acc 35.7955 best val_acc 35.795455
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 287, bulyan: at multi-krum n_at 10 e 287 | val loss 1.8736 val acc 31.0065 best val_acc 35.795455
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 288, bulyan: at multi-krum n_at 10 e 288 | val loss 1.8458 val acc 34.2938 best val_acc 35.795455
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 289, bulyan: at multi-krum n_at 10 e 289 | val loss 1.7474 val acc 35.9375 best val_acc 35.937500
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 290, bulyan: at multi-krum n_at 10 e 290 | val loss 1.7290 val acc 36.0795 best val_acc 36.079545
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 291, bulyan: at multi-krum n_at 10 e 291 | val loss 1.9304 val acc 28.6526 best val_acc 36.079545
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 292, bulyan: at multi-krum n_at 10 e 292 | val loss 1.8729 val acc 29.8904 best val_acc 36.079545
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 293, bulyan: at multi-krum n_at 10 e 293 | val loss 2.0215 val acc 25.6088 best val_acc 36.079545
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 294, bulyan: at multi-krum n_at 10 e 294 | val loss 1.9653 val acc 29.1396 best val_acc 36.079545
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 295, bulyan: at multi-krum n_at 10 e 295 | val loss 1.8153 val acc 30.9659 best val_acc 36.079545
# discarded index [20, 47, 31, 26, 45, 10, 46, 29, 39, 15]
# epoch: 296, bulyan: at multi-krum n_at 10 e 296 | val loss 1.7648 val acc 34.2735 best val_acc 36.079545
# discarded index [20, 47, 31, 45, 26, 10, 46, 29, 39, 15]
# epoch: 297, bulyan: at multi-krum n_at 10 e 297 | val loss 1.8422 val acc 30.8847 best val_acc 36.079545
# discarded index [20, 47, 31, 45, 26, 10, 46, 29, 39, 15]
# epoch: 298, bulyan: at multi-krum n_at 10 e 298 | val loss 1.8957 val acc 31.9399 best val_acc 36.079545
# discarded index [20, 47, 31, 45, 26, 10, 46, 29, 39, 15]
# epoch: 299, bulyan: at multi-krum n_at 10 e 299 | val loss 1.8836 val acc 28.9164 best val_acc 36.079545
# discarded index [20, 47, 31, 45, 26, 10, 46, 29, 39, 15]
# epoch: 300, bulyan: at multi-krum n_at 10 e 300 | val loss 1.8892 val acc 31.6558 best val_acc 36.079545

# %%
import matplotlib.pyplot as plt

# Plotting the data
for col in ['loss', 'validation accuracy', 'best validation accuracy']:
    plt.plot(df['epoch'].tolist(), df[col].tolist())
    plt.title(f"{title} {col}")
    plt.show()
