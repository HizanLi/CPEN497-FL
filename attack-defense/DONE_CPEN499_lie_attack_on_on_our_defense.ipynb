# %% [markdown]
# # The notebook contains
# ### Code for _Bulyan_ aggregation algorithm, *when gradient updates of benign clients are unknown to adversary*
# ### Evaluation of all of the attacks (Fang, LIE, and our SOTA AGR-tailored and AGR-agnstic) on Bulyan

# %% [markdown]
# ## Import packages

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
from __future__ import print_function
import argparse, os, sys, csv, shutil, time, random, operator, pickle, ast, math
import numpy as np
import pandas as pd
from torch.optim import Optimizer
import torch.nn.functional as F
import torch
import pickle
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data as data
import torch.multiprocessing as mp
import math
sys.path.insert(0,'./../utils/')
from logger import *
from eval import *
from misc import *

from cifar10_normal_train import *
from cifar10_util import *
from adam import Adam
from sgd import SGD

# %% [markdown]
# ## Load Data
# Divide cifar10 data among 50 clients in Non-IID fashion using Dirichlet distribution

# %%
n_users = 50
user_tr_len = pickle.load(open('./data/user_tr_len.pkl','rb'))

user_train_data_tensors = pickle.load(open('./data/user_train_data_tensors.pkl','rb'))
user_train_label_tensors = pickle.load(open('./data/user_train_label_tensors.pkl','rb'))

val_data_tensor = pickle.load(open('./data/val_data_tensor.pkl','rb'))
val_label_tensor = pickle.load(open('./data/val_label_tensor.pkl','rb'))
te_data_tensor = pickle.load(open('./data/te_data_tensor.pkl','rb'))
te_label_tensor = pickle.load(open('./data/te_label_tensor.pkl','rb'))

# %% [markdown]
# ## Our Aggregation Function

# %%
def our_mean_defense(all_updates, n_attackers, history_updates):
    discarded_history = get_discarded_index(n_attackers, history_updates)

    mask = torch.ones(all_updates.size(0), dtype=torch.bool)
    mask[discarded_history] = False
    remaining_updates = all_updates[mask]

    print('discarded index', discarded_history)

    return torch.nanmean(remaining_updates, dim=0)

####
def euclidean_distance(row1, row2):
    return torch.sqrt(torch.sum((row1 - row2) ** 2))
####

def get_discarded_index(n_attackers, history_updates):
    n_users = history_updates.shape[0]

    ####
    distance_matrix = [[0 if i == j else euclidean_distance(history_updates[i, :], history_updates[j, :]) for j in range(n_users)] for i in range(n_users)]
    ####

    sum_of_distances = [sum(row) for row in distance_matrix]

    discarded_history = []
    for _ in range(n_attackers):
        max_distance = max(sum_of_distances)
        index_of_max_distance = sum_of_distances.index(max_distance)
        discarded_history.append(index_of_max_distance)

        for i in range(n_users):
            sum_of_distances[i] -= distance_matrix[i][index_of_max_distance]
        sum_of_distances[index_of_max_distance] = -1

    return discarded_history

# %% [markdown]
# ## Set nepochs

# %%
nepochs= 300

# %% [markdown]
# ## LIE attack and our defense

# %%
def lie_attack(all_updates, z):
    avg = torch.mean(all_updates, dim=0)
    std = torch.std(all_updates, dim=0)
    return avg + z * std

# %%
batch_size=250
resume=0

schedule=[1000]

gamma=.5
opt = 'sgd'
fed_lr=0.5
criterion=nn.CrossEntropyLoss()
use_cuda = torch.cuda.is_available()

at_type = 'multi-krum'

aggregation='bulyan'
multi_k = False
candidates = []

dev_type ='std'
n_attackers=[10]
z_values={3:0.69847, 5:0.7054, 8:0.71904, 10:0.72575, 12:0.73891}

arch='alexnet'
chkpt='./'+aggregation

past_mean = []
past_abs_sum = []
past_median = []
past_lower_quartile = []
past_upper_quartile = []
past_std = []

title = "LIE attack and our defense"

for n_attacker in n_attackers:
    epoch_num = 0
    best_global_acc = 0
    best_global_te_acc = 0

    torch.cuda.empty_cache()

    fed_model, _ = return_model(arch, 0.1, 0.9, parallel=False)
    optimizer_fed = SGD(fed_model.parameters(), lr=fed_lr)

    df = pd.DataFrame(columns = ['epoch', 'loss', 'validation accuracy', 'best validation accuracy'])

    ####
    history = torch.zeros((n_users, nepochs + 1), dtype=torch.float32).cuda()
    ####

    model_grads = []
    while epoch_num <= nepochs:
        user_grads=[]

        for i in range(n_users): # 50
            nbatches = user_tr_len[i]//batch_size

            inputs = user_train_data_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]
            targets = user_train_label_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]

            targets = targets.type(torch.LongTensor)

            inputs, targets = inputs.cuda(), targets.cuda()
            inputs, targets = torch.autograd.Variable(inputs), torch.autograd.Variable(targets)

            outputs = fed_model(inputs)
            loss = criterion(outputs, targets)
            fed_model.zero_grad()
            loss.backward(retain_graph=True)

            param_grad=[]
            for param in fed_model.parameters():
                param_grad=param.grad.data.view(-1) if not len(param_grad) else torch.cat((param_grad,param.grad.view(-1)))


            user_grads=param_grad[None, :] if len(user_grads)==0 else torch.cat((user_grads,param_grad[None,:]), 0)

        if epoch_num in schedule:
            for param_group in optimizer_fed.param_groups:
                param_group['lr'] *= gamma
                print('New learnin rate ', param_group['lr'])

        updates_abs_mean = user_grads.abs().mean(dim=1, keepdim=True)

        if n_attacker > 0:
            mal_update = lie_attack(user_grads, z_values[n_attacker])
            malicious_grads = torch.cat((torch.stack([mal_update]*n_attacker), user_grads[n_attacker:]))
        else:   # No attack
            malicious_grads = user_grads

        if not (malicious_grads.shape[0]==50):
            print(malicious_grads.shape)

        updates_abs_mean = malicious_grads.abs().mean(dim=1, keepdim=True)

        history[:, epoch_num] = updates_abs_mean.squeeze()
        agg_grads = our_mean_defense(malicious_grads, n_attacker, history)

        del user_grads

        start_idx=0

        optimizer_fed.zero_grad()

        model_grads=[]

        for i, param in enumerate(fed_model.parameters()):
            param_=agg_grads[start_idx:start_idx+len(param.data.view(-1))].reshape(param.data.shape)
            start_idx=start_idx+len(param.data.view(-1))
            param_=param_.cuda()
            model_grads.append(param_)

        optimizer_fed.step(model_grads)

        val_loss, val_acc = test(val_data_tensor,val_label_tensor,fed_model,criterion,use_cuda)
        te_loss, te_acc = test(te_data_tensor,te_label_tensor, fed_model, criterion, use_cuda)

        is_best = best_global_acc < val_acc

        best_global_acc = max(best_global_acc, val_acc)

        if is_best:
            best_global_te_acc = te_acc


        print('epoch: %d, %s: at %s n_at %d e %d | val loss %.4f val acc %.4f best val_acc %f'%(epoch_num, aggregation, at_type, n_attacker, epoch_num, val_loss, val_acc, best_global_acc))
        new_row = pd.DataFrame([{
            'epoch': epoch_num,
            'loss': val_loss,
            'validation accuracy': val_acc,
            'best validation accuracy': best_global_acc
            }])
        df = pd.concat([df, new_row], ignore_index=True)
        df.to_csv('lie_our-defense.csv', index=False)

        if val_loss > 1000:
            print('val loss %f too high'%val_loss)
            break

        epoch_num+=1
# Out:
# discarded index [15, 34, 20, 47, 39, 29, 45, 17, 31, 41]
# c:\Users\Hizan\Desktop\CPEN497-FL\attack-defense\sgd.py:109: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\python_arg_parser.cpp:1630.)
#   p.data.add_(-group['lr'], d_p)
# C:\Users\Hizan\AppData\Local\Temp\ipykernel_17624\664639141.py:132: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, new_row], ignore_index=True)
# epoch: 0, bulyan: at multi-krum n_at 10 e 0 | val loss 2.3023 val acc 9.8620 best val_acc 9.862013
# discarded index [15, 20, 39, 34, 47, 45, 29, 18, 17, 41]
# epoch: 1, bulyan: at multi-krum n_at 10 e 1 | val loss 2.3019 val acc 10.2679 best val_acc 10.267857
# discarded index [15, 20, 39, 34, 47, 45, 29, 18, 41, 17]
# epoch: 2, bulyan: at multi-krum n_at 10 e 2 | val loss 2.3016 val acc 10.2881 best val_acc 10.288149
# discarded index [15, 20, 39, 34, 47, 45, 29, 18, 41, 17]
# epoch: 3, bulyan: at multi-krum n_at 10 e 3 | val loss 2.3014 val acc 10.3084 best val_acc 10.308442
# discarded index [15, 20, 39, 34, 47, 45, 29, 18, 41, 17]
# epoch: 4, bulyan: at multi-krum n_at 10 e 4 | val loss 2.3013 val acc 10.3084 best val_acc 10.308442
# discarded index [15, 20, 39, 34, 47, 45, 29, 18, 41, 17]
# epoch: 5, bulyan: at multi-krum n_at 10 e 5 | val loss 2.3012 val acc 10.3084 best val_acc 10.308442
# discarded index [15, 20, 39, 34, 47, 45, 29, 18, 41, 17]
# epoch: 6, bulyan: at multi-krum n_at 10 e 6 | val loss 2.3010 val acc 10.3084 best val_acc 10.308442
# discarded index [20, 15, 39, 34, 47, 45, 29, 18, 41, 17]
# epoch: 7, bulyan: at multi-krum n_at 10 e 7 | val loss 2.3008 val acc 10.3084 best val_acc 10.308442
# discarded index [20, 15, 39, 34, 47, 45, 29, 18, 41, 17]
# epoch: 8, bulyan: at multi-krum n_at 10 e 8 | val loss 2.3006 val acc 10.3693 best val_acc 10.369318
# discarded index [20, 15, 39, 34, 47, 45, 29, 18, 41, 17]
# epoch: 9, bulyan: at multi-krum n_at 10 e 9 | val loss 2.3004 val acc 10.3693 best val_acc 10.369318
# discarded index [20, 15, 39, 47, 34, 45, 29, 18, 41, 17]
# epoch: 10, bulyan: at multi-krum n_at 10 e 10 | val loss 2.3002 val acc 11.0187 best val_acc 11.018669
# discarded index [20, 15, 39, 47, 34, 45, 29, 18, 41, 26]
# epoch: 11, bulyan: at multi-krum n_at 10 e 11 | val loss 2.3000 val acc 10.7143 best val_acc 11.018669
# discarded index [20, 15, 39, 47, 34, 45, 29, 18, 41, 26]
# epoch: 12, bulyan: at multi-krum n_at 10 e 12 | val loss 2.2997 val acc 11.3028 best val_acc 11.302760
# discarded index [20, 15, 39, 47, 34, 45, 29, 18, 41, 26]
# epoch: 13, bulyan: at multi-krum n_at 10 e 13 | val loss 2.2994 val acc 12.1956 best val_acc 12.195617
# discarded index [20, 15, 39, 47, 34, 45, 29, 18, 41, 26]
# epoch: 14, bulyan: at multi-krum n_at 10 e 14 | val loss 2.2990 val acc 12.3985 best val_acc 12.398539
# discarded index [20, 15, 47, 39, 34, 45, 29, 18, 41, 26]
# epoch: 15, bulyan: at multi-krum n_at 10 e 15 | val loss 2.2986 val acc 12.3377 best val_acc 12.398539
# discarded index [20, 15, 47, 39, 34, 45, 29, 18, 41, 26]
# epoch: 16, bulyan: at multi-krum n_at 10 e 16 | val loss 2.2982 val acc 13.8596 best val_acc 13.859578
# discarded index [20, 15, 47, 39, 34, 45, 29, 18, 41, 26]
# epoch: 17, bulyan: at multi-krum n_at 10 e 17 | val loss 2.2976 val acc 13.8190 best val_acc 13.859578
# discarded index [20, 15, 47, 39, 34, 45, 29, 18, 41, 26]
# epoch: 18, bulyan: at multi-krum n_at 10 e 18 | val loss 2.2968 val acc 13.7784 best val_acc 13.859578
# discarded index [20, 15, 47, 39, 34, 29, 45, 18, 41, 26]
# epoch: 19, bulyan: at multi-krum n_at 10 e 19 | val loss 2.2961 val acc 14.1234 best val_acc 14.123377
# discarded index [20, 15, 47, 39, 34, 29, 45, 41, 18, 26]
# epoch: 20, bulyan: at multi-krum n_at 10 e 20 | val loss 2.2951 val acc 14.5901 best val_acc 14.590097
# discarded index [20, 47, 15, 39, 34, 29, 45, 41, 18, 26]
# epoch: 21, bulyan: at multi-krum n_at 10 e 21 | val loss 2.2938 val acc 14.5495 best val_acc 14.590097
# discarded index [20, 47, 15, 39, 34, 29, 45, 18, 41, 26]
# epoch: 22, bulyan: at multi-krum n_at 10 e 22 | val loss 2.2923 val acc 14.7321 best val_acc 14.732143
# discarded index [20, 47, 15, 39, 34, 29, 41, 45, 18, 26]
# epoch: 23, bulyan: at multi-krum n_at 10 e 23 | val loss 2.2905 val acc 14.7727 best val_acc 14.772727
# discarded index [20, 47, 15, 39, 34, 29, 41, 45, 26, 18]
# epoch: 24, bulyan: at multi-krum n_at 10 e 24 | val loss 2.2880 val acc 14.5089 best val_acc 14.772727
# discarded index [20, 47, 15, 34, 39, 29, 41, 18, 45, 26]
# epoch: 25, bulyan: at multi-krum n_at 10 e 25 | val loss 2.2850 val acc 14.4075 best val_acc 14.772727
# discarded index [20, 47, 15, 34, 39, 29, 41, 18, 26, 45]
# epoch: 26, bulyan: at multi-krum n_at 10 e 26 | val loss 2.2809 val acc 14.4075 best val_acc 14.772727
# discarded index [20, 47, 15, 34, 39, 26, 29, 41, 18, 45]
# epoch: 27, bulyan: at multi-krum n_at 10 e 27 | val loss 2.2757 val acc 14.4278 best val_acc 14.772727
# discarded index [20, 47, 15, 34, 26, 39, 29, 41, 18, 45]
# epoch: 28, bulyan: at multi-krum n_at 10 e 28 | val loss 2.2684 val acc 14.2857 best val_acc 14.772727
# discarded index [20, 47, 15, 34, 41, 26, 29, 39, 18, 45]
# epoch: 29, bulyan: at multi-krum n_at 10 e 29 | val loss 2.2592 val acc 15.0974 best val_acc 15.097403
# discarded index [47, 20, 15, 34, 41, 26, 29, 46, 39, 18]
# epoch: 30, bulyan: at multi-krum n_at 10 e 30 | val loss 2.2463 val acc 17.2890 best val_acc 17.288961
# discarded index [20, 47, 34, 41, 15, 26, 46, 29, 39, 13]
# epoch: 31, bulyan: at multi-krum n_at 10 e 31 | val loss 2.2322 val acc 19.3385 best val_acc 19.338474
# discarded index [47, 20, 46, 26, 41, 13, 15, 31, 29, 19]
# epoch: 32, bulyan: at multi-krum n_at 10 e 32 | val loss 2.2187 val acc 17.5731 best val_acc 19.338474
# discarded index [47, 20, 41, 46, 19, 26, 13, 29, 15, 31]
# epoch: 33, bulyan: at multi-krum n_at 10 e 33 | val loss 2.2305 val acc 20.6169 best val_acc 20.616883
# discarded index [47, 20, 46, 13, 34, 41, 19, 26, 15, 31]
# epoch: 34, bulyan: at multi-krum n_at 10 e 34 | val loss 2.2603 val acc 12.1956 best val_acc 20.616883
# discarded index [47, 20, 46, 13, 41, 19, 26, 12, 31, 10]
# epoch: 35, bulyan: at multi-krum n_at 10 e 35 | val loss 2.2813 val acc 11.7492 best val_acc 20.616883
# discarded index [47, 20, 46, 13, 41, 19, 26, 12, 31, 10]
# epoch: 36, bulyan: at multi-krum n_at 10 e 36 | val loss 2.2679 val acc 13.6161 best val_acc 20.616883
# discarded index [47, 20, 46, 13, 41, 19, 26, 12, 31, 10]
# epoch: 37, bulyan: at multi-krum n_at 10 e 37 | val loss 2.2510 val acc 17.8774 best val_acc 20.616883
# discarded index [47, 20, 46, 13, 41, 19, 26, 31, 12, 10]
# epoch: 38, bulyan: at multi-krum n_at 10 e 38 | val loss 2.2273 val acc 20.6169 best val_acc 20.616883
# discarded index [47, 20, 46, 13, 41, 19, 26, 31, 12, 10]
# epoch: 39, bulyan: at multi-krum n_at 10 e 39 | val loss 2.1951 val acc 21.2459 best val_acc 21.245942
# discarded index [47, 20, 46, 41, 13, 19, 26, 31, 12, 10]
# epoch: 40, bulyan: at multi-krum n_at 10 e 40 | val loss 2.1593 val acc 22.0373 best val_acc 22.037338
# discarded index [47, 20, 46, 41, 13, 19, 26, 31, 10, 12]
# epoch: 41, bulyan: at multi-krum n_at 10 e 41 | val loss 2.1364 val acc 21.7330 best val_acc 22.037338
# discarded index [47, 20, 46, 41, 19, 13, 26, 31, 10, 12]
# epoch: 42, bulyan: at multi-krum n_at 10 e 42 | val loss 2.1160 val acc 22.3620 best val_acc 22.362013
# discarded index [20, 47, 46, 41, 19, 13, 26, 31, 10, 12]
# epoch: 43, bulyan: at multi-krum n_at 10 e 43 | val loss 2.1019 val acc 23.0925 best val_acc 23.092532
# discarded index [20, 47, 46, 41, 19, 26, 13, 31, 10, 29]
# epoch: 44, bulyan: at multi-krum n_at 10 e 44 | val loss 2.0955 val acc 21.3271 best val_acc 23.092532
# discarded index [20, 47, 41, 19, 46, 26, 13, 31, 10, 39]
# epoch: 45, bulyan: at multi-krum n_at 10 e 45 | val loss 2.3752 val acc 13.1899 best val_acc 23.092532
# discarded index [20, 47, 19, 41, 46, 26, 13, 31, 34, 11]
# epoch: 46, bulyan: at multi-krum n_at 10 e 46 | val loss 2.2431 val acc 11.2825 best val_acc 23.092532
# discarded index [20, 47, 19, 41, 46, 26, 13, 31, 34, 11]
# epoch: 47, bulyan: at multi-krum n_at 10 e 47 | val loss 2.2677 val acc 14.0625 best val_acc 23.092532
# discarded index [20, 47, 19, 41, 46, 26, 13, 31, 34, 11]
# epoch: 48, bulyan: at multi-krum n_at 10 e 48 | val loss 2.2361 val acc 15.2800 best val_acc 23.092532
# discarded index [20, 47, 19, 41, 46, 26, 13, 31, 34, 11]
# epoch: 49, bulyan: at multi-krum n_at 10 e 49 | val loss 2.1985 val acc 18.3644 best val_acc 23.092532
# discarded index [20, 47, 19, 41, 46, 26, 13, 31, 34, 11]
# epoch: 50, bulyan: at multi-krum n_at 10 e 50 | val loss 2.1803 val acc 16.1526 best val_acc 23.092532
# discarded index [20, 47, 19, 41, 46, 26, 13, 31, 34, 11]
# epoch: 51, bulyan: at multi-krum n_at 10 e 51 | val loss 2.1778 val acc 16.5381 best val_acc 23.092532
# discarded index [20, 47, 19, 41, 46, 26, 13, 31, 34, 11]
# epoch: 52, bulyan: at multi-krum n_at 10 e 52 | val loss 2.1659 val acc 16.9846 best val_acc 23.092532
# discarded index [20, 47, 19, 41, 46, 26, 13, 31, 34, 11]
# epoch: 53, bulyan: at multi-krum n_at 10 e 53 | val loss 2.1777 val acc 17.0860 best val_acc 23.092532
# discarded index [20, 47, 19, 41, 46, 26, 13, 31, 34, 11]
# epoch: 54, bulyan: at multi-krum n_at 10 e 54 | val loss 2.1502 val acc 18.5674 best val_acc 23.092532
# discarded index [20, 47, 19, 41, 46, 26, 13, 31, 34, 11]
# epoch: 55, bulyan: at multi-krum n_at 10 e 55 | val loss 2.1683 val acc 17.8166 best val_acc 23.092532
# discarded index [20, 47, 19, 41, 46, 26, 13, 31, 34, 11]
# epoch: 56, bulyan: at multi-krum n_at 10 e 56 | val loss 2.1427 val acc 19.5211 best val_acc 23.092532
# discarded index [20, 47, 19, 41, 46, 26, 13, 31, 34, 11]
# epoch: 57, bulyan: at multi-krum n_at 10 e 57 | val loss 2.1933 val acc 19.4399 best val_acc 23.092532
# discarded index [20, 47, 19, 41, 46, 26, 13, 31, 34, 11]
# epoch: 58, bulyan: at multi-krum n_at 10 e 58 | val loss 2.1242 val acc 20.5763 best val_acc 23.092532
# discarded index [20, 47, 19, 41, 46, 26, 13, 31, 34, 11]
# epoch: 59, bulyan: at multi-krum n_at 10 e 59 | val loss 2.1361 val acc 20.7386 best val_acc 23.092532
# discarded index [20, 47, 19, 41, 46, 26, 13, 31, 34, 11]
# epoch: 60, bulyan: at multi-krum n_at 10 e 60 | val loss 2.1208 val acc 20.5357 best val_acc 23.092532
# discarded index [20, 47, 19, 41, 46, 26, 13, 31, 34, 32]
# epoch: 61, bulyan: at multi-krum n_at 10 e 61 | val loss 2.2027 val acc 14.1031 best val_acc 23.092532
# discarded index [20, 47, 19, 41, 46, 26, 31, 13, 34, 11]
# epoch: 62, bulyan: at multi-krum n_at 10 e 62 | val loss 2.1070 val acc 20.6372 best val_acc 23.092532
# discarded index [20, 47, 19, 41, 26, 46, 31, 13, 29, 34]
# epoch: 63, bulyan: at multi-krum n_at 10 e 63 | val loss 2.1415 val acc 18.8718 best val_acc 23.092532
# discarded index [20, 47, 19, 41, 26, 46, 31, 13, 29, 10]
# epoch: 64, bulyan: at multi-krum n_at 10 e 64 | val loss 2.2875 val acc 16.8222 best val_acc 23.092532
# discarded index [20, 47, 19, 41, 46, 26, 13, 31, 29, 30]
# epoch: 65, bulyan: at multi-krum n_at 10 e 65 | val loss 2.2983 val acc 10.3693 best val_acc 23.092532
# discarded index [20, 47, 19, 41, 46, 26, 13, 31, 29, 30]
# epoch: 66, bulyan: at multi-krum n_at 10 e 66 | val loss 2.2711 val acc 11.3028 best val_acc 23.092532
# discarded index [20, 47, 19, 41, 26, 46, 31, 13, 29, 30]
# epoch: 67, bulyan: at multi-krum n_at 10 e 67 | val loss 2.2257 val acc 13.8799 best val_acc 23.092532
# discarded index [20, 47, 19, 41, 26, 46, 31, 13, 29, 30]
# epoch: 68, bulyan: at multi-krum n_at 10 e 68 | val loss 2.1652 val acc 17.0860 best val_acc 23.092532
# discarded index [20, 47, 19, 41, 26, 46, 31, 13, 29, 30]
# epoch: 69, bulyan: at multi-krum n_at 10 e 69 | val loss 2.1302 val acc 18.1412 best val_acc 23.092532
# discarded index [20, 47, 19, 41, 26, 46, 31, 13, 29, 30]
# epoch: 70, bulyan: at multi-krum n_at 10 e 70 | val loss 2.0956 val acc 19.9067 best val_acc 23.092532
# discarded index [20, 47, 19, 26, 41, 31, 46, 13, 29, 45]
# epoch: 71, bulyan: at multi-krum n_at 10 e 71 | val loss 2.0992 val acc 19.1964 best val_acc 23.092532
# discarded index [20, 47, 26, 19, 41, 31, 46, 13, 29, 45]
# epoch: 72, bulyan: at multi-krum n_at 10 e 72 | val loss 2.0800 val acc 19.9675 best val_acc 23.092532
# discarded index [20, 47, 19, 26, 41, 31, 46, 13, 29, 45]
# epoch: 73, bulyan: at multi-krum n_at 10 e 73 | val loss 2.1921 val acc 15.5844 best val_acc 23.092532
# discarded index [20, 47, 19, 26, 31, 41, 46, 13, 29, 45]
# epoch: 74, bulyan: at multi-krum n_at 10 e 74 | val loss 2.0764 val acc 18.2021 best val_acc 23.092532
# discarded index [20, 47, 19, 26, 31, 41, 46, 13, 29, 45]
# epoch: 75, bulyan: at multi-krum n_at 10 e 75 | val loss 2.1060 val acc 19.0747 best val_acc 23.092532
# discarded index [20, 47, 26, 19, 31, 41, 46, 13, 29, 45]
# epoch: 76, bulyan: at multi-krum n_at 10 e 76 | val loss 2.0971 val acc 17.1469 best val_acc 23.092532
# discarded index [20, 47, 26, 19, 41, 31, 46, 13, 29, 45]
# epoch: 77, bulyan: at multi-krum n_at 10 e 77 | val loss 2.2048 val acc 16.3352 best val_acc 23.092532
# discarded index [20, 47, 26, 19, 31, 41, 46, 13, 29, 45]
# epoch: 78, bulyan: at multi-krum n_at 10 e 78 | val loss 2.1080 val acc 18.0601 best val_acc 23.092532
# discarded index [20, 47, 26, 19, 31, 41, 46, 13, 29, 45]
# epoch: 79, bulyan: at multi-krum n_at 10 e 79 | val loss 2.0696 val acc 20.3734 best val_acc 23.092532
# discarded index [20, 47, 26, 31, 19, 41, 46, 13, 29, 45]
# epoch: 80, bulyan: at multi-krum n_at 10 e 80 | val loss 2.0591 val acc 22.3214 best val_acc 23.092532
# discarded index [20, 47, 26, 31, 19, 41, 46, 13, 29, 45]
# epoch: 81, bulyan: at multi-krum n_at 10 e 81 | val loss 2.1955 val acc 16.0106 best val_acc 23.092532
# discarded index [20, 47, 26, 31, 19, 41, 46, 13, 29, 45]
# epoch: 82, bulyan: at multi-krum n_at 10 e 82 | val loss 2.0847 val acc 17.9586 best val_acc 23.092532
# discarded index [20, 47, 26, 31, 19, 41, 46, 13, 29, 30]
# epoch: 83, bulyan: at multi-krum n_at 10 e 83 | val loss 2.0467 val acc 22.2808 best val_acc 23.092532
# discarded index [20, 47, 26, 31, 19, 41, 46, 13, 29, 45]
# epoch: 84, bulyan: at multi-krum n_at 10 e 84 | val loss 2.0834 val acc 19.7037 best val_acc 23.092532
# discarded index [20, 47, 26, 31, 19, 41, 46, 13, 29, 30]
# epoch: 85, bulyan: at multi-krum n_at 10 e 85 | val loss 2.1048 val acc 19.9878 best val_acc 23.092532
# discarded index [20, 47, 26, 31, 19, 41, 46, 13, 29, 45]
# epoch: 86, bulyan: at multi-krum n_at 10 e 86 | val loss 2.0539 val acc 21.0430 best val_acc 23.092532
# discarded index [20, 47, 26, 31, 19, 41, 46, 13, 29, 45]
# epoch: 87, bulyan: at multi-krum n_at 10 e 87 | val loss 2.0275 val acc 22.0982 best val_acc 23.092532
# discarded index [20, 47, 26, 31, 41, 19, 46, 13, 29, 45]
# epoch: 88, bulyan: at multi-krum n_at 10 e 88 | val loss 2.0190 val acc 21.3474 best val_acc 23.092532
# discarded index [20, 47, 26, 31, 41, 19, 46, 13, 29, 45]
# epoch: 89, bulyan: at multi-krum n_at 10 e 89 | val loss 2.1371 val acc 18.5471 best val_acc 23.092532
# discarded index [20, 47, 26, 31, 19, 41, 46, 13, 29, 45]
# epoch: 90, bulyan: at multi-krum n_at 10 e 90 | val loss 2.0595 val acc 21.3880 best val_acc 23.092532
# discarded index [20, 47, 26, 31, 19, 41, 46, 13, 29, 30]
# epoch: 91, bulyan: at multi-krum n_at 10 e 91 | val loss 2.1844 val acc 15.4627 best val_acc 23.092532
# discarded index [20, 47, 26, 31, 19, 41, 46, 13, 29, 30]
# epoch: 92, bulyan: at multi-krum n_at 10 e 92 | val loss 2.0524 val acc 21.6315 best val_acc 23.092532
# discarded index [20, 47, 26, 31, 19, 41, 46, 13, 29, 45]
# epoch: 93, bulyan: at multi-krum n_at 10 e 93 | val loss 2.0154 val acc 22.5244 best val_acc 23.092532
# discarded index [20, 47, 26, 31, 19, 41, 46, 13, 29, 45]
# epoch: 94, bulyan: at multi-krum n_at 10 e 94 | val loss 2.0813 val acc 20.2110 best val_acc 23.092532
# discarded index [20, 47, 26, 31, 41, 19, 46, 13, 29, 30]
# epoch: 95, bulyan: at multi-krum n_at 10 e 95 | val loss 2.0833 val acc 19.2573 best val_acc 23.092532
# discarded index [20, 47, 26, 31, 41, 19, 46, 13, 29, 30]
# epoch: 96, bulyan: at multi-krum n_at 10 e 96 | val loss 2.1596 val acc 16.8831 best val_acc 23.092532
# discarded index [20, 47, 26, 31, 41, 19, 46, 13, 29, 30]
# epoch: 97, bulyan: at multi-krum n_at 10 e 97 | val loss 2.1151 val acc 17.4513 best val_acc 23.092532
# discarded index [20, 47, 26, 31, 41, 19, 46, 13, 29, 30]
# epoch: 98, bulyan: at multi-krum n_at 10 e 98 | val loss 2.0649 val acc 19.1964 best val_acc 23.092532
# discarded index [20, 47, 26, 31, 41, 19, 46, 13, 29, 30]
# epoch: 99, bulyan: at multi-krum n_at 10 e 99 | val loss 2.0740 val acc 21.9156 best val_acc 23.092532
# discarded index [20, 47, 26, 31, 41, 19, 46, 13, 29, 30]
# epoch: 100, bulyan: at multi-krum n_at 10 e 100 | val loss 2.0281 val acc 21.6518 best val_acc 23.092532
# discarded index [20, 47, 26, 31, 41, 19, 46, 13, 29, 30]
# epoch: 101, bulyan: at multi-krum n_at 10 e 101 | val loss 2.1410 val acc 18.9529 best val_acc 23.092532
# discarded index [20, 47, 26, 31, 41, 19, 46, 13, 29, 30]
# epoch: 102, bulyan: at multi-krum n_at 10 e 102 | val loss 2.0293 val acc 22.6664 best val_acc 23.092532
# discarded index [20, 47, 26, 31, 41, 19, 46, 13, 29, 30]
# epoch: 103, bulyan: at multi-krum n_at 10 e 103 | val loss 2.0468 val acc 21.9968 best val_acc 23.092532
# discarded index [20, 47, 26, 31, 41, 19, 46, 13, 29, 30]
# epoch: 104, bulyan: at multi-krum n_at 10 e 104 | val loss 1.9946 val acc 25.1015 best val_acc 25.101461
# discarded index [20, 47, 26, 31, 41, 19, 46, 13, 29, 30]
# epoch: 105, bulyan: at multi-krum n_at 10 e 105 | val loss 2.1222 val acc 20.4343 best val_acc 25.101461
# discarded index [20, 47, 26, 31, 41, 19, 46, 13, 29, 30]
# epoch: 106, bulyan: at multi-krum n_at 10 e 106 | val loss 2.0254 val acc 21.6518 best val_acc 25.101461
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 13, 30]
# epoch: 107, bulyan: at multi-krum n_at 10 e 107 | val loss 2.0102 val acc 23.5390 best val_acc 25.101461
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 13, 30]
# epoch: 108, bulyan: at multi-krum n_at 10 e 108 | val loss 2.0020 val acc 24.0463 best val_acc 25.101461
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 13, 30]
# epoch: 109, bulyan: at multi-krum n_at 10 e 109 | val loss 2.0382 val acc 23.7216 best val_acc 25.101461
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 13, 30]
# epoch: 110, bulyan: at multi-krum n_at 10 e 110 | val loss 1.9759 val acc 24.1071 best val_acc 25.101461
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 13, 30]
# epoch: 111, bulyan: at multi-krum n_at 10 e 111 | val loss 2.0427 val acc 23.5998 best val_acc 25.101461
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 30, 13]
# epoch: 112, bulyan: at multi-krum n_at 10 e 112 | val loss 2.0253 val acc 20.9213 best val_acc 25.101461
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 30, 13]
# epoch: 113, bulyan: at multi-krum n_at 10 e 113 | val loss 2.1686 val acc 19.2776 best val_acc 25.101461
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 30, 13]
# epoch: 114, bulyan: at multi-krum n_at 10 e 114 | val loss 2.1118 val acc 19.8864 best val_acc 25.101461
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 30, 13]
# epoch: 115, bulyan: at multi-krum n_at 10 e 115 | val loss 2.0595 val acc 21.4894 best val_acc 25.101461
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 30, 13]
# epoch: 116, bulyan: at multi-krum n_at 10 e 116 | val loss 2.0226 val acc 23.3563 best val_acc 25.101461
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 30, 13]
# epoch: 117, bulyan: at multi-krum n_at 10 e 117 | val loss 1.9814 val acc 23.1940 best val_acc 25.101461
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 30, 13]
# epoch: 118, bulyan: at multi-krum n_at 10 e 118 | val loss 2.0597 val acc 19.2979 best val_acc 25.101461
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 30, 13]
# epoch: 119, bulyan: at multi-krum n_at 10 e 119 | val loss 2.0340 val acc 21.8547 best val_acc 25.101461
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 30, 13]
# epoch: 120, bulyan: at multi-krum n_at 10 e 120 | val loss 2.1124 val acc 20.3937 best val_acc 25.101461
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 30, 13]
# epoch: 121, bulyan: at multi-krum n_at 10 e 121 | val loss 2.0000 val acc 21.8344 best val_acc 25.101461
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 30, 13]
# epoch: 122, bulyan: at multi-krum n_at 10 e 122 | val loss 1.9940 val acc 22.8693 best val_acc 25.101461
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 30, 13]
# epoch: 123, bulyan: at multi-krum n_at 10 e 123 | val loss 2.0359 val acc 22.5446 best val_acc 25.101461
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 30, 13]
# epoch: 124, bulyan: at multi-krum n_at 10 e 124 | val loss 1.9510 val acc 25.5479 best val_acc 25.547890
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 30, 13]
# epoch: 125, bulyan: at multi-krum n_at 10 e 125 | val loss 2.0706 val acc 19.4399 best val_acc 25.547890
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 30, 45]
# epoch: 126, bulyan: at multi-krum n_at 10 e 126 | val loss 1.9980 val acc 24.9797 best val_acc 25.547890
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 30, 45]
# epoch: 127, bulyan: at multi-krum n_at 10 e 127 | val loss 1.9513 val acc 24.3101 best val_acc 25.547890
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 30, 45]
# epoch: 128, bulyan: at multi-krum n_at 10 e 128 | val loss 1.9571 val acc 26.2175 best val_acc 26.217532
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 30, 45]
# epoch: 129, bulyan: at multi-krum n_at 10 e 129 | val loss 1.9992 val acc 23.3157 best val_acc 26.217532
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 30, 45]
# epoch: 130, bulyan: at multi-krum n_at 10 e 130 | val loss 2.0773 val acc 19.6429 best val_acc 26.217532
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 30, 45]
# epoch: 131, bulyan: at multi-krum n_at 10 e 131 | val loss 2.0856 val acc 20.9619 best val_acc 26.217532
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 45, 30]
# epoch: 132, bulyan: at multi-krum n_at 10 e 132 | val loss 1.9629 val acc 25.6291 best val_acc 26.217532
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 45, 30]
# epoch: 133, bulyan: at multi-krum n_at 10 e 133 | val loss 1.9915 val acc 25.4667 best val_acc 26.217532
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 45, 30]
# epoch: 134, bulyan: at multi-krum n_at 10 e 134 | val loss 2.0055 val acc 23.3360 best val_acc 26.217532
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 45, 13]
# epoch: 135, bulyan: at multi-krum n_at 10 e 135 | val loss 2.2526 val acc 17.0860 best val_acc 26.217532
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 45, 13]
# epoch: 136, bulyan: at multi-krum n_at 10 e 136 | val loss 2.1693 val acc 16.4570 best val_acc 26.217532
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 45, 13]
# epoch: 137, bulyan: at multi-krum n_at 10 e 137 | val loss 2.0864 val acc 19.7646 best val_acc 26.217532
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 45, 13]
# epoch: 138, bulyan: at multi-krum n_at 10 e 138 | val loss 2.0206 val acc 21.6518 best val_acc 26.217532
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 45, 13]
# epoch: 139, bulyan: at multi-krum n_at 10 e 139 | val loss 1.9998 val acc 24.3506 best val_acc 26.217532
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 45, 13]
# epoch: 140, bulyan: at multi-krum n_at 10 e 140 | val loss 1.9832 val acc 24.0260 best val_acc 26.217532
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 45, 13]
# epoch: 141, bulyan: at multi-krum n_at 10 e 141 | val loss 2.1591 val acc 20.6981 best val_acc 26.217532
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 45, 13]
# epoch: 142, bulyan: at multi-krum n_at 10 e 142 | val loss 2.0806 val acc 22.3823 best val_acc 26.217532
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 45, 13]
# epoch: 143, bulyan: at multi-krum n_at 10 e 143 | val loss 1.9280 val acc 26.2175 best val_acc 26.217532
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 45, 13]
# epoch: 144, bulyan: at multi-krum n_at 10 e 144 | val loss 1.9355 val acc 26.8872 best val_acc 26.887175
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 45, 30]
# epoch: 145, bulyan: at multi-krum n_at 10 e 145 | val loss 1.9474 val acc 25.5885 best val_acc 26.887175
# discarded index [20, 47, 26, 31, 41, 19, 46, 29, 45, 10]
# epoch: 146, bulyan: at multi-krum n_at 10 e 146 | val loss 2.0151 val acc 23.5795 best val_acc 26.887175
# discarded index [20, 47, 26, 31, 41, 19, 29, 46, 45, 10]
# epoch: 147, bulyan: at multi-krum n_at 10 e 147 | val loss 2.0445 val acc 20.5154 best val_acc 26.887175
# discarded index [20, 47, 26, 31, 41, 19, 29, 46, 45, 10]
# epoch: 148, bulyan: at multi-krum n_at 10 e 148 | val loss 2.0221 val acc 25.1420 best val_acc 26.887175
# discarded index [20, 47, 26, 31, 41, 19, 29, 46, 45, 10]
# epoch: 149, bulyan: at multi-krum n_at 10 e 149 | val loss 1.9354 val acc 24.9797 best val_acc 26.887175
# discarded index [20, 47, 26, 31, 41, 19, 29, 46, 45, 10]
# epoch: 150, bulyan: at multi-krum n_at 10 e 150 | val loss 1.9435 val acc 25.6088 best val_acc 26.887175
# discarded index [20, 47, 26, 31, 41, 19, 29, 46, 45, 10]
# epoch: 151, bulyan: at multi-krum n_at 10 e 151 | val loss 1.8946 val acc 27.2524 best val_acc 27.252435
# discarded index [20, 47, 26, 31, 41, 19, 29, 46, 45, 10]
# epoch: 152, bulyan: at multi-krum n_at 10 e 152 | val loss 2.0572 val acc 22.3011 best val_acc 27.252435
# discarded index [20, 47, 26, 31, 41, 19, 29, 46, 45, 10]
# epoch: 153, bulyan: at multi-krum n_at 10 e 153 | val loss 1.9271 val acc 25.8320 best val_acc 27.252435
# discarded index [20, 47, 26, 31, 41, 19, 29, 46, 45, 10]
# epoch: 154, bulyan: at multi-krum n_at 10 e 154 | val loss 1.9482 val acc 25.6696 best val_acc 27.252435
# discarded index [20, 47, 26, 31, 41, 19, 29, 46, 45, 10]
# epoch: 155, bulyan: at multi-krum n_at 10 e 155 | val loss 1.8921 val acc 27.2119 best val_acc 27.252435
# discarded index [20, 47, 26, 31, 41, 19, 29, 46, 45, 10]
# epoch: 156, bulyan: at multi-krum n_at 10 e 156 | val loss 2.0592 val acc 21.3271 best val_acc 27.252435
# discarded index [20, 47, 26, 31, 41, 19, 29, 46, 45, 10]
# epoch: 157, bulyan: at multi-krum n_at 10 e 157 | val loss 1.9575 val acc 23.9042 best val_acc 27.252435
# discarded index [20, 47, 26, 31, 41, 19, 29, 45, 46, 10]
# epoch: 158, bulyan: at multi-krum n_at 10 e 158 | val loss 1.8829 val acc 28.7135 best val_acc 28.713474
# discarded index [20, 47, 26, 31, 41, 19, 29, 45, 46, 10]
# epoch: 159, bulyan: at multi-krum n_at 10 e 159 | val loss 1.9349 val acc 27.6177 best val_acc 28.713474
# discarded index [20, 47, 26, 31, 41, 19, 29, 45, 46, 10]
# epoch: 160, bulyan: at multi-krum n_at 10 e 160 | val loss 1.9132 val acc 28.8961 best val_acc 28.896104
# discarded index [20, 47, 26, 31, 41, 19, 29, 45, 46, 10]
# epoch: 161, bulyan: at multi-krum n_at 10 e 161 | val loss 2.1370 val acc 20.7386 best val_acc 28.896104
# discarded index [20, 47, 26, 31, 41, 19, 29, 45, 46, 10]
# epoch: 162, bulyan: at multi-krum n_at 10 e 162 | val loss 2.0170 val acc 24.7768 best val_acc 28.896104
# discarded index [20, 47, 26, 31, 41, 19, 29, 45, 46, 10]
# epoch: 163, bulyan: at multi-krum n_at 10 e 163 | val loss 1.9369 val acc 27.9018 best val_acc 28.896104
# discarded index [20, 47, 26, 31, 41, 19, 29, 45, 46, 10]
# epoch: 164, bulyan: at multi-krum n_at 10 e 164 | val loss 1.9640 val acc 25.2638 best val_acc 28.896104
# discarded index [20, 47, 26, 31, 41, 19, 29, 45, 46, 10]
# epoch: 165, bulyan: at multi-krum n_at 10 e 165 | val loss 2.0756 val acc 23.8636 best val_acc 28.896104
# discarded index [20, 47, 26, 31, 41, 19, 29, 45, 46, 10]
# epoch: 166, bulyan: at multi-krum n_at 10 e 166 | val loss 2.1482 val acc 16.6396 best val_acc 28.896104
# discarded index [20, 47, 26, 31, 41, 19, 29, 45, 46, 10]
# epoch: 167, bulyan: at multi-krum n_at 10 e 167 | val loss 2.0504 val acc 25.4261 best val_acc 28.896104
# discarded index [20, 47, 26, 31, 41, 19, 29, 45, 46, 10]
# epoch: 168, bulyan: at multi-krum n_at 10 e 168 | val loss 1.9945 val acc 27.3945 best val_acc 28.896104
# discarded index [20, 47, 26, 31, 41, 19, 29, 45, 46, 10]
# epoch: 169, bulyan: at multi-krum n_at 10 e 169 | val loss 1.9507 val acc 30.6006 best val_acc 30.600649
# discarded index [20, 47, 26, 31, 41, 19, 29, 45, 46, 10]
# epoch: 170, bulyan: at multi-krum n_at 10 e 170 | val loss 1.8821 val acc 29.6875 best val_acc 30.600649
# discarded index [20, 47, 26, 31, 41, 19, 29, 45, 46, 10]
# epoch: 171, bulyan: at multi-krum n_at 10 e 171 | val loss 1.9844 val acc 26.0349 best val_acc 30.600649
# discarded index [20, 47, 26, 31, 41, 29, 19, 45, 46, 10]
# epoch: 172, bulyan: at multi-krum n_at 10 e 172 | val loss 1.9340 val acc 25.7305 best val_acc 30.600649
# discarded index [20, 47, 26, 31, 41, 29, 19, 45, 46, 10]
# epoch: 173, bulyan: at multi-krum n_at 10 e 173 | val loss 2.0573 val acc 23.4578 best val_acc 30.600649
# discarded index [20, 47, 26, 31, 41, 29, 19, 45, 46, 10]
# epoch: 174, bulyan: at multi-krum n_at 10 e 174 | val loss 1.8871 val acc 31.2500 best val_acc 31.250000
# discarded index [20, 47, 26, 31, 41, 29, 19, 45, 46, 10]
# epoch: 175, bulyan: at multi-krum n_at 10 e 175 | val loss 1.8540 val acc 29.3831 best val_acc 31.250000
# discarded index [20, 47, 31, 26, 41, 29, 19, 45, 46, 10]
# epoch: 176, bulyan: at multi-krum n_at 10 e 176 | val loss 1.9037 val acc 27.1307 best val_acc 31.250000
# discarded index [20, 47, 26, 31, 41, 29, 19, 45, 46, 10]
# epoch: 177, bulyan: at multi-krum n_at 10 e 177 | val loss 1.9749 val acc 25.9334 best val_acc 31.250000
# discarded index [20, 47, 26, 31, 41, 29, 45, 19, 46, 10]
# epoch: 178, bulyan: at multi-krum n_at 10 e 178 | val loss 2.1552 val acc 18.5674 best val_acc 31.250000
# discarded index [20, 47, 26, 31, 41, 29, 45, 19, 46, 10]
# epoch: 179, bulyan: at multi-krum n_at 10 e 179 | val loss 2.0079 val acc 25.2435 best val_acc 31.250000
# discarded index [20, 47, 26, 31, 41, 29, 45, 19, 46, 10]
# epoch: 180, bulyan: at multi-krum n_at 10 e 180 | val loss 1.9934 val acc 29.2208 best val_acc 31.250000
# discarded index [20, 47, 26, 31, 41, 29, 45, 19, 46, 10]
# epoch: 181, bulyan: at multi-krum n_at 10 e 181 | val loss 1.9167 val acc 28.2062 best val_acc 31.250000
# discarded index [20, 47, 26, 31, 41, 29, 45, 19, 46, 10]
# epoch: 182, bulyan: at multi-krum n_at 10 e 182 | val loss 1.9407 val acc 29.8904 best val_acc 31.250000
# discarded index [20, 47, 26, 31, 41, 29, 45, 19, 46, 10]
# epoch: 183, bulyan: at multi-krum n_at 10 e 183 | val loss 1.8799 val acc 30.9050 best val_acc 31.250000
# discarded index [20, 47, 26, 31, 29, 41, 45, 19, 46, 10]
# epoch: 184, bulyan: at multi-krum n_at 10 e 184 | val loss 1.9859 val acc 27.2321 best val_acc 31.250000
# discarded index [20, 47, 26, 31, 29, 41, 45, 19, 46, 10]
# epoch: 185, bulyan: at multi-krum n_at 10 e 185 | val loss 1.8929 val acc 29.0584 best val_acc 31.250000
# discarded index [20, 47, 26, 31, 29, 41, 45, 19, 46, 10]
# epoch: 186, bulyan: at multi-krum n_at 10 e 186 | val loss 2.0208 val acc 26.2378 best val_acc 31.250000
# discarded index [20, 47, 26, 31, 29, 41, 45, 19, 46, 10]
# epoch: 187, bulyan: at multi-krum n_at 10 e 187 | val loss 1.9098 val acc 27.9424 best val_acc 31.250000
# discarded index [20, 47, 26, 31, 29, 41, 45, 19, 46, 10]
# epoch: 188, bulyan: at multi-krum n_at 10 e 188 | val loss 1.8972 val acc 29.7078 best val_acc 31.250000
# discarded index [20, 47, 26, 31, 29, 41, 45, 19, 46, 10]
# epoch: 189, bulyan: at multi-krum n_at 10 e 189 | val loss 1.8524 val acc 29.2817 best val_acc 31.250000
# discarded index [20, 47, 26, 31, 29, 41, 45, 19, 46, 10]
# epoch: 190, bulyan: at multi-krum n_at 10 e 190 | val loss 1.9448 val acc 30.0122 best val_acc 31.250000
# discarded index [20, 47, 26, 31, 29, 41, 45, 19, 46, 10]
# epoch: 191, bulyan: at multi-krum n_at 10 e 191 | val loss 1.8579 val acc 31.3718 best val_acc 31.371753
# discarded index [20, 47, 26, 31, 29, 41, 45, 19, 46, 10]
# epoch: 192, bulyan: at multi-krum n_at 10 e 192 | val loss 1.9058 val acc 28.6323 best val_acc 31.371753
# discarded index [20, 47, 26, 31, 29, 41, 45, 19, 46, 10]
# epoch: 193, bulyan: at multi-krum n_at 10 e 193 | val loss 1.9609 val acc 26.7654 best val_acc 31.371753
# discarded index [20, 47, 26, 31, 29, 41, 45, 19, 46, 10]
# epoch: 194, bulyan: at multi-krum n_at 10 e 194 | val loss 2.0536 val acc 24.5536 best val_acc 31.371753
# discarded index [20, 47, 26, 31, 29, 41, 45, 19, 46, 10]
# epoch: 195, bulyan: at multi-krum n_at 10 e 195 | val loss 1.9442 val acc 29.7078 best val_acc 31.371753
# discarded index [20, 47, 26, 31, 29, 41, 45, 19, 46, 10]
# epoch: 196, bulyan: at multi-krum n_at 10 e 196 | val loss 1.8941 val acc 30.0933 best val_acc 31.371753
# discarded index [20, 47, 26, 31, 29, 41, 45, 19, 46, 10]
# epoch: 197, bulyan: at multi-krum n_at 10 e 197 | val loss 1.8193 val acc 33.5633 best val_acc 33.563312
# discarded index [20, 47, 26, 31, 29, 41, 45, 19, 46, 10]
# epoch: 198, bulyan: at multi-krum n_at 10 e 198 | val loss 1.8695 val acc 30.8644 best val_acc 33.563312
# discarded index [20, 47, 26, 31, 29, 41, 45, 19, 46, 10]
# epoch: 199, bulyan: at multi-krum n_at 10 e 199 | val loss 1.8616 val acc 30.1136 best val_acc 33.563312
# discarded index [20, 47, 26, 31, 29, 41, 45, 19, 46, 10]
# epoch: 200, bulyan: at multi-krum n_at 10 e 200 | val loss 1.9429 val acc 29.6266 best val_acc 33.563312
# discarded index [20, 47, 31, 26, 29, 41, 45, 19, 46, 10]
# epoch: 201, bulyan: at multi-krum n_at 10 e 201 | val loss 1.8548 val acc 31.8588 best val_acc 33.563312
# discarded index [20, 47, 31, 26, 29, 41, 45, 19, 46, 10]
# epoch: 202, bulyan: at multi-krum n_at 10 e 202 | val loss 1.9571 val acc 28.9570 best val_acc 33.563312
# discarded index [20, 47, 31, 26, 29, 41, 45, 19, 46, 10]
# epoch: 203, bulyan: at multi-krum n_at 10 e 203 | val loss 1.8569 val acc 30.2760 best val_acc 33.563312
# discarded index [20, 47, 31, 26, 29, 41, 45, 19, 46, 10]
# epoch: 204, bulyan: at multi-krum n_at 10 e 204 | val loss 1.9816 val acc 28.1656 best val_acc 33.563312
# discarded index [20, 47, 31, 26, 29, 41, 45, 19, 46, 10]
# epoch: 205, bulyan: at multi-krum n_at 10 e 205 | val loss 1.8445 val acc 33.2386 best val_acc 33.563312
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 206, bulyan: at multi-krum n_at 10 e 206 | val loss 1.8277 val acc 30.6818 best val_acc 33.563312
# discarded index [20, 47, 31, 26, 29, 41, 45, 19, 46, 10]
# epoch: 207, bulyan: at multi-krum n_at 10 e 207 | val loss 1.9036 val acc 28.9773 best val_acc 33.563312
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 208, bulyan: at multi-krum n_at 10 e 208 | val loss 1.8974 val acc 29.2208 best val_acc 33.563312
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 209, bulyan: at multi-krum n_at 10 e 209 | val loss 1.8493 val acc 32.2443 best val_acc 33.563312
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 210, bulyan: at multi-krum n_at 10 e 210 | val loss 1.9104 val acc 28.9570 best val_acc 33.563312
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 211, bulyan: at multi-krum n_at 10 e 211 | val loss 1.8184 val acc 31.7979 best val_acc 33.563312
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 212, bulyan: at multi-krum n_at 10 e 212 | val loss 2.0275 val acc 26.7857 best val_acc 33.563312
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 213, bulyan: at multi-krum n_at 10 e 213 | val loss 2.0323 val acc 25.2232 best val_acc 33.563312
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 214, bulyan: at multi-krum n_at 10 e 214 | val loss 2.0170 val acc 21.8953 best val_acc 33.563312
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 215, bulyan: at multi-krum n_at 10 e 215 | val loss 1.9234 val acc 27.8612 best val_acc 33.563312
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 216, bulyan: at multi-krum n_at 10 e 216 | val loss 1.9134 val acc 31.3109 best val_acc 33.563312
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 217, bulyan: at multi-krum n_at 10 e 217 | val loss 1.8193 val acc 33.2995 best val_acc 33.563312
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 218, bulyan: at multi-krum n_at 10 e 218 | val loss 1.9346 val acc 27.5568 best val_acc 33.563312
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 219, bulyan: at multi-krum n_at 10 e 219 | val loss 1.8045 val acc 34.3141 best val_acc 34.314123
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 220, bulyan: at multi-krum n_at 10 e 220 | val loss 1.8269 val acc 31.5747 best val_acc 34.314123
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 221, bulyan: at multi-krum n_at 10 e 221 | val loss 1.8129 val acc 32.8531 best val_acc 34.314123
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 222, bulyan: at multi-krum n_at 10 e 222 | val loss 1.9900 val acc 29.0381 best val_acc 34.314123
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 223, bulyan: at multi-krum n_at 10 e 223 | val loss 2.0566 val acc 24.6956 best val_acc 34.314123
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 224, bulyan: at multi-krum n_at 10 e 224 | val loss 1.9351 val acc 27.8409 best val_acc 34.314123
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 225, bulyan: at multi-krum n_at 10 e 225 | val loss 1.8695 val acc 28.8961 best val_acc 34.314123
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 226, bulyan: at multi-krum n_at 10 e 226 | val loss 1.8084 val acc 33.1778 best val_acc 34.314123
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 227, bulyan: at multi-krum n_at 10 e 227 | val loss 1.8869 val acc 28.9976 best val_acc 34.314123
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 228, bulyan: at multi-krum n_at 10 e 228 | val loss 1.8097 val acc 33.6039 best val_acc 34.314123
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 229, bulyan: at multi-krum n_at 10 e 229 | val loss 1.8914 val acc 31.1485 best val_acc 34.314123
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 230, bulyan: at multi-krum n_at 10 e 230 | val loss 1.8173 val acc 32.2646 best val_acc 34.314123
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 231, bulyan: at multi-krum n_at 10 e 231 | val loss 1.9732 val acc 26.0349 best val_acc 34.314123
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 232, bulyan: at multi-krum n_at 10 e 232 | val loss 1.8629 val acc 32.4878 best val_acc 34.314123
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 233, bulyan: at multi-krum n_at 10 e 233 | val loss 1.8452 val acc 30.9862 best val_acc 34.314123
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 234, bulyan: at multi-krum n_at 10 e 234 | val loss 1.8040 val acc 34.0300 best val_acc 34.314123
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 235, bulyan: at multi-krum n_at 10 e 235 | val loss 1.8326 val acc 30.3977 best val_acc 34.314123
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 236, bulyan: at multi-krum n_at 10 e 236 | val loss 1.8688 val acc 29.9919 best val_acc 34.314123
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 237, bulyan: at multi-krum n_at 10 e 237 | val loss 1.8556 val acc 31.7167 best val_acc 34.314123
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 238, bulyan: at multi-krum n_at 10 e 238 | val loss 1.8616 val acc 30.4383 best val_acc 34.314123
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 239, bulyan: at multi-krum n_at 10 e 239 | val loss 1.8604 val acc 30.3369 best val_acc 34.314123
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 240, bulyan: at multi-krum n_at 10 e 240 | val loss 1.8440 val acc 32.3661 best val_acc 34.314123
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 241, bulyan: at multi-krum n_at 10 e 241 | val loss 1.7961 val acc 33.8068 best val_acc 34.314123
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 242, bulyan: at multi-krum n_at 10 e 242 | val loss 1.8033 val acc 34.1721 best val_acc 34.314123
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 243, bulyan: at multi-krum n_at 10 e 243 | val loss 1.9286 val acc 28.1250 best val_acc 34.314123
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 244, bulyan: at multi-krum n_at 10 e 244 | val loss 1.9929 val acc 26.6437 best val_acc 34.314123
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 245, bulyan: at multi-krum n_at 10 e 245 | val loss 1.8864 val acc 31.3920 best val_acc 34.314123
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 246, bulyan: at multi-krum n_at 10 e 246 | val loss 1.8965 val acc 31.7776 best val_acc 34.314123
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 247, bulyan: at multi-krum n_at 10 e 247 | val loss 1.7747 val acc 34.4765 best val_acc 34.476461
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 248, bulyan: at multi-krum n_at 10 e 248 | val loss 1.8362 val acc 32.8531 best val_acc 34.476461
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 249, bulyan: at multi-krum n_at 10 e 249 | val loss 1.7808 val acc 34.3750 best val_acc 34.476461
# discarded index [20, 47, 26, 31, 29, 45, 41, 19, 10, 46]
# epoch: 250, bulyan: at multi-krum n_at 10 e 250 | val loss 1.8466 val acc 31.2906 best val_acc 34.476461
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 251, bulyan: at multi-krum n_at 10 e 251 | val loss 1.7847 val acc 32.5893 best val_acc 34.476461
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 252, bulyan: at multi-krum n_at 10 e 252 | val loss 1.8863 val acc 31.3718 best val_acc 34.476461
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 253, bulyan: at multi-krum n_at 10 e 253 | val loss 1.8270 val acc 31.9602 best val_acc 34.476461
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 254, bulyan: at multi-krum n_at 10 e 254 | val loss 1.7494 val acc 36.3028 best val_acc 36.302760
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 255, bulyan: at multi-krum n_at 10 e 255 | val loss 1.8205 val acc 31.3718 best val_acc 36.302760
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 256, bulyan: at multi-krum n_at 10 e 256 | val loss 1.8221 val acc 30.6412 best val_acc 36.302760
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 257, bulyan: at multi-krum n_at 10 e 257 | val loss 1.9054 val acc 30.1948 best val_acc 36.302760
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 258, bulyan: at multi-krum n_at 10 e 258 | val loss 1.8182 val acc 33.5227 best val_acc 36.302760
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 259, bulyan: at multi-krum n_at 10 e 259 | val loss 1.7450 val acc 36.2216 best val_acc 36.302760
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 260, bulyan: at multi-krum n_at 10 e 260 | val loss 1.7781 val acc 33.8068 best val_acc 36.302760
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 261, bulyan: at multi-krum n_at 10 e 261 | val loss 1.8208 val acc 31.9602 best val_acc 36.302760
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 262, bulyan: at multi-krum n_at 10 e 262 | val loss 1.8389 val acc 30.5804 best val_acc 36.302760
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 263, bulyan: at multi-krum n_at 10 e 263 | val loss 1.7706 val acc 35.9984 best val_acc 36.302760
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 264, bulyan: at multi-krum n_at 10 e 264 | val loss 1.7458 val acc 36.0998 best val_acc 36.302760
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 265, bulyan: at multi-krum n_at 10 e 265 | val loss 1.7993 val acc 32.9545 best val_acc 36.302760
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 266, bulyan: at multi-krum n_at 10 e 266 | val loss 1.9000 val acc 30.9862 best val_acc 36.302760
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 267, bulyan: at multi-krum n_at 10 e 267 | val loss 1.8938 val acc 31.3718 best val_acc 36.302760
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 268, bulyan: at multi-krum n_at 10 e 268 | val loss 1.9106 val acc 28.6932 best val_acc 36.302760
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 269, bulyan: at multi-krum n_at 10 e 269 | val loss 1.7541 val acc 35.6940 best val_acc 36.302760
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 270, bulyan: at multi-krum n_at 10 e 270 | val loss 1.7571 val acc 34.9635 best val_acc 36.302760
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 271, bulyan: at multi-krum n_at 10 e 271 | val loss 1.7479 val acc 37.6623 best val_acc 37.662338
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 272, bulyan: at multi-krum n_at 10 e 272 | val loss 1.8735 val acc 33.1981 best val_acc 37.662338
# discarded index [20, 47, 26, 31, 29, 45, 41, 19, 10, 46]
# epoch: 273, bulyan: at multi-krum n_at 10 e 273 | val loss 2.0349 val acc 26.5625 best val_acc 37.662338
# discarded index [20, 47, 26, 31, 29, 45, 41, 19, 10, 46]
# epoch: 274, bulyan: at multi-krum n_at 10 e 274 | val loss 2.0278 val acc 25.3247 best val_acc 37.662338
# discarded index [20, 47, 26, 31, 29, 45, 41, 19, 10, 46]
# epoch: 275, bulyan: at multi-krum n_at 10 e 275 | val loss 2.0332 val acc 26.8466 best val_acc 37.662338
# discarded index [20, 47, 26, 31, 29, 45, 41, 19, 10, 46]
# epoch: 276, bulyan: at multi-krum n_at 10 e 276 | val loss 1.8926 val acc 32.1429 best val_acc 37.662338
# discarded index [20, 47, 26, 31, 29, 45, 41, 19, 10, 46]
# epoch: 277, bulyan: at multi-krum n_at 10 e 277 | val loss 1.8531 val acc 32.8531 best val_acc 37.662338
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 278, bulyan: at multi-krum n_at 10 e 278 | val loss 1.8152 val acc 34.4765 best val_acc 37.662338
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 279, bulyan: at multi-krum n_at 10 e 279 | val loss 1.9719 val acc 28.4497 best val_acc 37.662338
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 280, bulyan: at multi-krum n_at 10 e 280 | val loss 1.9200 val acc 28.6932 best val_acc 37.662338
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 281, bulyan: at multi-krum n_at 10 e 281 | val loss 2.0242 val acc 28.9570 best val_acc 37.662338
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 282, bulyan: at multi-krum n_at 10 e 282 | val loss 1.9316 val acc 28.3076 best val_acc 37.662338
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 283, bulyan: at multi-krum n_at 10 e 283 | val loss 1.8118 val acc 34.6591 best val_acc 37.662338
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 284, bulyan: at multi-krum n_at 10 e 284 | val loss 1.8276 val acc 34.1315 best val_acc 37.662338
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 285, bulyan: at multi-krum n_at 10 e 285 | val loss 1.7929 val acc 34.9432 best val_acc 37.662338
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 286, bulyan: at multi-krum n_at 10 e 286 | val loss 1.7931 val acc 34.6388 best val_acc 37.662338
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 287, bulyan: at multi-krum n_at 10 e 287 | val loss 1.8300 val acc 32.8937 best val_acc 37.662338
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 288, bulyan: at multi-krum n_at 10 e 288 | val loss 2.0080 val acc 26.8060 best val_acc 37.662338
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 10, 46]
# epoch: 289, bulyan: at multi-krum n_at 10 e 289 | val loss 2.0024 val acc 28.0844 best val_acc 37.662338
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 290, bulyan: at multi-krum n_at 10 e 290 | val loss 1.9244 val acc 32.8734 best val_acc 37.662338
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 291, bulyan: at multi-krum n_at 10 e 291 | val loss 1.8458 val acc 34.3344 best val_acc 37.662338
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 292, bulyan: at multi-krum n_at 10 e 292 | val loss 1.7976 val acc 37.3782 best val_acc 37.662338
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 293, bulyan: at multi-krum n_at 10 e 293 | val loss 1.7884 val acc 37.1144 best val_acc 37.662338
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 294, bulyan: at multi-krum n_at 10 e 294 | val loss 1.7463 val acc 37.2362 best val_acc 37.662338
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 295, bulyan: at multi-krum n_at 10 e 295 | val loss 1.8501 val acc 31.3109 best val_acc 37.662338
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 296, bulyan: at multi-krum n_at 10 e 296 | val loss 1.8150 val acc 34.8823 best val_acc 37.662338
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 297, bulyan: at multi-krum n_at 10 e 297 | val loss 1.7634 val acc 35.9375 best val_acc 37.662338
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 298, bulyan: at multi-krum n_at 10 e 298 | val loss 1.7203 val acc 37.6420 best val_acc 37.662338
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 299, bulyan: at multi-krum n_at 10 e 299 | val loss 1.8742 val acc 33.7865 best val_acc 37.662338
# discarded index [20, 47, 31, 26, 29, 45, 41, 19, 46, 10]
# epoch: 300, bulyan: at multi-krum n_at 10 e 300 | val loss 1.8003 val acc 36.0390 best val_acc 37.662338

# %%
import matplotlib.pyplot as plt

# Plotting the data
for col in ['loss', 'validation accuracy', 'best validation accuracy']:
    plt.plot(df['epoch'].tolist(), df[col].tolist())
    plt.title(f"{title} {col}")
    plt.show()
