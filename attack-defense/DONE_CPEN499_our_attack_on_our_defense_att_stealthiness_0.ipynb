# %% [markdown]
# # The notebook contains
# ### Code for Our attack and our aggregation algorithm
# ### Evaluation of our defense with different parameters in our attack

# %% [markdown]
# ## Import packages

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
from __future__ import print_function
import argparse, os, sys, csv, shutil, time, random, operator, pickle, ast, math
import numpy as np
import pandas as pd
from torch.optim import Optimizer
import torch.nn.functional as F
import torch
import pickle
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data as data
import torch.multiprocessing as mp
import math
sys.path.insert(0,'./../utils/')
from logger import *
from eval import *
from misc import *

from cifar10_normal_train import *
from cifar10_util import *
from adam import Adam
from sgd import SGD

# %% [markdown]
# ### Load Data
# Divide cifar10 data among 50 clients in Non-IID fashion using Dirichlet distribution

# %%
n_users = 50
user_tr_len = pickle.load(open('./data/user_tr_len.pkl','rb'))

user_train_data_tensors = pickle.load(open('./data/user_train_data_tensors.pkl','rb'))
user_train_label_tensors = pickle.load(open('./data/user_train_label_tensors.pkl','rb'))

val_data_tensor = pickle.load(open('./data/val_data_tensor.pkl','rb'))
val_label_tensor = pickle.load(open('./data/val_label_tensor.pkl','rb'))
te_data_tensor = pickle.load(open('./data/te_data_tensor.pkl','rb'))
te_label_tensor = pickle.load(open('./data/te_label_tensor.pkl','rb'))

# %% [markdown]
# ### Our Aggregation Function

# %%
def our_mean_defense(all_updates, n_attackers, history_updates):
    discarded_history = get_discarded_index(n_attackers, history_updates)

    mask = torch.ones(all_updates.size(0), dtype=torch.bool)
    mask[discarded_history] = False
    remaining_updates = all_updates[mask]

    print('discarded index', discarded_history)

    return torch.nanmean(remaining_updates, dim=0)

####
def euclidean_distance(row1, row2):
    return torch.sqrt(torch.sum((row1 - row2) ** 2))
####

def get_discarded_index(n_attackers, history_updates):
    n_users = history_updates.shape[0]

    ####
    distance_matrix = [[0 if i == j else euclidean_distance(history_updates[i, :], history_updates[j, :]) for j in range(n_users)] for i in range(n_users)]
    ####

    sum_of_distances = [sum(row) for row in distance_matrix]

    discarded_history = []
    for _ in range(n_attackers):
        max_distance = max(sum_of_distances)
        index_of_max_distance = sum_of_distances.index(max_distance)
        discarded_history.append(index_of_max_distance)

        for i in range(n_users):
            sum_of_distances[i] -= distance_matrix[i][index_of_max_distance]
        sum_of_distances[index_of_max_distance] = -1

    return discarded_history

# %% [markdown]
# ### Set nepochs

# %%
nepochs= 300

# %% [markdown]
# # our_attack & our defense

# %% [markdown]
# ## attacker stealthiness: discard 10
#
# 10 bisection; 10 iterations; 10 discarded

# %% [markdown]
# ### our_attack_mean
# $ argmin_\theta(\ -L(\theta_{attacker(s)}) + \lambda_1 |\bar{\theta_{abs\ mean\ benige\ users}} - \bar{\theta_{abs\ attacker(s)}}|$

# %%
device = 'cuda:0'
def check_condition(lambda1, prev_grad, loss_grad, history, all_updates, n_users, n_attacker, epoch_num):
    loss_grad = loss_grad.to(device)
    prev_grad = prev_grad.to(device)
    new_grad = lambda1 * (loss_grad + prev_grad)

    ####
    mal_updates = torch.stack([new_grad.clone().detach() for _ in range(n_attacker)])
    malicious_grads = torch.cat((mal_updates, all_updates[n_attacker:]), 0)

    history_updates = history.clone().detach()
    history_updates[:, epoch_num] = malicious_grads.abs().mean(dim=1, keepdim=True).squeeze()
    ####

    discarded_history = get_discarded_index(n_attacker, history_updates)

    detected_mal = len([item for item in discarded_history if item < 10])
    return detected_mal / len(discarded_history) <= n_attacker / n_users

def find_upper_bound(lambda1, prev_grad, loss_grad, history, all_updates, n_users, n_attacker, epoch_num):
    while check_condition(lambda1, prev_grad, loss_grad, history, all_updates, n_users, n_attacker, epoch_num):
        lambda1 *= 2  # Exponentially increase lambda
    return lambda1


def projection(prev_grad, loss_grad, history, all_updates, n_users, n_attacker, epoch_num):
    updates_abs_mean = all_updates.abs().mean(dim=1, keepdim=True)
    median_value = torch.median(updates_abs_mean).item()

    ####
    history_updates = history.clone().detach()
    history_updates[:, epoch_num] = updates_abs_mean.mean(dim=1, keepdim=True).squeeze()
    ####

    loss_grad = loss_grad.to(device)
    prev_grad = prev_grad.to(device)

    lambda_low = median_value/(prev_grad + loss_grad).abs().mean().item()
    lambda_high = find_upper_bound(lambda_low, prev_grad, loss_grad, history_updates, all_updates, n_users, n_attacker, epoch_num)
    if lambda_high < lambda_low:
        lambda_high = lambda_low
        print("SHOULD NEVER REACH THIS LINE")
        print('lambda_low: ', lambda_low, ' lambda_high: ', lambda_high)
    tolerance = 1e-6

    iterations_count = 0
    while lambda_high - lambda_low > tolerance and iterations_count < 10:
        lambda_mid = (lambda_low + lambda_high) / 2
        if check_condition(lambda_mid, prev_grad, loss_grad, history_updates, all_updates, n_users, n_attacker, epoch_num):
            lambda_low = lambda_mid
        else:
            lambda_high = lambda_mid
        iterations_count += 1

    lambda1 = lambda_low

    return lambda1 * (prev_grad + loss_grad)

def our_attack_mean(n_user, epoch_num, history_updates, all_updates, model_params, n_attacker, arch, criterion, user_train_data_tensors, user_train_label_tensors):
    attacker_tr_data_tensor = user_train_data_tensors[0].cuda()
    attacker_tr_label_tensor = user_train_label_tensors[0].cuda()

    fed_model, _ = return_model(arch, 0.1, 0.9, parallel=False)
    fed_model.eval()  # Ensure the model is in evaluation mode

    new_grad = -all_updates[0].clone().detach().requires_grad_(True)
    prev_grad = np.zeros(len(new_grad))
    new_grad = projection(torch.from_numpy(prev_grad), new_grad, history_updates, all_updates, n_user, n_attacker, epoch_num)

    for _ in range(10):
        outputs = fed_model(attacker_tr_data_tensor)
        loss = criterion(outputs, attacker_tr_label_tensor)

        loss.backward(retain_graph=True)
        param_grad = []
        for param in fed_model.parameters():
            param_grad.append(param.grad.view(-1).detach())

        param_grad = torch.cat(param_grad)
        prev_grad = new_grad
        new_grad = projection(prev_grad, param_grad, history_updates, all_updates, n_user, n_attacker, epoch_num)

        difference = torch.mean(torch.abs(new_grad - prev_grad)).item()
        if difference < 1e-6:
            # print("STOPPED! Difference is too small, stop finding best attack grad")
            break

        fed_model.zero_grad()

    result_attacker_grads = [new_grad.clone().detach() for _ in range(10)]
    return torch.stack(result_attacker_grads).cuda()

# %% [markdown]
# ### our attack (10 attacker) + our defense

# %%
batch_size=250
resume=0

schedule=[1000]

gamma=.5
opt = 'sgd'
fed_lr=0.5
criterion=nn.CrossEntropyLoss()
use_cuda = torch.cuda.is_available()

aggregation='bulyan'
multi_k = False
candidates = []

at_type='our-agr'
dev_type ='std'
n_attackers=[10]

arch='alexnet'
chkpt='./'+aggregation

past_mean = []
past_abs_sum = []
past_median = []
past_lower_quartile = []
past_upper_quartile = []
past_std = []

title = "our attack (10 attacker) + our defense"

for n_attacker in n_attackers:
    epoch_num = 0
    best_global_acc = 0
    best_global_te_acc = 0

    torch.cuda.empty_cache()

    fed_model, _ = return_model(arch, 0.1, 0.9, parallel=False)
    optimizer_fed = SGD(fed_model.parameters(), lr=fed_lr)

    df = pd.DataFrame(columns = ['epoch', 'loss', 'validation accuracy', 'best validation accuracy'])

    ####
    history = torch.zeros((n_users, nepochs + 1), dtype=torch.float32).cuda()
    ####

    model_grads = []
    flag = False
    while epoch_num <= nepochs:
        user_grads=[]

        for i in range(n_users): # 50
            nbatches = user_tr_len[i]//batch_size

            inputs = user_train_data_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]
            targets = user_train_label_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]

            targets = targets.type(torch.LongTensor)

            inputs, targets = inputs.cuda(), targets.cuda()
            inputs, targets = torch.autograd.Variable(inputs), torch.autograd.Variable(targets)

            outputs = fed_model(inputs)
            loss = criterion(outputs, targets)
            fed_model.zero_grad()
            loss.backward(retain_graph=True)

            param_grad=[]
            for param in fed_model.parameters():
                param_grad=param.grad.data.view(-1) if not len(param_grad) else torch.cat((param_grad,param.grad.view(-1)))


            user_grads=param_grad[None, :] if len(user_grads)==0 else torch.cat((user_grads,param_grad[None,:]), 0)

        if epoch_num in schedule:
            for param_group in optimizer_fed.param_groups:
                param_group['lr'] *= gamma
                print('New learnin rate ', param_group['lr'])

        updates_abs_mean = user_grads.abs().mean(dim=1, keepdim=True)

        if n_attacker > 0:
            model_params = torch.cat([p.data.view(-1) for p in fed_model.parameters()])
            mal_updates = our_attack_mean(n_users, epoch_num, history, user_grads, model_params, n_attacker, arch, criterion, user_train_data_tensors, user_train_label_tensors)
            malicious_grads = torch.cat((mal_updates, user_grads[n_attacker:]), 0) # torch.Size([50, 2472266])


        if not (malicious_grads.shape[0]==50):
            print(malicious_grads.shape)

        updates_abs_mean = malicious_grads.abs().mean(dim=1, keepdim=True)

        history[:, epoch_num] = updates_abs_mean.squeeze()
        agg_grads = our_mean_defense(malicious_grads, n_attacker, history)

        del user_grads

        start_idx=0

        optimizer_fed.zero_grad()

        model_grads=[]

        for i, param in enumerate(fed_model.parameters()):
            param_=agg_grads[start_idx:start_idx+len(param.data.view(-1))].reshape(param.data.shape)
            start_idx=start_idx+len(param.data.view(-1))
            param_=param_.cuda()
            model_grads.append(param_)

        optimizer_fed.step(model_grads)

        val_loss, val_acc = test(val_data_tensor,val_label_tensor,fed_model,criterion, use_cuda)
        te_loss, te_acc = test(te_data_tensor,te_label_tensor, fed_model, criterion, use_cuda)

        is_best = best_global_acc < val_acc

        best_global_acc = max(best_global_acc, val_acc)

        if is_best:
            best_global_te_acc = te_acc


        print('epoch: %d, %s: at %s n_at %d e %d | val loss %.4f val acc %.4f best val_acc %f'%(epoch_num, aggregation, at_type, n_attacker, epoch_num, val_loss, val_acc, best_global_acc))
        new_row = pd.DataFrame([{
            'epoch': epoch_num,
            'loss': val_loss,
            'validation accuracy': val_acc,
            'best validation accuracy': best_global_acc
            }])
        df = pd.concat([df, new_row], ignore_index=True)
        df.to_csv('our_attack_stealthiness_discard_10.csv', index=False)

        if val_loss > 1000:
            print('val loss %f too high'%val_loss)
            break

        epoch_num+=1
# Out:
# discarded index [34, 20, 33, 37, 47, 11, 49, 28, 25, 44]
# epoch: 0, bulyan: at our-agr n_at 10 e 0 | val loss 2.3025 val acc 9.9026 best val_acc 9.902597
# c:\Users\Hizan\Desktop\CPEN497-FL\attack-defense\sgd.py:109: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\python_arg_parser.cpp:1630.)
#   p.data.add_(-group['lr'], d_p)
# C:\Users\Hizan\AppData\Local\Temp\ipykernel_18088\4126899468.py:131: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, new_row], ignore_index=True)
# discarded index [20, 34, 37, 33, 47, 11, 43, 25, 28, 49]
# epoch: 1, bulyan: at our-agr n_at 10 e 1 | val loss 2.3022 val acc 10.1461 best val_acc 10.146104
# discarded index [34, 20, 37, 32, 33, 11, 25, 49, 43, 44]
# epoch: 2, bulyan: at our-agr n_at 10 e 2 | val loss 2.3021 val acc 10.1461 best val_acc 10.146104
# discarded index [20, 34, 47, 15, 37, 39, 0, 1, 2, 3]
# epoch: 3, bulyan: at our-agr n_at 10 e 3 | val loss 2.3018 val acc 10.1461 best val_acc 10.146104
# discarded index [20, 34, 47, 15, 39, 37, 33, 49, 11, 25]
# epoch: 4, bulyan: at our-agr n_at 10 e 4 | val loss 2.3018 val acc 10.1461 best val_acc 10.146104
# discarded index [20, 34, 47, 15, 39, 37, 32, 25, 43, 49]
# epoch: 5, bulyan: at our-agr n_at 10 e 5 | val loss 2.3021 val acc 10.1461 best val_acc 10.146104
# discarded index [20, 34, 47, 15, 39, 37, 33, 32, 49, 11]
# epoch: 6, bulyan: at our-agr n_at 10 e 6 | val loss 2.3024 val acc 10.1461 best val_acc 10.146104
# discarded index [20, 34, 47, 15, 39, 37, 33, 25, 11, 43]
# epoch: 7, bulyan: at our-agr n_at 10 e 7 | val loss 2.3027 val acc 10.1461 best val_acc 10.146104
# discarded index [20, 34, 47, 39, 15, 37, 32, 33, 11, 49]
# epoch: 8, bulyan: at our-agr n_at 10 e 8 | val loss 2.3029 val acc 10.1461 best val_acc 10.146104
# discarded index [20, 34, 47, 15, 39, 37, 33, 32, 25, 43]
# epoch: 9, bulyan: at our-agr n_at 10 e 9 | val loss 2.3033 val acc 10.1461 best val_acc 10.146104
# discarded index [20, 34, 47, 15, 39, 37, 33, 49, 32, 11]
# epoch: 10, bulyan: at our-agr n_at 10 e 10 | val loss 2.3039 val acc 10.1461 best val_acc 10.146104
# discarded index [20, 34, 47, 39, 15, 32, 37, 33, 11, 43]
# epoch: 11, bulyan: at our-agr n_at 10 e 11 | val loss 2.3042 val acc 10.1461 best val_acc 10.146104
# discarded index [20, 34, 47, 15, 39, 33, 37, 32, 11, 49]
# epoch: 12, bulyan: at our-agr n_at 10 e 12 | val loss 2.3052 val acc 10.1461 best val_acc 10.146104
# discarded index [20, 34, 47, 15, 39, 33, 28, 37, 43, 24]
# epoch: 13, bulyan: at our-agr n_at 10 e 13 | val loss 2.3053 val acc 10.1461 best val_acc 10.146104
# discarded index [20, 34, 47, 15, 39, 32, 24, 33, 37, 11]
# epoch: 14, bulyan: at our-agr n_at 10 e 14 | val loss 2.3065 val acc 10.1461 best val_acc 10.146104
# discarded index [20, 34, 47, 15, 39, 33, 24, 11, 32, 43]
# epoch: 15, bulyan: at our-agr n_at 10 e 15 | val loss 2.3077 val acc 10.1461 best val_acc 10.146104
# discarded index [20, 34, 47, 15, 39, 28, 24, 33, 11, 37]
# epoch: 16, bulyan: at our-agr n_at 10 e 16 | val loss 2.3079 val acc 10.1461 best val_acc 10.146104
# discarded index [20, 34, 47, 28, 32, 24, 43, 33, 25, 11]
# epoch: 17, bulyan: at our-agr n_at 10 e 17 | val loss 2.3076 val acc 10.1664 best val_acc 10.166396
# discarded index [20, 34, 47, 15, 39, 0, 1, 2, 3, 4]
# epoch: 18, bulyan: at our-agr n_at 10 e 18 | val loss 2.3013 val acc 11.5260 best val_acc 11.525974
# discarded index [20, 34, 47, 28, 33, 24, 43, 11, 25, 32]
# epoch: 19, bulyan: at our-agr n_at 10 e 19 | val loss 2.2979 val acc 12.9464 best val_acc 12.946429
# discarded index [20, 47, 34, 39, 45, 15, 0, 1, 2, 3]
# epoch: 20, bulyan: at our-agr n_at 10 e 20 | val loss 2.2960 val acc 11.1404 best val_acc 12.946429
# discarded index [20, 47, 34, 45, 43, 32, 49, 33, 11, 28]
# epoch: 21, bulyan: at our-agr n_at 10 e 21 | val loss 2.3024 val acc 11.4854 best val_acc 12.946429
# discarded index [20, 47, 45, 34, 49, 43, 32, 11, 44, 25]
# epoch: 22, bulyan: at our-agr n_at 10 e 22 | val loss 2.3131 val acc 11.3839 best val_acc 12.946429
# discarded index [20, 47, 45, 34, 49, 11, 43, 44, 0, 1]
# epoch: 23, bulyan: at our-agr n_at 10 e 23 | val loss 2.2889 val acc 12.9464 best val_acc 12.946429
# discarded index [20, 47, 45, 34, 49, 43, 11, 44, 14, 40]
# epoch: 24, bulyan: at our-agr n_at 10 e 24 | val loss 2.3662 val acc 9.4156 best val_acc 12.946429
# discarded index [20, 47, 45, 34, 11, 49, 43, 44, 32, 12]
# epoch: 25, bulyan: at our-agr n_at 10 e 25 | val loss 2.3728 val acc 8.5836 best val_acc 12.946429
# discarded index [20, 47, 45, 34, 11, 49, 43, 44, 32, 12]
# epoch: 26, bulyan: at our-agr n_at 10 e 26 | val loss 2.3486 val acc 10.1461 best val_acc 12.946429
# discarded index [20, 47, 45, 34, 11, 22, 49, 44, 27, 12]
# epoch: 27, bulyan: at our-agr n_at 10 e 27 | val loss 2.3208 val acc 13.9002 best val_acc 13.900162
# discarded index [20, 47, 45, 34, 22, 11, 27, 49, 44, 10]
# epoch: 28, bulyan: at our-agr n_at 10 e 28 | val loss 3.3424 val acc 14.3669 best val_acc 14.366883
# discarded index [20, 47, 45, 18, 35, 27, 21, 11, 23, 49]
# epoch: 29, bulyan: at our-agr n_at 10 e 29 | val loss 2.9745 val acc 10.1461 best val_acc 14.366883
# discarded index [20, 47, 45, 18, 35, 27, 21, 11, 23, 49]
# epoch: 30, bulyan: at our-agr n_at 10 e 30 | val loss 2.8501 val acc 10.1461 best val_acc 14.366883
# discarded index [20, 47, 45, 18, 35, 27, 21, 23, 11, 49]
# epoch: 31, bulyan: at our-agr n_at 10 e 31 | val loss 2.7658 val acc 12.1347 best val_acc 14.366883
# discarded index [20, 47, 45, 18, 35, 27, 21, 11, 23, 49]
# epoch: 32, bulyan: at our-agr n_at 10 e 32 | val loss 2.6971 val acc 17.0252 best val_acc 17.025162
# discarded index [20, 47, 45, 18, 35, 27, 21, 11, 23, 49]
# epoch: 33, bulyan: at our-agr n_at 10 e 33 | val loss 2.6193 val acc 16.6193 best val_acc 17.025162
# discarded index [20, 47, 45, 18, 35, 27, 31, 0, 1, 2]
# epoch: 34, bulyan: at our-agr n_at 10 e 34 | val loss 2.5019 val acc 17.1875 best val_acc 17.187500
# discarded index [20, 47, 45, 18, 35, 27, 31, 21, 0, 1]
# epoch: 35, bulyan: at our-agr n_at 10 e 35 | val loss 3.0412 val acc 10.1055 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 18, 35, 27, 17, 0, 1]
# epoch: 36, bulyan: at our-agr n_at 10 e 36 | val loss 3.1402 val acc 10.1461 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 18, 35, 27, 17, 0, 1]
# epoch: 37, bulyan: at our-agr n_at 10 e 37 | val loss 2.7140 val acc 10.1664 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 18, 35, 27, 17, 0, 1]
# epoch: 38, bulyan: at our-agr n_at 10 e 38 | val loss 2.5617 val acc 10.6737 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 0, 1, 2, 3, 4, 5]
# epoch: 39, bulyan: at our-agr n_at 10 e 39 | val loss 2.3241 val acc 15.5235 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 18, 35, 27, 17, 0, 1]
# epoch: 40, bulyan: at our-agr n_at 10 e 40 | val loss 2.5473 val acc 9.8214 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 18, 35, 27, 17, 0, 1]
# epoch: 41, bulyan: at our-agr n_at 10 e 41 | val loss 2.5713 val acc 10.2679 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 18, 35, 27, 17, 0, 1]
# epoch: 42, bulyan: at our-agr n_at 10 e 42 | val loss 2.5078 val acc 11.0998 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 0, 1, 2, 3, 4, 5]
# epoch: 43, bulyan: at our-agr n_at 10 e 43 | val loss 2.3513 val acc 15.3003 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 18, 35, 27, 17, 0, 1]
# epoch: 44, bulyan: at our-agr n_at 10 e 44 | val loss 2.5617 val acc 8.1778 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 0, 1]
# epoch: 45, bulyan: at our-agr n_at 10 e 45 | val loss 2.5392 val acc 10.6331 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 0, 1]
# epoch: 46, bulyan: at our-agr n_at 10 e 46 | val loss 2.4178 val acc 9.9635 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 0, 1]
# epoch: 47, bulyan: at our-agr n_at 10 e 47 | val loss 2.3001 val acc 10.3084 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 0, 1]
# epoch: 48, bulyan: at our-agr n_at 10 e 48 | val loss 2.3090 val acc 8.5227 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 0, 1]
# epoch: 49, bulyan: at our-agr n_at 10 e 49 | val loss 2.2936 val acc 15.8888 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 0, 1]
# epoch: 50, bulyan: at our-agr n_at 10 e 50 | val loss 2.4295 val acc 9.5373 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 0, 1]
# epoch: 51, bulyan: at our-agr n_at 10 e 51 | val loss 2.4960 val acc 10.3693 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 0, 1]
# epoch: 52, bulyan: at our-agr n_at 10 e 52 | val loss 2.5779 val acc 14.3466 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 0, 1]
# epoch: 53, bulyan: at our-agr n_at 10 e 53 | val loss 2.3927 val acc 10.3084 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 0, 1]
# epoch: 54, bulyan: at our-agr n_at 10 e 54 | val loss 2.3442 val acc 8.6039 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 0, 1]
# epoch: 55, bulyan: at our-agr n_at 10 e 55 | val loss 2.2936 val acc 14.4481 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 0, 1]
# epoch: 56, bulyan: at our-agr n_at 10 e 56 | val loss 2.4232 val acc 9.9838 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 0, 1]
# epoch: 57, bulyan: at our-agr n_at 10 e 57 | val loss 2.4829 val acc 11.2013 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 0, 1]
# epoch: 58, bulyan: at our-agr n_at 10 e 58 | val loss 2.7230 val acc 12.4391 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 0, 1]
# epoch: 59, bulyan: at our-agr n_at 10 e 59 | val loss 2.4892 val acc 10.3084 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 0, 1]
# epoch: 60, bulyan: at our-agr n_at 10 e 60 | val loss 2.3376 val acc 12.9870 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 0, 1]
# epoch: 61, bulyan: at our-agr n_at 10 e 61 | val loss 2.2873 val acc 15.8482 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 0, 1]
# epoch: 62, bulyan: at our-agr n_at 10 e 62 | val loss 2.4403 val acc 10.5519 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 0, 1]
# epoch: 63, bulyan: at our-agr n_at 10 e 63 | val loss 2.4825 val acc 13.2508 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 0, 1]
# epoch: 64, bulyan: at our-agr n_at 10 e 64 | val loss 2.7669 val acc 16.4367 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 0, 1]
# epoch: 65, bulyan: at our-agr n_at 10 e 65 | val loss 2.4973 val acc 10.3693 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 0, 1]
# epoch: 66, bulyan: at our-agr n_at 10 e 66 | val loss 2.3205 val acc 15.8685 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 0, 1]
# epoch: 67, bulyan: at our-agr n_at 10 e 67 | val loss 2.3002 val acc 15.8279 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 0, 1]
# epoch: 68, bulyan: at our-agr n_at 10 e 68 | val loss 2.7989 val acc 15.8888 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 69, bulyan: at our-agr n_at 10 e 69 | val loss 2.5981 val acc 12.6420 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 70, bulyan: at our-agr n_at 10 e 70 | val loss 2.4938 val acc 13.3929 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 71, bulyan: at our-agr n_at 10 e 71 | val loss 2.3363 val acc 16.8019 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 72, bulyan: at our-agr n_at 10 e 72 | val loss 2.4197 val acc 16.0106 best val_acc 17.187500
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 73, bulyan: at our-agr n_at 10 e 73 | val loss 2.3881 val acc 17.4310 best val_acc 17.431006
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 74, bulyan: at our-agr n_at 10 e 74 | val loss 3.0969 val acc 14.9554 best val_acc 17.431006
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 75, bulyan: at our-agr n_at 10 e 75 | val loss 2.8329 val acc 11.7695 best val_acc 17.431006
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 76, bulyan: at our-agr n_at 10 e 76 | val loss 2.4369 val acc 14.1234 best val_acc 17.431006
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 77, bulyan: at our-agr n_at 10 e 77 | val loss 2.3216 val acc 18.3644 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 78, bulyan: at our-agr n_at 10 e 78 | val loss 2.8297 val acc 15.4627 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 79, bulyan: at our-agr n_at 10 e 79 | val loss 2.7478 val acc 10.8157 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 80, bulyan: at our-agr n_at 10 e 80 | val loss 2.8601 val acc 16.2744 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 21, 11]
# epoch: 81, bulyan: at our-agr n_at 10 e 81 | val loss 2.6418 val acc 12.0536 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 21, 11]
# epoch: 82, bulyan: at our-agr n_at 10 e 82 | val loss 2.4926 val acc 15.9700 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 83, bulyan: at our-agr n_at 10 e 83 | val loss 2.3937 val acc 16.5787 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 84, bulyan: at our-agr n_at 10 e 84 | val loss 3.1260 val acc 16.6193 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 0, 1, 2]
# epoch: 85, bulyan: at our-agr n_at 10 e 85 | val loss 3.3572 val acc 10.9375 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 86, bulyan: at our-agr n_at 10 e 86 | val loss 3.8534 val acc 9.6997 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 87, bulyan: at our-agr n_at 10 e 87 | val loss 3.4462 val acc 10.3084 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 88, bulyan: at our-agr n_at 10 e 88 | val loss 2.6838 val acc 10.1055 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 89, bulyan: at our-agr n_at 10 e 89 | val loss 3.1690 val acc 10.1461 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 90, bulyan: at our-agr n_at 10 e 90 | val loss 5.5836 val acc 9.8011 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 21, 11]
# epoch: 91, bulyan: at our-agr n_at 10 e 91 | val loss 4.4629 val acc 9.8620 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 21, 11]
# epoch: 92, bulyan: at our-agr n_at 10 e 92 | val loss 3.6233 val acc 9.1315 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 21, 11]
# epoch: 93, bulyan: at our-agr n_at 10 e 93 | val loss 4.9329 val acc 9.6997 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 0, 1]
# epoch: 94, bulyan: at our-agr n_at 10 e 94 | val loss 3.8047 val acc 10.3084 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 0, 1]
# epoch: 95, bulyan: at our-agr n_at 10 e 95 | val loss 3.8553 val acc 9.8823 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 0, 1]
# epoch: 96, bulyan: at our-agr n_at 10 e 96 | val loss 3.3949 val acc 10.3084 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 0, 1]
# epoch: 97, bulyan: at our-agr n_at 10 e 97 | val loss 4.2117 val acc 10.0244 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 0, 1]
# epoch: 98, bulyan: at our-agr n_at 10 e 98 | val loss 3.5828 val acc 10.3084 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 0, 1]
# epoch: 99, bulyan: at our-agr n_at 10 e 99 | val loss 3.4189 val acc 9.8620 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 0, 1]
# epoch: 100, bulyan: at our-agr n_at 10 e 100 | val loss 2.7494 val acc 10.3084 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 0, 1]
# epoch: 101, bulyan: at our-agr n_at 10 e 101 | val loss 2.5714 val acc 10.7549 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 0, 1]
# epoch: 102, bulyan: at our-agr n_at 10 e 102 | val loss 3.5030 val acc 10.1461 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 0, 1]
# epoch: 103, bulyan: at our-agr n_at 10 e 103 | val loss 9.0026 val acc 12.4391 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 104, bulyan: at our-agr n_at 10 e 104 | val loss 5.7266 val acc 9.8620 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 105, bulyan: at our-agr n_at 10 e 105 | val loss 4.0188 val acc 10.3084 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 106, bulyan: at our-agr n_at 10 e 106 | val loss 3.5397 val acc 9.8011 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 107, bulyan: at our-agr n_at 10 e 107 | val loss 4.1471 val acc 10.1461 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 108, bulyan: at our-agr n_at 10 e 108 | val loss 4.5991 val acc 10.1867 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 109, bulyan: at our-agr n_at 10 e 109 | val loss 3.4815 val acc 10.3084 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 110, bulyan: at our-agr n_at 10 e 110 | val loss 2.5658 val acc 9.8620 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 111, bulyan: at our-agr n_at 10 e 111 | val loss 2.9112 val acc 12.2362 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 112, bulyan: at our-agr n_at 10 e 112 | val loss 4.9333 val acc 10.0244 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 113, bulyan: at our-agr n_at 10 e 113 | val loss 3.4726 val acc 10.3084 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 114, bulyan: at our-agr n_at 10 e 114 | val loss 3.7546 val acc 9.8620 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 115, bulyan: at our-agr n_at 10 e 115 | val loss 2.9581 val acc 10.3084 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 116, bulyan: at our-agr n_at 10 e 116 | val loss 2.5456 val acc 9.8011 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 117, bulyan: at our-agr n_at 10 e 117 | val loss 2.9033 val acc 10.1461 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 118, bulyan: at our-agr n_at 10 e 118 | val loss 4.9493 val acc 9.8011 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 119, bulyan: at our-agr n_at 10 e 119 | val loss 3.3103 val acc 10.3084 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 120, bulyan: at our-agr n_at 10 e 120 | val loss 2.7371 val acc 9.8620 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 121, bulyan: at our-agr n_at 10 e 121 | val loss 2.4345 val acc 10.3084 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 122, bulyan: at our-agr n_at 10 e 122 | val loss 2.3863 val acc 9.8823 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 123, bulyan: at our-agr n_at 10 e 123 | val loss 2.4466 val acc 10.1461 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 124, bulyan: at our-agr n_at 10 e 124 | val loss 3.2237 val acc 9.8011 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 125, bulyan: at our-agr n_at 10 e 125 | val loss 3.0073 val acc 10.1461 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 126, bulyan: at our-agr n_at 10 e 126 | val loss 2.9973 val acc 10.1867 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 127, bulyan: at our-agr n_at 10 e 127 | val loss 2.5781 val acc 10.3084 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 128, bulyan: at our-agr n_at 10 e 128 | val loss 2.3940 val acc 9.8011 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 129, bulyan: at our-agr n_at 10 e 129 | val loss 2.3985 val acc 10.1461 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 130, bulyan: at our-agr n_at 10 e 130 | val loss 2.6647 val acc 9.8011 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 131, bulyan: at our-agr n_at 10 e 131 | val loss 2.6149 val acc 10.1461 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 132, bulyan: at our-agr n_at 10 e 132 | val loss 2.7588 val acc 9.8011 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 133, bulyan: at our-agr n_at 10 e 133 | val loss 2.4830 val acc 10.3084 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 134, bulyan: at our-agr n_at 10 e 134 | val loss 2.3815 val acc 9.9026 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 135, bulyan: at our-agr n_at 10 e 135 | val loss 2.3407 val acc 10.3084 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 136, bulyan: at our-agr n_at 10 e 136 | val loss 2.4014 val acc 9.8011 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 137, bulyan: at our-agr n_at 10 e 137 | val loss 2.3904 val acc 10.1461 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 138, bulyan: at our-agr n_at 10 e 138 | val loss 2.4907 val acc 9.8011 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 139, bulyan: at our-agr n_at 10 e 139 | val loss 2.3952 val acc 10.3084 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 140, bulyan: at our-agr n_at 10 e 140 | val loss 2.4223 val acc 9.8011 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 141, bulyan: at our-agr n_at 10 e 141 | val loss 2.3689 val acc 14.1031 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 142, bulyan: at our-agr n_at 10 e 142 | val loss 2.3994 val acc 9.8011 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 143, bulyan: at our-agr n_at 10 e 143 | val loss 2.3481 val acc 11.3839 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 144, bulyan: at our-agr n_at 10 e 144 | val loss 2.3757 val acc 9.8011 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 145, bulyan: at our-agr n_at 10 e 145 | val loss 2.3265 val acc 13.5146 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 146, bulyan: at our-agr n_at 10 e 146 | val loss 2.3434 val acc 9.8011 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 0, 1, 2]
# epoch: 147, bulyan: at our-agr n_at 10 e 147 | val loss 2.3153 val acc 15.6453 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 148, bulyan: at our-agr n_at 10 e 148 | val loss 2.3475 val acc 9.8011 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 149, bulyan: at our-agr n_at 10 e 149 | val loss 2.3320 val acc 15.7670 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 150, bulyan: at our-agr n_at 10 e 150 | val loss 2.3759 val acc 9.8011 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 151, bulyan: at our-agr n_at 10 e 151 | val loss 2.3230 val acc 15.9903 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 152, bulyan: at our-agr n_at 10 e 152 | val loss 2.3451 val acc 9.8011 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 153, bulyan: at our-agr n_at 10 e 153 | val loss 2.3186 val acc 15.7062 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 154, bulyan: at our-agr n_at 10 e 154 | val loss 2.3599 val acc 9.8011 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 155, bulyan: at our-agr n_at 10 e 155 | val loss 2.3047 val acc 16.3555 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 156, bulyan: at our-agr n_at 10 e 156 | val loss 2.3401 val acc 9.8011 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 157, bulyan: at our-agr n_at 10 e 157 | val loss 2.3001 val acc 15.4424 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 158, bulyan: at our-agr n_at 10 e 158 | val loss 2.3773 val acc 15.9497 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 0, 1, 2]
# epoch: 159, bulyan: at our-agr n_at 10 e 159 | val loss 2.3533 val acc 16.1932 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 0, 1, 2]
# epoch: 160, bulyan: at our-agr n_at 10 e 160 | val loss 2.5459 val acc 14.0016 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 161, bulyan: at our-agr n_at 10 e 161 | val loss 2.3423 val acc 13.9002 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 162, bulyan: at our-agr n_at 10 e 162 | val loss 2.4825 val acc 16.4976 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 163, bulyan: at our-agr n_at 10 e 163 | val loss 2.3881 val acc 13.4943 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 164, bulyan: at our-agr n_at 10 e 164 | val loss 2.3231 val acc 11.3231 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 165, bulyan: at our-agr n_at 10 e 165 | val loss 2.3174 val acc 17.2281 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 166, bulyan: at our-agr n_at 10 e 166 | val loss 2.5365 val acc 10.7143 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 167, bulyan: at our-agr n_at 10 e 167 | val loss 2.3504 val acc 12.9870 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 168, bulyan: at our-agr n_at 10 e 168 | val loss 2.3010 val acc 15.9091 best val_acc 18.364448
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 169, bulyan: at our-agr n_at 10 e 169 | val loss 2.2644 val acc 18.6080 best val_acc 18.607955
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 170, bulyan: at our-agr n_at 10 e 170 | val loss 2.3935 val acc 16.6599 best val_acc 18.607955
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 171, bulyan: at our-agr n_at 10 e 171 | val loss 2.2653 val acc 16.6193 best val_acc 18.607955
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 172, bulyan: at our-agr n_at 10 e 172 | val loss 2.2743 val acc 16.4367 best val_acc 18.607955
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 173, bulyan: at our-agr n_at 10 e 173 | val loss 2.2645 val acc 18.7703 best val_acc 18.770292
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 174, bulyan: at our-agr n_at 10 e 174 | val loss 2.5441 val acc 14.5901 best val_acc 18.770292
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 175, bulyan: at our-agr n_at 10 e 175 | val loss 2.3036 val acc 16.6802 best val_acc 18.770292
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 176, bulyan: at our-agr n_at 10 e 176 | val loss 2.1693 val acc 17.1875 best val_acc 18.770292
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 177, bulyan: at our-agr n_at 10 e 177 | val loss 2.1534 val acc 18.9529 best val_acc 18.952922
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 178, bulyan: at our-agr n_at 10 e 178 | val loss 2.4064 val acc 17.2078 best val_acc 18.952922
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 179, bulyan: at our-agr n_at 10 e 179 | val loss 2.3067 val acc 17.8369 best val_acc 18.952922
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 180, bulyan: at our-agr n_at 10 e 180 | val loss 2.3073 val acc 15.4830 best val_acc 18.952922
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 181, bulyan: at our-agr n_at 10 e 181 | val loss 2.3265 val acc 18.4862 best val_acc 18.952922
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 182, bulyan: at our-agr n_at 10 e 182 | val loss 2.7055 val acc 15.1583 best val_acc 18.952922
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 183, bulyan: at our-agr n_at 10 e 183 | val loss 2.3744 val acc 16.1526 best val_acc 18.952922
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 184, bulyan: at our-agr n_at 10 e 184 | val loss 2.1948 val acc 17.7963 best val_acc 18.952922
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 185, bulyan: at our-agr n_at 10 e 185 | val loss 2.1785 val acc 18.9732 best val_acc 18.973214
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 186, bulyan: at our-agr n_at 10 e 186 | val loss 2.3526 val acc 16.7614 best val_acc 18.973214
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 187, bulyan: at our-agr n_at 10 e 187 | val loss 2.2807 val acc 17.9180 best val_acc 18.973214
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 188, bulyan: at our-agr n_at 10 e 188 | val loss 2.3257 val acc 17.8369 best val_acc 18.973214
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 189, bulyan: at our-agr n_at 10 e 189 | val loss 2.3342 val acc 18.5268 best val_acc 18.973214
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 190, bulyan: at our-agr n_at 10 e 190 | val loss 2.5291 val acc 17.2078 best val_acc 18.973214
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 191, bulyan: at our-agr n_at 10 e 191 | val loss 2.2929 val acc 19.4196 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 192, bulyan: at our-agr n_at 10 e 192 | val loss 2.1664 val acc 18.7297 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 193, bulyan: at our-agr n_at 10 e 193 | val loss 2.2522 val acc 14.6713 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 194, bulyan: at our-agr n_at 10 e 194 | val loss 2.4358 val acc 10.7143 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 195, bulyan: at our-agr n_at 10 e 195 | val loss 2.3154 val acc 13.2508 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 196, bulyan: at our-agr n_at 10 e 196 | val loss 2.2712 val acc 17.0657 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 197, bulyan: at our-agr n_at 10 e 197 | val loss 2.1776 val acc 18.9935 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 198, bulyan: at our-agr n_at 10 e 198 | val loss 2.3602 val acc 16.7614 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 199, bulyan: at our-agr n_at 10 e 199 | val loss 2.3168 val acc 17.4716 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 200, bulyan: at our-agr n_at 10 e 200 | val loss 2.3000 val acc 16.0917 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 201, bulyan: at our-agr n_at 10 e 201 | val loss 2.2983 val acc 18.4862 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 202, bulyan: at our-agr n_at 10 e 202 | val loss 2.6030 val acc 16.6802 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 203, bulyan: at our-agr n_at 10 e 203 | val loss 2.3580 val acc 15.8076 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 204, bulyan: at our-agr n_at 10 e 204 | val loss 2.2660 val acc 16.1729 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 205, bulyan: at our-agr n_at 10 e 205 | val loss 2.2628 val acc 18.4862 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 206, bulyan: at our-agr n_at 10 e 206 | val loss 2.3159 val acc 16.4164 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 207, bulyan: at our-agr n_at 10 e 207 | val loss 2.2887 val acc 18.4050 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 208, bulyan: at our-agr n_at 10 e 208 | val loss 2.5386 val acc 16.8222 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 209, bulyan: at our-agr n_at 10 e 209 | val loss 2.3418 val acc 16.0917 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 210, bulyan: at our-agr n_at 10 e 210 | val loss 2.2003 val acc 14.6916 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 211, bulyan: at our-agr n_at 10 e 211 | val loss 2.2433 val acc 19.1356 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 212, bulyan: at our-agr n_at 10 e 212 | val loss 2.4393 val acc 16.7817 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 213, bulyan: at our-agr n_at 10 e 213 | val loss 2.3067 val acc 17.3498 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 214, bulyan: at our-agr n_at 10 e 214 | val loss 2.3656 val acc 15.9903 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 215, bulyan: at our-agr n_at 10 e 215 | val loss 2.4052 val acc 15.0974 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 216, bulyan: at our-agr n_at 10 e 216 | val loss 2.2541 val acc 12.1347 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 217, bulyan: at our-agr n_at 10 e 217 | val loss 2.2027 val acc 17.2890 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 218, bulyan: at our-agr n_at 10 e 218 | val loss 2.2119 val acc 16.8019 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 219, bulyan: at our-agr n_at 10 e 219 | val loss 2.4974 val acc 16.2135 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 220, bulyan: at our-agr n_at 10 e 220 | val loss 2.5119 val acc 14.6104 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 221, bulyan: at our-agr n_at 10 e 221 | val loss 2.3948 val acc 15.4627 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 222, bulyan: at our-agr n_at 10 e 222 | val loss 2.1500 val acc 16.0106 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 223, bulyan: at our-agr n_at 10 e 223 | val loss 2.1837 val acc 17.5325 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 224, bulyan: at our-agr n_at 10 e 224 | val loss 2.1512 val acc 17.2281 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 21]
# epoch: 225, bulyan: at our-agr n_at 10 e 225 | val loss 2.4170 val acc 17.6542 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 226, bulyan: at our-agr n_at 10 e 226 | val loss 2.3105 val acc 16.0917 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 227, bulyan: at our-agr n_at 10 e 227 | val loss 2.2332 val acc 18.4659 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 228, bulyan: at our-agr n_at 10 e 228 | val loss 2.2439 val acc 16.4164 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 229, bulyan: at our-agr n_at 10 e 229 | val loss 2.8664 val acc 17.3093 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 230, bulyan: at our-agr n_at 10 e 230 | val loss 2.5066 val acc 16.5584 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 231, bulyan: at our-agr n_at 10 e 231 | val loss 2.4107 val acc 15.6453 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 232, bulyan: at our-agr n_at 10 e 232 | val loss 2.4021 val acc 18.7094 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 233, bulyan: at our-agr n_at 10 e 233 | val loss 2.4798 val acc 16.5584 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 234, bulyan: at our-agr n_at 10 e 234 | val loss 2.4048 val acc 16.4164 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 235, bulyan: at our-agr n_at 10 e 235 | val loss 2.3831 val acc 16.7411 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 236, bulyan: at our-agr n_at 10 e 236 | val loss 2.2692 val acc 18.4862 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 237, bulyan: at our-agr n_at 10 e 237 | val loss 2.4648 val acc 17.3498 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 238, bulyan: at our-agr n_at 10 e 238 | val loss 2.3792 val acc 17.6339 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 239, bulyan: at our-agr n_at 10 e 239 | val loss 2.4061 val acc 16.7817 best val_acc 19.419643
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 240, bulyan: at our-agr n_at 10 e 240 | val loss 2.3611 val acc 19.6023 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 241, bulyan: at our-agr n_at 10 e 241 | val loss 2.4860 val acc 18.1412 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 242, bulyan: at our-agr n_at 10 e 242 | val loss 2.3085 val acc 17.1469 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 243, bulyan: at our-agr n_at 10 e 243 | val loss 2.3644 val acc 17.9789 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 244, bulyan: at our-agr n_at 10 e 244 | val loss 2.3880 val acc 18.0398 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 245, bulyan: at our-agr n_at 10 e 245 | val loss 2.6193 val acc 18.2021 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 246, bulyan: at our-agr n_at 10 e 246 | val loss 2.3365 val acc 17.2078 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 247, bulyan: at our-agr n_at 10 e 247 | val loss 2.1385 val acc 17.5122 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 248, bulyan: at our-agr n_at 10 e 248 | val loss 2.1688 val acc 18.3847 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 249, bulyan: at our-agr n_at 10 e 249 | val loss 2.6578 val acc 17.6136 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 250, bulyan: at our-agr n_at 10 e 250 | val loss 2.4863 val acc 17.3093 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 251, bulyan: at our-agr n_at 10 e 251 | val loss 2.3475 val acc 12.8247 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 252, bulyan: at our-agr n_at 10 e 252 | val loss 2.5772 val acc 11.1607 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 253, bulyan: at our-agr n_at 10 e 253 | val loss 2.5198 val acc 15.0974 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 254, bulyan: at our-agr n_at 10 e 254 | val loss 2.2530 val acc 13.5146 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 255, bulyan: at our-agr n_at 10 e 255 | val loss 2.1414 val acc 17.0657 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 256, bulyan: at our-agr n_at 10 e 256 | val loss 2.1701 val acc 14.2654 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 257, bulyan: at our-agr n_at 10 e 257 | val loss 2.1838 val acc 19.0747 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 258, bulyan: at our-agr n_at 10 e 258 | val loss 2.3725 val acc 12.1956 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 259, bulyan: at our-agr n_at 10 e 259 | val loss 2.3776 val acc 17.7151 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 260, bulyan: at our-agr n_at 10 e 260 | val loss 2.2042 val acc 15.5844 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 261, bulyan: at our-agr n_at 10 e 261 | val loss 2.2459 val acc 19.1153 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 262, bulyan: at our-agr n_at 10 e 262 | val loss 2.6821 val acc 15.4830 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 263, bulyan: at our-agr n_at 10 e 263 | val loss 2.5398 val acc 13.7175 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 264, bulyan: at our-agr n_at 10 e 264 | val loss 2.3756 val acc 16.5381 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 265, bulyan: at our-agr n_at 10 e 265 | val loss 2.2669 val acc 18.9732 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 266, bulyan: at our-agr n_at 10 e 266 | val loss 2.4283 val acc 18.9529 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 267, bulyan: at our-agr n_at 10 e 267 | val loss 2.3067 val acc 17.5122 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 268, bulyan: at our-agr n_at 10 e 268 | val loss 2.2400 val acc 17.5731 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 269, bulyan: at our-agr n_at 10 e 269 | val loss 2.4042 val acc 18.6282 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 270, bulyan: at our-agr n_at 10 e 270 | val loss 3.0641 val acc 18.3644 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 271, bulyan: at our-agr n_at 10 e 271 | val loss 2.7292 val acc 17.5122 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 272, bulyan: at our-agr n_at 10 e 272 | val loss 2.3202 val acc 19.0950 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 273, bulyan: at our-agr n_at 10 e 273 | val loss 2.2435 val acc 17.6948 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 274, bulyan: at our-agr n_at 10 e 274 | val loss 2.5696 val acc 17.3093 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 275, bulyan: at our-agr n_at 10 e 275 | val loss 2.4430 val acc 14.6713 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 276, bulyan: at our-agr n_at 10 e 276 | val loss 2.4455 val acc 17.8774 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 277, bulyan: at our-agr n_at 10 e 277 | val loss 2.1934 val acc 17.4919 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 278, bulyan: at our-agr n_at 10 e 278 | val loss 2.7433 val acc 17.1875 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 279, bulyan: at our-agr n_at 10 e 279 | val loss 2.5771 val acc 15.5641 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 280, bulyan: at our-agr n_at 10 e 280 | val loss 2.4902 val acc 16.6599 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 281, bulyan: at our-agr n_at 10 e 281 | val loss 2.3691 val acc 18.0195 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 282, bulyan: at our-agr n_at 10 e 282 | val loss 2.5052 val acc 15.3815 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 283, bulyan: at our-agr n_at 10 e 283 | val loss 2.2747 val acc 17.9992 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 284, bulyan: at our-agr n_at 10 e 284 | val loss 2.3190 val acc 17.6948 best val_acc 19.602273
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 285, bulyan: at our-agr n_at 10 e 285 | val loss 2.4847 val acc 19.7849 best val_acc 19.784903
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 286, bulyan: at our-agr n_at 10 e 286 | val loss 2.7207 val acc 14.9148 best val_acc 19.784903
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 287, bulyan: at our-agr n_at 10 e 287 | val loss 2.2896 val acc 19.5211 best val_acc 19.784903
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 288, bulyan: at our-agr n_at 10 e 288 | val loss 2.3632 val acc 19.6834 best val_acc 19.784903
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 289, bulyan: at our-agr n_at 10 e 289 | val loss 2.4570 val acc 19.2979 best val_acc 19.784903
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 290, bulyan: at our-agr n_at 10 e 290 | val loss 2.7389 val acc 16.1932 best val_acc 19.784903
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 291, bulyan: at our-agr n_at 10 e 291 | val loss 2.4682 val acc 17.7760 best val_acc 19.784903
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 292, bulyan: at our-agr n_at 10 e 292 | val loss 2.5332 val acc 17.9789 best val_acc 19.784903
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 293, bulyan: at our-agr n_at 10 e 293 | val loss 2.6536 val acc 16.7208 best val_acc 19.784903
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 294, bulyan: at our-agr n_at 10 e 294 | val loss 2.9591 val acc 16.6396 best val_acc 19.784903
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 295, bulyan: at our-agr n_at 10 e 295 | val loss 2.4844 val acc 16.8628 best val_acc 19.784903
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 296, bulyan: at our-agr n_at 10 e 296 | val loss 2.3485 val acc 17.7557 best val_acc 19.784903
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 297, bulyan: at our-agr n_at 10 e 297 | val loss 2.4564 val acc 17.4716 best val_acc 19.784903
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 298, bulyan: at our-agr n_at 10 e 298 | val loss 3.2389 val acc 12.7029 best val_acc 19.784903
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 299, bulyan: at our-agr n_at 10 e 299 | val loss 2.9409 val acc 17.7151 best val_acc 19.784903
# discarded index [20, 47, 45, 31, 35, 18, 27, 17, 11, 44]
# epoch: 300, bulyan: at our-agr n_at 10 e 300 | val loss 2.6743 val acc 15.8076 best val_acc 19.784903

# %%
import matplotlib.pyplot as plt

# Plotting the data
for col in ['loss', 'validation accuracy', 'best validation accuracy']:
    plt.plot(df['epoch'].tolist(), df[col].tolist())
    plt.title(f"{title} {col}")
    plt.show()
