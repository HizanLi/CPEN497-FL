# %% [markdown]
# # The notebook contains
# ### Code for _Bulyan_ aggregation algorithm
# ### Evaluation of our SOTA AGR-tailored attack on Bulyan

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# C:\Users\Hizan\AppData\Local\Temp\ipykernel_29228\912229180.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:90% !important; }</style>

# %%
from __future__ import print_function
import argparse, os, sys, csv, shutil, time, random, operator, pickle, ast, math, json
import numpy as np
import pandas as pd
from torch.optim import Optimizer
import torch.nn.functional as F
import torch
import pickle
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data as data
import torch.multiprocessing as mp

sys.path.insert(0,'./../utils/')
from logger import *
from eval import *
from misc import *

from femnist_normal_train import *
from femnist_util import *
from adam import Adam
from sgd import SGD
import torchvision.transforms as transforms
import torchvision.datasets as datasets

# %% [markdown]
# ## Get the FEMNIST dataset; we use [LEAF framework](https://leaf.cmu.edu/)

# %%
user_tr_data = []
user_tr_labels = []

for i in range(34):
    f = '/mnt/nfs/work1/amir/vshejwalkar/femnist/data/train/all_data_%d_niid_0_keep_0_train_9.json'%i
    with open(f, 'r') as myfile:
        data=myfile.read()
    obj = json.loads(data)
    
    for user in obj['users']:
        user_tr_data.append(obj['user_data'][user]['x'])
        user_tr_labels.append(obj['user_data'][user]['y'])

user_te_data = []
user_te_labels = []

for i in range(34):
    f = '/mnt/nfs/work1/amir/vshejwalkar/femnist/data/test/all_data_%d_niid_0_keep_0_test_9.json'%i
    with open(f, 'r') as myfile:
        data=myfile.read()
    obj = json.loads(data)
    
    for user in obj['users']:
        user_te_data.append(obj['user_data'][user]['x'])
        user_te_labels.append(obj['user_data'][user]['y'])

# %%
user_tr_data_tensors=[]
user_tr_label_tensors=[]

for i in range(len(user_tr_data)):
    
    user_tr_data_tensor=torch.from_numpy(np.array(user_tr_data[i])).type(torch.FloatTensor)
    user_tr_label_tensor=torch.from_numpy(np.array(user_tr_labels[i])).type(torch.LongTensor)

    user_tr_data_tensors.append(user_tr_data_tensor)
    user_tr_label_tensors.append(user_tr_label_tensor)
    
    # print('user %d tr len %d'%(i,len(user_tr_data_tensor)))

# %%
te_data = np.concatenate(user_te_data, 0)
te_labels = np.concatenate(user_te_labels)
te_len = len(te_labels)

te_data_tensor = torch.from_numpy(te_data[:(te_len//2)]).type(torch.FloatTensor)
te_label_tensor = torch.from_numpy(te_labels[:(te_len//2)]).type(torch.LongTensor)

val_data_tensor = torch.from_numpy(te_data[(te_len//2):]).type(torch.FloatTensor)
val_label_tensor = torch.from_numpy(te_labels[(te_len//2):]).type(torch.LongTensor)

# %% [markdown]
# ## Code for Multi-krum aggregation algorithm

# %%
def multi_krum(all_updates, n_attackers, multi_k=False):
    candidates = []
    candidate_indices = []
    remaining_updates = all_updates
    all_indices = np.arange(len(all_updates))

    while len(remaining_updates) > 2 * n_attackers + 2:
        distances = []
        for update in remaining_updates:
            distance = torch.norm((remaining_updates - update), dim=1) ** 2
            distances = distance[None, :] if not len(distances) else torch.cat((distances, distance[None, :]), 0)

        distances = torch.sort(distances, dim=1)[0]
        scores = torch.sum(distances[:, :len(remaining_updates) - 2 - n_attackers], dim=1)
        indices = torch.argsort(scores)[:len(remaining_updates) - 2 - n_attackers]

        candidate_indices.append(all_indices[indices[0].cpu().numpy()])
        all_indices = np.delete(all_indices, indices[0].cpu().numpy())
        candidates = remaining_updates[indices[0]][None, :] if not len(candidates) else torch.cat((candidates, remaining_updates[indices[0]][None, :]), 0)
        remaining_updates = torch.cat((remaining_updates[:indices[0]], remaining_updates[indices[0] + 1:]), 0)
        if not multi_k:
            break
    # print(len(remaining_updates))
    aggregate = torch.mean(candidates, dim=0)
    return aggregate, np.array(candidate_indices)

# %% [markdown]
# ## Code for Bulyan aggregation algorithm

# %%
def bulyan(all_updates, n_attackers):
    nusers = all_updates.shape[0]
    bulyan_cluster = []
    candidate_indices = []
    remaining_updates = all_updates
    all_indices = np.arange(len(all_updates))

    while len(bulyan_cluster) < (nusers - 2 * n_attackers):
        torch.cuda.empty_cache()
        distances = []
        for update in remaining_updates:
            distance = []
            for update_ in remaining_updates:
                distance.append(torch.norm((update - update_)) ** 2)
            distance = torch.Tensor(distance).float()
            distances = distance[None, :] if not len(distances) else torch.cat((distances, distance[None, :]), 0)
        # print(distances)

        distances = torch.sort(distances, dim=1)[0]

        scores = torch.sum(distances[:, :len(remaining_updates) - 2 - n_attackers], dim=1)
        indices = torch.argsort(scores)[:len(remaining_updates) - 2 - n_attackers]
        if not len(indices):
            break
        candidate_indices.append(all_indices[indices[0].cpu().numpy()])
        all_indices = np.delete(all_indices, indices[0].cpu().numpy())
        bulyan_cluster = remaining_updates[indices[0]][None, :] if not len(bulyan_cluster) else torch.cat((bulyan_cluster, remaining_updates[indices[0]][None, :]), 0)
        remaining_updates = torch.cat((remaining_updates[:indices[0]], remaining_updates[indices[0] + 1:]), 0)

    # print('dim of bulyan cluster ', bulyan_cluster.shape)

    n, d = bulyan_cluster.shape
    param_med = torch.median(bulyan_cluster, dim=0)[0]
    sort_idx = torch.argsort(torch.abs(bulyan_cluster - param_med), dim=0)
    sorted_params = bulyan_cluster[sort_idx, torch.arange(d)[None, :]]

    return torch.mean(sorted_params[:n - 2 * n_attackers], dim=0), np.array(candidate_indices)

# %% [markdown]
# ## Code for Fang attack on Bulyan
# ### Fang attacks on MKrum and Bulyan are the same

# %%
def our_attack_mkrum(all_updates, model_re, n_attackers,dev_type='unit_vec'):

    if dev_type == 'unit_vec':
        deviation = model_re / torch.norm(model_re)  # unit vector, dir opp to good dir
    elif dev_type == 'sign':
        deviation = torch.sign(model_re)
    elif dev_type == 'std':
        deviation = torch.std(all_updates, 0)
        
    lamda = torch.Tensor([20.0]).cuda() #compute_lambda_our(all_updates, model_re, n_attackers)
    # print(lamda)
    threshold_diff = 1e-5
    lamda_fail = lamda
    lamda_succ = 0

    while torch.abs(lamda_succ - lamda) > threshold_diff:
        mal_update = (model_re - lamda * deviation)
        mal_updates = torch.stack([mal_update] * n_attackers)
        mal_updates = torch.cat((mal_updates, all_updates), 0)

        agg_grads, krum_candidate = multi_krum(mal_updates, n_attackers, multi_k=True)

        if np.sum(krum_candidate < n_attackers) == n_attackers:
            # print('successful lamda is ', lamda)
            lamda_succ = lamda
            lamda = lamda + lamda_fail / 2
        else:
            lamda = lamda - lamda_fail / 2

        lamda_fail = lamda_fail / 2

    mal_update = (model_re - lamda_succ * deviation)

    return mal_update

# %% [markdown]
# ## Our attack

# %%
def our_attack_mean_std(all_updates, n_attacker, criterion, user_tr_data_tensors, user_tr_label_tensors):
    
    all_updates_deviation = all_updates.std(dim=1, keepdim=True) # [50, 1]
    benign_std_avg = all_updates_deviation.mean() # [1, 1]

    all_updates_abs_mean = all_updates.abs().mean(dim=1, keepdim=True)  # [50,1]
    benign_abs_mean_avg = all_updates_abs_mean.mean() # [1, 1]

    result_attacker_grads = [] 
    # print(type(n_attacker))
    attacker_grads = all_updates[:n_attacker]


    for index, attacker_grad in enumerate(attacker_grads):

        attacker_tr_data_tensor = user_tr_data_tensors[index].cuda()
        attacker_tr_label_tensor = user_tr_label_tensors[index].cuda()

        def rosen(X):
            X = X.cuda()
            attacker_abs_mean = X.abs().mean()
            attacker_std = X.abs().std()

        #     # Reshape X into the shape of fed_model.parameters
            fed_model = mnist_conv().cuda()
            optimizer_fed = SGD(fed_model.parameters(), lr=0.5)

            optimizer_fed.zero_grad()
            model_grads=[]
            start_idx = 0
            for i, param in enumerate(fed_model.parameters()):
                param_=X[start_idx:start_idx+len(param.data.view(-1))].reshape(param.data.shape)
                start_idx=start_idx+len(param.data.view(-1))
                param_=param_.cuda()
                model_grads.append(param_)
            optimizer_fed.step(model_grads)

            return -criterion(fed_model(attacker_tr_data_tensor), attacker_tr_label_tensor) + torch.abs(benign_std_avg - attacker_abs_mean) + torch.abs(benign_abs_mean_avg - attacker_std)
        
        from torchmin import minimize

        res = minimize(
            rosen, attacker_grad, 
            method='l-bfgs', 
            options=dict(line_search='strong-wolfe'),
            max_iter=100,
            disp=False
        )
        result_attacker_grads.append(res.grad)
        # if result_attacker_grads is None:
        #     result_attacker_grads = res.grad
        # else:
        #     result_attacker_grads.append(res.grad)
    return torch.stack(result_attacker_grads).cuda()

# %% [markdown]
# ## Shejwallwar attack, 20% attacker

# %%
resume=0
nepochs=500
gamma=.1
fed_lr=0.001

criterion = nn.CrossEntropyLoss()
use_cuda = torch.cuda.is_available()
batch_size = 100
schedule = [2000]

aggregation = 'bulyan'
at_type = 'our-agr'
chkpt = './' + aggregation
epoch_num = 0

at_fractions = [20]

for at_fraction in at_fractions:

    fed_model = mnist_conv().cuda()
    fed_model.apply(weights_init)
    optimizer_fed = Adam(fed_model.parameters(), lr=fed_lr)

    print('==> Initializing global model')
    epoch_num = 0
    best_global_acc=0
    best_global_te_acc=0

    df = pd.DataFrame(columns = ['epoch', 'loss', 'validation accuracy', 'best validation accuracy'])
    while epoch_num <= nepochs:
        user_grads = []
        
        round_users = np.random.choice(3400, 60)
        n_attacker = np.sum(round_users < (34*at_fraction))

        while  n_attacker < 2 or n_attacker > 14:
            round_users = np.random.choice(3400, 60)
            n_attacker = np.sum(round_users < (34*at_fraction))

        benign_user_index = [i for i, x in enumerate(round_users) if x >= (34*at_fraction)]
        print('n_attacker is ', n_attacker)
                
        for i in round_users:

            inputs = user_tr_data_tensors[i]
            targets = user_tr_label_tensors[i]

            inputs, targets = inputs.cuda(), targets.cuda()
            inputs, targets = torch.autograd.Variable(inputs), torch.autograd.Variable(targets)

            outputs = fed_model(inputs)
            loss = criterion(outputs, targets)
            optimizer_fed.zero_grad()
            loss.backward(retain_graph=True)

            param_grad=[]
            for param in fed_model.parameters():
                param_grad=param.grad.data.view(-1) if not len(param_grad) else torch.cat((param_grad,param.grad.view(-1)))

            user_grads=param_grad[None,:] if len(user_grads)==0 else torch.cat((user_grads,param_grad[None,:]),0)    

        malicious_grads = user_grads
        # print("malicious_grads before n_attacker", malicious_grads.shape)

        if n_attacker > 0:
            agg_grads = torch.mean(malicious_grads, 0)
            mal_update = our_attack_mkrum(malicious_grads, agg_grads, n_attacker, dev_type='sign')
            mal_updates = torch.stack([mal_update] * n_attacker)

            # print("mal_updates shape: ", mal_updates.shape)

            indices_tensor = torch.tensor(benign_user_index, dtype=torch.long)
            benign_user_grads = user_grads[indices_tensor]
            malicious_grads = torch.cat((mal_updates, benign_user_grads), 0)    
        
        # print("malicious_grads after n_attacker", malicious_grads.shape)

        if epoch_num == 0: print('malicious grads shape ', malicious_grads.shape)

        if aggregation == 'mean':
            agg_grads=torch.mean(malicious_grads,dim=0)
            
        elif aggregation=='krum' or aggregation=='mkrum':
            multi_k = True if aggregation == 'mkrum' else False
            if epoch_num == 0: print('multi krum is ', multi_k)
            agg_grads, krum_candidate = multi_krum(malicious_grads, n_attacker, multi_k=multi_k)

        elif aggregation == 'bulyan':
            agg_grads, krum_candidate = bulyan(malicious_grads, n_attacker)
            
        start_idx=0

        if epoch_num in schedule:
            for param_group in optimizer_fed.param_groups:
                param_group['lr'] *= gamma
                print('New learnin rate ', param_group['lr'])

        optimizer_fed.zero_grad()

        model_grads=[]

        for i, param in enumerate(fed_model.parameters()):
            param_=agg_grads[start_idx:start_idx+len(param.data.view(-1))].reshape(param.data.shape)
            start_idx=start_idx+len(param.data.view(-1))
            param_=param_.cuda()
            model_grads.append(param_)

        optimizer_fed.step(model_grads)

        val_loss, val_acc = test(val_data_tensor,val_label_tensor,fed_model,criterion,use_cuda)
        te_loss, te_acc = test(te_data_tensor,te_label_tensor, fed_model, criterion, use_cuda)

        is_best = best_global_acc < val_acc

        best_global_acc = max(best_global_acc, val_acc)

        if is_best:
            best_global_te_acc = te_acc


        print('epoch: %d, %s: at %s n_at %d n_mal_sel %d e %d | val loss %.4f val acc %.4f best val_acc %f'%(epoch_num, aggregation, at_type, n_attacker, np.sum(krum_candidate < n_attacker), epoch_num, val_loss, val_acc, best_global_acc))
        new_row = pd.DataFrame([{
            'epoch': epoch_num, 
            'loss': val_loss, 
            'validation accuracy': val_acc, 
            'best validation accuracy': best_global_acc
            }])
        df = pd.concat([df, new_row], ignore_index=True)       
        
        df.to_csv('./attack_femnist.csv', index=False)

        epoch_num+=1
# Out:
# ==> Initializing global model
# n_attacker is  11
# malicious grads shape  torch.Size([60, 848382])
# c:\Users\Hizan\Desktop\CPEN497-FL\CPEN497-499\adam.py:76: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\python_arg_parser.cpp:1630.)
#   exp_avg.mul_(beta1).add_(1 - beta1, grad)
# epoch: 0, bulyan: at our-agr n_at 11 n_mal_sel 8 e 0 | val loss 3.9550 val acc 5.8388 best val_acc 5.838816
# n_attacker is  13
# C:\Users\Hizan\AppData\Local\Temp\ipykernel_29228\2147956894.py:128: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, new_row], ignore_index=True)
# epoch: 1, bulyan: at our-agr n_at 13 n_mal_sel 12 e 1 | val loss 3.7880 val acc 5.8388 best val_acc 5.838816
# n_attacker is  11
# epoch: 2, bulyan: at our-agr n_at 11 n_mal_sel 7 e 2 | val loss 3.7152 val acc 5.8388 best val_acc 5.838816
# n_attacker is  9
# epoch: 3, bulyan: at our-agr n_at 9 n_mal_sel 6 e 3 | val loss 3.7983 val acc 7.0518 best val_acc 7.051809
# n_attacker is  13
# epoch: 4, bulyan: at our-agr n_at 13 n_mal_sel 9 e 4 | val loss 3.8005 val acc 6.3245 best val_acc 7.051809
# n_attacker is  13
# epoch: 5, bulyan: at our-agr n_at 13 n_mal_sel 8 e 5 | val loss 3.7149 val acc 5.4893 best val_acc 7.051809
# n_attacker is  7
# epoch: 6, bulyan: at our-agr n_at 7 n_mal_sel 5 e 6 | val loss 3.6320 val acc 5.4893 best val_acc 7.051809
# n_attacker is  12
# epoch: 7, bulyan: at our-agr n_at 12 n_mal_sel 8 e 7 | val loss 3.6169 val acc 8.6657 best val_acc 8.665707
# n_attacker is  13
# epoch: 8, bulyan: at our-agr n_at 13 n_mal_sel 6 e 8 | val loss 3.6206 val acc 6.1421 best val_acc 8.665707
# n_attacker is  7
# epoch: 9, bulyan: at our-agr n_at 7 n_mal_sel 5 e 9 | val loss 3.6172 val acc 6.8025 best val_acc 8.665707
# n_attacker is  7
# epoch: 10, bulyan: at our-agr n_at 7 n_mal_sel 5 e 10 | val loss 3.6140 val acc 6.7460 best val_acc 8.665707
# n_attacker is  8
# epoch: 11, bulyan: at our-agr n_at 8 n_mal_sel 5 e 11 | val loss 3.6089 val acc 6.7460 best val_acc 8.665707
# n_attacker is  12
# epoch: 12, bulyan: at our-agr n_at 12 n_mal_sel 8 e 12 | val loss 3.6065 val acc 6.7460 best val_acc 8.665707
# n_attacker is  8
# epoch: 13, bulyan: at our-agr n_at 8 n_mal_sel 7 e 13 | val loss 3.6076 val acc 10.4852 best val_acc 10.485197
# n_attacker is  8
# epoch: 14, bulyan: at our-agr n_at 8 n_mal_sel 6 e 14 | val loss 3.6107 val acc 5.8388 best val_acc 10.485197
# n_attacker is  14
# epoch: 15, bulyan: at our-agr n_at 14 n_mal_sel 9 e 15 | val loss 3.6102 val acc 5.8388 best val_acc 10.485197
# n_attacker is  13
# epoch: 16, bulyan: at our-agr n_at 13 n_mal_sel 7 e 16 | val loss 3.6058 val acc 8.4935 best val_acc 10.485197
# n_attacker is  8
# epoch: 17, bulyan: at our-agr n_at 8 n_mal_sel 5 e 17 | val loss 3.6022 val acc 8.8687 best val_acc 10.485197
# n_attacker is  13
# epoch: 18, bulyan: at our-agr n_at 13 n_mal_sel 9 e 18 | val loss 3.5966 val acc 5.8542 best val_acc 10.485197
# n_attacker is  10
# epoch: 19, bulyan: at our-agr n_at 10 n_mal_sel 6 e 19 | val loss 3.5905 val acc 5.8260 best val_acc 10.485197
# n_attacker is  14
# epoch: 20, bulyan: at our-agr n_at 14 n_mal_sel 8 e 20 | val loss 3.5847 val acc 7.8562 best val_acc 10.485197
# n_attacker is  12
# epoch: 21, bulyan: at our-agr n_at 12 n_mal_sel 9 e 21 | val loss 3.5787 val acc 18.8065 best val_acc 18.806538
# n_attacker is  9
# epoch: 22, bulyan: at our-agr n_at 9 n_mal_sel 8 e 22 | val loss 3.5779 val acc 13.1707 best val_acc 18.806538
# n_attacker is  10
# epoch: 23, bulyan: at our-agr n_at 10 n_mal_sel 8 e 23 | val loss 3.5795 val acc 13.2787 best val_acc 18.806538
# n_attacker is  11
# epoch: 24, bulyan: at our-agr n_at 11 n_mal_sel 7 e 24 | val loss 3.5823 val acc 11.3435 best val_acc 18.806538
# n_attacker is  8
# epoch: 25, bulyan: at our-agr n_at 8 n_mal_sel 6 e 25 | val loss 3.5868 val acc 10.2899 best val_acc 18.806538
# n_attacker is  14
# epoch: 26, bulyan: at our-agr n_at 14 n_mal_sel 9 e 26 | val loss 3.5865 val acc 13.2735 best val_acc 18.806538
# n_attacker is  8
# epoch: 27, bulyan: at our-agr n_at 8 n_mal_sel 6 e 27 | val loss 3.5832 val acc 19.8011 best val_acc 19.801090
# n_attacker is  10
# epoch: 28, bulyan: at our-agr n_at 10 n_mal_sel 7 e 28 | val loss 3.5778 val acc 17.4059 best val_acc 19.801090
# n_attacker is  13
# epoch: 29, bulyan: at our-agr n_at 13 n_mal_sel 8 e 29 | val loss 3.5697 val acc 18.4545 best val_acc 19.801090
# n_attacker is  14
# epoch: 30, bulyan: at our-agr n_at 14 n_mal_sel 10 e 30 | val loss 3.5581 val acc 10.7370 best val_acc 19.801090
# n_attacker is  8
# epoch: 31, bulyan: at our-agr n_at 8 n_mal_sel 6 e 31 | val loss 3.5454 val acc 8.3368 best val_acc 19.801090
# n_attacker is  9
# epoch: 32, bulyan: at our-agr n_at 9 n_mal_sel 7 e 32 | val loss 3.5319 val acc 12.0040 best val_acc 19.801090
# n_attacker is  10
# epoch: 33, bulyan: at our-agr n_at 10 n_mal_sel 7 e 33 | val loss 3.5228 val acc 22.6640 best val_acc 22.663960
# n_attacker is  10
# epoch: 34, bulyan: at our-agr n_at 10 n_mal_sel 6 e 34 | val loss 3.5179 val acc 26.7552 best val_acc 26.755243
# n_attacker is  12
# epoch: 35, bulyan: at our-agr n_at 12 n_mal_sel 9 e 35 | val loss 3.5196 val acc 22.1680 best val_acc 26.755243
# n_attacker is  11
# epoch: 36, bulyan: at our-agr n_at 11 n_mal_sel 8 e 36 | val loss 3.5245 val acc 17.9174 best val_acc 26.755243
# n_attacker is  9
# epoch: 37, bulyan: at our-agr n_at 9 n_mal_sel 7 e 37 | val loss 3.5066 val acc 24.4963 best val_acc 26.755243
# n_attacker is  8
# epoch: 38, bulyan: at our-agr n_at 8 n_mal_sel 6 e 38 | val loss 3.4889 val acc 26.0485 best val_acc 26.755243
# n_attacker is  10
# epoch: 39, bulyan: at our-agr n_at 10 n_mal_sel 9 e 39 | val loss 3.4779 val acc 30.1475 best val_acc 30.147512
# n_attacker is  9
# epoch: 40, bulyan: at our-agr n_at 9 n_mal_sel 7 e 40 | val loss 3.4697 val acc 30.3120 best val_acc 30.311986
# n_attacker is  14
# epoch: 41, bulyan: at our-agr n_at 14 n_mal_sel 12 e 41 | val loss 3.4655 val acc 27.4414 best val_acc 30.311986
# n_attacker is  7
# epoch: 42, bulyan: at our-agr n_at 7 n_mal_sel 6 e 42 | val loss 3.4544 val acc 27.0482 best val_acc 30.311986
# n_attacker is  11
# epoch: 43, bulyan: at our-agr n_at 11 n_mal_sel 8 e 43 | val loss 3.4285 val acc 30.0781 best val_acc 30.311986
# n_attacker is  9
# epoch: 44, bulyan: at our-agr n_at 9 n_mal_sel 8 e 44 | val loss 3.4059 val acc 30.6564 best val_acc 30.656353
# n_attacker is  5
# epoch: 45, bulyan: at our-agr n_at 5 n_mal_sel 5 e 45 | val loss 3.3793 val acc 31.5918 best val_acc 31.591797
# n_attacker is  10
# epoch: 46, bulyan: at our-agr n_at 10 n_mal_sel 9 e 46 | val loss 3.3508 val acc 35.6188 best val_acc 35.618832
# n_attacker is  11
# epoch: 47, bulyan: at our-agr n_at 11 n_mal_sel 9 e 47 | val loss 3.3277 val acc 36.1688 best val_acc 36.168791
# n_attacker is  12
# epoch: 48, bulyan: at our-agr n_at 12 n_mal_sel 9 e 48 | val loss 3.3102 val acc 34.9198 best val_acc 36.168791
# n_attacker is  11
# epoch: 49, bulyan: at our-agr n_at 11 n_mal_sel 9 e 49 | val loss 3.2972 val acc 34.6757 best val_acc 36.168791
# n_attacker is  10
# epoch: 50, bulyan: at our-agr n_at 10 n_mal_sel 8 e 50 | val loss 3.2810 val acc 38.3455 best val_acc 38.345498
# n_attacker is  14
# epoch: 51, bulyan: at our-agr n_at 14 n_mal_sel 11 e 51 | val loss 3.2545 val acc 38.2864 best val_acc 38.345498
# n_attacker is  10
# epoch: 52, bulyan: at our-agr n_at 10 n_mal_sel 8 e 52 | val loss 3.2330 val acc 36.8318 best val_acc 38.345498
# n_attacker is  12
# epoch: 53, bulyan: at our-agr n_at 12 n_mal_sel 10 e 53 | val loss 3.2021 val acc 36.8986 best val_acc 38.345498
# n_attacker is  11
# epoch: 54, bulyan: at our-agr n_at 11 n_mal_sel 9 e 54 | val loss 3.1731 val acc 37.5000 best val_acc 38.345498
# n_attacker is  8
# epoch: 55, bulyan: at our-agr n_at 8 n_mal_sel 7 e 55 | val loss 3.1332 val acc 40.5479 best val_acc 40.547903
# n_attacker is  9
# epoch: 56, bulyan: at our-agr n_at 9 n_mal_sel 7 e 56 | val loss 3.1236 val acc 37.5000 best val_acc 40.547903
# n_attacker is  13
# epoch: 57, bulyan: at our-agr n_at 13 n_mal_sel 11 e 57 | val loss 3.0773 val acc 38.9597 best val_acc 40.547903
# n_attacker is  11
# epoch: 58, bulyan: at our-agr n_at 11 n_mal_sel 10 e 58 | val loss 3.0438 val acc 40.5993 best val_acc 40.599301
# n_attacker is  11
# epoch: 59, bulyan: at our-agr n_at 11 n_mal_sel 9 e 59 | val loss 3.0068 val acc 40.5248 best val_acc 40.599301
# n_attacker is  11
# epoch: 60, bulyan: at our-agr n_at 11 n_mal_sel 10 e 60 | val loss 2.9772 val acc 39.4274 best val_acc 40.599301
# n_attacker is  9
# epoch: 61, bulyan: at our-agr n_at 9 n_mal_sel 7 e 61 | val loss 2.9506 val acc 42.0564 best val_acc 42.056435
# n_attacker is  13
# epoch: 62, bulyan: at our-agr n_at 13 n_mal_sel 11 e 62 | val loss 2.9423 val acc 40.6738 best val_acc 42.056435
# n_attacker is  9
# epoch: 63, bulyan: at our-agr n_at 9 n_mal_sel 8 e 63 | val loss 2.9077 val acc 39.1139 best val_acc 42.056435
# n_attacker is  10
# epoch: 64, bulyan: at our-agr n_at 10 n_mal_sel 9 e 64 | val loss 2.8847 val acc 39.3889 best val_acc 42.056435
# n_attacker is  9
# epoch: 65, bulyan: at our-agr n_at 9 n_mal_sel 8 e 65 | val loss 2.8445 val acc 42.6758 best val_acc 42.675781
# n_attacker is  12
# epoch: 66, bulyan: at our-agr n_at 12 n_mal_sel 11 e 66 | val loss 2.8245 val acc 41.7018 best val_acc 42.675781
# n_attacker is  13
# epoch: 67, bulyan: at our-agr n_at 13 n_mal_sel 11 e 67 | val loss 2.8250 val acc 40.6301 best val_acc 42.675781
# n_attacker is  13
# epoch: 68, bulyan: at our-agr n_at 13 n_mal_sel 11 e 68 | val loss 2.8008 val acc 38.2607 best val_acc 42.675781
# n_attacker is  7
# epoch: 69, bulyan: at our-agr n_at 7 n_mal_sel 6 e 69 | val loss 2.7464 val acc 43.0741 best val_acc 43.074116
# n_attacker is  14
# epoch: 109, bulyan: at our-agr n_at 5 n_mal_sel 5 e 109 | val loss 2.2777 val acc 45.9601 best val_acc 45.960115
# n_attacker is  14
# epoch: 110, bulyan: at our-agr n_at 14 n_mal_sel 12 e 110 | val loss 2.2963 val acc 45.6414 best val_acc 45.960115
# n_attacker is  8
# epoch: 111, bulyan: at our-agr n_at 8 n_mal_sel 8 e 111 | val loss 2.2999 val acc 45.7751 best val_acc 45.960115
# n_attacker is  8
# epoch: 112, bulyan: at our-agr n_at 8 n_mal_sel 8 e 112 | val loss 2.2966 val acc 45.8779 best val_acc 45.960115
# n_attacker is  10
# epoch: 113, bulyan: at our-agr n_at 10 n_mal_sel 9 e 113 | val loss 2.2985 val acc 45.2714 best val_acc 45.960115
# n_attacker is  9
# epoch: 114, bulyan: at our-agr n_at 9 n_mal_sel 8 e 114 | val loss 2.2833 val acc 45.6286 best val_acc 45.960115
# n_attacker is  13
# epoch: 115, bulyan: at our-agr n_at 13 n_mal_sel 12 e 115 | val loss 2.3010 val acc 44.6829 best val_acc 45.960115
# n_attacker is  10
# epoch: 116, bulyan: at our-agr n_at 10 n_mal_sel 9 e 116 | val loss 2.2899 val acc 45.8188 best val_acc 45.960115
# n_attacker is  14
# epoch: 117, bulyan: at our-agr n_at 14 n_mal_sel 12 e 117 | val loss 2.3136 val acc 45.7263 best val_acc 45.960115
# n_attacker is  6
# epoch: 118, bulyan: at our-agr n_at 6 n_mal_sel 6 e 118 | val loss 2.2948 val acc 46.1220 best val_acc 46.122019
# n_attacker is  11
# epoch: 119, bulyan: at our-agr n_at 11 n_mal_sel 10 e 119 | val loss 2.2723 val acc 46.3559 best val_acc 46.355880
# n_attacker is  12
# epoch: 120, bulyan: at our-agr n_at 12 n_mal_sel 11 e 120 | val loss 2.2731 val acc 46.2454 best val_acc 46.355880
# n_attacker is  10
# epoch: 121, bulyan: at our-agr n_at 10 n_mal_sel 9 e 121 | val loss 2.2735 val acc 46.3430 best val_acc 46.355880
# n_attacker is  10
# epoch: 122, bulyan: at our-agr n_at 10 n_mal_sel 9 e 122 | val loss 2.2718 val acc 45.9935 best val_acc 46.355880
# n_attacker is  14
# epoch: 123, bulyan: at our-agr n_at 14 n_mal_sel 13 e 123 | val loss 2.3283 val acc 44.2768 best val_acc 46.355880
# n_attacker is  11
# epoch: 124, bulyan: at our-agr n_at 11 n_mal_sel 10 e 124 | val loss 2.3128 val acc 45.7751 best val_acc 46.355880
# n_attacker is  11
# epoch: 125, bulyan: at our-agr n_at 11 n_mal_sel 10 e 125 | val loss 2.2919 val acc 46.2711 best val_acc 46.355880
# n_attacker is  10
# epoch: 126, bulyan: at our-agr n_at 10 n_mal_sel 9 e 126 | val loss 2.2714 val acc 46.5615 best val_acc 46.561472
# n_attacker is  10
# epoch: 127, bulyan: at our-agr n_at 10 n_mal_sel 9 e 127 | val loss 2.2579 val acc 46.5666 best val_acc 46.566612
# n_attacker is  10
# epoch: 128, bulyan: at our-agr n_at 10 n_mal_sel 9 e 128 | val loss 2.2795 val acc 45.9601 best val_acc 46.566612
# n_attacker is  6
# epoch: 284, bulyan: at our-agr n_at 6 n_mal_sel 5 e 284 | val loss 2.1143 val acc 49.8201 best val_acc 49.956312
# n_attacker is  13
# epoch: 285, bulyan: at our-agr n_at 13 n_mal_sel 12 e 285 | val loss 2.1093 val acc 50.1465 best val_acc 50.146484
# n_attacker is  7
# epoch: 286, bulyan: at our-agr n_at 7 n_mal_sel 6 e 286 | val loss 2.1078 val acc 50.2544 best val_acc 50.254420
# n_attacker is  13
# epoch: 287, bulyan: at our-agr n_at 13 n_mal_sel 12 e 287 | val loss 2.1349 val acc 49.5940 best val_acc 50.254420
# n_attacker is  7
# epoch: 288, bulyan: at our-agr n_at 7 n_mal_sel 7 e 288 | val loss 2.1298 val acc 50.4369 best val_acc 50.436883
# n_attacker is  10
# epoch: 289, bulyan: at our-agr n_at 10 n_mal_sel 9 e 289 | val loss 2.0978 val acc 50.9791 best val_acc 50.979132
# n_attacker is  10
# epoch: 290, bulyan: at our-agr n_at 10 n_mal_sel 9 e 290 | val loss 2.1132 val acc 49.6993 best val_acc 50.979132
# n_attacker is  14
# epoch: 291, bulyan: at our-agr n_at 14 n_mal_sel 12 e 291 | val loss 2.0886 val acc 50.1542 best val_acc 50.979132
# n_attacker is  8
# epoch: 292, bulyan: at our-agr n_at 8 n_mal_sel 7 e 292 | val loss 2.0792 val acc 50.1850 best val_acc 50.979132
# n_attacker is  14
# epoch: 293, bulyan: at our-agr n_at 14 n_mal_sel 12 e 293 | val loss 2.0880 val acc 50.2030 best val_acc 50.979132
# n_attacker is  10
# epoch: 294, bulyan: at our-agr n_at 10 n_mal_sel 10 e 294 | val loss 2.0864 val acc 50.6091 best val_acc 50.979132
# n_attacker is  11
# epoch: 295, bulyan: at our-agr n_at 11 n_mal_sel 10 e 295 | val loss 2.0765 val acc 51.1230 best val_acc 51.123047
# n_attacker is  10
# epoch: 296, bulyan: at our-agr n_at 10 n_mal_sel 9 e 296 | val loss 2.0772 val acc 51.3106 best val_acc 51.310650
# n_attacker is  14
# epoch: 297, bulyan: at our-agr n_at 14 n_mal_sel 12 e 297 | val loss 2.1046 val acc 50.8224 best val_acc 51.310650
# n_attacker is  12
# epoch: 298, bulyan: at our-agr n_at 12 n_mal_sel 11 e 298 | val loss 2.1139 val acc 50.6502 best val_acc 51.310650
# n_attacker is  10
# epoch: 299, bulyan: at our-agr n_at 10 n_mal_sel 9 e 299 | val loss 2.0914 val acc 50.5243 best val_acc 51.310650
# n_attacker is  12
# epoch: 300, bulyan: at our-agr n_at 12 n_mal_sel 11 e 300 | val loss 2.0751 val acc 49.9820 best val_acc 51.310650
# n_attacker is  11
# epoch: 301, bulyan: at our-agr n_at 11 n_mal_sel 10 e 301 | val loss 2.0718 val acc 49.8664 best val_acc 51.310650
# n_attacker is  11
# epoch: 302, bulyan: at our-agr n_at 11 n_mal_sel 10 e 302 | val loss 2.0639 val acc 50.2005 best val_acc 51.310650
# n_attacker is  14
# epoch: 303, bulyan: at our-agr n_at 14 n_mal_sel 13 e 303 | val loss 2.0673 val acc 50.4420 best val_acc 51.310650
# n_attacker is  13
# epoch: 304, bulyan: at our-agr n_at 13 n_mal_sel 11 e 304 | val loss 2.0760 val acc 50.7761 best val_acc 51.310650
# n_attacker is  13
# epoch: 305, bulyan: at our-agr n_at 13 n_mal_sel 12 e 305 | val loss 2.0831 val acc 50.8404 best val_acc 51.310650
# n_attacker is  14
# epoch: 306, bulyan: at our-agr n_at 14 n_mal_sel 13 e 306 | val loss 2.0740 val acc 50.5500 best val_acc 51.310650
# n_attacker is  13
# epoch: 307, bulyan: at our-agr n_at 13 n_mal_sel 12 e 307 | val loss 2.0913 val acc 50.1850 best val_acc 51.310650
# n_attacker is  11
# epoch: 308, bulyan: at our-agr n_at 11 n_mal_sel 10 e 308 | val loss 2.1010 val acc 50.1311 best val_acc 51.310650
# n_attacker is  8
# epoch: 309, bulyan: at our-agr n_at 8 n_mal_sel 7 e 309 | val loss 2.0964 val acc 50.1259 best val_acc 51.310650
# n_attacker is  12
# epoch: 310, bulyan: at our-agr n_at 12 n_mal_sel 12 e 310 | val loss 2.0872 val acc 49.9872 best val_acc 51.310650
# n_attacker is  8
# epoch: 311, bulyan: at our-agr n_at 8 n_mal_sel 8 e 311 | val loss 2.0924 val acc 50.2981 best val_acc 51.310650
# n_attacker is  4
# epoch: 312, bulyan: at our-agr n_at 4 n_mal_sel 3 e 312 | val loss 2.0726 val acc 50.7376 best val_acc 51.310650
# n_attacker is  11
# epoch: 313, bulyan: at our-agr n_at 11 n_mal_sel 10 e 313 | val loss 2.0901 val acc 50.1516 best val_acc 51.310650
# n_attacker is  10
# epoch: 314, bulyan: at our-agr n_at 10 n_mal_sel 9 e 314 | val loss 2.0881 val acc 50.0925 best val_acc 51.310650
# n_attacker is  11
# epoch: 315, bulyan: at our-agr n_at 11 n_mal_sel 9 e 315 | val loss 2.0716 val acc 50.1645 best val_acc 51.310650
# n_attacker is  8
# epoch: 316, bulyan: at our-agr n_at 8 n_mal_sel 7 e 316 | val loss 2.0505 val acc 50.3803 best val_acc 51.310650
# n_attacker is  10
# epoch: 317, bulyan: at our-agr n_at 10 n_mal_sel 10 e 317 | val loss 2.0522 val acc 50.4831 best val_acc 51.310650
# n_attacker is  13
# epoch: 318, bulyan: at our-agr n_at 13 n_mal_sel 12 e 318 | val loss 2.0678 val acc 50.4574 best val_acc 51.310650
# n_attacker is  8
# epoch: 319, bulyan: at our-agr n_at 8 n_mal_sel 8 e 319 | val loss 2.0786 val acc 50.5063 best val_acc 51.310650
# n_attacker is  10
# epoch: 320, bulyan: at our-agr n_at 10 n_mal_sel 9 e 320 | val loss 2.0872 val acc 50.2107 best val_acc 51.310650
# n_attacker is  12
# epoch: 321, bulyan: at our-agr n_at 12 n_mal_sel 11 e 321 | val loss 2.0792 val acc 50.7119 best val_acc 51.310650
# n_attacker is  6
# epoch: 322, bulyan: at our-agr n_at 6 n_mal_sel 5 e 322 | val loss 2.0676 val acc 50.7504 best val_acc 51.310650
# n_attacker is  7
# epoch: 323, bulyan: at our-agr n_at 7 n_mal_sel 6 e 323 | val loss 2.0593 val acc 50.5345 best val_acc 51.310650
# n_attacker is  13
# epoch: 324, bulyan: at our-agr n_at 13 n_mal_sel 12 e 324 | val loss 2.0622 val acc 50.4754 best val_acc 51.310650
# n_attacker is  7
# epoch: 325, bulyan: at our-agr n_at 7 n_mal_sel 6 e 325 | val loss 2.0542 val acc 50.5834 best val_acc 51.310650
# n_attacker is  13
# epoch: 326, bulyan: at our-agr n_at 13 n_mal_sel 12 e 326 | val loss 2.0476 val acc 51.0871 best val_acc 51.310650
# n_attacker is  13
# epoch: 327, bulyan: at our-agr n_at 13 n_mal_sel 11 e 327 | val loss 2.0490 val acc 51.3775 best val_acc 51.377467
# n_attacker is  10
# epoch: 328, bulyan: at our-agr n_at 10 n_mal_sel 9 e 328 | val loss 2.0533 val acc 51.0254 best val_acc 51.377467
# n_attacker is  12
# epoch: 329, bulyan: at our-agr n_at 12 n_mal_sel 11 e 329 | val loss 2.0740 val acc 50.6553 best val_acc 51.377467
# n_attacker is  11
# epoch: 330, bulyan: at our-agr n_at 11 n_mal_sel 9 e 330 | val loss 2.0706 val acc 51.2027 best val_acc 51.377467
# n_attacker is  10
# epoch: 331, bulyan: at our-agr n_at 10 n_mal_sel 9 e 331 | val loss 2.0674 val acc 51.7552 best val_acc 51.755243
# n_attacker is  12
# epoch: 332, bulyan: at our-agr n_at 12 n_mal_sel 11 e 332 | val loss 2.0480 val acc 52.3001 best val_acc 52.300062
# n_attacker is  8
# epoch: 333, bulyan: at our-agr n_at 8 n_mal_sel 7 e 333 | val loss 2.0277 val acc 52.6804 best val_acc 52.680407
# n_attacker is  14
# epoch: 334, bulyan: at our-agr n_at 14 n_mal_sel 12 e 334 | val loss 2.0260 val acc 52.3309 best val_acc 52.680407
# n_attacker is  11
# epoch: 335, bulyan: at our-agr n_at 11 n_mal_sel 10 e 335 | val loss 2.0275 val acc 52.0765 best val_acc 52.680407
# n_attacker is  14
# epoch: 336, bulyan: at our-agr n_at 14 n_mal_sel 12 e 336 | val loss 2.0161 val acc 52.1279 best val_acc 52.680407
# n_attacker is  13
# epoch: 337, bulyan: at our-agr n_at 13 n_mal_sel 12 e 337 | val loss 2.0359 val acc 51.9506 best val_acc 52.680407
# n_attacker is  14
# epoch: 338, bulyan: at our-agr n_at 14 n_mal_sel 13 e 338 | val loss 2.0375 val acc 52.0045 best val_acc 52.680407
# n_attacker is  9
# epoch: 339, bulyan: at our-agr n_at 9 n_mal_sel 7 e 339 | val loss 2.0198 val acc 51.7630 best val_acc 52.680407
# n_attacker is  14
# epoch: 340, bulyan: at our-agr n_at 14 n_mal_sel 12 e 340 | val loss 2.0487 val acc 50.7453 best val_acc 52.680407
# n_attacker is  7
# epoch: 341, bulyan: at our-agr n_at 7 n_mal_sel 7 e 341 | val loss 2.0459 val acc 50.5628 best val_acc 52.680407
# n_attacker is  12
# %%
import matplotlib.pyplot as plt

# Plotting the data
for col in ['loss', 'validation accuracy', 'best validation accuracy']:
    plt.plot(df['epoch'].tolist(), df[col].tolist())
    plt.title("shejwallwar_has_attack_20%_attacker_"+col)
    plt.savefig('./shejwallwar_attack_femnist_20_percent_attacker' + col + '.png')
    plt.show()

# %% [markdown]
# ## Shejwallwar attack, 2 attacker each round

# %%
resume=0
nepochs=500
gamma=.1
fed_lr=0.001

criterion = nn.CrossEntropyLoss()
use_cuda = torch.cuda.is_available()
batch_size = 100
schedule = [2000]

aggregation = 'bulyan'
at_type = 'our-agr'
chkpt = './' + aggregation
epoch_num = 0

at_fractions = [0]
n_attacker = 0 

for at_fraction in at_fractions:

    fed_model = mnist_conv().cuda()
    fed_model.apply(weights_init)
    optimizer_fed = Adam(fed_model.parameters(), lr=fed_lr)

    print('==> Initializing global model')
    epoch_num = 0
    best_global_acc=0
    best_global_te_acc=0

    df = pd.DataFrame(columns = ['epoch', 'loss', 'validation accuracy', 'best validation accuracy'])

    while epoch_num <= nepochs:
        user_grads = []
        
        round_users = np.random.choice(3400, 60)
        
        for i in round_users:

            inputs = user_tr_data_tensors[i]
            targets = user_tr_label_tensors[i]

            inputs, targets = inputs.cuda(), targets.cuda()
            inputs, targets = torch.autograd.Variable(inputs), torch.autograd.Variable(targets)

            outputs = fed_model(inputs)
            loss = criterion(outputs, targets)
            optimizer_fed.zero_grad()
            loss.backward(retain_graph=True)

            param_grad=[]
            for param in fed_model.parameters():
                param_grad=param.grad.data.view(-1) if not len(param_grad) else torch.cat((param_grad,param.grad.view(-1)))

            user_grads=param_grad[None,:] if len(user_grads)==0 else torch.cat((user_grads,param_grad[None,:]),0)    

        malicious_grads = user_grads

        if epoch_num == 0: print('malicious grads shape ', malicious_grads.shape)

        if aggregation == 'mean':
            agg_grads=torch.mean(malicious_grads,dim=0)
            
        elif aggregation=='krum' or aggregation=='mkrum':
            multi_k = True if aggregation == 'mkrum' else False
            if epoch_num == 0: print('multi krum is ', multi_k)
            agg_grads, krum_candidate = multi_krum(malicious_grads, n_attacker, multi_k=multi_k)

        elif aggregation == 'bulyan':
            agg_grads, krum_candidate = bulyan(malicious_grads, n_attacker)
            
        start_idx=0

        if epoch_num in schedule:
            for param_group in optimizer_fed.param_groups:
                param_group['lr'] *= gamma
                print('New learnin rate ', param_group['lr'])

        optimizer_fed.zero_grad()

        model_grads=[]

        for i, param in enumerate(fed_model.parameters()):
            param_=agg_grads[start_idx:start_idx+len(param.data.view(-1))].reshape(param.data.shape)
            start_idx=start_idx+len(param.data.view(-1))
            param_=param_.cuda()
            model_grads.append(param_)

        optimizer_fed.step(model_grads)

        val_loss, val_acc = test(val_data_tensor,val_label_tensor,fed_model,criterion,use_cuda)
        te_loss, te_acc = test(te_data_tensor,te_label_tensor, fed_model, criterion, use_cuda)

        is_best = best_global_acc < val_acc

        best_global_acc = max(best_global_acc, val_acc)

        if is_best:
            best_global_te_acc = te_acc

        print('epoch: %d, %s: at %s n_at %d n_mal_sel %d e %d | val loss %.4f val acc %.4f best val_acc %f'%(epoch_num, aggregation, at_type, n_attacker, np.sum(krum_candidate < n_attacker), epoch_num, val_loss, val_acc, best_global_acc))
        new_row = pd.DataFrame([{
            'epoch': epoch_num, 
            'loss': val_loss, 
            'validation accuracy': val_acc, 
            'best validation accuracy': best_global_acc
            }])
        df = pd.concat([df, new_row], ignore_index=True)       
        
        df.to_csv('./no_attack_femnist.csv', index=False)
        epoch_num+=1

# %%
import matplotlib.pyplot as plt

# Plotting the data
for col in ['loss', 'validation accuracy', 'best validation accuracy']:
    plt.plot(df['epoch'].tolist(), df[col].tolist())
    plt.title("shejwallwar_has_attack_20%_attacker_"+col)
    plt.savefig('./shejwallwar_attack_femnist_20_percent_attacker' + col + '.png')
    plt.show()

# %% [markdown]
# ## Our attacker 20% attacker

# %%
resume=0
nepochs=500
gamma=.1
fed_lr=0.001

criterion = nn.CrossEntropyLoss()
use_cuda = torch.cuda.is_available()
batch_size = 100
schedule = [2000]

aggregation = 'bulyan'
at_type = 'our-agr'
chkpt = './' + aggregation
epoch_num = 0

at_fractions = [20]

for at_fraction in at_fractions:

    fed_model = mnist_conv().cuda()
    fed_model.apply(weights_init)
    optimizer_fed = Adam(fed_model.parameters(), lr=fed_lr)

    print('==> Initializing global model')
    epoch_num = 0
    best_global_acc=0
    best_global_te_acc=0

    df = pd.DataFrame(columns = ['epoch', 'loss', 'validation accuracy', 'best validation accuracy'])
    while epoch_num <= nepochs:
        user_grads = []
        
        round_users = np.random.choice(3400, 60)
        n_attacker = np.sum(round_users < (34*at_fraction))

        while  n_attacker < 2 or n_attacker > 14:
            round_users = np.random.choice(3400, 60)
            n_attacker = np.sum(round_users < (34*at_fraction))

        benign_user_index = [i for i, x in enumerate(round_users) if x >= (34*at_fraction)]
        print('n_attacker is ', n_attacker)
                
        for i in round_users:

            inputs = user_tr_data_tensors[i]
            targets = user_tr_label_tensors[i]

            inputs, targets = inputs.cuda(), targets.cuda()
            inputs, targets = torch.autograd.Variable(inputs), torch.autograd.Variable(targets)

            outputs = fed_model(inputs)
            loss = criterion(outputs, targets)
            optimizer_fed.zero_grad()
            loss.backward(retain_graph=True)

            param_grad=[]
            for param in fed_model.parameters():
                param_grad=param.grad.data.view(-1) if not len(param_grad) else torch.cat((param_grad,param.grad.view(-1)))

            user_grads=param_grad[None,:] if len(user_grads)==0 else torch.cat((user_grads,param_grad[None,:]),0)    

        malicious_grads = user_grads
        # print("malicious_grads before n_attacker", malicious_grads.shape)

        if n_attacker > 0:

            mal_updates = our_attack_mean_std(user_grads, n_attacker, criterion, user_tr_data_tensors, user_tr_label_tensors)

            indices_tensor = torch.tensor(benign_user_index, dtype=torch.long)
            benign_user_grads = user_grads[indices_tensor]
            malicious_grads = torch.cat((mal_updates, benign_user_grads), 0)    
        
        # print("malicious_grads after n_attacker", malicious_grads.shape)

        if epoch_num == 0: print('malicious grads shape ', malicious_grads.shape)

        if aggregation == 'mean':
            agg_grads=torch.mean(malicious_grads,dim=0)
            
        elif aggregation=='krum' or aggregation=='mkrum':
            multi_k = True if aggregation == 'mkrum' else False
            if epoch_num == 0: print('multi krum is ', multi_k)
            agg_grads, krum_candidate = multi_krum(malicious_grads, n_attacker, multi_k=multi_k)

        elif aggregation == 'bulyan':
            agg_grads, krum_candidate = bulyan(malicious_grads, n_attacker)
            
        start_idx=0

        if epoch_num in schedule:
            for param_group in optimizer_fed.param_groups:
                param_group['lr'] *= gamma
                print('New learnin rate ', param_group['lr'])

        optimizer_fed.zero_grad()

        model_grads=[]

        for i, param in enumerate(fed_model.parameters()):
            param_=agg_grads[start_idx:start_idx+len(param.data.view(-1))].reshape(param.data.shape)
            start_idx=start_idx+len(param.data.view(-1))
            param_=param_.cuda()
            model_grads.append(param_)

        optimizer_fed.step(model_grads)

        val_loss, val_acc = test(val_data_tensor,val_label_tensor,fed_model,criterion,use_cuda)
        te_loss, te_acc = test(te_data_tensor,te_label_tensor, fed_model, criterion, use_cuda)

        is_best = best_global_acc < val_acc

        best_global_acc = max(best_global_acc, val_acc)

        if is_best:
            best_global_te_acc = te_acc


        print('epoch: %d, %s: at %s n_at %d n_mal_sel %d e %d | val loss %.4f val acc %.4f best val_acc %f'%(epoch_num, aggregation, at_type, n_attacker, np.sum(krum_candidate < n_attacker), epoch_num, val_loss, val_acc, best_global_acc))
        new_row = pd.DataFrame([{
            'epoch': epoch_num, 
            'loss': val_loss, 
            'validation accuracy': val_acc, 
            'best validation accuracy': best_global_acc
            }])
        df = pd.concat([df, new_row], ignore_index=True)       
        
        df.to_csv('./attack_femnist.csv', index=False)

        epoch_num+=1

# %%
import matplotlib.pyplot as plt

# Plotting the data
for col in ['loss', 'validation accuracy', 'best validation accuracy']:
    plt.plot(df['epoch'].tolist(), df[col].tolist())
    plt.title("has_attack_20%_attacker_"+col)
    plt.savefig('./attack_femnist_20_percent_attacker' + col + '.png')
    plt.show()

# %% [markdown]
# ## Our attack, 2 attacker each round

# %%
resume=0
nepochs=500
gamma=.1
fed_lr=0.001

criterion = nn.CrossEntropyLoss()
use_cuda = torch.cuda.is_available()
batch_size = 100
schedule = [2000]

aggregation = 'bulyan'
at_type = 'our-agr'
chkpt = './' + aggregation
epoch_num = 0

at_fractions = [0]
n_attacker = 0 

for at_fraction in at_fractions:

    fed_model = mnist_conv().cuda()
    fed_model.apply(weights_init)
    optimizer_fed = Adam(fed_model.parameters(), lr=fed_lr)

    print('==> Initializing global model')
    epoch_num = 0
    best_global_acc=0
    best_global_te_acc=0

    df = pd.DataFrame(columns = ['epoch', 'loss', 'validation accuracy', 'best validation accuracy'])

    while epoch_num <= nepochs:
        user_grads = []
        
        round_users = np.random.choice(3400, 60)
        
        for i in round_users:

            inputs = user_tr_data_tensors[i]
            targets = user_tr_label_tensors[i]

            inputs, targets = inputs.cuda(), targets.cuda()
            inputs, targets = torch.autograd.Variable(inputs), torch.autograd.Variable(targets)

            outputs = fed_model(inputs)
            loss = criterion(outputs, targets)
            optimizer_fed.zero_grad()
            loss.backward(retain_graph=True)

            param_grad=[]
            for param in fed_model.parameters():
                param_grad=param.grad.data.view(-1) if not len(param_grad) else torch.cat((param_grad,param.grad.view(-1)))

            user_grads=param_grad[None,:] if len(user_grads)==0 else torch.cat((user_grads,param_grad[None,:]),0)    

        malicious_grads = user_grads

        if epoch_num == 0: print('malicious grads shape ', malicious_grads.shape)

        if aggregation == 'mean':
            agg_grads=torch.mean(malicious_grads,dim=0)
            
        elif aggregation=='krum' or aggregation=='mkrum':
            multi_k = True if aggregation == 'mkrum' else False
            if epoch_num == 0: print('multi krum is ', multi_k)
            agg_grads, krum_candidate = multi_krum(malicious_grads, n_attacker, multi_k=multi_k)

        elif aggregation == 'bulyan':
            agg_grads, krum_candidate = bulyan(malicious_grads, n_attacker)
            
        start_idx=0

        if epoch_num in schedule:
            for param_group in optimizer_fed.param_groups:
                param_group['lr'] *= gamma
                print('New learnin rate ', param_group['lr'])

        optimizer_fed.zero_grad()

        model_grads=[]

        for i, param in enumerate(fed_model.parameters()):
            param_=agg_grads[start_idx:start_idx+len(param.data.view(-1))].reshape(param.data.shape)
            start_idx=start_idx+len(param.data.view(-1))
            param_=param_.cuda()
            model_grads.append(param_)

        optimizer_fed.step(model_grads)

        val_loss, val_acc = test(val_data_tensor,val_label_tensor,fed_model,criterion,use_cuda)
        te_loss, te_acc = test(te_data_tensor,te_label_tensor, fed_model, criterion, use_cuda)

        is_best = best_global_acc < val_acc

        best_global_acc = max(best_global_acc, val_acc)

        if is_best:
            best_global_te_acc = te_acc

        print('epoch: %d, %s: at %s n_at %d n_mal_sel %d e %d | val loss %.4f val acc %.4f best val_acc %f'%(epoch_num, aggregation, at_type, n_attacker, np.sum(krum_candidate < n_attacker), epoch_num, val_loss, val_acc, best_global_acc))
        new_row = pd.DataFrame([{
            'epoch': epoch_num, 
            'loss': val_loss, 
            'validation accuracy': val_acc, 
            'best validation accuracy': best_global_acc
            }])
        df = pd.concat([df, new_row], ignore_index=True)       
        
        df.to_csv('./no_attack_femnist.csv', index=False)
        epoch_num+=1

# %%
import matplotlib.pyplot as plt

# Plotting the data
for col in ['loss', 'validation accuracy', 'best validation accuracy']:
    plt.plot(df['epoch'].tolist(), df[col].tolist())
    plt.title("has_2_attacker_"+col)
    plt.savefig('./no_attack_FEMNIST_' + col + '.png')
    plt.show()
