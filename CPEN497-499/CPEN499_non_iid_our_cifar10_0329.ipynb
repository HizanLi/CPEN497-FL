# %% [markdown]
# # The notebook contains
# ### Code for _Bulyan_ aggregation algorithm, *when gradient updates of benign clients are unknown to adversary*
# ### Evaluation of all of the attacks (Fang, LIE, and our SOTA AGR-tailored and AGR-agnstic) on Bulyan

# %% [markdown]
# ## Import packages

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
from __future__ import print_function
import argparse, os, sys, csv, shutil, time, random, operator, pickle, ast, math
import numpy as np
import pandas as pd
from torch.optim import Optimizer
import torch.nn.functional as F
import torch
import pickle
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data as data
import torch.multiprocessing as mp
import math
sys.path.insert(0,'./../utils/')
from logger import *
from eval import *
from misc import *

from cifar10_normal_train import *
from cifar10_util import *
from adam import Adam
from sgd import SGD

# %% [markdown]
# ## Data split
# Divide cifar10 data among 50 clients in Non-IID fashion using Dirichlet distribution
#
# Graph the distribution of classes for each user

# %%
import torchvision.transforms as transforms
import torchvision.datasets as datasets
data_loc='/mnt/nfs/work1/amir/vshejwalkar/cifar10_data/'
# load the train dataset

train_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ])

cifar10_train = datasets.CIFAR10(root=data_loc, train=True, download=True, transform=train_transform)

cifar10_test = datasets.CIFAR10(root=data_loc, train=False, download=True, transform=train_transform)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
total_tr_len = len(cifar10_train)

X={}
Y=[]
for i in range(len(cifar10_train)):
    data = cifar10_train[i][0].numpy()
    label = cifar10_train[i][1]

    if label in X:
        X[label].append(data)
    else:
        X[label] = []
        X[label].append(data)
        Y.append(label)

for label in X:
    X[label] = np.array(X[label])
Y=np.array(Y)

alpha = 1
n_users = 50

# %%
user_train_data_non_tensors = [[] for _ in range(n_users)]
user_train_label_non_tensors = [[] for _ in range(n_users)]

for label in Y:
    alpha_list = [alpha for _ in range(n_users)]
    probs = np.random.dirichlet(alpha_list)

    taken_index = 0

    for i, prob in enumerate(probs):
        if i == n_users - 1:
            user_train_data_non_tensors[i].extend(X[label][taken_index:])
            user_train_label_non_tensors[i].extend([label for _ in range(len(X[label]) - taken_index)])
        else:
            n_sample = math.floor(prob * len(X[label]))

            user_train_data_non_tensors[i].extend(X[label][taken_index : taken_index + n_sample])
            user_train_label_non_tensors[i].extend([label for _ in range(n_sample)])
            taken_index += n_sample

user_train_data_tensors = []
user_train_label_tensors = []

user_tr_len = []

for i in range(n_users):

    if len(user_train_data_non_tensors[i]) != len(user_train_label_non_tensors[i]):
        sys.exit(f"Shape does not match user_train_data_non_tensors[i] hsa {len(user_train_data_non_tensors[i])}, while user_train_label_non_tensors[i] has {len(user_train_label_non_tensors[i])}")


    num_data = len(user_train_data_non_tensors[i])
    user_tr_len.append(num_data)

    user_train_data_tensors.append(torch.from_numpy(np.array(user_train_data_non_tensors[i])).type(torch.FloatTensor))
    user_train_label_tensors.append(torch.from_numpy(np.array(user_train_label_non_tensors[i])).type(torch.LongTensor))

    r=np.arange(num_data)

    np.random.shuffle(r)

    user_train_data_tensors[i] = user_train_data_tensors[i][r]
    user_train_label_tensors[i] = user_train_label_tensors[i][r]

    print(f'user {i} has {user_train_data_tensors[i].shape[0]} train data, and {user_train_label_tensors[i].shape[0]} train labels')
# Out:
# user 0 has 875 train data, and 875 train labels
# user 1 has 857 train data, and 857 train labels
# user 2 has 829 train data, and 829 train labels
# user 3 has 811 train data, and 811 train labels
# user 4 has 624 train data, and 624 train labels
# user 5 has 1113 train data, and 1113 train labels
# user 6 has 1121 train data, and 1121 train labels
# user 7 has 855 train data, and 855 train labels
# user 8 has 807 train data, and 807 train labels
# user 9 has 1125 train data, and 1125 train labels
# user 10 has 820 train data, and 820 train labels
# user 11 has 1014 train data, and 1014 train labels
# user 12 has 1101 train data, and 1101 train labels
# user 13 has 1108 train data, and 1108 train labels
# user 14 has 651 train data, and 651 train labels
# user 15 has 825 train data, and 825 train labels
# user 16 has 1709 train data, and 1709 train labels
# user 17 has 1176 train data, and 1176 train labels
# user 18 has 869 train data, and 869 train labels
# user 19 has 540 train data, and 540 train labels
# user 20 has 1066 train data, and 1066 train labels
# user 21 has 813 train data, and 813 train labels
# user 22 has 608 train data, and 608 train labels
# user 23 has 987 train data, and 987 train labels
# user 24 has 848 train data, and 848 train labels
# user 25 has 979 train data, and 979 train labels
# user 26 has 596 train data, and 596 train labels
# user 27 has 1244 train data, and 1244 train labels
# user 28 has 1351 train data, and 1351 train labels
# user 29 has 718 train data, and 718 train labels
# user 30 has 929 train data, and 929 train labels
# user 31 has 1058 train data, and 1058 train labels
# user 32 has 1403 train data, and 1403 train labels
# user 33 has 1289 train data, and 1289 train labels
# user 34 has 725 train data, and 725 train labels
# user 35 has 1084 train data, and 1084 train labels
# user 36 has 789 train data, and 789 train labels
# user 37 has 1330 train data, and 1330 train labels
# user 38 has 942 train data, and 942 train labels
# user 39 has 1144 train data, and 1144 train labels
# user 40 has 872 train data, and 872 train labels
# user 41 has 1603 train data, and 1603 train labels
# user 42 has 1398 train data, and 1398 train labels
# user 43 has 771 train data, and 771 train labels
# user 44 has 1083 train data, and 1083 train labels
# user 45 has 1206 train data, and 1206 train labels
# user 46 has 849 train data, and 849 train labels
# user 47 has 1094 train data, and 1094 train labels
# user 48 has 649 train data, and 649 train labels
# user 49 has 1742 train data, and 1742 train labels

# %%
X2 = []
Y2 = []

for i in range(len(cifar10_test)):
    X2.append(cifar10_test[i][0].numpy())
    Y2.append(cifar10_test[i][1])

X2=np.array(X2)
Y2=np.array(Y2)

half_index = len(X2) // 2

val_data= X2[:half_index]
val_label= Y2[:half_index]

te_data=X2[half_index:]
te_label=Y2[half_index:]

val_data_tensor=torch.from_numpy(val_data).type(torch.FloatTensor)
val_label_tensor=torch.from_numpy(val_label).type(torch.LongTensor)

te_data_tensor=torch.from_numpy(te_data).type(torch.FloatTensor)
te_label_tensor=torch.from_numpy(te_label).type(torch.LongTensor)

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# Example data
users = [f"user {i}" for i in range(50)]
labels = [f"label {i}" for i in range(10)]


percentages = []
for user_data in user_train_label_non_tensors:
    temp_holder = []
    for label in range(10):
        temp_holder.append(user_data.count(label))
    percentages.append(temp_holder)

percentages = np.array(percentages)

# Assuming 'percentages' is populated correctly as shown previously
# Convert percentages to cumulative sum for stacking
cumulative = np.cumsum(percentages, axis=1)

# Plot
fig, ax = plt.subplots(figsize=(10, 6))

# Colors for each ethnicity, ensuring there are enough colors for all labels
colors = plt.cm.Paired(range(len(labels))) # Repeating colors to match the number of labels

# Create stacked bars
for i in range(len(labels)):  # Iterate over the number of labels
    if i == 0:
        ax.bar(users, percentages[:, i], color=colors[i], label=labels[i])
    else:
        ax.bar(users, percentages[:, i], bottom=cumulative[:, i-1], color=colors[i], label=labels[i])

# Add some text for labels, title, and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage')
ax.set_title('Stacked Percentage Bar Chart by User and Label')
ax.set_xticks(np.arange(len(users)))
ax.set_xticklabels(users, rotation=90)  # Rotate labels if needed
ax.legend()


plt.savefig('./non_iid_user_label_distribution.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Our Aggregation Function

# %%
def our_mean_defense(all_updates, n_attackers, history_updates):
    discarded_history = get_discarded_index(n_attackers, history_updates)

    mask = torch.ones(all_updates.size(0), dtype=torch.bool)
    mask[discarded_history] = False
    remaining_updates = all_updates[mask]

    print('discarded index', discarded_history)

    return torch.nanmean(remaining_updates, dim=0)

####
def euclidean_distance(row1, row2):
    return torch.sqrt(torch.sum((row1 - row2) ** 2))
####

def get_discarded_index(n_attackers, history_updates):
    n_users = history_updates.shape[0]

    ####
    distance_matrix = [[0 if i == j else euclidean_distance(history_updates[i, :], history_updates[j, :]) for j in range(n_users)] for i in range(n_users)]
    ####

    sum_of_distances = [sum(row) for row in distance_matrix]

    discarded_history = []
    for _ in range(n_attackers):
        max_distance = max(sum_of_distances)
        index_of_max_distance = sum_of_distances.index(max_distance)
        discarded_history.append(index_of_max_distance)

        for i in range(n_users):
            sum_of_distances[i] -= distance_matrix[i][index_of_max_distance]
        sum_of_distances[index_of_max_distance] = -1

    return discarded_history

# %% [markdown]
# ## Code for no defense aggregation algorithm

# %%
def no_defense_aggregation(user_grads):
    return torch.nanmean(user_grads, dim=0)

# %% [markdown]
# ## our_attack_mean
# $ argmin_\theta(\ -L(\theta_{attacker(s)}) + \lambda_1 |\bar{\theta_{abs\ mean\ benige\ users}} - \bar{\theta_{abs\ attacker(s)}}|$

# %%
device = 'cuda:0'
def check_condition(lambda1, prev_grad, loss_grad, history, all_updates, n_users, n_attacker, epoch_num):
    loss_grad = loss_grad.to(device)
    prev_grad = prev_grad.to(device)
    new_grad = lambda1 * (loss_grad + prev_grad)

    ####
    mal_updates = torch.stack([new_grad.clone().detach() for _ in range(n_attacker)])
    malicious_grads = torch.cat((mal_updates, all_updates[n_attacker:]), 0)

    history_updates = history.clone().detach()
    history_updates[:, epoch_num] = malicious_grads.abs().mean(dim=1, keepdim=True).squeeze()
    ####

    discarded_history = get_discarded_index(n_attacker+2, history_updates)

    detected_mal = len([item for item in discarded_history if item < 10])
    return detected_mal / len(discarded_history) <= n_attacker / n_users

def find_upper_bound(lambda1, prev_grad, loss_grad, history, all_updates, n_users, n_attacker, epoch_num):
    while check_condition(lambda1, prev_grad, loss_grad, history, all_updates, n_users, n_attacker, epoch_num):
        lambda1 *= 2  # Exponentially increase lambda
    return lambda1


def projection(prev_grad, loss_grad, history, all_updates, n_users, n_attacker, epoch_num):
    updates_abs_mean = all_updates.abs().mean(dim=1, keepdim=True)
    median_value = torch.median(updates_abs_mean).item()

    ####
    history_updates = history.clone().detach()
    history_updates[:, epoch_num] = updates_abs_mean.mean(dim=1, keepdim=True).squeeze()
    ####

    loss_grad = loss_grad.to(device)
    prev_grad = prev_grad.to(device)

    lambda_low = median_value/(prev_grad + loss_grad).abs().mean().item()
    lambda_high = find_upper_bound(lambda_low, prev_grad, loss_grad, history_updates, all_updates, n_users, n_attacker, epoch_num)
    if lambda_high < lambda_low:
        lambda_high = lambda_low
        print("SHOULD NEVER REACH THIS LINE")
        print('lambda_low: ', lambda_low, ' lambda_high: ', lambda_high)
    tolerance = 1e-6


    while lambda_high - lambda_low > tolerance:
        lambda_mid = (lambda_low + lambda_high) / 2
        if check_condition(lambda_mid, prev_grad, loss_grad, history_updates, all_updates, n_users, n_attacker, epoch_num):
            lambda_low = lambda_mid
        else:
            lambda_high = lambda_mid

    lambda1 = lambda_low

    return lambda1 * (prev_grad + loss_grad)

def our_attack_mean(n_user, epoch_num, history_updates, all_updates, model_params, n_attacker, arch, criterion, user_train_data_tensors, user_train_label_tensors):
    attacker_tr_data_tensor = user_train_data_tensors[0].cuda()
    attacker_tr_label_tensor = user_train_label_tensors[0].cuda()

    fed_model, _ = return_model(arch, 0.1, 0.9, parallel=False)
    fed_model.eval()  # Ensure the model is in evaluation mode

    new_grad = -all_updates[0].clone().detach().requires_grad_(True)
    prev_grad = np.zeros(len(new_grad))
    new_grad = projection(torch.from_numpy(prev_grad), new_grad, history_updates, all_updates, n_user, n_attacker, epoch_num)

    while True:
        outputs = fed_model(attacker_tr_data_tensor)
        loss = criterion(outputs, attacker_tr_label_tensor)

        loss.backward(retain_graph=True)
        param_grad = []
        for param in fed_model.parameters():
            param_grad.append(param.grad.view(-1).detach())

        param_grad = torch.cat(param_grad)
        prev_grad = new_grad
        new_grad = projection(prev_grad, param_grad, history_updates, all_updates, n_user, n_attacker, epoch_num)

        difference = torch.mean(torch.abs(new_grad - prev_grad)).item()
        if difference < 1e-6:
            # print("STOPPED! Difference is too small, stop finding best attack grad")
            break

        fed_model.zero_grad()

    result_attacker_grads = [new_grad.clone().detach() for _ in range(10)]
    return torch.stack(result_attacker_grads).cuda()

# %% [markdown]
# ## Set number of epochs

# %%
nepochs= 300

# %% [markdown]
# ## no defense

# %%
batch_size=250
resume=0

schedule=[1000]

gamma=.5
opt = 'sgd'
fed_lr=0.5
criterion=nn.CrossEntropyLoss()
use_cuda = torch.cuda.is_available()

aggregation='bulyan'
multi_k = False
candidates = []

at_type='our-agr'
dev_type ='std'
n_attackers=[10]

arch='alexnet'
chkpt='./'+aggregation

past_mean = []
past_abs_sum = []
past_median = []
past_lower_quartile = []
past_upper_quartile = []
past_std = []


for n_attacker in n_attackers:
    epoch_num = 0
    best_global_acc = 0
    best_global_te_acc = 0

    torch.cuda.empty_cache()

    fed_model, _ = return_model(arch, 0.1, 0.9, parallel=False)
    optimizer_fed = SGD(fed_model.parameters(), lr=fed_lr)

    df = pd.DataFrame(columns = ['epoch', 'loss', 'validation accuracy', 'best validation accuracy'])

    ####
    history = torch.zeros((n_users, nepochs + 1), dtype=torch.float32).cuda()
    ####

    model_grads = []
    flag = False
    while epoch_num <= nepochs:
        user_grads=[]

        for i in range(n_users): # 50
            nbatches = user_tr_len[i]//batch_size

            inputs = user_train_data_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]
            targets = user_train_label_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]

            targets = targets.type(torch.LongTensor)

            inputs, targets = inputs.cuda(), targets.cuda()
            inputs, targets = torch.autograd.Variable(inputs), torch.autograd.Variable(targets)

            outputs = fed_model(inputs)
            loss = criterion(outputs, targets)
            fed_model.zero_grad()
            loss.backward(retain_graph=True)

            param_grad=[]
            for param in fed_model.parameters():
                param_grad=param.grad.data.view(-1) if not len(param_grad) else torch.cat((param_grad,param.grad.view(-1)))


            user_grads=param_grad[None, :] if len(user_grads)==0 else torch.cat((user_grads,param_grad[None,:]), 0)

        if epoch_num in schedule:
            for param_group in optimizer_fed.param_groups:
                param_group['lr'] *= gamma
                print('New learnin rate ', param_group['lr'])

        updates_abs_mean = user_grads.abs().mean(dim=1, keepdim=True)

        if n_attacker > 0:
            model_params = torch.cat([p.data.view(-1) for p in fed_model.parameters()])
            mal_updates = our_attack_mean(n_users, epoch_num, history, user_grads, model_params, n_attacker, arch, criterion, user_train_data_tensors, user_train_label_tensors)
            malicious_grads = torch.cat((mal_updates, user_grads[n_attacker:]), 0) # torch.Size([50, 2472266])
        else:   # No attack
            malicious_grads = user_grads

        if not (malicious_grads.shape[0]==50):
            print(malicious_grads.shape)

        updates_abs_mean = malicious_grads.abs().mean(dim=1, keepdim=True)

        history[:, epoch_num] = updates_abs_mean.squeeze()
        agg_grads = no_defense_aggregation(malicious_grads)
        # agg_grads = our_mean_defense(malicious_grads, n_attacker, history)

        del user_grads

        start_idx=0

        optimizer_fed.zero_grad()

        model_grads=[]

        for i, param in enumerate(fed_model.parameters()):
            param_=agg_grads[start_idx:start_idx+len(param.data.view(-1))].reshape(param.data.shape)
            start_idx=start_idx+len(param.data.view(-1))
            param_=param_.cuda()
            model_grads.append(param_)

        optimizer_fed.step(model_grads)

        val_loss, val_acc = test(val_data_tensor,val_label_tensor,fed_model,criterion,use_cuda)
        te_loss, te_acc = test(te_data_tensor,te_label_tensor, fed_model, criterion, use_cuda)

        is_best = best_global_acc < val_acc

        best_global_acc = max(best_global_acc, val_acc)

        if is_best:
            best_global_te_acc = te_acc


        print('epoch: %d, %s: at %s n_at %d e %d | val loss %.4f val acc %.4f best val_acc %f'%(epoch_num, aggregation, at_type, n_attacker, epoch_num, val_loss, val_acc, best_global_acc))
        new_row = pd.DataFrame([{
            'epoch': epoch_num,
            'loss': val_loss,
            'validation accuracy': val_acc,
            'best validation accuracy': best_global_acc
            }])
        df = pd.concat([df, new_row], ignore_index=True)
        df.to_csv('./our attack + 10 attacker + our defense.csv', index=False)

        if val_loss > 1000:
            print('val loss %f too high'%val_loss)
            break

        epoch_num+=1
# Out:
# c:\Users\Hizan\Desktop\CPEN497-FL\CPEN497-499\sgd.py:109: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\python_arg_parser.cpp:1630.)
#   p.data.add_(-group['lr'], d_p)
# epoch: 0, bulyan: at our-agr n_at 10 e 0 | val loss 2.3028 val acc 8.7054 best val_acc 8.705357
# C:\Users\Hizan\AppData\Local\Temp\ipykernel_3024\2633842343.py:132: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, new_row], ignore_index=True)
# epoch: 1, bulyan: at our-agr n_at 10 e 1 | val loss 2.3024 val acc 10.2476 best val_acc 10.247565
# epoch: 2, bulyan: at our-agr n_at 10 e 2 | val loss 2.3022 val acc 10.3084 best val_acc 10.308442
# epoch: 3, bulyan: at our-agr n_at 10 e 3 | val loss 2.3021 val acc 10.3084 best val_acc 10.308442
# epoch: 4, bulyan: at our-agr n_at 10 e 4 | val loss 2.3020 val acc 10.3084 best val_acc 10.308442
# epoch: 5, bulyan: at our-agr n_at 10 e 5 | val loss 2.3020 val acc 10.3084 best val_acc 10.308442
# epoch: 6, bulyan: at our-agr n_at 10 e 6 | val loss 2.3022 val acc 10.3084 best val_acc 10.308442
# epoch: 7, bulyan: at our-agr n_at 10 e 7 | val loss 2.3025 val acc 10.3084 best val_acc 10.308442
# epoch: 8, bulyan: at our-agr n_at 10 e 8 | val loss 2.3026 val acc 10.3084 best val_acc 10.308442
# epoch: 9, bulyan: at our-agr n_at 10 e 9 | val loss 2.3031 val acc 10.3084 best val_acc 10.308442
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 84
#      82 if n_attacker > 0:
#      83     model_params = torch.cat([p.data.view(-1) for p in fed_model.parameters()])
# ---> 84     mal_updates = our_attack_mean(n_users, epoch_num, history, user_grads, model_params, n_attacker, arch, criterion, user_train_data_tensors, user_train_label_tensors)
#      85     malicious_grads = torch.cat((mal_updates, user_grads[n_attacker:]), 0) # torch.Size([50, 2472266])
#      86 else:   # No attack
#
# Cell In[10], line 80, in our_attack_mean(n_user, epoch_num, history_updates, all_updates, model_params, n_attacker, arch, criterion, user_train_data_tensors, user_train_label_tensors)
#      78 param_grad = torch.cat(param_grad)
#      79 prev_grad = new_grad
# ---> 80 new_grad = projection(prev_grad, param_grad, history_updates, all_updates, n_user, n_attacker, epoch_num)
#      82 difference = torch.mean(torch.abs(new_grad - prev_grad)).item()
#      83 if difference < 1e-6:
#      84     # print("STOPPED! Difference is too small, stop finding best attack grad")
#
# Cell In[10], line 39, in projection(prev_grad, loss_grad, history, all_updates, n_users, n_attacker, epoch_num)
#      36 prev_grad = prev_grad.to(device)
#      38 lambda_low = median_value/(prev_grad + loss_grad).abs().mean().item()
# ---> 39 lambda_high = find_upper_bound(lambda_low, prev_grad, loss_grad, history_updates, all_updates, n_users, n_attacker, epoch_num)
#      40 if lambda_high < lambda_low:
#      41     lambda_high = lambda_low
#
# Cell In[10], line 21, in find_upper_bound(lambda1, prev_grad, loss_grad, history, all_updates, n_users, n_attacker, epoch_num)
#      20 def find_upper_bound(lambda1, prev_grad, loss_grad, history, all_updates, n_users, n_attacker, epoch_num):
# ---> 21     while check_condition(lambda1, prev_grad, loss_grad, history, all_updates, n_users, n_attacker, epoch_num):
#      22         lambda1 *= 2  # Exponentially increase lambda
#      23     return lambda1
#
# Cell In[10], line 15, in check_condition(lambda1, prev_grad, loss_grad, history, all_updates, n_users, n_attacker, epoch_num)
#      12 history_updates[:, epoch_num] = malicious_grads.abs().mean(dim=1, keepdim=True).squeeze()
#      13 ####
# ---> 15 discarded_history = get_discarded_index(n_attacker+2, history_updates)
#      17 detected_mal = len([item for item in discarded_history if item < 10])
#      18 return detected_mal / len(discarded_history) <= n_attacker / n_users
#
# Cell In[8], line 28, in get_discarded_index(n_attackers, history_updates)
#      26 discarded_history = []
#      27 for _ in range(n_attackers):
# ---> 28     max_distance = max(sum_of_distances)
#      29     index_of_max_distance = sum_of_distances.index(max_distance)
#      30     discarded_history.append(index_of_max_distance)
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

# Plotting the data
for col in ['loss', 'validation accuracy', 'best validation accuracy']:
    plt.plot(df['epoch'].tolist(), df[col].tolist())
    plt.title("our attack + 10 attacker + no defense_"+col)
    plt.savefig('./our attack + 10 attacker + no defense ' + col + '.png')
    plt.show()

# %% [markdown]
# ## No Attack

# %%
batch_size=250
resume=0

schedule=[1000]

gamma=.5
opt = 'sgd'
fed_lr=0.5
criterion=nn.CrossEntropyLoss()
use_cuda = torch.cuda.is_available()

aggregation='bulyan'
multi_k = False
candidates = []

at_type='our-agr'
dev_type ='std'
n_attackers=[0]

arch='alexnet'
chkpt='./'+aggregation

past_mean = []
past_abs_sum = []
past_median = []
past_lower_quartile = []
past_upper_quartile = []
past_std = []


for n_attacker in n_attackers:
    epoch_num = 0
    best_global_acc = 0
    best_global_te_acc = 0

    torch.cuda.empty_cache()

    fed_model, _ = return_model(arch, 0.1, 0.9, parallel=False)
    optimizer_fed = SGD(fed_model.parameters(), lr=fed_lr)

    df = pd.DataFrame(columns = ['epoch', 'loss', 'validation accuracy', 'best validation accuracy'])

    ####
    history = torch.zeros((n_users, nepochs + 1), dtype=torch.float32).cuda()
    ####

    model_grads = []
    flag = False
    while epoch_num <= nepochs:
        user_grads=[]

        for i in range(n_users): # 50
            nbatches = user_tr_len[i]//batch_size

            inputs = user_train_data_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]
            targets = user_train_label_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]

            targets = targets.type(torch.LongTensor)

            inputs, targets = inputs.cuda(), targets.cuda()
            inputs, targets = torch.autograd.Variable(inputs), torch.autograd.Variable(targets)

            outputs = fed_model(inputs)
            loss = criterion(outputs, targets)
            fed_model.zero_grad()
            loss.backward(retain_graph=True)

            param_grad=[]
            for param in fed_model.parameters():
                param_grad=param.grad.data.view(-1) if not len(param_grad) else torch.cat((param_grad,param.grad.view(-1)))


            user_grads=param_grad[None, :] if len(user_grads)==0 else torch.cat((user_grads,param_grad[None,:]), 0)

        if epoch_num in schedule:
            for param_group in optimizer_fed.param_groups:
                param_group['lr'] *= gamma
                print('New learnin rate ', param_group['lr'])

        updates_abs_mean = user_grads.abs().mean(dim=1, keepdim=True)

        if n_attacker > 0:
            model_params = torch.cat([p.data.view(-1) for p in fed_model.parameters()])
            mal_updates = our_attack_mean(n_users, epoch_num, history, user_grads, model_params, n_attacker, arch, criterion, user_train_data_tensors, user_train_label_tensors)
            malicious_grads = torch.cat((mal_updates, user_grads[n_attacker:]), 0) # torch.Size([50, 2472266])
        else:   # No attack
            malicious_grads = user_grads

        if not (malicious_grads.shape[0]==50):
            print(malicious_grads.shape)

        updates_abs_mean = malicious_grads.abs().mean(dim=1, keepdim=True)

        history[:, epoch_num] = updates_abs_mean.squeeze()
        # agg_grads = no_defense_aggregation(malicious_grads)
        agg_grads = our_mean_defense(malicious_grads, n_attacker, history)

        del user_grads

        start_idx=0

        optimizer_fed.zero_grad()

        model_grads=[]

        for i, param in enumerate(fed_model.parameters()):
            param_=agg_grads[start_idx:start_idx+len(param.data.view(-1))].reshape(param.data.shape)
            start_idx=start_idx+len(param.data.view(-1))
            param_=param_.cuda()
            model_grads.append(param_)

        optimizer_fed.step(model_grads)

        val_loss, val_acc = test(val_data_tensor,val_label_tensor,fed_model,criterion,use_cuda)
        te_loss, te_acc = test(te_data_tensor,te_label_tensor, fed_model, criterion, use_cuda)

        is_best = best_global_acc < val_acc

        best_global_acc = max(best_global_acc, val_acc)

        if is_best:
            best_global_te_acc = te_acc


        print('epoch: %d, %s: at %s n_at %d e %d | val loss %.4f val acc %.4f best val_acc %f'%(epoch_num, aggregation, at_type, n_attacker, epoch_num, val_loss, val_acc, best_global_acc))
        new_row = pd.DataFrame([{
            'epoch': epoch_num,
            'loss': val_loss,
            'validation accuracy': val_acc,
            'best validation accuracy': best_global_acc
            }])
        df = pd.concat([df, new_row], ignore_index=True)
        df.to_csv('./our attack + 10 attacker + our defense.csv', index=False)

        if val_loss > 1000:
            print('val loss %f too high'%val_loss)
            break

        epoch_num+=1
# Out:
# discarded index []
# epoch: 0, bulyan: at our-agr n_at 0 e 0 | val loss 2.3029 val acc 9.6997 best val_acc 9.699675
# C:\Users\Hizan\AppData\Local\Temp\ipykernel_3024\56042239.py:132: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, new_row], ignore_index=True)
# discarded index []
# epoch: 1, bulyan: at our-agr n_at 0 e 1 | val loss 2.3023 val acc 9.6997 best val_acc 9.699675
# discarded index []
# epoch: 2, bulyan: at our-agr n_at 0 e 2 | val loss 2.3018 val acc 9.6997 best val_acc 9.699675
# discarded index []
# epoch: 3, bulyan: at our-agr n_at 0 e 3 | val loss 2.3014 val acc 9.6997 best val_acc 9.699675
# discarded index []
# epoch: 4, bulyan: at our-agr n_at 0 e 4 | val loss 2.3008 val acc 9.6997 best val_acc 9.699675
# discarded index []
# epoch: 5, bulyan: at our-agr n_at 0 e 5 | val loss 2.3003 val acc 9.6997 best val_acc 9.699675
# discarded index []
# epoch: 6, bulyan: at our-agr n_at 0 e 6 | val loss 2.2998 val acc 9.6997 best val_acc 9.699675
# discarded index []
# epoch: 7, bulyan: at our-agr n_at 0 e 7 | val loss 2.2990 val acc 9.6997 best val_acc 9.699675
# discarded index []
# epoch: 8, bulyan: at our-agr n_at 0 e 8 | val loss 2.2982 val acc 9.6997 best val_acc 9.699675
# discarded index []
# epoch: 9, bulyan: at our-agr n_at 0 e 9 | val loss 2.2973 val acc 9.6997 best val_acc 9.699675
# discarded index []
# epoch: 10, bulyan: at our-agr n_at 0 e 10 | val loss 2.2961 val acc 9.6997 best val_acc 9.699675
# discarded index []
# epoch: 11, bulyan: at our-agr n_at 0 e 11 | val loss 2.2948 val acc 9.6997 best val_acc 9.699675
# discarded index []
# epoch: 12, bulyan: at our-agr n_at 0 e 12 | val loss 2.2931 val acc 9.7200 best val_acc 9.719968
# discarded index []
# epoch: 13, bulyan: at our-agr n_at 0 e 13 | val loss 2.2907 val acc 11.4651 best val_acc 11.465097
# discarded index []
# epoch: 14, bulyan: at our-agr n_at 0 e 14 | val loss 2.2879 val acc 13.1696 best val_acc 13.169643
# discarded index []
# epoch: 15, bulyan: at our-agr n_at 0 e 15 | val loss 2.2841 val acc 14.2451 best val_acc 14.245130
# discarded index []
# epoch: 16, bulyan: at our-agr n_at 0 e 16 | val loss 2.2786 val acc 14.7930 best val_acc 14.793019
# discarded index []
# epoch: 17, bulyan: at our-agr n_at 0 e 17 | val loss 2.2712 val acc 16.0714 best val_acc 16.071429
# discarded index []
# epoch: 18, bulyan: at our-agr n_at 0 e 18 | val loss 2.2616 val acc 15.4627 best val_acc 16.071429
# discarded index []
# epoch: 19, bulyan: at our-agr n_at 0 e 19 | val loss 2.2484 val acc 18.0804 best val_acc 18.080357
# discarded index []
# epoch: 20, bulyan: at our-agr n_at 0 e 20 | val loss 2.2333 val acc 20.4545 best val_acc 20.454545
# discarded index []
# epoch: 21, bulyan: at our-agr n_at 0 e 21 | val loss 2.2175 val acc 16.2946 best val_acc 20.454545
# discarded index []
# epoch: 22, bulyan: at our-agr n_at 0 e 22 | val loss 2.2120 val acc 15.4424 best val_acc 20.454545
# discarded index []
# epoch: 23, bulyan: at our-agr n_at 0 e 23 | val loss 2.3408 val acc 11.9927 best val_acc 20.454545
# discarded index []
# epoch: 24, bulyan: at our-agr n_at 0 e 24 | val loss 2.3086 val acc 12.6420 best val_acc 20.454545
# discarded index []
# epoch: 25, bulyan: at our-agr n_at 0 e 25 | val loss 2.3022 val acc 12.1347 best val_acc 20.454545
# discarded index []
# epoch: 26, bulyan: at our-agr n_at 0 e 26 | val loss 2.2979 val acc 11.3028 best val_acc 20.454545
# discarded index []
# epoch: 27, bulyan: at our-agr n_at 0 e 27 | val loss 2.2939 val acc 10.4505 best val_acc 20.454545
# discarded index []
# epoch: 28, bulyan: at our-agr n_at 0 e 28 | val loss 2.2895 val acc 10.2476 best val_acc 20.454545
# discarded index []
# epoch: 29, bulyan: at our-agr n_at 0 e 29 | val loss 2.2845 val acc 10.1867 best val_acc 20.454545
# discarded index []
# epoch: 30, bulyan: at our-agr n_at 0 e 30 | val loss 2.2787 val acc 9.9635 best val_acc 20.454545
# discarded index []
# epoch: 31, bulyan: at our-agr n_at 0 e 31 | val loss 2.2717 val acc 9.9026 best val_acc 20.454545
# discarded index []
# epoch: 32, bulyan: at our-agr n_at 0 e 32 | val loss 2.2640 val acc 9.8011 best val_acc 20.454545
# discarded index []
# epoch: 33, bulyan: at our-agr n_at 0 e 33 | val loss 2.2560 val acc 9.8823 best val_acc 20.454545
# discarded index []
# epoch: 34, bulyan: at our-agr n_at 0 e 34 | val loss 2.2470 val acc 9.8214 best val_acc 20.454545
# discarded index []
# epoch: 35, bulyan: at our-agr n_at 0 e 35 | val loss 2.2377 val acc 9.9229 best val_acc 20.454545
# discarded index []
# epoch: 36, bulyan: at our-agr n_at 0 e 36 | val loss 2.2283 val acc 10.5114 best val_acc 20.454545
# discarded index []
# epoch: 37, bulyan: at our-agr n_at 0 e 37 | val loss 2.2190 val acc 12.6826 best val_acc 20.454545
# discarded index []
# epoch: 38, bulyan: at our-agr n_at 0 e 38 | val loss 2.2101 val acc 18.0195 best val_acc 20.454545
# discarded index []
# epoch: 39, bulyan: at our-agr n_at 0 e 39 | val loss 2.2034 val acc 17.6542 best val_acc 20.454545
# discarded index []
# epoch: 40, bulyan: at our-agr n_at 0 e 40 | val loss 2.1941 val acc 19.8052 best val_acc 20.454545
# discarded index []
# epoch: 41, bulyan: at our-agr n_at 0 e 41 | val loss 2.1925 val acc 20.8401 best val_acc 20.840097
# discarded index []
# epoch: 42, bulyan: at our-agr n_at 0 e 42 | val loss 2.1972 val acc 20.3937 best val_acc 20.840097
# discarded index []
# epoch: 43, bulyan: at our-agr n_at 0 e 43 | val loss 2.2567 val acc 14.3466 best val_acc 20.840097
# discarded index []
# epoch: 44, bulyan: at our-agr n_at 0 e 44 | val loss 2.1771 val acc 20.8604 best val_acc 20.860390
# discarded index []
# epoch: 45, bulyan: at our-agr n_at 0 e 45 | val loss 2.1646 val acc 23.0317 best val_acc 23.031656
# discarded index []
# epoch: 46, bulyan: at our-agr n_at 0 e 46 | val loss 2.1777 val acc 21.5909 best val_acc 23.031656
# discarded index []
# epoch: 47, bulyan: at our-agr n_at 0 e 47 | val loss 2.1891 val acc 23.2346 best val_acc 23.234578
# discarded index []
# epoch: 48, bulyan: at our-agr n_at 0 e 48 | val loss 2.2838 val acc 14.4278 best val_acc 23.234578
# discarded index []
# epoch: 49, bulyan: at our-agr n_at 0 e 49 | val loss 2.2463 val acc 16.6193 best val_acc 23.234578
# discarded index []
# epoch: 50, bulyan: at our-agr n_at 0 e 50 | val loss 2.1795 val acc 18.9529 best val_acc 23.234578
# discarded index []
# epoch: 51, bulyan: at our-agr n_at 0 e 51 | val loss 2.1006 val acc 22.4229 best val_acc 23.234578
# discarded index []
# epoch: 52, bulyan: at our-agr n_at 0 e 52 | val loss 2.0598 val acc 23.9042 best val_acc 23.904221
# discarded index []
# epoch: 53, bulyan: at our-agr n_at 0 e 53 | val loss 2.0405 val acc 24.6550 best val_acc 24.655032
# discarded index []
# epoch: 54, bulyan: at our-agr n_at 0 e 54 | val loss 2.1368 val acc 22.3214 best val_acc 24.655032
# discarded index []
# epoch: 55, bulyan: at our-agr n_at 0 e 55 | val loss 2.9264 val acc 12.9058 best val_acc 24.655032
# discarded index []
# epoch: 56, bulyan: at our-agr n_at 0 e 56 | val loss 2.2974 val acc 9.5982 best val_acc 24.655032
# discarded index []
# epoch: 57, bulyan: at our-agr n_at 0 e 57 | val loss 2.2826 val acc 9.5779 best val_acc 24.655032
# discarded index []
# epoch: 58, bulyan: at our-agr n_at 0 e 58 | val loss 2.2643 val acc 9.4562 best val_acc 24.655032
# discarded index []
# epoch: 59, bulyan: at our-agr n_at 0 e 59 | val loss 2.2456 val acc 9.4765 best val_acc 24.655032
# discarded index []
# epoch: 60, bulyan: at our-agr n_at 0 e 60 | val loss 2.2283 val acc 9.9026 best val_acc 24.655032
# discarded index []
# epoch: 61, bulyan: at our-agr n_at 0 e 61 | val loss 2.2137 val acc 10.1867 best val_acc 24.655032
# discarded index []
# epoch: 62, bulyan: at our-agr n_at 0 e 62 | val loss 2.2014 val acc 12.7638 best val_acc 24.655032
# discarded index []
# epoch: 63, bulyan: at our-agr n_at 0 e 63 | val loss 2.1998 val acc 10.7143 best val_acc 24.655032
# discarded index []
# epoch: 64, bulyan: at our-agr n_at 0 e 64 | val loss 2.2315 val acc 9.4968 best val_acc 24.655032
# discarded index []
# epoch: 65, bulyan: at our-agr n_at 0 e 65 | val loss 2.2163 val acc 10.2679 best val_acc 24.655032
# discarded index []
# epoch: 66, bulyan: at our-agr n_at 0 e 66 | val loss 2.1910 val acc 17.7151 best val_acc 24.655032
# discarded index []
# epoch: 67, bulyan: at our-agr n_at 0 e 67 | val loss 2.1815 val acc 18.1818 best val_acc 24.655032
# discarded index []
# epoch: 68, bulyan: at our-agr n_at 0 e 68 | val loss 2.2010 val acc 18.7906 best val_acc 24.655032
# discarded index []
# epoch: 69, bulyan: at our-agr n_at 0 e 69 | val loss 2.1487 val acc 21.3677 best val_acc 24.655032
# discarded index []
# epoch: 70, bulyan: at our-agr n_at 0 e 70 | val loss 2.1376 val acc 21.9156 best val_acc 24.655032
# discarded index []
# epoch: 71, bulyan: at our-agr n_at 0 e 71 | val loss 2.1513 val acc 21.3677 best val_acc 24.655032
# discarded index []
# epoch: 72, bulyan: at our-agr n_at 0 e 72 | val loss 2.2293 val acc 17.5933 best val_acc 24.655032
# discarded index []
# epoch: 73, bulyan: at our-agr n_at 0 e 73 | val loss 2.1260 val acc 22.1388 best val_acc 24.655032
# discarded index []
# epoch: 74, bulyan: at our-agr n_at 0 e 74 | val loss 2.1308 val acc 21.8547 best val_acc 24.655032
# discarded index []
# epoch: 75, bulyan: at our-agr n_at 0 e 75 | val loss 2.1818 val acc 19.5617 best val_acc 24.655032
# discarded index []
# epoch: 76, bulyan: at our-agr n_at 0 e 76 | val loss 2.1126 val acc 21.6315 best val_acc 24.655032
# discarded index []
# epoch: 77, bulyan: at our-agr n_at 0 e 77 | val loss 2.1272 val acc 20.3125 best val_acc 24.655032
# discarded index []
# epoch: 78, bulyan: at our-agr n_at 0 e 78 | val loss 2.2200 val acc 17.6136 best val_acc 24.655032
# discarded index []
# epoch: 79, bulyan: at our-agr n_at 0 e 79 | val loss 2.1739 val acc 18.4659 best val_acc 24.655032
# discarded index []
# epoch: 80, bulyan: at our-agr n_at 0 e 80 | val loss 2.1592 val acc 19.9067 best val_acc 24.655032
# discarded index []
# epoch: 81, bulyan: at our-agr n_at 0 e 81 | val loss 2.1541 val acc 20.2516 best val_acc 24.655032
# discarded index []
# epoch: 82, bulyan: at our-agr n_at 0 e 82 | val loss 2.2508 val acc 14.9351 best val_acc 24.655032
# discarded index []
# epoch: 83, bulyan: at our-agr n_at 0 e 83 | val loss 2.1791 val acc 20.6372 best val_acc 24.655032
# discarded index []
# epoch: 84, bulyan: at our-agr n_at 0 e 84 | val loss 2.1253 val acc 22.7273 best val_acc 24.655032
# discarded index []
# epoch: 85, bulyan: at our-agr n_at 0 e 85 | val loss 2.1292 val acc 21.2865 best val_acc 24.655032
# discarded index []
# epoch: 86, bulyan: at our-agr n_at 0 e 86 | val loss 2.2417 val acc 14.8539 best val_acc 24.655032
# discarded index []
# epoch: 87, bulyan: at our-agr n_at 0 e 87 | val loss 2.1366 val acc 18.4050 best val_acc 24.655032
# discarded index []
# epoch: 88, bulyan: at our-agr n_at 0 e 88 | val loss 2.0989 val acc 24.2492 best val_acc 24.655032
# discarded index []
# epoch: 89, bulyan: at our-agr n_at 0 e 89 | val loss 2.1088 val acc 23.8636 best val_acc 24.655032
# discarded index []
# epoch: 90, bulyan: at our-agr n_at 0 e 90 | val loss 2.0852 val acc 22.8896 best val_acc 24.655032
# discarded index []
# epoch: 91, bulyan: at our-agr n_at 0 e 91 | val loss 2.1296 val acc 20.9821 best val_acc 24.655032
# discarded index []
# epoch: 92, bulyan: at our-agr n_at 0 e 92 | val loss 2.0705 val acc 24.0869 best val_acc 24.655032
# discarded index []
# epoch: 93, bulyan: at our-agr n_at 0 e 93 | val loss 2.1599 val acc 19.0950 best val_acc 24.655032
# discarded index []
# epoch: 94, bulyan: at our-agr n_at 0 e 94 | val loss 2.0651 val acc 23.1331 best val_acc 24.655032
# discarded index []
# epoch: 95, bulyan: at our-agr n_at 0 e 95 | val loss 2.1163 val acc 21.5706 best val_acc 24.655032
# discarded index []
# epoch: 96, bulyan: at our-agr n_at 0 e 96 | val loss 2.1078 val acc 22.0170 best val_acc 24.655032
# discarded index []
# epoch: 97, bulyan: at our-agr n_at 0 e 97 | val loss 2.2469 val acc 15.2394 best val_acc 24.655032
# discarded index []
# epoch: 98, bulyan: at our-agr n_at 0 e 98 | val loss 2.1585 val acc 20.6372 best val_acc 24.655032
# discarded index []
# epoch: 99, bulyan: at our-agr n_at 0 e 99 | val loss 2.1009 val acc 21.9765 best val_acc 24.655032
# discarded index []
# epoch: 100, bulyan: at our-agr n_at 0 e 100 | val loss 2.0523 val acc 23.1128 best val_acc 24.655032
# discarded index []
# epoch: 101, bulyan: at our-agr n_at 0 e 101 | val loss 2.0502 val acc 23.1331 best val_acc 24.655032
# discarded index []
# epoch: 102, bulyan: at our-agr n_at 0 e 102 | val loss 2.1529 val acc 20.6778 best val_acc 24.655032
# discarded index []
# epoch: 103, bulyan: at our-agr n_at 0 e 103 | val loss 2.0666 val acc 22.3823 best val_acc 24.655032
# discarded index []
# epoch: 104, bulyan: at our-agr n_at 0 e 104 | val loss 2.2194 val acc 16.1323 best val_acc 24.655032
# discarded index []
# epoch: 105, bulyan: at our-agr n_at 0 e 105 | val loss 2.1376 val acc 18.8718 best val_acc 24.655032
# discarded index []
# epoch: 106, bulyan: at our-agr n_at 0 e 106 | val loss 2.0581 val acc 23.2549 best val_acc 24.655032
# discarded index []
# epoch: 107, bulyan: at our-agr n_at 0 e 107 | val loss 2.1206 val acc 21.6112 best val_acc 24.655032
# discarded index []
# epoch: 108, bulyan: at our-agr n_at 0 e 108 | val loss 2.2602 val acc 13.7784 best val_acc 24.655032
# discarded index []
# epoch: 109, bulyan: at our-agr n_at 0 e 109 | val loss 2.1741 val acc 19.4805 best val_acc 24.655032
# discarded index []
# epoch: 110, bulyan: at our-agr n_at 0 e 110 | val loss 2.1550 val acc 18.4050 best val_acc 24.655032
# discarded index []
# epoch: 111, bulyan: at our-agr n_at 0 e 111 | val loss 2.1888 val acc 19.2979 best val_acc 24.655032
# discarded index []
# epoch: 112, bulyan: at our-agr n_at 0 e 112 | val loss 2.2541 val acc 13.7581 best val_acc 24.655032
# discarded index []
# epoch: 113, bulyan: at our-agr n_at 0 e 113 | val loss 2.2090 val acc 15.3409 best val_acc 24.655032
# discarded index []
# epoch: 114, bulyan: at our-agr n_at 0 e 114 | val loss 2.2257 val acc 14.6104 best val_acc 24.655032
# discarded index []
# epoch: 115, bulyan: at our-agr n_at 0 e 115 | val loss 2.1857 val acc 16.2135 best val_acc 24.655032
# discarded index []
# epoch: 116, bulyan: at our-agr n_at 0 e 116 | val loss 2.2513 val acc 12.5812 best val_acc 24.655032
# discarded index []
# epoch: 117, bulyan: at our-agr n_at 0 e 117 | val loss 2.1250 val acc 16.5990 best val_acc 24.655032
# discarded index []
# epoch: 118, bulyan: at our-agr n_at 0 e 118 | val loss 2.1366 val acc 18.6891 best val_acc 24.655032
# discarded index []
# epoch: 119, bulyan: at our-agr n_at 0 e 119 | val loss 2.2074 val acc 13.9002 best val_acc 24.655032
# discarded index []
# epoch: 120, bulyan: at our-agr n_at 0 e 120 | val loss 2.0818 val acc 19.1761 best val_acc 24.655032
# discarded index []
# epoch: 121, bulyan: at our-agr n_at 0 e 121 | val loss 2.0614 val acc 19.8661 best val_acc 24.655032
# discarded index []
# epoch: 122, bulyan: at our-agr n_at 0 e 122 | val loss 2.0507 val acc 21.1648 best val_acc 24.655032
# discarded index []
# epoch: 123, bulyan: at our-agr n_at 0 e 123 | val loss 2.0398 val acc 21.7532 best val_acc 24.655032
# discarded index []
# epoch: 124, bulyan: at our-agr n_at 0 e 124 | val loss 2.0343 val acc 25.4464 best val_acc 25.446429
# discarded index []
# epoch: 125, bulyan: at our-agr n_at 0 e 125 | val loss 2.0326 val acc 22.8287 best val_acc 25.446429
# discarded index []
# epoch: 126, bulyan: at our-agr n_at 0 e 126 | val loss 2.0475 val acc 24.2898 best val_acc 25.446429
# discarded index []
# epoch: 127, bulyan: at our-agr n_at 0 e 127 | val loss 2.0432 val acc 24.3101 best val_acc 25.446429
# discarded index []
# epoch: 128, bulyan: at our-agr n_at 0 e 128 | val loss 2.2379 val acc 17.7151 best val_acc 25.446429
# discarded index []
# epoch: 129, bulyan: at our-agr n_at 0 e 129 | val loss 2.0698 val acc 24.3101 best val_acc 25.446429
# discarded index []
# epoch: 130, bulyan: at our-agr n_at 0 e 130 | val loss 2.0048 val acc 25.9537 best val_acc 25.953734
# discarded index []
# epoch: 131, bulyan: at our-agr n_at 0 e 131 | val loss 2.0748 val acc 21.9359 best val_acc 25.953734
# discarded index []
# epoch: 132, bulyan: at our-agr n_at 0 e 132 | val loss 2.0257 val acc 25.8726 best val_acc 25.953734
# discarded index []
# epoch: 133, bulyan: at our-agr n_at 0 e 133 | val loss 2.1544 val acc 19.9067 best val_acc 25.953734
# discarded index []
# epoch: 134, bulyan: at our-agr n_at 0 e 134 | val loss 2.0062 val acc 26.3393 best val_acc 26.339286
# discarded index []
# epoch: 135, bulyan: at our-agr n_at 0 e 135 | val loss 2.0294 val acc 24.3709 best val_acc 26.339286
# discarded index []
# epoch: 136, bulyan: at our-agr n_at 0 e 136 | val loss 2.1134 val acc 26.9278 best val_acc 26.927760
# discarded index []
# epoch: 137, bulyan: at our-agr n_at 0 e 137 | val loss 2.3064 val acc 14.2451 best val_acc 26.927760
# discarded index []
# epoch: 138, bulyan: at our-agr n_at 0 e 138 | val loss 2.2230 val acc 18.9529 best val_acc 26.927760
# discarded index []
# epoch: 139, bulyan: at our-agr n_at 0 e 139 | val loss 2.2049 val acc 20.7792 best val_acc 26.927760
# discarded index []
# epoch: 140, bulyan: at our-agr n_at 0 e 140 | val loss 2.2461 val acc 16.1323 best val_acc 26.927760
# discarded index []
# epoch: 141, bulyan: at our-agr n_at 0 e 141 | val loss 2.1509 val acc 18.6282 best val_acc 26.927760
# discarded index []
# epoch: 142, bulyan: at our-agr n_at 0 e 142 | val loss 2.1250 val acc 19.5211 best val_acc 26.927760
# discarded index []
# epoch: 143, bulyan: at our-agr n_at 0 e 143 | val loss 2.1617 val acc 18.5877 best val_acc 26.927760
# discarded index []
# epoch: 144, bulyan: at our-agr n_at 0 e 144 | val loss 2.0505 val acc 22.9505 best val_acc 26.927760
# discarded index []
# epoch: 145, bulyan: at our-agr n_at 0 e 145 | val loss 2.0499 val acc 23.5390 best val_acc 26.927760
# discarded index []
# epoch: 146, bulyan: at our-agr n_at 0 e 146 | val loss 2.1041 val acc 22.2200 best val_acc 26.927760
# discarded index []
# epoch: 147, bulyan: at our-agr n_at 0 e 147 | val loss 2.0388 val acc 24.6144 best val_acc 26.927760
# discarded index []
# epoch: 148, bulyan: at our-agr n_at 0 e 148 | val loss 2.1325 val acc 19.1761 best val_acc 26.927760
# discarded index []
# epoch: 149, bulyan: at our-agr n_at 0 e 149 | val loss 2.0597 val acc 22.7679 best val_acc 26.927760
# discarded index []
# epoch: 150, bulyan: at our-agr n_at 0 e 150 | val loss 2.1038 val acc 22.6664 best val_acc 26.927760
# discarded index []
# epoch: 151, bulyan: at our-agr n_at 0 e 151 | val loss 2.0510 val acc 24.3709 best val_acc 26.927760
# discarded index []
# epoch: 152, bulyan: at our-agr n_at 0 e 152 | val loss 2.1347 val acc 21.3271 best val_acc 26.927760
# discarded index []
# epoch: 153, bulyan: at our-agr n_at 0 e 153 | val loss 2.0319 val acc 23.9042 best val_acc 26.927760
# discarded index []
# epoch: 154, bulyan: at our-agr n_at 0 e 154 | val loss 2.0348 val acc 26.8060 best val_acc 26.927760
# discarded index []
# epoch: 155, bulyan: at our-agr n_at 0 e 155 | val loss 2.0098 val acc 28.0844 best val_acc 28.084416
# discarded index []
# epoch: 156, bulyan: at our-agr n_at 0 e 156 | val loss 2.1291 val acc 22.0373 best val_acc 28.084416
# discarded index []
# epoch: 157, bulyan: at our-agr n_at 0 e 157 | val loss 2.0287 val acc 26.2378 best val_acc 28.084416
# discarded index []
# epoch: 158, bulyan: at our-agr n_at 0 e 158 | val loss 2.0410 val acc 24.1680 best val_acc 28.084416
# discarded index []
# epoch: 159, bulyan: at our-agr n_at 0 e 159 | val loss 2.0136 val acc 26.6234 best val_acc 28.084416
# discarded index []
# epoch: 160, bulyan: at our-agr n_at 0 e 160 | val loss 2.1130 val acc 22.5649 best val_acc 28.084416
# discarded index []
# epoch: 161, bulyan: at our-agr n_at 0 e 161 | val loss 1.9879 val acc 26.5219 best val_acc 28.084416
# discarded index []
# epoch: 162, bulyan: at our-agr n_at 0 e 162 | val loss 2.0115 val acc 25.9334 best val_acc 28.084416
# discarded index []
# epoch: 163, bulyan: at our-agr n_at 0 e 163 | val loss 2.0186 val acc 27.8612 best val_acc 28.084416
# discarded index []
# epoch: 164, bulyan: at our-agr n_at 0 e 164 | val loss 2.1783 val acc 18.9935 best val_acc 28.084416
# discarded index []
# epoch: 165, bulyan: at our-agr n_at 0 e 165 | val loss 2.0690 val acc 23.2346 best val_acc 28.084416
# discarded index []
# epoch: 166, bulyan: at our-agr n_at 0 e 166 | val loss 1.9975 val acc 26.5219 best val_acc 28.084416
# discarded index []
# epoch: 167, bulyan: at our-agr n_at 0 e 167 | val loss 1.9882 val acc 26.0349 best val_acc 28.084416
# discarded index []
# epoch: 168, bulyan: at our-agr n_at 0 e 168 | val loss 2.1245 val acc 22.1591 best val_acc 28.084416
# discarded index []
# epoch: 169, bulyan: at our-agr n_at 0 e 169 | val loss 1.9578 val acc 29.5657 best val_acc 29.565747
# discarded index []
# epoch: 170, bulyan: at our-agr n_at 0 e 170 | val loss 1.9000 val acc 29.8701 best val_acc 29.870130
# discarded index []
# epoch: 171, bulyan: at our-agr n_at 0 e 171 | val loss 1.8970 val acc 30.9862 best val_acc 30.986201
# discarded index []
# epoch: 172, bulyan: at our-agr n_at 0 e 172 | val loss 1.9329 val acc 30.1948 best val_acc 30.986201
# discarded index []
# epoch: 173, bulyan: at our-agr n_at 0 e 173 | val loss 2.0985 val acc 20.2719 best val_acc 30.986201
# discarded index []
# epoch: 174, bulyan: at our-agr n_at 0 e 174 | val loss 2.0098 val acc 26.7248 best val_acc 30.986201
# discarded index []
# epoch: 175, bulyan: at our-agr n_at 0 e 175 | val loss 2.0716 val acc 21.1445 best val_acc 30.986201
# discarded index []
# epoch: 176, bulyan: at our-agr n_at 0 e 176 | val loss 2.0340 val acc 25.2232 best val_acc 30.986201
# discarded index []
# epoch: 177, bulyan: at our-agr n_at 0 e 177 | val loss 2.1875 val acc 20.2719 best val_acc 30.986201
# discarded index []
# epoch: 178, bulyan: at our-agr n_at 0 e 178 | val loss 2.1242 val acc 19.5820 best val_acc 30.986201
# discarded index []
# epoch: 179, bulyan: at our-agr n_at 0 e 179 | val loss 2.1176 val acc 22.8084 best val_acc 30.986201
# discarded index []
# epoch: 180, bulyan: at our-agr n_at 0 e 180 | val loss 2.0483 val acc 26.1364 best val_acc 30.986201
# discarded index []
# epoch: 181, bulyan: at our-agr n_at 0 e 181 | val loss 2.1607 val acc 19.3994 best val_acc 30.986201
# discarded index []
# epoch: 182, bulyan: at our-agr n_at 0 e 182 | val loss 1.9689 val acc 27.4959 best val_acc 30.986201
# discarded index []
# epoch: 183, bulyan: at our-agr n_at 0 e 183 | val loss 1.9105 val acc 28.0032 best val_acc 30.986201
# discarded index []
# epoch: 184, bulyan: at our-agr n_at 0 e 184 | val loss 1.8682 val acc 31.8385 best val_acc 31.838474
# discarded index []
# epoch: 185, bulyan: at our-agr n_at 0 e 185 | val loss 1.8622 val acc 29.9919 best val_acc 31.838474
# discarded index []
# epoch: 186, bulyan: at our-agr n_at 0 e 186 | val loss 1.8415 val acc 32.0617 best val_acc 32.061688
# discarded index []
# epoch: 187, bulyan: at our-agr n_at 0 e 187 | val loss 1.8749 val acc 28.7946 best val_acc 32.061688
# discarded index []
# epoch: 188, bulyan: at our-agr n_at 0 e 188 | val loss 1.9581 val acc 26.7248 best val_acc 32.061688
# discarded index []
# epoch: 189, bulyan: at our-agr n_at 0 e 189 | val loss 2.0170 val acc 23.7419 best val_acc 32.061688
# discarded index []
# epoch: 190, bulyan: at our-agr n_at 0 e 190 | val loss 2.0254 val acc 25.6696 best val_acc 32.061688
# discarded index []
# epoch: 191, bulyan: at our-agr n_at 0 e 191 | val loss 1.9619 val acc 28.0235 best val_acc 32.061688
# discarded index []
# epoch: 192, bulyan: at our-agr n_at 0 e 192 | val loss 2.1243 val acc 19.5008 best val_acc 32.061688
# discarded index []
# epoch: 193, bulyan: at our-agr n_at 0 e 193 | val loss 1.9053 val acc 27.7597 best val_acc 32.061688
# discarded index []
# epoch: 194, bulyan: at our-agr n_at 0 e 194 | val loss 1.9071 val acc 30.0122 best val_acc 32.061688
# discarded index []
# epoch: 195, bulyan: at our-agr n_at 0 e 195 | val loss 1.8951 val acc 27.6380 best val_acc 32.061688
# discarded index []
# epoch: 196, bulyan: at our-agr n_at 0 e 196 | val loss 2.0452 val acc 25.3653 best val_acc 32.061688
# discarded index []
# epoch: 197, bulyan: at our-agr n_at 0 e 197 | val loss 1.9604 val acc 27.5568 best val_acc 32.061688
# discarded index []
# epoch: 198, bulyan: at our-agr n_at 0 e 198 | val loss 2.0012 val acc 24.1477 best val_acc 32.061688
# discarded index []
# epoch: 199, bulyan: at our-agr n_at 0 e 199 | val loss 1.8967 val acc 29.9716 best val_acc 32.061688
# discarded index []
# epoch: 200, bulyan: at our-agr n_at 0 e 200 | val loss 1.9744 val acc 26.5828 best val_acc 32.061688
# discarded index []
# epoch: 201, bulyan: at our-agr n_at 0 e 201 | val loss 1.8368 val acc 28.6932 best val_acc 32.061688
# discarded index []
# epoch: 202, bulyan: at our-agr n_at 0 e 202 | val loss 1.8154 val acc 30.6209 best val_acc 32.061688
# discarded index []
# epoch: 203, bulyan: at our-agr n_at 0 e 203 | val loss 1.7716 val acc 35.2476 best val_acc 35.247565
# discarded index []
# epoch: 204, bulyan: at our-agr n_at 0 e 204 | val loss 1.7899 val acc 31.6964 best val_acc 35.247565
# discarded index []
# epoch: 205, bulyan: at our-agr n_at 0 e 205 | val loss 1.8923 val acc 32.6907 best val_acc 35.247565
# discarded index []
# epoch: 206, bulyan: at our-agr n_at 0 e 206 | val loss 2.1647 val acc 16.9237 best val_acc 35.247565
# discarded index []
# epoch: 207, bulyan: at our-agr n_at 0 e 207 | val loss 1.8486 val acc 29.5860 best val_acc 35.247565
# discarded index []
# epoch: 208, bulyan: at our-agr n_at 0 e 208 | val loss 1.8274 val acc 31.5138 best val_acc 35.247565
# discarded index []
# epoch: 209, bulyan: at our-agr n_at 0 e 209 | val loss 1.9906 val acc 26.4205 best val_acc 35.247565
# discarded index []
# epoch: 210, bulyan: at our-agr n_at 0 e 210 | val loss 2.1099 val acc 23.0519 best val_acc 35.247565
# discarded index []
# epoch: 211, bulyan: at our-agr n_at 0 e 211 | val loss 2.0437 val acc 25.6696 best val_acc 35.247565
# discarded index []
# epoch: 212, bulyan: at our-agr n_at 0 e 212 | val loss 1.9746 val acc 27.8612 best val_acc 35.247565
# discarded index []
# epoch: 213, bulyan: at our-agr n_at 0 e 213 | val loss 1.9207 val acc 30.0731 best val_acc 35.247565
# discarded index []
# epoch: 214, bulyan: at our-agr n_at 0 e 214 | val loss 1.9365 val acc 27.5162 best val_acc 35.247565
# discarded index []
# epoch: 215, bulyan: at our-agr n_at 0 e 215 | val loss 1.8860 val acc 29.1599 best val_acc 35.247565
# discarded index []
# epoch: 216, bulyan: at our-agr n_at 0 e 216 | val loss 1.8390 val acc 30.8442 best val_acc 35.247565
# discarded index []
# epoch: 217, bulyan: at our-agr n_at 0 e 217 | val loss 1.8415 val acc 32.1429 best val_acc 35.247565
# discarded index []
# epoch: 218, bulyan: at our-agr n_at 0 e 218 | val loss 2.1788 val acc 19.3994 best val_acc 35.247565
# discarded index []
# epoch: 219, bulyan: at our-agr n_at 0 e 219 | val loss 1.9246 val acc 27.7800 best val_acc 35.247565
# discarded index []
# epoch: 220, bulyan: at our-agr n_at 0 e 220 | val loss 1.9172 val acc 29.4440 best val_acc 35.247565
# discarded index []
# epoch: 221, bulyan: at our-agr n_at 0 e 221 | val loss 1.9686 val acc 27.4351 best val_acc 35.247565
# discarded index []
# epoch: 222, bulyan: at our-agr n_at 0 e 222 | val loss 1.8500 val acc 30.9862 best val_acc 35.247565
# discarded index []
# epoch: 223, bulyan: at our-agr n_at 0 e 223 | val loss 1.8238 val acc 30.9050 best val_acc 35.247565
# discarded index []
# epoch: 224, bulyan: at our-agr n_at 0 e 224 | val loss 1.8013 val acc 32.7110 best val_acc 35.247565
# discarded index []
# epoch: 225, bulyan: at our-agr n_at 0 e 225 | val loss 1.8301 val acc 31.6153 best val_acc 35.247565
# discarded index []
# epoch: 226, bulyan: at our-agr n_at 0 e 226 | val loss 1.9566 val acc 26.9683 best val_acc 35.247565
# discarded index []
# epoch: 227, bulyan: at our-agr n_at 0 e 227 | val loss 2.0545 val acc 24.6753 best val_acc 35.247565
# discarded index []
# epoch: 228, bulyan: at our-agr n_at 0 e 228 | val loss 1.9730 val acc 23.1940 best val_acc 35.247565
# discarded index []
# epoch: 229, bulyan: at our-agr n_at 0 e 229 | val loss 1.9392 val acc 30.3369 best val_acc 35.247565
# discarded index []
# epoch: 230, bulyan: at our-agr n_at 0 e 230 | val loss 1.8468 val acc 32.0617 best val_acc 35.247565
# discarded index []
# epoch: 231, bulyan: at our-agr n_at 0 e 231 | val loss 1.9420 val acc 28.9570 best val_acc 35.247565
# discarded index []
# epoch: 232, bulyan: at our-agr n_at 0 e 232 | val loss 1.8324 val acc 31.7979 best val_acc 35.247565
# discarded index []
# epoch: 233, bulyan: at our-agr n_at 0 e 233 | val loss 1.8832 val acc 29.3425 best val_acc 35.247565
# discarded index []
# epoch: 234, bulyan: at our-agr n_at 0 e 234 | val loss 1.8317 val acc 34.0097 best val_acc 35.247565
# discarded index []
# epoch: 235, bulyan: at our-agr n_at 0 e 235 | val loss 1.8566 val acc 32.6907 best val_acc 35.247565
# discarded index []
# epoch: 236, bulyan: at our-agr n_at 0 e 236 | val loss 1.8452 val acc 33.2589 best val_acc 35.247565
# discarded index []
# epoch: 237, bulyan: at our-agr n_at 0 e 237 | val loss 2.0587 val acc 25.3856 best val_acc 35.247565
# discarded index []
# epoch: 238, bulyan: at our-agr n_at 0 e 238 | val loss 1.9034 val acc 28.8149 best val_acc 35.247565
# discarded index []
# epoch: 239, bulyan: at our-agr n_at 0 e 239 | val loss 1.7816 val acc 33.7865 best val_acc 35.247565
# discarded index []
# epoch: 240, bulyan: at our-agr n_at 0 e 240 | val loss 1.7366 val acc 36.1404 best val_acc 36.140422
# discarded index []
# epoch: 241, bulyan: at our-agr n_at 0 e 241 | val loss 1.7258 val acc 36.4245 best val_acc 36.424513
# discarded index []
# epoch: 242, bulyan: at our-agr n_at 0 e 242 | val loss 1.7586 val acc 35.4302 best val_acc 36.424513
# discarded index []
# epoch: 243, bulyan: at our-agr n_at 0 e 243 | val loss 1.9451 val acc 26.6843 best val_acc 36.424513
# discarded index []
# epoch: 244, bulyan: at our-agr n_at 0 e 244 | val loss 1.9745 val acc 30.7224 best val_acc 36.424513
# discarded index []
# epoch: 245, bulyan: at our-agr n_at 0 e 245 | val loss 2.0988 val acc 23.8231 best val_acc 36.424513
# discarded index []
# epoch: 246, bulyan: at our-agr n_at 0 e 246 | val loss 1.9599 val acc 27.5568 best val_acc 36.424513
# discarded index []
# epoch: 247, bulyan: at our-agr n_at 0 e 247 | val loss 1.8431 val acc 29.4034 best val_acc 36.424513
# discarded index []
# epoch: 248, bulyan: at our-agr n_at 0 e 248 | val loss 1.7726 val acc 33.0357 best val_acc 36.424513
# discarded index []
# epoch: 249, bulyan: at our-agr n_at 0 e 249 | val loss 1.7787 val acc 31.7167 best val_acc 36.424513
# discarded index []
# epoch: 250, bulyan: at our-agr n_at 0 e 250 | val loss 2.0205 val acc 25.3856 best val_acc 36.424513
# discarded index []
# epoch: 251, bulyan: at our-agr n_at 0 e 251 | val loss 1.8853 val acc 30.2557 best val_acc 36.424513
# discarded index []
# epoch: 252, bulyan: at our-agr n_at 0 e 252 | val loss 1.7497 val acc 35.4708 best val_acc 36.424513
# discarded index []
# epoch: 253, bulyan: at our-agr n_at 0 e 253 | val loss 1.8497 val acc 32.0211 best val_acc 36.424513
# discarded index []
# epoch: 254, bulyan: at our-agr n_at 0 e 254 | val loss 1.9963 val acc 26.9886 best val_acc 36.424513
# discarded index []
# epoch: 255, bulyan: at our-agr n_at 0 e 255 | val loss 2.0439 val acc 23.7622 best val_acc 36.424513
# discarded index []
# epoch: 256, bulyan: at our-agr n_at 0 e 256 | val loss 1.9438 val acc 29.8701 best val_acc 36.424513
# discarded index []
# epoch: 257, bulyan: at our-agr n_at 0 e 257 | val loss 1.9456 val acc 31.3515 best val_acc 36.424513
# discarded index []
# epoch: 258, bulyan: at our-agr n_at 0 e 258 | val loss 1.8259 val acc 31.8385 best val_acc 36.424513
# discarded index []
# epoch: 259, bulyan: at our-agr n_at 0 e 259 | val loss 1.8452 val acc 29.4034 best val_acc 36.424513
# discarded index []
# epoch: 260, bulyan: at our-agr n_at 0 e 260 | val loss 1.7275 val acc 34.3547 best val_acc 36.424513
# discarded index []
# epoch: 261, bulyan: at our-agr n_at 0 e 261 | val loss 1.7805 val acc 32.0617 best val_acc 36.424513
# discarded index []
# epoch: 262, bulyan: at our-agr n_at 0 e 262 | val loss 1.8053 val acc 34.4359 best val_acc 36.424513
# discarded index []
# epoch: 263, bulyan: at our-agr n_at 0 e 263 | val loss 1.7870 val acc 36.3433 best val_acc 36.424513
# discarded index []
# epoch: 264, bulyan: at our-agr n_at 0 e 264 | val loss 1.7173 val acc 36.9115 best val_acc 36.911526
# discarded index []
# epoch: 265, bulyan: at our-agr n_at 0 e 265 | val loss 1.7923 val acc 34.1315 best val_acc 36.911526
# discarded index []
# epoch: 266, bulyan: at our-agr n_at 0 e 266 | val loss 1.8570 val acc 31.8791 best val_acc 36.911526
# discarded index []
# epoch: 267, bulyan: at our-agr n_at 0 e 267 | val loss 1.8438 val acc 30.9456 best val_acc 36.911526
# discarded index []
# epoch: 268, bulyan: at our-agr n_at 0 e 268 | val loss 1.7510 val acc 34.8011 best val_acc 36.911526
# discarded index []
# epoch: 269, bulyan: at our-agr n_at 0 e 269 | val loss 1.7241 val acc 36.1810 best val_acc 36.911526
# discarded index []
# epoch: 270, bulyan: at our-agr n_at 0 e 270 | val loss 1.7434 val acc 35.5722 best val_acc 36.911526
# discarded index []
# epoch: 271, bulyan: at our-agr n_at 0 e 271 | val loss 1.9421 val acc 30.2557 best val_acc 36.911526
# discarded index []
# epoch: 272, bulyan: at our-agr n_at 0 e 272 | val loss 1.8403 val acc 31.0674 best val_acc 36.911526
# discarded index []
# epoch: 273, bulyan: at our-agr n_at 0 e 273 | val loss 1.8548 val acc 29.1599 best val_acc 36.911526
# discarded index []
# epoch: 274, bulyan: at our-agr n_at 0 e 274 | val loss 1.7279 val acc 36.5666 best val_acc 36.911526
# discarded index []
# epoch: 275, bulyan: at our-agr n_at 0 e 275 | val loss 1.7597 val acc 34.7200 best val_acc 36.911526
# discarded index []
# epoch: 276, bulyan: at our-agr n_at 0 e 276 | val loss 1.6362 val acc 40.0568 best val_acc 40.056818
# discarded index []
# epoch: 277, bulyan: at our-agr n_at 0 e 277 | val loss 1.6223 val acc 39.6713 best val_acc 40.056818
# discarded index []
# epoch: 278, bulyan: at our-agr n_at 0 e 278 | val loss 1.6487 val acc 38.4943 best val_acc 40.056818
# discarded index []
# epoch: 279, bulyan: at our-agr n_at 0 e 279 | val loss 1.6245 val acc 38.8799 best val_acc 40.056818
# discarded index []
# epoch: 280, bulyan: at our-agr n_at 0 e 280 | val loss 1.6466 val acc 38.4943 best val_acc 40.056818
# discarded index []
# epoch: 281, bulyan: at our-agr n_at 0 e 281 | val loss 1.6504 val acc 38.7581 best val_acc 40.056818
# discarded index []
# epoch: 282, bulyan: at our-agr n_at 0 e 282 | val loss 1.6442 val acc 39.2045 best val_acc 40.056818
# discarded index []
# epoch: 283, bulyan: at our-agr n_at 0 e 283 | val loss 1.8088 val acc 33.8068 best val_acc 40.056818
# discarded index []
# epoch: 284, bulyan: at our-agr n_at 0 e 284 | val loss 1.9294 val acc 29.3831 best val_acc 40.056818
# discarded index []
# epoch: 285, bulyan: at our-agr n_at 0 e 285 | val loss 1.8426 val acc 34.1518 best val_acc 40.056818
# discarded index []
# epoch: 286, bulyan: at our-agr n_at 0 e 286 | val loss 1.8468 val acc 29.5455 best val_acc 40.056818
# discarded index []
# epoch: 287, bulyan: at our-agr n_at 0 e 287 | val loss 1.7138 val acc 37.5203 best val_acc 40.056818
# discarded index []
# epoch: 288, bulyan: at our-agr n_at 0 e 288 | val loss 1.7663 val acc 35.2679 best val_acc 40.056818
# discarded index []
# epoch: 289, bulyan: at our-agr n_at 0 e 289 | val loss 1.7961 val acc 36.3231 best val_acc 40.056818
# discarded index []
# epoch: 290, bulyan: at our-agr n_at 0 e 290 | val loss 1.9940 val acc 25.7508 best val_acc 40.056818
# discarded index []
# epoch: 291, bulyan: at our-agr n_at 0 e 291 | val loss 1.8288 val acc 34.8823 best val_acc 40.056818
# discarded index []
# epoch: 292, bulyan: at our-agr n_at 0 e 292 | val loss 1.8734 val acc 33.0763 best val_acc 40.056818
# discarded index []
# epoch: 293, bulyan: at our-agr n_at 0 e 293 | val loss 1.7786 val acc 33.2995 best val_acc 40.056818
# discarded index []
# epoch: 294, bulyan: at our-agr n_at 0 e 294 | val loss 1.6941 val acc 38.5958 best val_acc 40.056818
# discarded index []
# epoch: 295, bulyan: at our-agr n_at 0 e 295 | val loss 1.7108 val acc 37.6826 best val_acc 40.056818
# discarded index []
# epoch: 296, bulyan: at our-agr n_at 0 e 296 | val loss 1.8412 val acc 32.3864 best val_acc 40.056818
# discarded index []
# epoch: 297, bulyan: at our-agr n_at 0 e 297 | val loss 1.7922 val acc 31.4935 best val_acc 40.056818
# discarded index []
# epoch: 298, bulyan: at our-agr n_at 0 e 298 | val loss 1.7936 val acc 32.4269 best val_acc 40.056818
# discarded index []
# epoch: 299, bulyan: at our-agr n_at 0 e 299 | val loss 1.7749 val acc 36.0187 best val_acc 40.056818
# discarded index []
# epoch: 300, bulyan: at our-agr n_at 0 e 300 | val loss 1.8497 val acc 32.5893 best val_acc 40.056818

# %%
import matplotlib.pyplot as plt

# Plotting the data
for col in ['loss', 'validation accuracy', 'best validation accuracy']:
    plt.plot(df['epoch'].tolist(), df[col].tolist())
    plt.title("no attack_"+col)
    plt.savefig('./no attack ' + col + '.png')
    plt.show()

# %% [markdown]
# ## Execute our attack + 10 attacker + our defense

# %%
batch_size=250
resume=0

schedule=[1000]

gamma=.5
opt = 'sgd'
fed_lr=0.5
criterion=nn.CrossEntropyLoss()
use_cuda = torch.cuda.is_available()

aggregation='bulyan'
multi_k = False
candidates = []

at_type='our-agr'
dev_type ='std'
n_attackers=[10]

arch='alexnet'
chkpt='./'+aggregation

past_mean = []
past_abs_sum = []
past_median = []
past_lower_quartile = []
past_upper_quartile = []
past_std = []


for n_attacker in n_attackers:
    epoch_num = 0
    best_global_acc = 0
    best_global_te_acc = 0

    torch.cuda.empty_cache()

    fed_model, _ = return_model(arch, 0.1, 0.9, parallel=False)
    optimizer_fed = SGD(fed_model.parameters(), lr=fed_lr)

    df = pd.DataFrame(columns = ['epoch', 'loss', 'validation accuracy', 'best validation accuracy'])

    ####
    history = torch.zeros((n_users, nepochs + 1), dtype=torch.float32).cuda()
    ####

    model_grads = []
    flag = False
    while epoch_num <= nepochs:
        user_grads=[]

        for i in range(n_users): # 50
            nbatches = user_tr_len[i]//batch_size

            inputs = user_train_data_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]
            targets = user_train_label_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]

            targets = targets.type(torch.LongTensor)

            inputs, targets = inputs.cuda(), targets.cuda()
            inputs, targets = torch.autograd.Variable(inputs), torch.autograd.Variable(targets)

            outputs = fed_model(inputs)
            loss = criterion(outputs, targets)
            fed_model.zero_grad()
            loss.backward(retain_graph=True)

            param_grad=[]
            for param in fed_model.parameters():
                param_grad=param.grad.data.view(-1) if not len(param_grad) else torch.cat((param_grad,param.grad.view(-1)))


            user_grads=param_grad[None, :] if len(user_grads)==0 else torch.cat((user_grads,param_grad[None,:]), 0)

        if epoch_num in schedule:
            for param_group in optimizer_fed.param_groups:
                param_group['lr'] *= gamma
                print('New learnin rate ', param_group['lr'])

        updates_abs_mean = user_grads.abs().mean(dim=1, keepdim=True)

        if n_attacker > 0:
            model_params = torch.cat([p.data.view(-1) for p in fed_model.parameters()])
            mal_updates = our_attack_mean(n_users, epoch_num, history, user_grads, model_params, n_attacker, arch, criterion, user_train_data_tensors, user_train_label_tensors)
            malicious_grads = torch.cat((mal_updates, user_grads[n_attacker:]), 0) # torch.Size([50, 2472266])
        else:   # No attack
            malicious_grads = user_grads

        if not (malicious_grads.shape[0]==50):
            print(malicious_grads.shape)

        updates_abs_mean = malicious_grads.abs().mean(dim=1, keepdim=True)

        history[:, epoch_num] = updates_abs_mean.squeeze()
        # agg_grads = no_defense_aggregation(malicious_grads)
        agg_grads = our_mean_defense(malicious_grads, n_attacker, history)

        del user_grads

        start_idx=0

        optimizer_fed.zero_grad()

        model_grads=[]

        for i, param in enumerate(fed_model.parameters()):
            param_=agg_grads[start_idx:start_idx+len(param.data.view(-1))].reshape(param.data.shape)
            start_idx=start_idx+len(param.data.view(-1))
            param_=param_.cuda()
            model_grads.append(param_)

        optimizer_fed.step(model_grads)

        val_loss, val_acc = test(val_data_tensor,val_label_tensor,fed_model,criterion,use_cuda)
        te_loss, te_acc = test(te_data_tensor,te_label_tensor, fed_model, criterion, use_cuda)

        is_best = best_global_acc < val_acc

        best_global_acc = max(best_global_acc, val_acc)

        if is_best:
            best_global_te_acc = te_acc


        print('epoch: %d, %s: at %s n_at %d e %d | val loss %.4f val acc %.4f best val_acc %f'%(epoch_num, aggregation, at_type, n_attacker, epoch_num, val_loss, val_acc, best_global_acc))
        new_row = pd.DataFrame([{
            'epoch': epoch_num,
            'loss': val_loss,
            'validation accuracy': val_acc,
            'best validation accuracy': best_global_acc
            }])
        df = pd.concat([df, new_row], ignore_index=True)
        df.to_csv('./our attack + 10 attacker + our defense.csv', index=False)

        if val_loss > 1000:
            print('val loss %f too high'%val_loss)
            break

        epoch_num+=1
# Out:
# discarded index [18, 39, 21, 47, 25, 29, 26, 42, 24, 49]
# epoch: 0, bulyan: at our-agr n_at 10 e 0 | val loss 2.3026 val acc 9.8620 best val_acc 9.862013
# C:\Users\Hizan\AppData\Local\Temp\ipykernel_3024\1099200655.py:132: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, new_row], ignore_index=True)
# discarded index [18, 39, 21, 29, 25, 35, 49, 42, 47, 48]
# epoch: 1, bulyan: at our-agr n_at 10 e 1 | val loss 2.3027 val acc 10.3084 best val_acc 10.308442
# discarded index [18, 39, 29, 26, 21, 45, 30, 0, 1, 2]
# epoch: 2, bulyan: at our-agr n_at 10 e 2 | val loss 2.3027 val acc 10.3084 best val_acc 10.308442
# discarded index [18, 39, 29, 26, 21, 25, 35, 49, 42, 47]
# epoch: 3, bulyan: at our-agr n_at 10 e 3 | val loss 2.3031 val acc 10.3084 best val_acc 10.308442
# discarded index [18, 39, 29, 26, 21, 25, 49, 35, 42, 47]
# epoch: 4, bulyan: at our-agr n_at 10 e 4 | val loss 2.3037 val acc 10.3084 best val_acc 10.308442
# discarded index [39, 18, 29, 26, 21, 49, 35, 42, 25, 47]
# epoch: 5, bulyan: at our-agr n_at 10 e 5 | val loss 2.3046 val acc 10.3084 best val_acc 10.308442
# discarded index [18, 39, 29, 26, 21, 30, 0, 1, 2, 3]
# epoch: 6, bulyan: at our-agr n_at 10 e 6 | val loss 2.3045 val acc 10.3084 best val_acc 10.308442
# discarded index [18, 39, 29, 26, 21, 30, 25, 35, 49, 42]
# epoch: 7, bulyan: at our-agr n_at 10 e 7 | val loss 2.3054 val acc 10.3084 best val_acc 10.308442
# discarded index [18, 39, 29, 26, 30, 21, 45, 0, 1, 2]
# epoch: 8, bulyan: at our-agr n_at 10 e 8 | val loss 2.3052 val acc 10.3084 best val_acc 10.308442
# discarded index [18, 39, 29, 26, 21, 30, 25, 35, 49, 42]
# epoch: 9, bulyan: at our-agr n_at 10 e 9 | val loss 2.3069 val acc 10.3084 best val_acc 10.308442
# discarded index [18, 39, 29, 26, 21, 30, 25, 35, 42, 49]
# epoch: 10, bulyan: at our-agr n_at 10 e 10 | val loss 2.3086 val acc 10.3084 best val_acc 10.308442
# discarded index [18, 39, 29, 26, 30, 21, 35, 25, 49, 42]
# epoch: 11, bulyan: at our-agr n_at 10 e 11 | val loss 2.3096 val acc 10.3084 best val_acc 10.308442
# discarded index [18, 39, 29, 26, 21, 30, 25, 35, 49, 42]
# epoch: 12, bulyan: at our-agr n_at 10 e 12 | val loss 2.3115 val acc 10.3084 best val_acc 10.308442
# discarded index [18, 39, 29, 21, 26, 30, 25, 35, 42, 49]
# epoch: 13, bulyan: at our-agr n_at 10 e 13 | val loss 2.3142 val acc 10.3084 best val_acc 10.308442
# discarded index [18, 39, 29, 26, 30, 21, 25, 35, 42, 49]
# epoch: 14, bulyan: at our-agr n_at 10 e 14 | val loss 2.3153 val acc 10.3084 best val_acc 10.308442
# discarded index [18, 39, 29, 21, 30, 26, 25, 35, 42, 49]
# epoch: 15, bulyan: at our-agr n_at 10 e 15 | val loss 2.3180 val acc 10.3084 best val_acc 10.308442
# discarded index [18, 39, 29, 21, 25, 35, 42, 26, 30, 49]
# epoch: 16, bulyan: at our-agr n_at 10 e 16 | val loss 2.3174 val acc 10.3084 best val_acc 10.308442
# discarded index [39, 18, 29, 35, 21, 25, 42, 13, 49, 17]
# epoch: 17, bulyan: at our-agr n_at 10 e 17 | val loss 2.3161 val acc 10.4302 best val_acc 10.430195
# discarded index [39, 18, 25, 21, 42, 13, 35, 24, 17, 40]
# epoch: 18, bulyan: at our-agr n_at 10 e 18 | val loss 2.3054 val acc 13.0885 best val_acc 13.088474
# discarded index [39, 18, 25, 35, 42, 13, 21, 17, 14, 40]
# epoch: 19, bulyan: at our-agr n_at 10 e 19 | val loss 2.2871 val acc 16.0106 best val_acc 16.010552
# discarded index [39, 18, 25, 30, 41, 35, 17, 47, 13, 42]
# epoch: 20, bulyan: at our-agr n_at 10 e 20 | val loss 2.2751 val acc 15.7873 best val_acc 16.010552
# discarded index [18, 41, 39, 21, 45, 24, 30, 23, 46, 25]
# epoch: 21, bulyan: at our-agr n_at 10 e 21 | val loss 2.2728 val acc 15.1989 best val_acc 16.010552
# discarded index [18, 41, 30, 46, 45, 39, 23, 29, 43, 21]
# epoch: 22, bulyan: at our-agr n_at 10 e 22 | val loss 2.3348 val acc 12.2159 best val_acc 16.010552
# discarded index [41, 18, 45, 30, 46, 23, 13, 24, 49, 39]
# epoch: 23, bulyan: at our-agr n_at 10 e 23 | val loss 2.6965 val acc 10.2881 best val_acc 16.010552
# discarded index [41, 18, 30, 13, 23, 45, 29, 39, 42, 24]
# epoch: 24, bulyan: at our-agr n_at 10 e 24 | val loss 4.7732 val acc 9.6794 best val_acc 16.010552

# %%
import matplotlib.pyplot as plt
import numpy as np

ne =  nepochs + 1

for j in range(10):
  plt.figure(figsize=(10, 6))
  x = np.arange(ne)
  for i in range(40):
      y = history[i+10]
      plt.plot(x, y, color='green')

  y = history[j]
  plt.plot(x, y, color='red')


  plt.title('history')
  plt.xlabel('epoch')
  plt.ylabel('mean')
  plt.legend()
  plt.grid(True)
  plt.savefig('./history_malicious_'+str(j)+'.png')
  plt.show()

# %%
ne = nepochs + 1

plt.figure(figsize=(10, 6))
x = np.arange(ne)
for i in range(40):
    y = history[i+10]
    plt.plot(x, y, color='green')

for i in range(10):
    y = history[i]
    plt.plot(x, y, color='red')

plt.title('history')
plt.xlabel('epoch')
plt.ylabel('mean')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Plotting the data
for col in ['loss', 'validation accuracy', 'best validation accuracy']:
    plt.plot(df['epoch'].tolist(), df[col].tolist())
    plt.title("our attack + 10 attacker + our defense_"+col)
    plt.savefig('./our attack + 10 attacker + our defense ' + col + '.png')
    plt.show()
