# %% [markdown]
# # The notebook contains
# ### Code for _Bulyan_ aggregation algorithm, *when gradient updates of benign clients are unknown to adversary*
# ### Evaluation of all of the attacks (Fang, LIE, and our SOTA AGR-tailored and AGR-agnstic) on Bulyan

# %% [markdown]
# ## Import packages

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
from __future__ import print_function
import argparse, os, sys, csv, shutil, time, random, operator, pickle, ast, math
import numpy as np
import pandas as pd
from torch.optim import Optimizer
import torch.nn.functional as F
import torch
import pickle
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data as data
import torch.multiprocessing as mp
import math
sys.path.insert(0,'./../utils/')
from logger import *
from eval import *
from misc import *

from cifar10_normal_train import *
from cifar10_util import *
from adam import Adam
from sgd import SGD

# %% [markdown]
# ## Data split
# Divide cifar10 data among 50 clients in Non-IID fashion using Dirichlet distribution
#
# Graph the distribution of classes for each user

# %%
import torchvision.transforms as transforms
import torchvision.datasets as datasets
data_loc='/mnt/nfs/work1/amir/vshejwalkar/cifar10_data/'
# load the train dataset

train_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ])

cifar10_train = datasets.CIFAR10(root=data_loc, train=True, download=True, transform=train_transform)

cifar10_test = datasets.CIFAR10(root=data_loc, train=False, download=True, transform=train_transform)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
total_tr_len = len(cifar10_train)

X={}
Y=[]
for i in range(len(cifar10_train)):
    data = cifar10_train[i][0].numpy()
    label = cifar10_train[i][1]

    if label in X:
        X[label].append(data)
    else:
        X[label] = []
        X[label].append(data)
        Y.append(label)

for label in X:
    X[label] = np.array(X[label])
Y=np.array(Y)

alpha = 1
n_users = 50

# %%
user_train_data_non_tensors = [[] for _ in range(n_users)]
user_train_label_non_tensors = [[] for _ in range(n_users)]

for label in Y:
    alpha_list = [alpha for _ in range(n_users)]
    probs = np.random.dirichlet(alpha_list)

    taken_index = 0

    for i, prob in enumerate(probs):
        if i == n_users - 1:
            user_train_data_non_tensors[i].extend(X[label][taken_index:])
            user_train_label_non_tensors[i].extend([label for _ in range(len(X[label]) - taken_index)])
        else:
            n_sample = math.floor(prob * len(X[label]))

            user_train_data_non_tensors[i].extend(X[label][taken_index : taken_index + n_sample])
            user_train_label_non_tensors[i].extend([label for _ in range(n_sample)])
            taken_index += n_sample

user_train_data_tensors = []
user_train_label_tensors = []

user_tr_len = []

for i in range(n_users):

    if len(user_train_data_non_tensors[i]) != len(user_train_label_non_tensors[i]):
        sys.exit(f"Shape does not match user_train_data_non_tensors[i] hsa {len(user_train_data_non_tensors[i])}, while user_train_label_non_tensors[i] has {len(user_train_label_non_tensors[i])}")


    num_data = len(user_train_data_non_tensors[i])
    user_tr_len.append(num_data)

    user_train_data_tensors.append(torch.from_numpy(np.array(user_train_data_non_tensors[i])).type(torch.FloatTensor))
    user_train_label_tensors.append(torch.from_numpy(np.array(user_train_label_non_tensors[i])).type(torch.LongTensor))

    r=np.arange(num_data)

    np.random.shuffle(r)

    user_train_data_tensors[i] = user_train_data_tensors[i][r]
    user_train_label_tensors[i] = user_train_label_tensors[i][r]

    print(f'user {i} has {user_train_data_tensors[i].shape[0]} train data, and {user_train_label_tensors[i].shape[0]} train labels')
# Out:
# user 0 has 1134 train data, and 1134 train labels
# user 1 has 1249 train data, and 1249 train labels
# user 2 has 1330 train data, and 1330 train labels
# user 3 has 955 train data, and 955 train labels
# user 4 has 1002 train data, and 1002 train labels
# user 5 has 968 train data, and 968 train labels
# user 6 has 1726 train data, and 1726 train labels
# user 7 has 909 train data, and 909 train labels
# user 8 has 983 train data, and 983 train labels
# user 9 has 989 train data, and 989 train labels
# user 10 has 807 train data, and 807 train labels
# user 11 has 555 train data, and 555 train labels
# user 12 has 1069 train data, and 1069 train labels
# user 13 has 917 train data, and 917 train labels
# user 14 has 1237 train data, and 1237 train labels
# user 15 has 1166 train data, and 1166 train labels
# user 16 has 871 train data, and 871 train labels
# user 17 has 1059 train data, and 1059 train labels
# user 18 has 688 train data, and 688 train labels
# user 19 has 565 train data, and 565 train labels
# user 20 has 867 train data, and 867 train labels
# user 21 has 941 train data, and 941 train labels
# user 22 has 705 train data, and 705 train labels
# user 23 has 872 train data, and 872 train labels
# user 24 has 698 train data, and 698 train labels
# user 25 has 554 train data, and 554 train labels
# user 26 has 765 train data, and 765 train labels
# user 27 has 942 train data, and 942 train labels
# user 28 has 1027 train data, and 1027 train labels
# user 29 has 842 train data, and 842 train labels
# user 30 has 1033 train data, and 1033 train labels
# user 31 has 1247 train data, and 1247 train labels
# user 32 has 1875 train data, and 1875 train labels
# user 33 has 914 train data, and 914 train labels
# user 34 has 775 train data, and 775 train labels
# user 35 has 1974 train data, and 1974 train labels
# user 36 has 1247 train data, and 1247 train labels
# user 37 has 998 train data, and 998 train labels
# user 38 has 957 train data, and 957 train labels
# user 39 has 751 train data, and 751 train labels
# user 40 has 1147 train data, and 1147 train labels
# user 41 has 487 train data, and 487 train labels
# user 42 has 1269 train data, and 1269 train labels
# user 43 has 994 train data, and 994 train labels
# user 44 has 1061 train data, and 1061 train labels
# user 45 has 742 train data, and 742 train labels
# user 46 has 1094 train data, and 1094 train labels
# user 47 has 1056 train data, and 1056 train labels
# user 48 has 1012 train data, and 1012 train labels
# user 49 has 975 train data, and 975 train labels

# %%
X2 = []
Y2 = []

for i in range(len(cifar10_test)):
    X2.append(cifar10_test[i][0].numpy())
    Y2.append(cifar10_test[i][1])

X2=np.array(X2)
Y2=np.array(Y2)

half_index = len(X2) // 2

val_data= X2[:half_index]
val_label= Y2[:half_index]

te_data=X2[half_index:]
te_label=Y2[half_index:]

val_data_tensor=torch.from_numpy(val_data).type(torch.FloatTensor)
val_label_tensor=torch.from_numpy(val_label).type(torch.LongTensor)

te_data_tensor=torch.from_numpy(te_data).type(torch.FloatTensor)
te_label_tensor=torch.from_numpy(te_label).type(torch.LongTensor)

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# Example data
users = [f"user {i}" for i in range(50)]
labels = [f"label {i}" for i in range(10)]


percentages = []
for user_data in user_train_label_non_tensors:
    temp_holder = []
    for label in range(10):
        temp_holder.append(user_data.count(label))
    percentages.append(temp_holder)

percentages = np.array(percentages)

# Assuming 'percentages' is populated correctly as shown previously
# Convert percentages to cumulative sum for stacking
cumulative = np.cumsum(percentages, axis=1)

# Plot
fig, ax = plt.subplots(figsize=(10, 6))

# Colors for each ethnicity, ensuring there are enough colors for all labels
colors = plt.cm.Paired(range(len(labels))) # Repeating colors to match the number of labels

# Create stacked bars
for i in range(len(labels)):  # Iterate over the number of labels
    if i == 0:
        ax.bar(users, percentages[:, i], color=colors[i], label=labels[i])
    else:
        ax.bar(users, percentages[:, i], bottom=cumulative[:, i-1], color=colors[i], label=labels[i])

# Add some text for labels, title, and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage')
ax.set_title('Stacked Percentage Bar Chart by User and Label')
ax.set_xticks(np.arange(len(users)))
ax.set_xticklabels(users, rotation=90)  # Rotate labels if needed
ax.legend()


plt.savefig('./non_iid_user_label_distribution.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Our Aggregation Function

# %%
def our_mean_defense(all_updates, n_attackers, history_updates):
    discarded_history = get_discarded_index(n_attackers, history_updates)

    mask = torch.ones(all_updates.size(0), dtype=torch.bool)
    mask[discarded_history] = False
    remaining_updates = all_updates[mask]

    print('discarded index', discarded_history)

    return torch.nanmean(remaining_updates, dim=0)

####
def euclidean_distance(row1, row2):
    return torch.sqrt(torch.sum((row1 - row2) ** 2))
####

def get_discarded_index(n_attackers, history_updates):
    n_users = history_updates.shape[0]

    ####
    distance_matrix = [[0 if i == j else euclidean_distance(history_updates[i, :], history_updates[j, :]) for j in range(n_users)] for i in range(n_users)]
    ####

    sum_of_distances = [sum(row) for row in distance_matrix]

    discarded_history = []
    for _ in range(n_attackers):
        max_distance = max(sum_of_distances)
        index_of_max_distance = sum_of_distances.index(max_distance)
        discarded_history.append(index_of_max_distance)

        for i in range(n_users):
            sum_of_distances[i] -= distance_matrix[i][index_of_max_distance]
        sum_of_distances[index_of_max_distance] = -1

    return discarded_history

# %% [markdown]
# ## Code for no defense aggregation algorithm

# %%
def no_defense_aggregation(user_grads):
    return torch.nanmean(user_grads, dim=0)

# %% [markdown]
# ## our_attack_mean
# $ argmin_\theta(\ -L(\theta_{attacker(s)}) + \lambda_1 |\bar{\theta_{abs\ mean\ benige\ users}} - \bar{\theta_{abs\ attacker(s)}}|$

# %%
device = 'cuda:0'
def check_condition(lambda1, prev_grad, loss_grad, history, all_updates, n_users, n_attacker, epoch_num):
    loss_grad = loss_grad.to(device)
    prev_grad = prev_grad.to(device)
    new_grad = lambda1 * (loss_grad + prev_grad)

    ####
    mal_updates = torch.stack([new_grad.clone().detach() for _ in range(n_attacker)])
    malicious_grads = torch.cat((mal_updates, all_updates[n_attacker:]), 0)

    history_updates = history.clone().detach()
    history_updates[:, epoch_num] = malicious_grads.abs().mean(dim=1, keepdim=True).squeeze()
    ####

    discarded_history = get_discarded_index(n_attacker+2, history_updates)

    detected_mal = len([item for item in discarded_history if item < 10])
    return detected_mal / len(discarded_history) <= n_attacker / n_users

def find_upper_bound(lambda1, prev_grad, loss_grad, history, all_updates, n_users, n_attacker, epoch_num):
    while check_condition(lambda1, prev_grad, loss_grad, history, all_updates, n_users, n_attacker, epoch_num):
        lambda1 *= 2  # Exponentially increase lambda
    return lambda1


def projection(prev_grad, loss_grad, history, all_updates, n_users, n_attacker, epoch_num):
    updates_abs_mean = all_updates.abs().mean(dim=1, keepdim=True)
    median_value = torch.median(updates_abs_mean).item()

    ####
    history_updates = history.clone().detach()
    history_updates[:, epoch_num] = updates_abs_mean.mean(dim=1, keepdim=True).squeeze()
    ####

    loss_grad = loss_grad.to(device)
    prev_grad = prev_grad.to(device)

    lambda_low = median_value/(prev_grad + loss_grad).abs().mean().item()
    lambda_high = find_upper_bound(lambda_low, prev_grad, loss_grad, history_updates, all_updates, n_users, n_attacker, epoch_num)
    if lambda_high < lambda_low:
        lambda_high = lambda_low
        print("SHOULD NEVER REACH THIS LINE")
        print('lambda_low: ', lambda_low, ' lambda_high: ', lambda_high)
    tolerance = 1e-6

    iterations_count = 0
    while lambda_high - lambda_low > tolerance and iterations_count < 10:
        lambda_mid = (lambda_low + lambda_high) / 2
        if check_condition(lambda_mid, prev_grad, loss_grad, history_updates, all_updates, n_users, n_attacker, epoch_num):
            lambda_low = lambda_mid
        else:
            lambda_high = lambda_mid
        iterations_count += 1

    lambda1 = lambda_low

    return lambda1 * (prev_grad + loss_grad)

def our_attack_mean(n_user, epoch_num, history_updates, all_updates, model_params, n_attacker, arch, criterion, user_train_data_tensors, user_train_label_tensors):
    attacker_tr_data_tensor = user_train_data_tensors[0].cuda()
    attacker_tr_label_tensor = user_train_label_tensors[0].cuda()

    fed_model, _ = return_model(arch, 0.1, 0.9, parallel=False)
    fed_model.eval()  # Ensure the model is in evaluation mode

    new_grad = -all_updates[0].clone().detach().requires_grad_(True)
    prev_grad = np.zeros(len(new_grad))
    new_grad = projection(torch.from_numpy(prev_grad), new_grad, history_updates, all_updates, n_user, n_attacker, epoch_num)

    for _ in range(5):
        outputs = fed_model(attacker_tr_data_tensor)
        loss = criterion(outputs, attacker_tr_label_tensor)

        loss.backward(retain_graph=True)
        param_grad = []
        for param in fed_model.parameters():
            param_grad.append(param.grad.view(-1).detach())

        param_grad = torch.cat(param_grad)
        prev_grad = new_grad
        new_grad = projection(prev_grad, param_grad, history_updates, all_updates, n_user, n_attacker, epoch_num)

        difference = torch.mean(torch.abs(new_grad - prev_grad)).item()
        if difference < 1e-6:
            # print("STOPPED! Difference is too small, stop finding best attack grad")
            break

        fed_model.zero_grad()

    result_attacker_grads = [new_grad.clone().detach() for _ in range(10)]
    return torch.stack(result_attacker_grads).cuda()

# %% [markdown]
# ## Set number of epochs

# %%
nepochs= 300

# %% [markdown]
# ## no defense

# %%
batch_size=250
resume=0

schedule=[1000]

gamma=.5
opt = 'sgd'
fed_lr=0.5
criterion=nn.CrossEntropyLoss()
use_cuda = torch.cuda.is_available()

aggregation='bulyan'
multi_k = False
candidates = []

at_type='our-agr'
dev_type ='std'
n_attackers=[10]

arch='alexnet'
chkpt='./'+aggregation

past_mean = []
past_abs_sum = []
past_median = []
past_lower_quartile = []
past_upper_quartile = []
past_std = []


for n_attacker in n_attackers:
    epoch_num = 0
    best_global_acc = 0
    best_global_te_acc = 0

    torch.cuda.empty_cache()

    fed_model, _ = return_model(arch, 0.1, 0.9, parallel=False)
    optimizer_fed = SGD(fed_model.parameters(), lr=fed_lr)

    df = pd.DataFrame(columns = ['epoch', 'loss', 'validation accuracy', 'best validation accuracy'])

    ####
    history = torch.zeros((n_users, nepochs + 1), dtype=torch.float32).cuda()
    ####

    model_grads = []
    flag = False
    while epoch_num <= nepochs:
        user_grads=[]

        for i in range(n_users): # 50
            nbatches = user_tr_len[i]//batch_size

            inputs = user_train_data_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]
            targets = user_train_label_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]

            targets = targets.type(torch.LongTensor)

            inputs, targets = inputs.cuda(), targets.cuda()
            inputs, targets = torch.autograd.Variable(inputs), torch.autograd.Variable(targets)

            outputs = fed_model(inputs)
            loss = criterion(outputs, targets)
            fed_model.zero_grad()
            loss.backward(retain_graph=True)

            param_grad=[]
            for param in fed_model.parameters():
                param_grad=param.grad.data.view(-1) if not len(param_grad) else torch.cat((param_grad,param.grad.view(-1)))


            user_grads=param_grad[None, :] if len(user_grads)==0 else torch.cat((user_grads,param_grad[None,:]), 0)

        if epoch_num in schedule:
            for param_group in optimizer_fed.param_groups:
                param_group['lr'] *= gamma
                print('New learnin rate ', param_group['lr'])

        updates_abs_mean = user_grads.abs().mean(dim=1, keepdim=True)

        if n_attacker > 0:
            model_params = torch.cat([p.data.view(-1) for p in fed_model.parameters()])
            mal_updates = our_attack_mean(n_users, epoch_num, history, user_grads, model_params, n_attacker, arch, criterion, user_train_data_tensors, user_train_label_tensors)
            malicious_grads = torch.cat((mal_updates, user_grads[n_attacker:]), 0) # torch.Size([50, 2472266])
        else:   # No attack
            malicious_grads = user_grads

        if not (malicious_grads.shape[0]==50):
            print(malicious_grads.shape)

        updates_abs_mean = malicious_grads.abs().mean(dim=1, keepdim=True)

        history[:, epoch_num] = updates_abs_mean.squeeze()
        agg_grads = no_defense_aggregation(malicious_grads)
        # agg_grads = our_mean_defense(malicious_grads, n_attacker, history)

        del user_grads

        start_idx=0

        optimizer_fed.zero_grad()

        model_grads=[]

        for i, param in enumerate(fed_model.parameters()):
            param_=agg_grads[start_idx:start_idx+len(param.data.view(-1))].reshape(param.data.shape)
            start_idx=start_idx+len(param.data.view(-1))
            param_=param_.cuda()
            model_grads.append(param_)

        optimizer_fed.step(model_grads)

        val_loss, val_acc = test(val_data_tensor,val_label_tensor,fed_model,criterion,use_cuda)
        te_loss, te_acc = test(te_data_tensor,te_label_tensor, fed_model, criterion, use_cuda)

        is_best = best_global_acc < val_acc

        best_global_acc = max(best_global_acc, val_acc)

        if is_best:
            best_global_te_acc = te_acc


        print('epoch: %d, %s: at %s n_at %d e %d | val loss %.4f val acc %.4f best val_acc %f'%(epoch_num, aggregation, at_type, n_attacker, epoch_num, val_loss, val_acc, best_global_acc))
        new_row = pd.DataFrame([{
            'epoch': epoch_num,
            'loss': val_loss,
            'validation accuracy': val_acc,
            'best validation accuracy': best_global_acc
            }])
        df = pd.concat([df, new_row], ignore_index=True)
        df.to_csv('./our attack + 10 attacker + our defense.csv', index=False)

        if val_loss > 1000:
            print('val loss %f too high'%val_loss)
            break

        epoch_num+=1
# Out:
# c:\Users\Hizan\Desktop\CPEN497-FL\CPEN497-499\sgd.py:109: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\python_arg_parser.cpp:1630.)
#   p.data.add_(-group['lr'], d_p)
# C:\Users\Hizan\AppData\Local\Temp\ipykernel_20104\2633842343.py:132: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, new_row], ignore_index=True)
# epoch: 0, bulyan: at our-agr n_at 10 e 0 | val loss 2.3027 val acc 10.2273 best val_acc 10.227273
# epoch: 1, bulyan: at our-agr n_at 10 e 1 | val loss 2.3025 val acc 10.2273 best val_acc 10.227273
# epoch: 2, bulyan: at our-agr n_at 10 e 2 | val loss 2.3025 val acc 10.2273 best val_acc 10.227273
# epoch: 3, bulyan: at our-agr n_at 10 e 3 | val loss 2.3024 val acc 10.2273 best val_acc 10.227273
# epoch: 4, bulyan: at our-agr n_at 10 e 4 | val loss 2.3025 val acc 10.2273 best val_acc 10.227273
# epoch: 5, bulyan: at our-agr n_at 10 e 5 | val loss 2.3026 val acc 10.2273 best val_acc 10.227273
# epoch: 6, bulyan: at our-agr n_at 10 e 6 | val loss 2.3026 val acc 10.2273 best val_acc 10.227273
# epoch: 7, bulyan: at our-agr n_at 10 e 7 | val loss 2.3025 val acc 10.2273 best val_acc 10.227273
# epoch: 8, bulyan: at our-agr n_at 10 e 8 | val loss 2.3026 val acc 10.2273 best val_acc 10.227273
# epoch: 9, bulyan: at our-agr n_at 10 e 9 | val loss 2.3026 val acc 10.2273 best val_acc 10.227273
# epoch: 10, bulyan: at our-agr n_at 10 e 10 | val loss 2.3027 val acc 10.2273 best val_acc 10.227273
# epoch: 11, bulyan: at our-agr n_at 10 e 11 | val loss 2.3028 val acc 10.2273 best val_acc 10.227273
# epoch: 12, bulyan: at our-agr n_at 10 e 12 | val loss 2.3028 val acc 10.2273 best val_acc 10.227273
# epoch: 13, bulyan: at our-agr n_at 10 e 13 | val loss 2.3026 val acc 10.2273 best val_acc 10.227273
# epoch: 14, bulyan: at our-agr n_at 10 e 14 | val loss 2.3024 val acc 10.2273 best val_acc 10.227273
# epoch: 15, bulyan: at our-agr n_at 10 e 15 | val loss 2.3022 val acc 10.2273 best val_acc 10.227273
# epoch: 16, bulyan: at our-agr n_at 10 e 16 | val loss 2.3020 val acc 10.2273 best val_acc 10.227273
# epoch: 17, bulyan: at our-agr n_at 10 e 17 | val loss 2.3014 val acc 10.2273 best val_acc 10.227273
# epoch: 18, bulyan: at our-agr n_at 10 e 18 | val loss 2.3009 val acc 10.2273 best val_acc 10.227273
# epoch: 19, bulyan: at our-agr n_at 10 e 19 | val loss 2.3000 val acc 10.2273 best val_acc 10.227273
# epoch: 20, bulyan: at our-agr n_at 10 e 20 | val loss 2.2990 val acc 10.3896 best val_acc 10.389610
# epoch: 21, bulyan: at our-agr n_at 10 e 21 | val loss 2.2970 val acc 11.3028 best val_acc 11.302760
# epoch: 22, bulyan: at our-agr n_at 10 e 22 | val loss 2.2940 val acc 11.4042 best val_acc 11.404221
# epoch: 23, bulyan: at our-agr n_at 10 e 23 | val loss 2.2918 val acc 12.5609 best val_acc 12.560877
# epoch: 24, bulyan: at our-agr n_at 10 e 24 | val loss 2.2884 val acc 11.3028 best val_acc 12.560877
# epoch: 25, bulyan: at our-agr n_at 10 e 25 | val loss 2.2851 val acc 13.8393 best val_acc 13.839286
# epoch: 26, bulyan: at our-agr n_at 10 e 26 | val loss 2.2875 val acc 15.1380 best val_acc 15.137987
# epoch: 27, bulyan: at our-agr n_at 10 e 27 | val loss 2.2832 val acc 15.2394 best val_acc 15.239448
# epoch: 28, bulyan: at our-agr n_at 10 e 28 | val loss 2.2770 val acc 15.1583 best val_acc 15.239448
# epoch: 29, bulyan: at our-agr n_at 10 e 29 | val loss 2.2491 val acc 15.5032 best val_acc 15.503247
# epoch: 30, bulyan: at our-agr n_at 10 e 30 | val loss 2.3096 val acc 14.1234 best val_acc 15.503247
# epoch: 31, bulyan: at our-agr n_at 10 e 31 | val loss 2.3270 val acc 10.9984 best val_acc 15.503247
# epoch: 32, bulyan: at our-agr n_at 10 e 32 | val loss 2.2571 val acc 12.2971 best val_acc 15.503247
# epoch: 33, bulyan: at our-agr n_at 10 e 33 | val loss 2.2318 val acc 15.6047 best val_acc 15.604708
# epoch: 34, bulyan: at our-agr n_at 10 e 34 | val loss 2.2484 val acc 16.3149 best val_acc 16.314935
# epoch: 35, bulyan: at our-agr n_at 10 e 35 | val loss 2.2819 val acc 14.9148 best val_acc 16.314935
# epoch: 36, bulyan: at our-agr n_at 10 e 36 | val loss 2.2270 val acc 13.1696 best val_acc 16.314935
# epoch: 37, bulyan: at our-agr n_at 10 e 37 | val loss 2.2039 val acc 18.7297 best val_acc 18.729708
# epoch: 38, bulyan: at our-agr n_at 10 e 38 | val loss 2.1473 val acc 19.0747 best val_acc 19.074675
# epoch: 39, bulyan: at our-agr n_at 10 e 39 | val loss 2.1622 val acc 17.9180 best val_acc 19.074675
# epoch: 40, bulyan: at our-agr n_at 10 e 40 | val loss 2.1339 val acc 17.4919 best val_acc 19.074675
# epoch: 41, bulyan: at our-agr n_at 10 e 41 | val loss 2.3591 val acc 18.1615 best val_acc 19.074675
# epoch: 42, bulyan: at our-agr n_at 10 e 42 | val loss 2.9300 val acc 10.4708 best val_acc 19.074675
# epoch: 43, bulyan: at our-agr n_at 10 e 43 | val loss 2.4956 val acc 10.2070 best val_acc 19.074675
# epoch: 44, bulyan: at our-agr n_at 10 e 44 | val loss 2.4381 val acc 10.6331 best val_acc 19.074675
# epoch: 45, bulyan: at our-agr n_at 10 e 45 | val loss 2.3777 val acc 13.5349 best val_acc 19.074675
# epoch: 46, bulyan: at our-agr n_at 10 e 46 | val loss 2.3485 val acc 10.9375 best val_acc 19.074675
# epoch: 47, bulyan: at our-agr n_at 10 e 47 | val loss 2.3358 val acc 11.9318 best val_acc 19.074675
# epoch: 48, bulyan: at our-agr n_at 10 e 48 | val loss 2.3557 val acc 10.5317 best val_acc 19.074675
# epoch: 49, bulyan: at our-agr n_at 10 e 49 | val loss 2.3371 val acc 14.4481 best val_acc 19.074675
# epoch: 50, bulyan: at our-agr n_at 10 e 50 | val loss 2.3824 val acc 10.1664 best val_acc 19.074675
# epoch: 51, bulyan: at our-agr n_at 10 e 51 | val loss 2.3314 val acc 11.5463 best val_acc 19.074675
# epoch: 52, bulyan: at our-agr n_at 10 e 52 | val loss 2.3586 val acc 10.0244 best val_acc 19.074675
# epoch: 53, bulyan: at our-agr n_at 10 e 53 | val loss 2.3380 val acc 13.7784 best val_acc 19.074675
# epoch: 54, bulyan: at our-agr n_at 10 e 54 | val loss 2.5206 val acc 9.6794 best val_acc 19.074675
# epoch: 55, bulyan: at our-agr n_at 10 e 55 | val loss 2.4528 val acc 11.4651 best val_acc 19.074675
# epoch: 56, bulyan: at our-agr n_at 10 e 56 | val loss 2.3271 val acc 10.1664 best val_acc 19.074675
# epoch: 57, bulyan: at our-agr n_at 10 e 57 | val loss 2.3286 val acc 10.0852 best val_acc 19.074675
# epoch: 58, bulyan: at our-agr n_at 10 e 58 | val loss 2.2859 val acc 13.2508 best val_acc 19.074675
# epoch: 59, bulyan: at our-agr n_at 10 e 59 | val loss 2.3088 val acc 9.9026 best val_acc 19.074675
# epoch: 60, bulyan: at our-agr n_at 10 e 60 | val loss 2.2672 val acc 12.4391 best val_acc 19.074675
# epoch: 61, bulyan: at our-agr n_at 10 e 61 | val loss 2.5421 val acc 16.1120 best val_acc 19.074675
# epoch: 62, bulyan: at our-agr n_at 10 e 62 | val loss 2.5609 val acc 10.2476 best val_acc 19.074675
# epoch: 63, bulyan: at our-agr n_at 10 e 63 | val loss 2.3797 val acc 15.2800 best val_acc 19.074675
# epoch: 64, bulyan: at our-agr n_at 10 e 64 | val loss 2.3251 val acc 15.6047 best val_acc 19.074675
# epoch: 65, bulyan: at our-agr n_at 10 e 65 | val loss 2.3043 val acc 13.8393 best val_acc 19.074675
# epoch: 66, bulyan: at our-agr n_at 10 e 66 | val loss 2.4225 val acc 15.0771 best val_acc 19.074675
# epoch: 67, bulyan: at our-agr n_at 10 e 67 | val loss 2.2936 val acc 15.5438 best val_acc 19.074675
# epoch: 68, bulyan: at our-agr n_at 10 e 68 | val loss 2.3329 val acc 15.4627 best val_acc 19.074675
# epoch: 69, bulyan: at our-agr n_at 10 e 69 | val loss 2.2944 val acc 12.2768 best val_acc 19.074675
# epoch: 70, bulyan: at our-agr n_at 10 e 70 | val loss 2.3024 val acc 15.6047 best val_acc 19.074675
# epoch: 71, bulyan: at our-agr n_at 10 e 71 | val loss 2.2501 val acc 17.6339 best val_acc 19.074675
# epoch: 72, bulyan: at our-agr n_at 10 e 72 | val loss 2.2686 val acc 15.9091 best val_acc 19.074675
# epoch: 73, bulyan: at our-agr n_at 10 e 73 | val loss 2.2759 val acc 12.9058 best val_acc 19.074675
# epoch: 74, bulyan: at our-agr n_at 10 e 74 | val loss 2.3731 val acc 16.7614 best val_acc 19.074675
# epoch: 75, bulyan: at our-agr n_at 10 e 75 | val loss 2.4085 val acc 14.6510 best val_acc 19.074675
# epoch: 76, bulyan: at our-agr n_at 10 e 76 | val loss 2.3405 val acc 14.6104 best val_acc 19.074675
# epoch: 77, bulyan: at our-agr n_at 10 e 77 | val loss 2.2993 val acc 15.2597 best val_acc 19.074675
# epoch: 78, bulyan: at our-agr n_at 10 e 78 | val loss 2.2531 val acc 18.6891 best val_acc 19.074675
# epoch: 79, bulyan: at our-agr n_at 10 e 79 | val loss 2.1726 val acc 14.9959 best val_acc 19.074675
# epoch: 80, bulyan: at our-agr n_at 10 e 80 | val loss 2.3930 val acc 17.0657 best val_acc 19.074675
# epoch: 81, bulyan: at our-agr n_at 10 e 81 | val loss 2.3843 val acc 15.6047 best val_acc 19.074675
# epoch: 82, bulyan: at our-agr n_at 10 e 82 | val loss 2.1382 val acc 18.5268 best val_acc 19.074675
# epoch: 83, bulyan: at our-agr n_at 10 e 83 | val loss 2.1426 val acc 17.0860 best val_acc 19.074675
# epoch: 84, bulyan: at our-agr n_at 10 e 84 | val loss 2.0841 val acc 19.4399 best val_acc 19.439935
# epoch: 85, bulyan: at our-agr n_at 10 e 85 | val loss 2.2431 val acc 17.6136 best val_acc 19.439935
# epoch: 86, bulyan: at our-agr n_at 10 e 86 | val loss 2.2751 val acc 17.2281 best val_acc 19.439935
# epoch: 87, bulyan: at our-agr n_at 10 e 87 | val loss 2.1755 val acc 17.9383 best val_acc 19.439935
# epoch: 88, bulyan: at our-agr n_at 10 e 88 | val loss 2.1654 val acc 14.2857 best val_acc 19.439935
# epoch: 89, bulyan: at our-agr n_at 10 e 89 | val loss 2.1907 val acc 18.6688 best val_acc 19.439935
# epoch: 90, bulyan: at our-agr n_at 10 e 90 | val loss 2.2384 val acc 13.6769 best val_acc 19.439935
# epoch: 91, bulyan: at our-agr n_at 10 e 91 | val loss 2.2299 val acc 17.2890 best val_acc 19.439935
# epoch: 92, bulyan: at our-agr n_at 10 e 92 | val loss 2.3753 val acc 15.7265 best val_acc 19.439935
# epoch: 93, bulyan: at our-agr n_at 10 e 93 | val loss 2.3260 val acc 16.3149 best val_acc 19.439935
# epoch: 94, bulyan: at our-agr n_at 10 e 94 | val loss 2.2207 val acc 15.0771 best val_acc 19.439935
# epoch: 95, bulyan: at our-agr n_at 10 e 95 | val loss 2.2856 val acc 17.1672 best val_acc 19.439935
# epoch: 96, bulyan: at our-agr n_at 10 e 96 | val loss 2.2495 val acc 13.1899 best val_acc 19.439935
# epoch: 97, bulyan: at our-agr n_at 10 e 97 | val loss 2.1274 val acc 19.0544 best val_acc 19.439935
# epoch: 98, bulyan: at our-agr n_at 10 e 98 | val loss 2.0899 val acc 18.4050 best val_acc 19.439935
# epoch: 99, bulyan: at our-agr n_at 10 e 99 | val loss 2.0735 val acc 21.5503 best val_acc 21.550325
# epoch: 100, bulyan: at our-agr n_at 10 e 100 | val loss 2.2683 val acc 16.4367 best val_acc 21.550325
# epoch: 101, bulyan: at our-agr n_at 10 e 101 | val loss 2.3884 val acc 15.5844 best val_acc 21.550325
# epoch: 102, bulyan: at our-agr n_at 10 e 102 | val loss 2.1713 val acc 18.0195 best val_acc 21.550325
# epoch: 103, bulyan: at our-agr n_at 10 e 103 | val loss 2.2101 val acc 17.7151 best val_acc 21.550325
# epoch: 104, bulyan: at our-agr n_at 10 e 104 | val loss 2.1628 val acc 16.3961 best val_acc 21.550325
# epoch: 105, bulyan: at our-agr n_at 10 e 105 | val loss 2.1142 val acc 19.5820 best val_acc 21.550325
# epoch: 106, bulyan: at our-agr n_at 10 e 106 | val loss 2.0548 val acc 18.6282 best val_acc 21.550325
# epoch: 107, bulyan: at our-agr n_at 10 e 107 | val loss 2.0583 val acc 18.9123 best val_acc 21.550325
# epoch: 108, bulyan: at our-agr n_at 10 e 108 | val loss 2.1466 val acc 18.4050 best val_acc 21.550325
# epoch: 109, bulyan: at our-agr n_at 10 e 109 | val loss 2.2581 val acc 18.9732 best val_acc 21.550325
# epoch: 110, bulyan: at our-agr n_at 10 e 110 | val loss 2.2610 val acc 14.9554 best val_acc 21.550325
# epoch: 111, bulyan: at our-agr n_at 10 e 111 | val loss 2.1403 val acc 16.4570 best val_acc 21.550325
# epoch: 112, bulyan: at our-agr n_at 10 e 112 | val loss 2.1797 val acc 17.2484 best val_acc 21.550325
# epoch: 140, bulyan: at our-agr n_at 10 e 140 | val loss 2.0264 val acc 21.1242 best val_acc 21.550325
# epoch: 141, bulyan: at our-agr n_at 10 e 141 | val loss 2.2894 val acc 16.9440 best val_acc 21.550325
# epoch: 142, bulyan: at our-agr n_at 10 e 142 | val loss 2.3906 val acc 15.7062 best val_acc 21.550325
# epoch: 143, bulyan: at our-agr n_at 10 e 143 | val loss 2.1256 val acc 16.1120 best val_acc 21.550325
# epoch: 144, bulyan: at our-agr n_at 10 e 144 | val loss 2.0849 val acc 18.3644 best val_acc 21.550325
# epoch: 145, bulyan: at our-agr n_at 10 e 145 | val loss 2.0686 val acc 17.0455 best val_acc 21.550325
# epoch: 146, bulyan: at our-agr n_at 10 e 146 | val loss 2.1235 val acc 18.9326 best val_acc 21.550325
# epoch: 147, bulyan: at our-agr n_at 10 e 147 | val loss 2.0974 val acc 18.2021 best val_acc 21.550325
# epoch: 148, bulyan: at our-agr n_at 10 e 148 | val loss 2.1321 val acc 18.6080 best val_acc 21.550325
# epoch: 149, bulyan: at our-agr n_at 10 e 149 | val loss 2.1409 val acc 16.9846 best val_acc 21.550325
# epoch: 150, bulyan: at our-agr n_at 10 e 150 | val loss 2.1907 val acc 21.2865 best val_acc 21.550325
# epoch: 151, bulyan: at our-agr n_at 10 e 151 | val loss 2.1957 val acc 17.2687 best val_acc 21.550325
# epoch: 152, bulyan: at our-agr n_at 10 e 152 | val loss 3.7140 val acc 17.3701 best val_acc 21.550325
# epoch: 153, bulyan: at our-agr n_at 10 e 153 | val loss 3.3241 val acc 9.8214 best val_acc 21.550325
# epoch: 154, bulyan: at our-agr n_at 10 e 154 | val loss 2.6951 val acc 9.7808 best val_acc 21.550325
# epoch: 155, bulyan: at our-agr n_at 10 e 155 | val loss 2.6355 val acc 14.3060 best val_acc 21.550325
# epoch: 156, bulyan: at our-agr n_at 10 e 156 | val loss 2.4956 val acc 10.2273 best val_acc 21.550325
# epoch: 157, bulyan: at our-agr n_at 10 e 157 | val loss 2.6818 val acc 11.9724 best val_acc 21.550325
# epoch: 158, bulyan: at our-agr n_at 10 e 158 | val loss 2.2373 val acc 17.3498 best val_acc 21.550325
# epoch: 159, bulyan: at our-agr n_at 10 e 159 | val loss 2.1421 val acc 17.2687 best val_acc 21.550325
# epoch: 160, bulyan: at our-agr n_at 10 e 160 | val loss 2.0591 val acc 20.0487 best val_acc 21.550325
# epoch: 161, bulyan: at our-agr n_at 10 e 161 | val loss 2.4061 val acc 17.6745 best val_acc 21.550325
# epoch: 162, bulyan: at our-agr n_at 10 e 162 | val loss 2.3212 val acc 13.9002 best val_acc 21.550325
# epoch: 163, bulyan: at our-agr n_at 10 e 163 | val loss 2.2952 val acc 18.1209 best val_acc 21.550325
# epoch: 164, bulyan: at our-agr n_at 10 e 164 | val loss 2.2464 val acc 14.0016 best val_acc 21.550325
# epoch: 165, bulyan: at our-agr n_at 10 e 165 | val loss 2.3683 val acc 19.5820 best val_acc 21.550325
# epoch: 192, bulyan: at our-agr n_at 10 e 192 | val loss 2.3700 val acc 13.9205 best val_acc 21.550325
# epoch: 193, bulyan: at our-agr n_at 10 e 193 | val loss 2.0845 val acc 17.9180 best val_acc 21.550325
# epoch: 194, bulyan: at our-agr n_at 10 e 194 | val loss 2.0678 val acc 18.3442 best val_acc 21.550325
# epoch: 195, bulyan: at our-agr n_at 10 e 195 | val loss 2.0258 val acc 19.2167 best val_acc 21.550325
# epoch: 196, bulyan: at our-agr n_at 10 e 196 | val loss 2.3104 val acc 18.2833 best val_acc 21.550325
# epoch: 197, bulyan: at our-agr n_at 10 e 197 | val loss 2.2776 val acc 17.0860 best val_acc 21.550325
# epoch: 198, bulyan: at our-agr n_at 10 e 198 | val loss 3.0555 val acc 19.9878 best val_acc 21.550325
# epoch: 199, bulyan: at our-agr n_at 10 e 199 | val loss 2.7178 val acc 10.0041 best val_acc 21.550325
# epoch: 200, bulyan: at our-agr n_at 10 e 200 | val loss 2.3084 val acc 16.6599 best val_acc 21.550325
# epoch: 201, bulyan: at our-agr n_at 10 e 201 | val loss 2.0736 val acc 19.6834 best val_acc 21.550325
# epoch: 202, bulyan: at our-agr n_at 10 e 202 | val loss 2.5899 val acc 18.1818 best val_acc 21.550325
# epoch: 203, bulyan: at our-agr n_at 10 e 203 | val loss 2.2624 val acc 17.6542 best val_acc 21.550325
# epoch: 204, bulyan: at our-agr n_at 10 e 204 | val loss 3.0051 val acc 17.9789 best val_acc 21.550325
# epoch: 205, bulyan: at our-agr n_at 10 e 205 | val loss 2.6020 val acc 15.5235 best val_acc 21.550325
# epoch: 206, bulyan: at our-agr n_at 10 e 206 | val loss 2.2166 val acc 16.7005 best val_acc 21.550325
# epoch: 207, bulyan: at our-agr n_at 10 e 207 | val loss 2.0031 val acc 22.7070 best val_acc 22.706981
# epoch: 208, bulyan: at our-agr n_at 10 e 208 | val loss 2.0296 val acc 18.6485 best val_acc 22.706981
# epoch: 209, bulyan: at our-agr n_at 10 e 209 | val loss 2.0271 val acc 21.3880 best val_acc 22.706981
# epoch: 210, bulyan: at our-agr n_at 10 e 210 | val loss 2.7179 val acc 18.2833 best val_acc 22.706981
# epoch: 211, bulyan: at our-agr n_at 10 e 211 | val loss 2.4020 val acc 18.1615 best val_acc 22.706981
# epoch: 212, bulyan: at our-agr n_at 10 e 212 | val loss 2.8434 val acc 18.3442 best val_acc 22.706981
# epoch: 213, bulyan: at our-agr n_at 10 e 213 | val loss 2.4113 val acc 16.7817 best val_acc 22.706981
# epoch: 214, bulyan: at our-agr n_at 10 e 214 | val loss 2.1997 val acc 18.1006 best val_acc 22.706981
# epoch: 215, bulyan: at our-agr n_at 10 e 215 | val loss 2.1594 val acc 15.5844 best val_acc 22.706981
# epoch: 216, bulyan: at our-agr n_at 10 e 216 | val loss 2.2042 val acc 18.0601 best val_acc 22.706981
# epoch: 217, bulyan: at our-agr n_at 10 e 217 | val loss 2.1713 val acc 18.7703 best val_acc 22.706981
# epoch: 218, bulyan: at our-agr n_at 10 e 218 | val loss 2.2984 val acc 18.5268 best val_acc 22.706981
# epoch: 219, bulyan: at our-agr n_at 10 e 219 | val loss 2.1434 val acc 19.8255 best val_acc 22.706981
# epoch: 220, bulyan: at our-agr n_at 10 e 220 | val loss 3.2025 val acc 18.3644 best val_acc 22.706981
# epoch: 221, bulyan: at our-agr n_at 10 e 221 | val loss 2.5816 val acc 13.3929 best val_acc 22.706981
# epoch: 222, bulyan: at our-agr n_at 10 e 222 | val loss 2.4052 val acc 17.7963 best val_acc 22.706981
# epoch: 223, bulyan: at our-agr n_at 10 e 223 | val loss 2.0538 val acc 19.9067 best val_acc 22.706981
# epoch: 224, bulyan: at our-agr n_at 10 e 224 | val loss 2.3057 val acc 17.9789 best val_acc 22.706981
# epoch: 225, bulyan: at our-agr n_at 10 e 225 | val loss 2.4057 val acc 15.1177 best val_acc 22.706981
# epoch: 226, bulyan: at our-agr n_at 10 e 226 | val loss 2.4566 val acc 18.8920 best val_acc 22.706981
# epoch: 227, bulyan: at our-agr n_at 10 e 227 | val loss 2.0663 val acc 16.1323 best val_acc 22.706981
# epoch: 228, bulyan: at our-agr n_at 10 e 228 | val loss 2.3171 val acc 18.5065 best val_acc 22.706981
# epoch: 229, bulyan: at our-agr n_at 10 e 229 | val loss 2.0690 val acc 16.8019 best val_acc 22.706981
# epoch: 230, bulyan: at our-agr n_at 10 e 230 | val loss 2.4525 val acc 18.0804 best val_acc 22.706981
# epoch: 231, bulyan: at our-agr n_at 10 e 231 | val loss 2.2391 val acc 17.2484 best val_acc 22.706981
# epoch: 232, bulyan: at our-agr n_at 10 e 232 | val loss 2.7965 val acc 19.0544 best val_acc 22.706981
# epoch: 233, bulyan: at our-agr n_at 10 e 233 | val loss 2.2974 val acc 16.8222 best val_acc 22.706981
# epoch: 234, bulyan: at our-agr n_at 10 e 234 | val loss 2.3282 val acc 18.8109 best val_acc 22.706981
# epoch: 235, bulyan: at our-agr n_at 10 e 235 | val loss 2.0927 val acc 18.5471 best val_acc 22.706981
# epoch: 236, bulyan: at our-agr n_at 10 e 236 | val loss 2.4735 val acc 17.7354 best val_acc 22.706981
# epoch: 237, bulyan: at our-agr n_at 10 e 237 | val loss 2.6753 val acc 14.3466 best val_acc 22.706981
# epoch: 238, bulyan: at our-agr n_at 10 e 238 | val loss 2.1649 val acc 18.5877 best val_acc 22.706981
# epoch: 239, bulyan: at our-agr n_at 10 e 239 | val loss 2.0084 val acc 21.3271 best val_acc 22.706981
# epoch: 240, bulyan: at our-agr n_at 10 e 240 | val loss 2.0188 val acc 18.7500 best val_acc 22.706981
# epoch: 241, bulyan: at our-agr n_at 10 e 241 | val loss 1.9851 val acc 18.9529 best val_acc 22.706981
# epoch: 242, bulyan: at our-agr n_at 10 e 242 | val loss 2.3378 val acc 18.2833 best val_acc 22.706981
# epoch: 243, bulyan: at our-agr n_at 10 e 243 | val loss 2.2619 val acc 18.3644 best val_acc 22.706981
# epoch: 244, bulyan: at our-agr n_at 10 e 244 | val loss 2.8027 val acc 19.9878 best val_acc 22.706981
# epoch: 245, bulyan: at our-agr n_at 10 e 245 | val loss 2.3875 val acc 14.8945 best val_acc 22.706981
# epoch: 246, bulyan: at our-agr n_at 10 e 246 | val loss 2.4332 val acc 17.2687 best val_acc 22.706981
# epoch: 247, bulyan: at our-agr n_at 10 e 247 | val loss 2.0579 val acc 21.8344 best val_acc 22.706981
# epoch: 248, bulyan: at our-agr n_at 10 e 248 | val loss 2.3591 val acc 18.0601 best val_acc 22.706981
# epoch: 249, bulyan: at our-agr n_at 10 e 249 | val loss 2.3690 val acc 16.9846 best val_acc 22.706981
# epoch: 250, bulyan: at our-agr n_at 10 e 250 | val loss 2.6393 val acc 17.5122 best val_acc 22.706981
# epoch: 251, bulyan: at our-agr n_at 10 e 251 | val loss 2.3897 val acc 11.5260 best val_acc 22.706981
# epoch: 252, bulyan: at our-agr n_at 10 e 252 | val loss 2.2517 val acc 18.7703 best val_acc 22.706981
# epoch: 253, bulyan: at our-agr n_at 10 e 253 | val loss 2.2429 val acc 18.1412 best val_acc 22.706981
# epoch: 254, bulyan: at our-agr n_at 10 e 254 | val loss 2.2718 val acc 18.3442 best val_acc 22.706981
# epoch: 255, bulyan: at our-agr n_at 10 e 255 | val loss 2.1706 val acc 20.5154 best val_acc 22.706981
# epoch: 256, bulyan: at our-agr n_at 10 e 256 | val loss 2.0985 val acc 18.1209 best val_acc 22.706981
# epoch: 257, bulyan: at our-agr n_at 10 e 257 | val loss 2.8718 val acc 18.4253 best val_acc 22.706981
# epoch: 258, bulyan: at our-agr n_at 10 e 258 | val loss 2.4576 val acc 17.1672 best val_acc 22.706981
# epoch: 259, bulyan: at our-agr n_at 10 e 259 | val loss 2.4353 val acc 17.9180 best val_acc 22.706981
# epoch: 260, bulyan: at our-agr n_at 10 e 260 | val loss 2.1256 val acc 17.0657 best val_acc 22.706981
# epoch: 261, bulyan: at our-agr n_at 10 e 261 | val loss 2.3095 val acc 18.2021 best val_acc 22.706981
# epoch: 262, bulyan: at our-agr n_at 10 e 262 | val loss 2.2896 val acc 17.4919 best val_acc 22.706981
# epoch: 263, bulyan: at our-agr n_at 10 e 263 | val loss 2.3954 val acc 18.7094 best val_acc 22.706981
# epoch: 264, bulyan: at our-agr n_at 10 e 264 | val loss 2.0696 val acc 16.3352 best val_acc 22.706981
# epoch: 265, bulyan: at our-agr n_at 10 e 265 | val loss 2.1249 val acc 21.3474 best val_acc 22.706981
# epoch: 266, bulyan: at our-agr n_at 10 e 266 | val loss 1.9862 val acc 19.0341 best val_acc 22.706981
# epoch: 267, bulyan: at our-agr n_at 10 e 267 | val loss 2.2319 val acc 18.4253 best val_acc 22.706981
# epoch: 268, bulyan: at our-agr n_at 10 e 268 | val loss 1.9880 val acc 18.1818 best val_acc 22.706981
# epoch: 269, bulyan: at our-agr n_at 10 e 269 | val loss 2.1880 val acc 20.0487 best val_acc 22.706981
# epoch: 270, bulyan: at our-agr n_at 10 e 270 | val loss 1.9968 val acc 20.8604 best val_acc 22.706981
# %%
import matplotlib.pyplot as plt

# Plotting the data
for col in ['loss', 'validation accuracy', 'best validation accuracy']:
    plt.plot(df['epoch'].tolist(), df[col].tolist())
    plt.title("our attack + 10 attacker + no defense_"+col)
    plt.savefig('./our attack + 10 attacker + no defense ' + col + '.png')
    plt.show()

# %% [markdown]
# ## No Attack

# %%
batch_size=250
resume=0

schedule=[1000]

gamma=.5
opt = 'sgd'
fed_lr=0.5
criterion=nn.CrossEntropyLoss()
use_cuda = torch.cuda.is_available()

aggregation='bulyan'
multi_k = False
candidates = []

at_type='our-agr'
dev_type ='std'
n_attackers=[0]

arch='alexnet'
chkpt='./'+aggregation

past_mean = []
past_abs_sum = []
past_median = []
past_lower_quartile = []
past_upper_quartile = []
past_std = []


for n_attacker in n_attackers:
    epoch_num = 0
    best_global_acc = 0
    best_global_te_acc = 0

    torch.cuda.empty_cache()

    fed_model, _ = return_model(arch, 0.1, 0.9, parallel=False)
    optimizer_fed = SGD(fed_model.parameters(), lr=fed_lr)

    df = pd.DataFrame(columns = ['epoch', 'loss', 'validation accuracy', 'best validation accuracy'])

    ####
    history = torch.zeros((n_users, nepochs + 1), dtype=torch.float32).cuda()
    ####

    model_grads = []
    flag = False
    while epoch_num <= nepochs:
        user_grads=[]

        for i in range(n_users): # 50
            nbatches = user_tr_len[i]//batch_size

            inputs = user_train_data_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]
            targets = user_train_label_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]

            targets = targets.type(torch.LongTensor)

            inputs, targets = inputs.cuda(), targets.cuda()
            inputs, targets = torch.autograd.Variable(inputs), torch.autograd.Variable(targets)

            outputs = fed_model(inputs)
            loss = criterion(outputs, targets)
            fed_model.zero_grad()
            loss.backward(retain_graph=True)

            param_grad=[]
            for param in fed_model.parameters():
                param_grad=param.grad.data.view(-1) if not len(param_grad) else torch.cat((param_grad,param.grad.view(-1)))


            user_grads=param_grad[None, :] if len(user_grads)==0 else torch.cat((user_grads,param_grad[None,:]), 0)

        if epoch_num in schedule:
            for param_group in optimizer_fed.param_groups:
                param_group['lr'] *= gamma
                print('New learnin rate ', param_group['lr'])

        updates_abs_mean = user_grads.abs().mean(dim=1, keepdim=True)

        if n_attacker > 0:
            model_params = torch.cat([p.data.view(-1) for p in fed_model.parameters()])
            mal_updates = our_attack_mean(n_users, epoch_num, history, user_grads, model_params, n_attacker, arch, criterion, user_train_data_tensors, user_train_label_tensors)
            malicious_grads = torch.cat((mal_updates, user_grads[n_attacker:]), 0) # torch.Size([50, 2472266])
        else:   # No attack
            malicious_grads = user_grads

        if not (malicious_grads.shape[0]==50):
            print(malicious_grads.shape)

        updates_abs_mean = malicious_grads.abs().mean(dim=1, keepdim=True)

        history[:, epoch_num] = updates_abs_mean.squeeze()
        # agg_grads = no_defense_aggregation(malicious_grads)
        agg_grads = our_mean_defense(malicious_grads, n_attacker, history)

        del user_grads

        start_idx=0

        optimizer_fed.zero_grad()

        model_grads=[]

        for i, param in enumerate(fed_model.parameters()):
            param_=agg_grads[start_idx:start_idx+len(param.data.view(-1))].reshape(param.data.shape)
            start_idx=start_idx+len(param.data.view(-1))
            param_=param_.cuda()
            model_grads.append(param_)

        optimizer_fed.step(model_grads)

        val_loss, val_acc = test(val_data_tensor,val_label_tensor,fed_model,criterion,use_cuda)
        te_loss, te_acc = test(te_data_tensor,te_label_tensor, fed_model, criterion, use_cuda)

        is_best = best_global_acc < val_acc

        best_global_acc = max(best_global_acc, val_acc)

        if is_best:
            best_global_te_acc = te_acc


        print('epoch: %d, %s: at %s n_at %d e %d | val loss %.4f val acc %.4f best val_acc %f'%(epoch_num, aggregation, at_type, n_attacker, epoch_num, val_loss, val_acc, best_global_acc))
        new_row = pd.DataFrame([{
            'epoch': epoch_num,
            'loss': val_loss,
            'validation accuracy': val_acc,
            'best validation accuracy': best_global_acc
            }])
        df = pd.concat([df, new_row], ignore_index=True)
        df.to_csv('./our attack + 10 attacker + our defense.csv', index=False)

        if val_loss > 1000:
            print('val loss %f too high'%val_loss)
            break

        epoch_num+=1
# Out:
# discarded index []
# epoch: 0, bulyan: at our-agr n_at 0 e 0 | val loss 2.3031 val acc 9.3547 best val_acc 9.354708
# C:\Users\Hizan\AppData\Local\Temp\ipykernel_20104\56042239.py:132: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, new_row], ignore_index=True)
# discarded index []
# epoch: 1, bulyan: at our-agr n_at 0 e 1 | val loss 2.3025 val acc 9.6997 best val_acc 9.699675
# discarded index []
# epoch: 2, bulyan: at our-agr n_at 0 e 2 | val loss 2.3020 val acc 9.6997 best val_acc 9.699675
# discarded index []
# epoch: 3, bulyan: at our-agr n_at 0 e 3 | val loss 2.3015 val acc 9.6997 best val_acc 9.699675
# discarded index []
# epoch: 4, bulyan: at our-agr n_at 0 e 4 | val loss 2.3010 val acc 9.6997 best val_acc 9.699675
# discarded index []
# epoch: 5, bulyan: at our-agr n_at 0 e 5 | val loss 2.3004 val acc 9.6997 best val_acc 9.699675
# discarded index []
# epoch: 6, bulyan: at our-agr n_at 0 e 6 | val loss 2.2998 val acc 9.6997 best val_acc 9.699675
# discarded index []
# epoch: 7, bulyan: at our-agr n_at 0 e 7 | val loss 2.2990 val acc 9.6997 best val_acc 9.699675
# discarded index []
# epoch: 8, bulyan: at our-agr n_at 0 e 8 | val loss 2.2981 val acc 9.6997 best val_acc 9.699675
# discarded index []
# epoch: 9, bulyan: at our-agr n_at 0 e 9 | val loss 2.2971 val acc 9.6997 best val_acc 9.699675
# discarded index []
# epoch: 10, bulyan: at our-agr n_at 0 e 10 | val loss 2.2959 val acc 10.0041 best val_acc 10.004058
# discarded index []
# epoch: 11, bulyan: at our-agr n_at 0 e 11 | val loss 2.2943 val acc 12.6623 best val_acc 12.662338
# discarded index []
# epoch: 12, bulyan: at our-agr n_at 0 e 12 | val loss 2.2922 val acc 13.7987 best val_acc 13.798701
# discarded index []
# epoch: 13, bulyan: at our-agr n_at 0 e 13 | val loss 2.2896 val acc 14.2857 best val_acc 14.285714
# discarded index []
# epoch: 14, bulyan: at our-agr n_at 0 e 14 | val loss 2.2861 val acc 14.6307 best val_acc 14.630682
# discarded index []
# epoch: 15, bulyan: at our-agr n_at 0 e 15 | val loss 2.2811 val acc 14.0219 best val_acc 14.630682
# discarded index []
# epoch: 16, bulyan: at our-agr n_at 0 e 16 | val loss 2.2743 val acc 13.8596 best val_acc 14.630682
# discarded index []
# epoch: 17, bulyan: at our-agr n_at 0 e 17 | val loss 2.2641 val acc 12.8247 best val_acc 14.630682
# discarded index []
# epoch: 18, bulyan: at our-agr n_at 0 e 18 | val loss 2.2506 val acc 12.7638 best val_acc 14.630682
# discarded index []
# epoch: 19, bulyan: at our-agr n_at 0 e 19 | val loss 2.2348 val acc 12.9058 best val_acc 14.630682
# discarded index []
# epoch: 20, bulyan: at our-agr n_at 0 e 20 | val loss 2.2182 val acc 15.5438 best val_acc 15.543831
# discarded index []
# epoch: 21, bulyan: at our-agr n_at 0 e 21 | val loss 2.1997 val acc 20.4748 best val_acc 20.474838
# discarded index []
# epoch: 22, bulyan: at our-agr n_at 0 e 22 | val loss 2.2187 val acc 16.8831 best val_acc 20.474838
# discarded index []
# epoch: 23, bulyan: at our-agr n_at 0 e 23 | val loss 2.3436 val acc 10.0041 best val_acc 20.474838
# discarded index []
# epoch: 24, bulyan: at our-agr n_at 0 e 24 | val loss 2.2548 val acc 18.1006 best val_acc 20.474838
# discarded index []
# epoch: 25, bulyan: at our-agr n_at 0 e 25 | val loss 2.1973 val acc 21.9765 best val_acc 21.976461
# discarded index []
# epoch: 26, bulyan: at our-agr n_at 0 e 26 | val loss 2.1654 val acc 19.3994 best val_acc 21.976461
# discarded index []
# epoch: 27, bulyan: at our-agr n_at 0 e 27 | val loss 2.1509 val acc 24.0463 best val_acc 24.046266
# discarded index []
# epoch: 28, bulyan: at our-agr n_at 0 e 28 | val loss 2.4483 val acc 14.4278 best val_acc 24.046266
# discarded index []
# epoch: 29, bulyan: at our-agr n_at 0 e 29 | val loss 2.3372 val acc 9.8620 best val_acc 24.046266
# discarded index []
# epoch: 30, bulyan: at our-agr n_at 0 e 30 | val loss 2.2972 val acc 10.3693 best val_acc 24.046266
# discarded index []
# epoch: 31, bulyan: at our-agr n_at 0 e 31 | val loss 2.2927 val acc 10.3287 best val_acc 24.046266
# discarded index []
# epoch: 32, bulyan: at our-agr n_at 0 e 32 | val loss 2.2881 val acc 10.3490 best val_acc 24.046266
# discarded index []
# epoch: 33, bulyan: at our-agr n_at 0 e 33 | val loss 2.2826 val acc 10.3084 best val_acc 24.046266
# discarded index []
# epoch: 34, bulyan: at our-agr n_at 0 e 34 | val loss 2.2767 val acc 10.3287 best val_acc 24.046266
# discarded index []
# epoch: 35, bulyan: at our-agr n_at 0 e 35 | val loss 2.2702 val acc 10.4099 best val_acc 24.046266
# discarded index []
# epoch: 36, bulyan: at our-agr n_at 0 e 36 | val loss 2.2629 val acc 12.1550 best val_acc 24.046266
# discarded index []
# epoch: 37, bulyan: at our-agr n_at 0 e 37 | val loss 2.2548 val acc 12.6015 best val_acc 24.046266
# discarded index []
# epoch: 38, bulyan: at our-agr n_at 0 e 38 | val loss 2.2463 val acc 12.2362 best val_acc 24.046266
# discarded index []
# epoch: 39, bulyan: at our-agr n_at 0 e 39 | val loss 2.2376 val acc 12.8247 best val_acc 24.046266
# discarded index []
# epoch: 40, bulyan: at our-agr n_at 0 e 40 | val loss 2.2285 val acc 12.0739 best val_acc 24.046266
# discarded index []
# epoch: 41, bulyan: at our-agr n_at 0 e 41 | val loss 2.2206 val acc 16.4367 best val_acc 24.046266
# discarded index []
# epoch: 42, bulyan: at our-agr n_at 0 e 42 | val loss 2.2125 val acc 18.2427 best val_acc 24.046266
# discarded index []
# epoch: 43, bulyan: at our-agr n_at 0 e 43 | val loss 2.2048 val acc 18.2630 best val_acc 24.046266
# discarded index []
# epoch: 44, bulyan: at our-agr n_at 0 e 44 | val loss 2.2030 val acc 19.4196 best val_acc 24.046266
# discarded index []
# epoch: 45, bulyan: at our-agr n_at 0 e 45 | val loss 2.2102 val acc 17.1672 best val_acc 24.046266
# discarded index []
# epoch: 46, bulyan: at our-agr n_at 0 e 46 | val loss 2.2698 val acc 14.9756 best val_acc 24.046266
# discarded index []
# epoch: 47, bulyan: at our-agr n_at 0 e 47 | val loss 2.2129 val acc 18.8515 best val_acc 24.046266
# discarded index []
# epoch: 48, bulyan: at our-agr n_at 0 e 48 | val loss 2.1947 val acc 19.3791 best val_acc 24.046266
# discarded index []
# epoch: 49, bulyan: at our-agr n_at 0 e 49 | val loss 2.2224 val acc 16.3961 best val_acc 24.046266
# discarded index []
# epoch: 50, bulyan: at our-agr n_at 0 e 50 | val loss 2.1813 val acc 18.6891 best val_acc 24.046266
# discarded index []
# epoch: 51, bulyan: at our-agr n_at 0 e 51 | val loss 2.2106 val acc 17.7557 best val_acc 24.046266
# discarded index []
# epoch: 52, bulyan: at our-agr n_at 0 e 52 | val loss 2.1836 val acc 20.2719 best val_acc 24.046266
# discarded index []
# epoch: 53, bulyan: at our-agr n_at 0 e 53 | val loss 2.2328 val acc 15.4221 best val_acc 24.046266
# discarded index []
# epoch: 54, bulyan: at our-agr n_at 0 e 54 | val loss 2.1617 val acc 19.8255 best val_acc 24.046266
# discarded index []
# epoch: 55, bulyan: at our-agr n_at 0 e 55 | val loss 2.1629 val acc 18.7297 best val_acc 24.046266
# discarded index []
# epoch: 56, bulyan: at our-agr n_at 0 e 56 | val loss 2.1555 val acc 19.5008 best val_acc 24.046266
# discarded index []
# epoch: 57, bulyan: at our-agr n_at 0 e 57 | val loss 2.1795 val acc 18.5877 best val_acc 24.046266
# discarded index []
# epoch: 58, bulyan: at our-agr n_at 0 e 58 | val loss 2.1711 val acc 20.0690 best val_acc 24.046266
# discarded index []
# epoch: 59, bulyan: at our-agr n_at 0 e 59 | val loss 2.2830 val acc 11.7898 best val_acc 24.046266
# discarded index []
# epoch: 60, bulyan: at our-agr n_at 0 e 60 | val loss 2.1973 val acc 17.2484 best val_acc 24.046266
# discarded index []
# epoch: 61, bulyan: at our-agr n_at 0 e 61 | val loss 2.1540 val acc 18.9732 best val_acc 24.046266
# discarded index []
# epoch: 62, bulyan: at our-agr n_at 0 e 62 | val loss 2.1977 val acc 17.7557 best val_acc 24.046266
# discarded index []
# epoch: 63, bulyan: at our-agr n_at 0 e 63 | val loss 2.1554 val acc 20.1705 best val_acc 24.046266
# discarded index []
# epoch: 64, bulyan: at our-agr n_at 0 e 64 | val loss 2.2486 val acc 15.2394 best val_acc 24.046266
# discarded index []
# epoch: 65, bulyan: at our-agr n_at 0 e 65 | val loss 2.1564 val acc 20.3734 best val_acc 24.046266
# discarded index []
# epoch: 66, bulyan: at our-agr n_at 0 e 66 | val loss 2.1211 val acc 21.2054 best val_acc 24.046266
# discarded index []
# epoch: 67, bulyan: at our-agr n_at 0 e 67 | val loss 2.1288 val acc 21.0430 best val_acc 24.046266
# discarded index []
# epoch: 68, bulyan: at our-agr n_at 0 e 68 | val loss 2.1222 val acc 20.6778 best val_acc 24.046266
# discarded index []
# epoch: 69, bulyan: at our-agr n_at 0 e 69 | val loss 2.1957 val acc 17.2687 best val_acc 24.046266
# discarded index []
# epoch: 70, bulyan: at our-agr n_at 0 e 70 | val loss 2.1647 val acc 19.8255 best val_acc 24.046266
# discarded index []
# epoch: 71, bulyan: at our-agr n_at 0 e 71 | val loss 2.2987 val acc 11.6071 best val_acc 24.046266
# discarded index []
# epoch: 72, bulyan: at our-agr n_at 0 e 72 | val loss 2.2123 val acc 17.0049 best val_acc 24.046266
# discarded index []
# epoch: 73, bulyan: at our-agr n_at 0 e 73 | val loss 2.1325 val acc 20.6575 best val_acc 24.046266
# discarded index []
# epoch: 74, bulyan: at our-agr n_at 0 e 74 | val loss 2.1482 val acc 18.5065 best val_acc 24.046266
# discarded index []
# epoch: 75, bulyan: at our-agr n_at 0 e 75 | val loss 2.1401 val acc 20.3531 best val_acc 24.046266
# discarded index []
# epoch: 76, bulyan: at our-agr n_at 0 e 76 | val loss 2.2661 val acc 12.9464 best val_acc 24.046266
# discarded index []
# epoch: 77, bulyan: at our-agr n_at 0 e 77 | val loss 2.1196 val acc 21.3068 best val_acc 24.046266
# discarded index []
# epoch: 78, bulyan: at our-agr n_at 0 e 78 | val loss 2.0981 val acc 23.4984 best val_acc 24.046266
# discarded index []
# epoch: 79, bulyan: at our-agr n_at 0 e 79 | val loss 2.1713 val acc 16.9440 best val_acc 24.046266
# discarded index []
# epoch: 80, bulyan: at our-agr n_at 0 e 80 | val loss 2.1017 val acc 22.1794 best val_acc 24.046266
# discarded index []
# epoch: 81, bulyan: at our-agr n_at 0 e 81 | val loss 2.1605 val acc 18.9732 best val_acc 24.046266
# discarded index []
# epoch: 82, bulyan: at our-agr n_at 0 e 82 | val loss 2.1430 val acc 21.6112 best val_acc 24.046266
# discarded index []
# epoch: 83, bulyan: at our-agr n_at 0 e 83 | val loss 2.3023 val acc 12.5203 best val_acc 24.046266
# discarded index []
# epoch: 84, bulyan: at our-agr n_at 0 e 84 | val loss 2.2235 val acc 20.2516 best val_acc 24.046266
# discarded index []
# epoch: 85, bulyan: at our-agr n_at 0 e 85 | val loss 2.1492 val acc 22.7679 best val_acc 24.046266
# discarded index []
# epoch: 86, bulyan: at our-agr n_at 0 e 86 | val loss 2.0963 val acc 23.4578 best val_acc 24.046266
# discarded index []
# epoch: 87, bulyan: at our-agr n_at 0 e 87 | val loss 2.0492 val acc 21.7330 best val_acc 24.046266
# discarded index []
# epoch: 88, bulyan: at our-agr n_at 0 e 88 | val loss 2.0537 val acc 21.6315 best val_acc 24.046266
# discarded index []
# epoch: 89, bulyan: at our-agr n_at 0 e 89 | val loss 2.1006 val acc 17.0455 best val_acc 24.046266
# discarded index []
# epoch: 90, bulyan: at our-agr n_at 0 e 90 | val loss 2.1771 val acc 18.7703 best val_acc 24.046266
# discarded index []
# epoch: 91, bulyan: at our-agr n_at 0 e 91 | val loss 2.2927 val acc 11.4651 best val_acc 24.046266
# discarded index []
# epoch: 92, bulyan: at our-agr n_at 0 e 92 | val loss 2.1335 val acc 15.9294 best val_acc 24.046266
# discarded index []
# epoch: 93, bulyan: at our-agr n_at 0 e 93 | val loss 2.0892 val acc 19.5211 best val_acc 24.046266
# discarded index []
# epoch: 94, bulyan: at our-agr n_at 0 e 94 | val loss 2.1613 val acc 16.3961 best val_acc 24.046266
# discarded index []
# epoch: 95, bulyan: at our-agr n_at 0 e 95 | val loss 2.0994 val acc 18.4050 best val_acc 24.046266
# discarded index []
# epoch: 96, bulyan: at our-agr n_at 0 e 96 | val loss 2.2482 val acc 15.4018 best val_acc 24.046266
# discarded index []
# epoch: 97, bulyan: at our-agr n_at 0 e 97 | val loss 2.1170 val acc 21.4489 best val_acc 24.046266
# discarded index []
# epoch: 98, bulyan: at our-agr n_at 0 e 98 | val loss 2.1551 val acc 17.4107 best val_acc 24.046266
# discarded index []
# epoch: 99, bulyan: at our-agr n_at 0 e 99 | val loss 2.0369 val acc 22.2200 best val_acc 24.046266
# discarded index []
# epoch: 100, bulyan: at our-agr n_at 0 e 100 | val loss 2.1054 val acc 17.1672 best val_acc 24.046266
# discarded index []
# epoch: 101, bulyan: at our-agr n_at 0 e 101 | val loss 2.0369 val acc 24.3304 best val_acc 24.330357
# discarded index []
# epoch: 102, bulyan: at our-agr n_at 0 e 102 | val loss 2.1655 val acc 18.2833 best val_acc 24.330357
# discarded index []
# epoch: 103, bulyan: at our-agr n_at 0 e 103 | val loss 2.0779 val acc 20.0081 best val_acc 24.330357
# discarded index []
# epoch: 104, bulyan: at our-agr n_at 0 e 104 | val loss 2.0900 val acc 21.7532 best val_acc 24.330357
# discarded index []
# epoch: 105, bulyan: at our-agr n_at 0 e 105 | val loss 2.0556 val acc 21.2865 best val_acc 24.330357
# discarded index []
# epoch: 106, bulyan: at our-agr n_at 0 e 106 | val loss 2.1231 val acc 16.4367 best val_acc 24.330357
# discarded index []
# epoch: 107, bulyan: at our-agr n_at 0 e 107 | val loss 2.0276 val acc 21.9156 best val_acc 24.330357
# discarded index []
# epoch: 108, bulyan: at our-agr n_at 0 e 108 | val loss 2.0267 val acc 22.1997 best val_acc 24.330357
# discarded index []
# epoch: 109, bulyan: at our-agr n_at 0 e 109 | val loss 2.0200 val acc 23.3360 best val_acc 24.330357
# discarded index []
# epoch: 110, bulyan: at our-agr n_at 0 e 110 | val loss 2.1133 val acc 19.8052 best val_acc 24.330357
# discarded index []
# epoch: 111, bulyan: at our-agr n_at 0 e 111 | val loss 1.9928 val acc 25.7508 best val_acc 25.750812
# discarded index []
# epoch: 112, bulyan: at our-agr n_at 0 e 112 | val loss 2.0034 val acc 25.1826 best val_acc 25.750812
# discarded index []
# epoch: 113, bulyan: at our-agr n_at 0 e 113 | val loss 1.9989 val acc 25.4261 best val_acc 25.750812
# discarded index []
# epoch: 114, bulyan: at our-agr n_at 0 e 114 | val loss 2.2904 val acc 16.2135 best val_acc 25.750812
# discarded index []
# epoch: 115, bulyan: at our-agr n_at 0 e 115 | val loss 2.1406 val acc 18.6282 best val_acc 25.750812
# discarded index []
# epoch: 116, bulyan: at our-agr n_at 0 e 116 | val loss 2.0939 val acc 24.3709 best val_acc 25.750812
# discarded index []
# epoch: 117, bulyan: at our-agr n_at 0 e 117 | val loss 2.0180 val acc 26.2784 best val_acc 26.278409
# discarded index []
# epoch: 118, bulyan: at our-agr n_at 0 e 118 | val loss 2.0005 val acc 23.9651 best val_acc 26.278409
# discarded index []
# epoch: 119, bulyan: at our-agr n_at 0 e 119 | val loss 1.9385 val acc 28.1453 best val_acc 28.145292
# discarded index []
# epoch: 120, bulyan: at our-agr n_at 0 e 120 | val loss 1.9398 val acc 26.6437 best val_acc 28.145292
# discarded index []
# epoch: 121, bulyan: at our-agr n_at 0 e 121 | val loss 1.9780 val acc 27.4351 best val_acc 28.145292
# discarded index []
# epoch: 122, bulyan: at our-agr n_at 0 e 122 | val loss 2.2201 val acc 20.1705 best val_acc 28.145292
# discarded index []
# epoch: 123, bulyan: at our-agr n_at 0 e 123 | val loss 2.3213 val acc 16.7005 best val_acc 28.145292
# discarded index []
# epoch: 124, bulyan: at our-agr n_at 0 e 124 | val loss 2.2901 val acc 15.8482 best val_acc 28.145292
# discarded index []
# epoch: 125, bulyan: at our-agr n_at 0 e 125 | val loss 2.2565 val acc 14.3872 best val_acc 28.145292
# discarded index []
# epoch: 126, bulyan: at our-agr n_at 0 e 126 | val loss 2.1580 val acc 16.9034 best val_acc 28.145292
# discarded index []
# epoch: 127, bulyan: at our-agr n_at 0 e 127 | val loss 2.1050 val acc 22.2200 best val_acc 28.145292
# discarded index []
# epoch: 128, bulyan: at our-agr n_at 0 e 128 | val loss 2.0730 val acc 24.0666 best val_acc 28.145292
# discarded index []
# epoch: 129, bulyan: at our-agr n_at 0 e 129 | val loss 2.0473 val acc 24.4927 best val_acc 28.145292
# discarded index []
# epoch: 130, bulyan: at our-agr n_at 0 e 130 | val loss 2.0614 val acc 22.5244 best val_acc 28.145292
# discarded index []
# epoch: 131, bulyan: at our-agr n_at 0 e 131 | val loss 2.0536 val acc 24.3709 best val_acc 28.145292
# discarded index []
# epoch: 132, bulyan: at our-agr n_at 0 e 132 | val loss 2.1659 val acc 17.2281 best val_acc 28.145292
# discarded index []
# discarded index []
# epoch: 298, bulyan: at our-agr n_at 0 e 298 | val loss 1.6181 val acc 41.3149 best val_acc 45.170455
# discarded index []
# epoch: 299, bulyan: at our-agr n_at 0 e 299 | val loss 1.5777 val acc 42.2687 best val_acc 45.170455
# discarded index []
# epoch: 300, bulyan: at our-agr n_at 0 e 300 | val loss 1.7439 val acc 38.0479 best val_acc 45.170455

# %%
import matplotlib.pyplot as plt

# Plotting the data
for col in ['loss', 'validation accuracy', 'best validation accuracy']:
    plt.plot(df['epoch'].tolist(), df[col].tolist())
    plt.title("no attack_"+col)
    plt.savefig('./no attack ' + col + '.png')
    plt.show()

# %% [markdown]
# ## Execute our attack + 10 attacker + our defense

# %%
batch_size=250
resume=0

schedule=[1000]

gamma=.5
opt = 'sgd'
fed_lr=0.5
criterion=nn.CrossEntropyLoss()
use_cuda = torch.cuda.is_available()

aggregation='bulyan'
multi_k = False
candidates = []

at_type='our-agr'
dev_type ='std'
n_attackers=[10]

arch='alexnet'
chkpt='./'+aggregation

past_mean = []
past_abs_sum = []
past_median = []
past_lower_quartile = []
past_upper_quartile = []
past_std = []


for n_attacker in n_attackers:
    epoch_num = 0
    best_global_acc = 0
    best_global_te_acc = 0

    torch.cuda.empty_cache()

    fed_model, _ = return_model(arch, 0.1, 0.9, parallel=False)
    optimizer_fed = SGD(fed_model.parameters(), lr=fed_lr)

    df = pd.DataFrame(columns = ['epoch', 'loss', 'validation accuracy', 'best validation accuracy'])

    ####
    history = torch.zeros((n_users, nepochs + 1), dtype=torch.float32).cuda()
    ####

    model_grads = []
    flag = False
    while epoch_num <= nepochs:
        user_grads=[]

        for i in range(n_users): # 50
            nbatches = user_tr_len[i]//batch_size

            inputs = user_train_data_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]
            targets = user_train_label_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]

            targets = targets.type(torch.LongTensor)

            inputs, targets = inputs.cuda(), targets.cuda()
            inputs, targets = torch.autograd.Variable(inputs), torch.autograd.Variable(targets)

            outputs = fed_model(inputs)
            loss = criterion(outputs, targets)
            fed_model.zero_grad()
            loss.backward(retain_graph=True)

            param_grad=[]
            for param in fed_model.parameters():
                param_grad=param.grad.data.view(-1) if not len(param_grad) else torch.cat((param_grad,param.grad.view(-1)))


            user_grads=param_grad[None, :] if len(user_grads)==0 else torch.cat((user_grads,param_grad[None,:]), 0)

        if epoch_num in schedule:
            for param_group in optimizer_fed.param_groups:
                param_group['lr'] *= gamma
                print('New learnin rate ', param_group['lr'])

        updates_abs_mean = user_grads.abs().mean(dim=1, keepdim=True)

        if n_attacker > 0:
            model_params = torch.cat([p.data.view(-1) for p in fed_model.parameters()])
            mal_updates = our_attack_mean(n_users, epoch_num, history, user_grads, model_params, n_attacker, arch, criterion, user_train_data_tensors, user_train_label_tensors)
            malicious_grads = torch.cat((mal_updates, user_grads[n_attacker:]), 0) # torch.Size([50, 2472266])
        else:   # No attack
            malicious_grads = user_grads

        if not (malicious_grads.shape[0]==50):
            print(malicious_grads.shape)

        updates_abs_mean = malicious_grads.abs().mean(dim=1, keepdim=True)

        history[:, epoch_num] = updates_abs_mean.squeeze()
        # agg_grads = no_defense_aggregation(malicious_grads)
        agg_grads = our_mean_defense(malicious_grads, n_attacker, history)

        del user_grads

        start_idx=0

        optimizer_fed.zero_grad()

        model_grads=[]

        for i, param in enumerate(fed_model.parameters()):
            param_=agg_grads[start_idx:start_idx+len(param.data.view(-1))].reshape(param.data.shape)
            start_idx=start_idx+len(param.data.view(-1))
            param_=param_.cuda()
            model_grads.append(param_)

        optimizer_fed.step(model_grads)

        val_loss, val_acc = test(val_data_tensor,val_label_tensor,fed_model,criterion,use_cuda)
        te_loss, te_acc = test(te_data_tensor,te_label_tensor, fed_model, criterion, use_cuda)

        is_best = best_global_acc < val_acc

        best_global_acc = max(best_global_acc, val_acc)

        if is_best:
            best_global_te_acc = te_acc


        print('epoch: %d, %s: at %s n_at %d e %d | val loss %.4f val acc %.4f best val_acc %f'%(epoch_num, aggregation, at_type, n_attacker, epoch_num, val_loss, val_acc, best_global_acc))
        new_row = pd.DataFrame([{
            'epoch': epoch_num,
            'loss': val_loss,
            'validation accuracy': val_acc,
            'best validation accuracy': best_global_acc
            }])
        df = pd.concat([df, new_row], ignore_index=True)
        df.to_csv('./our attack + 10 attacker + our defense.csv', index=False)

        if val_loss > 1000:
            print('val loss %f too high'%val_loss)
            break

        epoch_num+=1
# Out:
# discarded index [47, 43, 12, 18, 26, 46, 25, 49, 16, 40]
# epoch: 0, bulyan: at our-agr n_at 10 e 0 | val loss 2.3030 val acc 10.1867 best val_acc 10.186688
# C:\Users\Hizan\AppData\Local\Temp\ipykernel_20104\1099200655.py:132: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, new_row], ignore_index=True)
# discarded index [47, 43, 26, 12, 18, 46, 49, 25, 40, 35]
# epoch: 1, bulyan: at our-agr n_at 10 e 1 | val loss 2.3027 val acc 10.2273 best val_acc 10.227273
# discarded index [47, 43, 26, 12, 18, 49, 46, 25, 35, 29]
# epoch: 2, bulyan: at our-agr n_at 10 e 2 | val loss 2.3026 val acc 10.2273 best val_acc 10.227273
# discarded index [47, 12, 43, 26, 18, 49, 45, 41, 0, 1]
# epoch: 3, bulyan: at our-agr n_at 10 e 3 | val loss 2.3026 val acc 10.2273 best val_acc 10.227273
# discarded index [47, 43, 12, 26, 18, 49, 46, 25, 35, 29]
# epoch: 4, bulyan: at our-agr n_at 10 e 4 | val loss 2.3027 val acc 10.2273 best val_acc 10.227273
# discarded index [47,
# epoch: 23, bulyan: at our-agr n_at 10 e 23 | val loss 2.3016 val acc 9.8620 best val_acc 11.668019
# discarded index [23, 41, 47, 12, 43, 45, 24, 18, 26, 46]
# epoch: 24, bulyan: at our-agr n_at 10 e 24 | val loss 2.2992 val acc 9.9838 best val_acc 11.668019
# discarded index [23, 41, 47, 45, 12, 43, 26, 18, 24, 46]
# epoch: 25, bulyan: at our-agr n_at 10 e 25 | val loss 2.2985 val acc 10.5722 best val_acc 11.668019
# discarded index [23, 41, 47, 45, 12, 24, 43, 18, 26, 49]
# epoch: 26, bulyan: at our-agr n_at 10 e 26 | val loss 2.2941 val acc 13.3929 best val_acc 13.392857
# discarded index [23, 47, 41, 12, 45, 18, 43, 26, 20, 24]
# epoch: 27, bulyan: at our-agr n_at 10 e 27 | val loss 2.3050 val acc 13.7784 best val_acc 13.778409
# discarded index [23, 47, 20, 41, 12, 26, 18, 49, 45, 43]
# epoch: 28, bulyan: at our-agr n_at 10 e 28 | val loss 2.3042 val acc 14.1234 best val_acc 14.123377
# discarded index [23, 20, 47, 26, 18, 49, 12, 41, 43, 38]
# epoch: 29, bulyan: at our-agr n_at 10 e 29 | val loss 2.3150 val acc 15.0568 best val_acc 15.056818
# discarded index [20, 23, 47, 26, 18, 49, 12, 41, 35, 40]
# epoch: 30, bulyan: at our-agr n_at 10 e 30 | val loss 2.2909 val acc 14.0422 best val_acc 15.056818
# discarded index [20, 23, 47, 18, 26, 49, 12, 40, 35, 25]
# epoch: 31, bulyan: at our-agr n_at 10 e 31 | val loss 2.3028 val acc 10.7346 best val_acc 15.056818
# discarded index [20, 23, 47, 18, 26, 49, 12, 40, 35, 25]
# epoch: 32, bulyan: at our-agr n_at 10 e 32 | val loss 2.3916 val acc 10.9172 best val_acc 15.056818
# discarded index [23, 20, 24, 18, 47, 25, 26, 49, 41, 35]
# epoch: 33, bulyan: at our-agr n_at 10 e 33 | val loss 2.4077 val acc 9.3547 best val_acc 15.056818
# discarded index [23, 20, 24, 18, 47, 25, 26, 41, 49, 35]
# epoch: 34, bulyan: at our-agr n_at 10 e 34 | val loss 2.3053 val acc 11.7086 best val_acc 15.056818
# discarded index [20, 23, 24, 47, 18, 26, 25, 49, 41, 35]
# epoch: 35, bulyan: at our-agr n_at 10 e 35 | val loss 2.2810 val acc 13.2711 best val_acc 15.056818
# discarded index [20, 23, 24, 18, 47, 26, 25, 41, 49, 35]
# epoch: 36, bulyan: at our-agr n_at 10 e 36 | val loss 2.2649 val acc 16.5584 best val_acc 16.558442
# discarded index [20, 23, 47, 18, 26, 24, 49, 25, 41, 35]
# epoch: 37, bulyan: at our-agr n_at 10 e 37 | val loss 2.2454 val acc 14.6307 best val_acc 16.558442
# discarded index [20, 23, 47, 18, 24, 41, 26, 49, 25, 45]
# epoch: 38, bulyan: at our-agr n_at 10 e 38 | val loss 2.7033 val acc 15.3409 best val_acc 16.558442
# discarded index [20, 23, 25, 41, 45, 35, 24, 47, 18, 26]
# epoch: 39, bulyan: at our-agr n_at 10 e 39 | val loss 2.5384 val acc 11.4854 best val_acc 16.558442
# discarded index [20, 23, 25, 41, 45, 35, 24, 47, 18, 26]
# epoch: 40, bulyan: at our-agr n_at 10 e 40 | val loss 2.4829 val acc 10.9781 best val_acc 16.558442
# discarded index [20, 23, 25, 41, 45, 35, 24, 47, 18, 26]
# epoch: 41, bulyan: at our-agr n_at 10 e 41 | val loss 2.4694 val acc 10.6534 best val_acc 16.558442
# discarded index [20, 23, 25, 41, 45, 35, 24, 47, 18, 26]
# epoch: 42, bulyan: at our-agr n_at 10 e 42 | val loss 2.4166 val acc 11.5463 best val_acc 16.558442
# discarded index [20, 23, 25, 41, 45, 35, 24, 47, 18, 26]
# epoch: 43, bulyan: at our-agr n_at 10 e 43 | val loss 2.4066 val acc 10.9375 best val_acc 16.558442
# discarded index [20, 23, 25, 41, 45, 35, 24, 47, 18, 26]
# epoch: 44, bulyan: at our-agr n_at 10 e 44 | val loss 2.3860 val acc 13.1696 best val_acc 16.558442
# discarded index [20, 23, 25, 41, 45, 35, 24, 47, 18, 26]
# epoch: 45, bulyan: at our-agr n_at 10 e 45 | val loss 2.4172 val acc 11.4448 best val_acc 16.558442
# discarded index [20, 23, 25, 41, 45, 35, 24, 47, 26, 18]
# epoch: 46, bulyan: at our-agr n_at 10 e 46 | val loss 2.3672 val acc 14.8945 best val_acc 16.558442
# discarded index [20, 23, 25, 45, 41, 35, 24, 47, 26, 18]
# epoch: 47, bulyan: at our-agr n_at 10 e 47 | val loss 2.3795 val acc 11.8506 best val_acc 16.558442
# discarded index [20, 23, 25, 45, 41, 35, 24, 47, 26, 18]
# epoch: 48, bulyan: at our-agr n_at 10 e 48 | val loss 2.3681 val acc 15.4830 best val_acc 16.558442
# discarded index [20, 23, 25, 45, 41, 35, 24, 47, 26, 18]
# epoch: 49, bulyan: at our-agr n_at 10 e 49 | val loss 2.6038 val acc 10.2273 best val_acc 16.558442
# discarded index [20, 23, 45, 25, 35, 41, 47, 26, 24, 15]
# epoch: 50, bulyan: at our-agr n_at 10 e 50 | val loss 2.6337 val acc 10.2476 best val_acc 16.558442
# discarded index [20, 23, 45, 25, 41, 35, 47, 26, 24, 15]
# epoch: 51, bulyan: at our-agr n_at 10 e 51 | val loss 2.4861 val acc 12.3782 best val_acc 16.558442
# discarded index [20, 23, 45, 25, 41, 35, 47, 26, 24, 15]
# epoch: 52, bulyan: at our-agr n_at 10 e 52 | val loss 2.3510 val acc 10.3693 best val_acc 16.558442
# discarded index [20, 23, 45, 25, 41, 35, 47, 26, 24, 18]
# epoch: 53, bulyan: at our-agr n_at 10 e 53 | val loss 2.3061 val acc 15.7670 best val_acc 16.558442
# discarded index [20, 23, 45, 25, 41, 35, 47, 26, 24, 18]
# epoch: 54, bulyan: at our-agr n_at 10 e 54 | val loss 2.2820 val acc 17.4716 best val_acc 17.471591
# discarded index [20, 23, 45, 25, 41, 35, 47, 26, 24, 18]
# epoch: 55, bulyan: at our-agr n_at 10 e 55 | val loss 2.2496 val acc 17.6542 best val_acc 17.654221
# discarded index [20, 23, 45, 25, 41, 35, 47, 26, 24, 18]
# epoch: 56, bulyan: at our-agr n_at 10 e 56 | val loss 2.3272 val acc 19.2979 best val_acc 19.297890
# discarded index [20, 23, 45, 25, 35, 41, 44, 0, 1, 2]
# epoch: 57, bulyan: at our-agr n_at 10 e 57 | val loss 2.7125 val acc 10.2679 best val_acc 19.297890
# discarded index [20, 23, 45, 25, 35, 41, 44, 0, 1, 2]
# epoch: 58, bulyan: at our-agr n_at 10 e 58 | val loss 2.3354 val acc 17.9383 best val_acc 19.297890
# discarded index [20, 23, 45, 25, 35, 41, 44, 0, 1, 2]
# epoch: 59, bulyan: at our-agr n_at 10 e 59 | val loss 2.3453 val acc 16.4570 best val_acc 19.297890
# discarded index [20, 23, 45, 25, 35, 41, 44, 26, 47, 49]
# epoch: 60, bulyan: at our-agr n_at 10 e 60 | val loss 2.3596 val acc 13.7987 best val_acc 19.297890
# discarded index [20, 23, 45, 25, 35, 41, 44, 26, 47, 49]
# epoch: 61, bulyan: at our-agr n_at 10 e 61 | val loss 2.2494 val acc 14.5292 best val_acc 19.297890
# discarded index [20, 23, 45, 25, 35, 41, 44, 26, 47, 24]
# epoch: 62, bulyan: at our-agr n_at 10 e 62 | val loss 2.4170 val acc 19.5617 best val_acc 19.561688
# discarded index [20, 23, 25, 35, 45, 41, 44, 24, 26, 47]
# epoch: 63, bulyan: at our-agr n_at 10 e 63 | val loss 2.4733 val acc 12.3580 best val_acc 19.561688
# discarded index [20, 23, 25, 35, 45, 41, 44, 24, 26, 47]
# epoch: 64, bulyan: at our-agr n_at 10 e 64 | val loss 2.4351 val acc 13.1088 best val_acc 19.561688
# discarded index [20, 23, 25, 35, 45, 41, 44, 26, 24, 47]
# epoch: 65, bulyan: at our-agr n_at 10 e 65 | val loss 2.3872 val acc 14.6104 best val_acc 19.561688
# discarded index [20, 23, 25, 35, 45, 41, 44, 24, 26, 47]
# epoch: 66, bulyan: at our-agr n_at 10 e 66 | val loss 2.7089 val acc 16.2541 best val_acc 19.561688
# discarded index [20, 23, 35, 25, 41, 45, 44, 24, 15, 26]
# epoch: 67, bulyan: at our-agr n_at 10 e 67 | val loss 2.4953 val acc 14.8133 best val_acc 19.561688
# discarded index [20, 23, 35, 25, 41, 45, 44, 24, 15, 26]
# epoch: 68, bulyan: at our-agr n_at 10 e 68 | val loss 2.9451 val acc 9.6794 best val_acc 19.561688
# discarded index [20, 35, 45, 25, 23, 41, 44, 15, 24, 26]
# epoch: 69, bulyan: at our-agr n_at 10 e 69 | val loss 2.6272 val acc 10.6128 best val_acc 19.561688
# discarded index [20, 35, 45, 23, 25, 41, 44, 24, 15, 26]
# epoch: 70, bulyan: at our-agr n_at 10 e 70 | val loss 2.7220 val acc 13.1291 best val_acc 19.561688
# discarded index [20, 44, 35, 45, 25, 23, 41, 15, 24, 26]
# epoch: 71, bulyan: at our-agr n_at 10 e 71 | val loss 2.6689 val acc 10.5317 best val_acc 19.561688
# discarded index [20, 44, 35, 45, 25, 23, 41, 15, 24, 26]
# epoch: 72, bulyan: at our-agr n_at 10 e 72 | val loss 2.4434 val acc 10.2273 best val_acc 19.561688
# discarded index [20, 35, 45, 25, 23, 41, 44, 15, 24, 26]
# epoch: 73, bulyan: at our-agr n_at 10 e 73 | val loss 2.3535 val acc 13.3523 best val_acc 19.561688
# discarded index [20, 44, 35, 45, 25, 23, 41, 15, 24, 26]
# epoch: 74, bulyan: at our-agr n_at 10 e 74 | val loss 2.2611 val acc 15.9903 best val_acc 19.561688
# discarded index [20, 44, 35, 45, 25, 23, 41, 24, 15, 26]
# epoch: 75, bulyan: at our-agr n_at 10 e 75 | val loss 2.3539 val acc 17.9180 best val_acc 19.561688
# discarded index [20, 44, 35, 45, 25, 23, 41, 24, 15, 26]
# epoch: 76, bulyan: at our-agr n_at 10 e 76 | val loss 2.3118 val acc 17.3295 best val_acc 19.561688
# discarded index [20, 44, 35, 45, 25, 23, 41, 24, 15, 26]
# epoch: 77, bulyan: at our-agr n_at 10 e 77 | val loss 2.5316 val acc 18.6688 best val_acc 19.561688
# discarded index [20, 35, 45, 25, 23, 41, 44, 15, 24, 26]
# epoch: 78, bulyan: at our-agr n_at 10 e 78 | val loss 2.3160 val acc 15.3815 best val_acc 19.561688
# discarded index [20, 35, 45, 25, 23, 41, 44, 15, 24, 26]
# epoch: 79, bulyan: at our-agr n_at 10 e 79 | val loss 2.3131 val acc 17.5731 best val_acc 19.561688
# discarded index [20, 44, 35, 45, 25, 23, 41, 15, 24, 26]
# epoch: 80, bulyan: at our-agr n_at 10 e 80 | val loss 2.2070 val acc 15.6656 best val_acc 19.561688
# discarded index [20, 44, 35, 45, 25, 23, 41, 15, 24, 26]
# epoch: 81, bulyan: at our-agr n_at 10 e 81 | val loss 2.2469 val acc 19.9675 best val_acc 19.967532
# discarded index [20, 44, 35, 45, 25, 23, 41, 15, 24, 26]
# epoch: 82, bulyan: at our-agr n_at 10 e 82 | val loss 2.2753 val acc 18.4456 best val_acc 19.967532
# discarded index [20, 44, 35, 45, 25, 23, 41, 24, 15, 26]
# epoch: 83, bulyan: at our-agr n_at 10 e 83 | val loss 2.3766 val acc 13.1696 best val_acc 19.967532
# discarded index [20, 44, 35, 45, 25, 23, 41, 15, 26, 24]
# epoch: 84, bulyan: at our-agr n_at 10 e 84 | val loss 2.2420 val acc 15.2800 best val_acc 19.967532
# discarded index [20, 44, 35, 25, 45, 23, 41, 15, 26, 24]
# epoch: 85, bulyan: at our-agr n_at 10 e 85 | val loss 2.2843 val acc 20.0081 best val_acc 20.008117
# discarded index [20, 44, 35, 25, 45, 23, 41, 26, 15, 24]
# epoch: 86, bulyan: at our-agr n_at 10 e 86 | val loss 2.2746 val acc 17.9586 best val_acc 20.008117
# discarded index [20, 44, 35, 25, 45, 23, 41, 15, 26, 24]
# epoch: 87, bulyan: at our-agr n_at 10 e 87 | val loss 2.2191 val acc 15.6250 best val_acc 20.008117
# discarded index [20, 44, 35, 25, 45, 23, 41, 26, 15, 24]
# epoch: 88, bulyan: at our-agr n_at 10 e 88 | val loss 2.1315 val acc 17.5325 best val_acc 20.008117
# discarded index [20, 44, 35, 25, 45, 23, 41, 26, 15, 24]
# epoch: 89, bulyan: at our-agr n_at 10 e 89 | val loss 2.2771 val acc 20.0487 best val_acc 20.048701
# discarded index [20, 35, 44, 25, 45, 23, 41,
best val_acc 20.048701
# discarded index [20, 35, 44, 25, 45, 23, 41, 24, 15, 26]
# epoch: 114, bulyan: at our-agr n_at 10 e 114 | val loss 2.8782 val acc 18.6891 best val_acc 20.048701
# discarded index [20, 35, 44, 25, 45, 23, 41, 24, 26, 15]
# epoch: 115, bulyan: at our-agr n_at 10 e 115 | val loss 2.6055 val acc 11.7086 best val_acc 20.048701
# discarded index [20, 35, 44, 25, 23, 45, 41, 24, 26, 15]
# epoch: 116, bulyan: at our-agr n_at 10 e 116 | val loss 2.4967 val acc 10.9781 best val_acc 20.048701
# discarded index [20, 35, 44, 25, 45, 23, 41, 24, 26, 13]
# epoch: 117, bulyan: at our-agr n_at 10 e 117 | val loss 2.3257 val acc 15.6250 best val_acc 20.048701
# discarded index [20, 35, 44, 23, 25, 45, 41, 24, 26, 13]
# epoch: 118, bulyan: at our-agr n_at 10 e 118 | val loss 2.3436 val acc 18.0804 best val_acc 20.048701
# discarded index [20, 35, 44, 25, 45, 23, 41, 24, 26, 13]
# epoch: 119, bulyan: at our-agr n_at 10 e 119 | val loss 2.1831 val acc 16.9237 best val_acc 20.048701
# discarded index [20, 35, 44, 23, 25, 45, 41, 24, 26, 15]
# epoch: 120, bulyan: at our-agr n_at 10 e 120 | val loss 2.6606 val acc 17.6136 best val_acc 20.048701
# discarded index [20, 35, 44, 23, 25, 45, 41, 24, 26, 13]
# epoch: 121, bulyan: at our-agr n_at 10 e 121 | val loss 2.4068 val acc 15.5438 best val_acc 20.048701
# discarded index [20, 35, 44, 23, 25, 45, 41, 24, 26, 13]
# epoch: 122, bulyan: at our-agr n_at 10 e 122 | val loss 2.5061 val acc 18.9935 best val_acc 20.048701
# discarded index [20, 35, 44, 23, 25, 45, 41, 24, 15, 13]
# epoch: 123, bulyan: at our-agr n_at 10 e 123 | val loss 2.2758 val acc 17.1266 best val_acc 20.048701
# discarded index [20, 35, 44, 23, 25, 45, 41, 24, 15, 13]
# epoch: 124, bulyan: at our-agr n_at 10 e 124 | val loss 2.1054 val acc 20.0690 best val_acc 20.068994
# discarded index [20, 35, 44, 23, 25, 45, 41, 24, 26, 13]
# epoch: 125, bulyan: at our-agr n_at 10 e 125 | val loss 2.1260 val acc 20.5966 best val_acc 20.596591
# discarded index [20, 35, 44, 23, 25, 45, 41, 24, 26, 13]
# epoch: 126, bulyan: at our-agr n_at 10 e 126 | val loss 2.1643 val acc 17.1266 best val_acc 20.596591
# discarded index [20, 35, 44, 23, 25, 45, 41, 24, 15, 13]
# epoch: 127, bulyan: at our-agr n_at 10 e 127 | val loss 2.1556 val acc 17.4919 best val_acc 20.596591
# discarded index [20, 35, 44, 23, 25, 45, 41, 24, 26, 13]
# epoch: 128, bulyan: at our-agr n_at 10 e 128 | val loss 2.1439 val acc 19.5617 best val_acc 20.596591
# discarded index [20, 35, 44, 23, 25, 41, 45, 24, 26, 13]
# epoch: 129, bulyan: at our-agr n_at 10 e 129 | val loss 2.4049 val acc 17.5122 best val_acc 20.596591
# discarded index [20, 35, 44, 23, 25, 41, 45, 24, 26, 13]
# epoch: 130, bulyan: at our-agr n_at 10 e 130 | val loss 2.4822 val acc 12.2971 best val_acc 20.596591
# discarded index [20, 35, 23, 25, 41, 45, 44, 24, 26, 13]
# epoch: 131, bulyan: at our-agr n_at 10 e 131 | val loss 2.3443 val acc 14.1234 best val_acc 20.596591
# discarded index [20, 35, 23, 25, 41, 45, 44, 24, 26, 13]
# epoch: 132, bulyan: at our-agr n_at 10 e 132 | val loss 2.3129 val acc 16.4570 best val_acc 20.596591
# discarded index [20, 35, 23, 25, 41, 45, 44, 24, 26, 13]
# epoch: 133, bulyan: at our-agr n_at 10 e 133 | val loss 2.7638 val acc 18.5268 best val_acc 20.596591
# discarded index [20, 35, 23, 25, 41, 45, 44, 24, 15, 13]
# epoch: 134, bulyan: at our-agr n_at 10 e 134 | val loss 2.4262 val acc 16.3352 best val_acc 20.596591
# discarded index [20, 35, 23, 25, 41, 45, 44, 24, 15, 13]
# epoch: 135, bulyan: at our-agr n_at 10 e 135 | val loss 2.3701 val acc 17.5933 best val_acc 20.596591
# discarded index [20, 35, 23, 25, 41, 45, 44, 24, 15, 13]
# epoch: 136, bulyan: at our-agr n_at 10 e 136 | val loss 2.2808 val acc 17.3701 best val_acc 20.596591
# discarded index [20, 35, 23, 41, 25, 45, 44, 24, 15, 13]
# epoch: 137, bulyan: at our-agr n_at 10 e 137 | val loss 2.8753 val acc 19.3791 best val_acc 20.596591
# discarded index [20, 35, 23, 25, 41, 45, 44, 24, 15, 13]
# epoch: 138, bulyan: at our-agr n_at 10 e 138 | val loss 2.5107 val acc 13.9205 best val_acc 20.596591
# discarded index [20, 35, 23, 41, 25, 45, 44, 24, 15, 13]
# epoch: 139, bulyan: at our-agr n_at 10 e 139 | val loss 2.6698 val acc 16.2946 best val_acc 20.596591
# discarded index [20, 35, 23, 41, 25, 45, 44, 24, 15, 13]
# epoch: 140, bulyan: at our-agr n_at 10 e 140 | val loss 2.4890 val acc 17.7963 best val_acc 20.596591
# discarded index [20, 35, 23, 41, 25, 45, 44, 24, 15, 13]
# epoch: 141, bulyan: at our-agr n_at 10 e 141 | val loss 2.5486 val acc 16.7208 best val_acc 20.596591
# discarded index [20, 35, 23, 41, 25, 45, 44, 24, 15, 13]
# epoch: 142, bulyan: at our-agr n_at 10 e 142 | val loss 2.3383 val acc 16.0511 best val_acc 20.596591
# discarded index [20, 35, 23, 41, 25, 45, 44, 24, 15, 13]
# epoch: 143, bulyan: at our-agr n_at 10 e 143 | val loss 2.1882 val acc 16.8019 best val_acc 20.596591
# discarded index [20, 35, 23, 41, 25, 45, 44, 24, 15, 13]
# epoch: 144, bulyan: at our-agr n_at 10 e 144 | val loss 2.1598 val acc 17.9586 best val_acc 20.596591
# discarded index [20, 35, 23, 41, 25, 45, 44, 24, 15, 13]
# epoch: 145, bulyan: at our-agr n_at 10 e 145 | val loss 2.3247 val acc 17.4310 best val_acc 20.596591
# discarded index [20, 35, 23, 41, 25, 45, 44, 24, 15, 13]
# epoch: 146, bulyan: at our-agr n_at 10 e 146 | val loss 2.4067 val acc 17.3904 best val_acc 20.596591
# discarded index [20, 35, 23, 41, 25, 45, 44, 24, 15, 13]
# epoch: 147, bulyan: at our-agr n_at 10 e 147 | val loss 2.8409 val acc 12.7232 best val_acc 20.596591
# discarded index [20, 35, 23, 41, 45, 25, 44, 24, 13, 15]
# epoch: 148, bulyan: at our-agr n_at 10 e 148 | val loss 2.5121 val acc 12.7232 best val_acc 20.596591
# discarded index [20, 35, 23, 41, 45, 25, 44, 24, 15, 13]
# epoch: 149, bulyan: at our-agr n_at 10 e 149 | val loss 2.3177 val acc 16.4570 best val_acc 20.596591
# discarded index [20, 35, 23, 41, 45, 25, 44, 24, 13, 15]
# epoch: 150, bulyan: at our-agr n_at 10 e 150 | val loss 2.2518 val acc 14.2451 best val_acc 20.596591
# discarded index [20, 35, 23, 41, 45, 25, 44, 24, 13, 15]
# epoch: 151, bulyan: at our-agr n_at 10 e 151 | val loss 2.4366 val acc 11.6883 best val_acc 20.596591
# discarded index [20, 35, 23, 41, 45, 25, 44, 24, 13, 15]
# epoch: 152, bulyan: at our-agr n_at 10 e 152 | val loss 3.1036 val acc 17.6339 best val_acc 20.596591
# discarded index [20, 35, 23, 41, 45, 25, 44, 24, 13, 15]
# epoch: 153, bulyan: at our-agr n_at 10 e 153 | val loss 2.5866 val acc 17.5528 best val_acc 20.596591
# discarded index [20, 35, 23, 41, 45, 25, 44, 24, 13, 15]
# epoch: 154, bulyan: at our-agr n_at 10 e 154 | val loss 2.6205 val acc 18.0601 best val_acc 20.596591
# discarded index [20, 35, 23, 41, 45, 25, 44, 24, 13, 15]
# epoch: 155, bulyan: at our-agr n_at 10 e 155 | val loss 2.2341 val acc 17.1063 best val_acc 20.596591
# discarded index [20, 35, 23, 41, 45, 25, 44, 24, 13, 15]
# epoch: 156, bulyan: at our-agr n_at 10 e 156 | val loss 2.0684 val acc 18.9935 best val_acc 20.596591
# discarded index [20, 35, 23, 41, 45, 25, 44, 24, 13, 15]
# epoch: 157, bulyan: at our-agr n_at 10 e 157 | val loss 2.0413 val acc 21.4286 best val_acc 21.428571
# discarded index [20, 35, 23, 41, 45, 25, 44, 24, 13, 15]
# epoch: 158, bulyan: at our-agr n_at 10 e 158 | val loss 2.1489 val acc 17.1875 best val_acc 21.428571
# discarded index [20, 23, 35, 41, 45, 25, 44, 24, 13, 15]
# epoch: 159, bulyan: at our-agr n_at 10 e 159 | val loss 2.2886 val acc 16.9846 best val_acc 21.428571
# discarded index [20, 23, 35, 41, 45, 25, 44, 24, 13, 26]
# epoch: 160, bulyan: at our-agr n_at 10 e 160 | val loss 2.5780 val acc 13.1899 best val_acc 21.428571
# discarded index [20, 23, 35, 41, 45, 25, 44, 24, 13, 26]
# epoch: 161, bulyan: at our-agr n_at 10 e 161 | val loss 2.3343 val acc 16.6802 best val_acc 21.428571
# discarded index [20, 23, 35, 41, 45, 25, 44, 24, 13, 26]
# epoch: 162, bulyan: at our-agr n_at 10 e 162 | val loss 2.0989 val acc 19.6429 best val_acc 21.428571
# discarded index [20, 23, 35, 41, 45, 25, 44, 24, 13, 26]
# epoch: 163, bulyan: at our-agr n_at 10 e 163 | val loss 2.5641 val acc 19.6834 best val_acc 21.428571
# discarded index [20, 23, 35, 41, 45, 25, 44, 24, 13, 26]
# epoch: 164, bulyan: at our-agr n_at 10 e 164 | val loss 2.5784 val acc 14.0422 best val_acc 21.428571
# discarded index [20, 23, 35, 41, 45, 25, 44, 24, 13, 26]
# epoch: 165, bulyan: at our-agr n_at 10 e 165 | val loss 2.9911 val acc 18.4050 best val_acc 21.428571
# discarded index [20, 23, 35, 41, 45, 25, 44, 24, 13, 15]
# epoch: 166, bulyan: at our-agr n_at 10 e 166 | val loss 2.5037 val acc 11.9521 best val_acc 21.428571
# discarded index [20, 23, 35, 41, 45, 25, 44, 24, 13, 15]
# epoch: 167, bulyan: at our-agr n_at 10 e 167 | val loss 2.4260 val acc 17.5325 best val_acc 21.428571
# discarded index [20, 23, 35, 41, 45, 25, 44, 24, 13, 15]
# epoch: 168, bulyan: at our-agr n_at 10 e 168 | val loss 2.3489 val acc 16.7817 best val_acc 21.428571
# discarded index [20, 23, 35, 41, 45, 25, 44, 24, 13, 15]
# epoch: 169, bulyan: at our-agr n_at 10 e 169 | val loss 2.6266 val acc 11.4854 best val_acc 21.428571
# discarded index [20, 23, 35, 41, 45, 25, 44, 24, 13, 15]
# epoch: 170, bulyan: at our-agr n_at 10 e 170 | val loss 3.0852 val acc 13.4740 best val_acc 21.428571
# discarded index [20, 23, 35, 45, 41, 25, 44, 24, 13, 15]
# epoch: 171, bulyan: at our-agr n_at 10 e 171 | val loss 2.3351 val acc 16.6802 best val_acc 21.428571
# discarded index [20, 23, 35, 41, 45, 25, 44, 24, 13, 15]
# epoch: 172, bulyan: at our-agr n_at 10 e 172 | val loss 2.6195 val acc 18.6080 best val_acc 21.428571
# discarded index [20, 23, 35, 41, 45, 25, 44, 24, 13, 15]
# epoch: 173, bulyan: at our-agr n_at 10 e 173 | val loss 2.6549 val acc 13.0682 best val_acc 21.428571
# discarded index [20, 23, 35, 41, 45, 25, 44, 24, 13, 15]
# epoch: 174, bulyan: at our-agr n_at 10 e 174 | val loss 3.1314 val acc 14.9148 best val_acc 21.428571
# discarded index [20, 23, 35, 45, 41, 25, 44, 24, 13, 15]
# epoch: 175, bulyan: at our-agr n_at 10 e 175 | val loss 2.3460 val acc 17.6948 best val_acc 21.428571
# discarded index [20, 23, 35, 45, 41, 25, 44, 24, 13, 15]
# epoch: 176, bulyan: at our-agr n_at 10 e 176 | val loss 2.7322 val acc 18.3239 best val_acc 21.428571
# discarded index [20, 35, 23, 41, 45, 25, 44, 24, 13, 15]
# epoch: 177, bulyan: at our-agr n_at 10 e 177 | val loss 2.8408 val acc 10.3896 best val_acc 21.428571
# discarded index [20, 23, 35, 41, 45, 25, 44, 24, 13, 15]
# epoch: 178, bulyan: at our-agr n_at 10 e 178 | val loss 3.0990 val acc 10.1258 best val_acc 21.428571
# discarded index [20, 35, 23, 45, 41, 25, 44, 24, 13, 15]
# epoch: 179, bulyan: at our-agr n_at 10 e 179 | val loss 2.4911 val acc 9.8823 best val_acc 21.428571
# discarded index [20, 35, 23, 45, 41, 25, 44, 24, 13, 15]
# epoch: 180, bulyan: at our-agr n_at 10 e 180 | val loss 3.0180 val acc 15.8685 best val_acc 21.428571
# discarded index [20, 35, 23, 45, 41, 25, 44, 24, 13, 15]
# epoch: 181, bulyan: at our-agr n_at 10 e 181 | val loss 2.9257 val acc 9.9229 best val_acc 21.428571
# discarded index [20, 35, 23, 45, 41, 25, 44, 24, 13, 15]
# epoch: 182, bulyan: at our-agr n_at 10 e 182 | val loss 2.8697 val acc 16.0308 best val_acc 21.428571
# discarded index [20, 35, 23, 45, 41, 25, 44, 24, 13, 15]
# epoch: 183, bulyan: at our-agr n_at 10 e 183 | val loss 2.2013 val acc 15.0162 best val_acc 21.428571
# discarded index [20, 35, 23, 45, 41, 25, 44, 24, 13, 15]
# epoch: 184, bulyan: at our-agr n_at 10 e 184 | val loss 2.3305 val acc 19.3588 best val_acc 21.428571
# discarded index [20, 35, 23, 45, 41, 25, 44, 24, 13, 15]
# epoch: 185, bulyan: at our-agr n_at 10 e 185 | val loss 2.8211 val acc 15.5235 best val_acc 21.428571
# discarded index [20, 35, 23, 45, 41, 25, 44, 24, 13, 15]
# epoch: 186, bulyan: at our-agr n_at 10 e 186 | val loss 3.1909 val acc 18.3442 best val_acc 21.428571
# discarded index [20, 35, 23, 45, 41, 25, 44, 24, 13, 15]
# epoch: 187, bulyan: at our-agr n_at 10 e 187 | val loss 3.1297 val acc 11.0390 best val_acc 21.428571
# discarded index [20, 23, 35, 45, 41, 25, 44, 24, 13, 15]
# epoch: 188, bulyan: at our-agr n_at 10 e 188 | val loss 2.8499 val acc 16.3758 best val_acc 21.428571
# discarded index [20, 35, 23, 45, 41, 25, 44, 24, 13, 15]
# epoch: 189, bulyan: at our-agr n_at 10 e 189 | val loss 2.5550 val acc 12.7435 best val_acc 21.428571
# discarded index [20, 35, 23, 45, 41, 25, 44, 24, 13, 15]
# epoch: 190, bulyan: at our-agr n_at 10 e 190 | val loss 2.6141 val acc 10.0041 best val_acc 21.428571
# discarded index [20, 23, 35, 45, 41, 25, 44, 24, 13, 15]
# epoch: 191, bulyan: at our-agr n_at 10 e 191 | val loss 2.4904 val acc 17.4919 best val_acc 21.428571
# discarded index [20, 23, 35, 45, 41, 25, 44, 24, 13, 15]
# epoch: 192, bulyan: at our-agr n_at 10 e 192 | val loss 2.8095 val acc 14.7727 best val_acc 21.428571
# discarded index [20, 23, 35, 45, 41, 25, 44, 24, 13, 15]
# epoch: 193, bulyan: at our-agr n_at 10 e 193 | val loss 3.4977 val acc 19.3994 best val_acc 21.428571
# discarded index [20, 23, 35, 45, 41, 25, 44, 24, 13, 15]
# epoch: 194, bulyan: at our-agr n_at 10 e 194 | val loss 2.7002 val acc 12.7638 best val_acc 21.428571
# discarded index [20, 23, 35, 45, 41, 25, 44, 24, 13, 15]
# epoch: 195, bulyan: at our-agr n_at 10 e 195 | val loss 2.4492 val acc 15.5032 best val_acc 21.428571
# discarded index [20, 23, 35, 45, 41, 25, 44, 24, 13, 15]
# epoch: 196, bulyan: at our-agr n_at 10 e 196 | val loss 2.3334 val acc 13.5349 best val_acc 21.428571
# discarded index [20, 23, 35, 45, 41, 25, 44, 24, 13, 15]
# epoch: 197, bulyan: at our-agr n_at 10 e 197 | val loss 3.0374 val acc 16.9440 best val_acc 21.428571
# discarded index [20, 23, 35, 45, 41, 25, 44, 24, 13, 15]
# epoch: 198, bulyan: at our-agr n_at 10 e 198 | val loss 2.9915 val acc 16.7208 best val_acc 21.428571
# discarded index [20, 23, 35, 45, 41, 25, 44, 24, 13, 15]
# epoch: 199, bulyan: at our-agr n_at 10 e 199 | val loss 3.1271 val acc 12.2565 best val_acc 21.428571
# discarded index [20, 23, 35, 45, 41, 25, 44, 24, 15, 13]
# epoch: 200, bulyan: at our-agr n_at 10 e 200 | val loss 2.5278 val acc 14.0625 best val_acc 21.428571
# discarded index [20, 23, 35, 45, 41, 25, 44, 24, 15, 13]
# epoch: 201, bulyan: at our-agr n_at 10 e 201 | val loss 2.2667 val acc 17.6339 best val_acc 21.428571
# discarded index [20, 23, 35, 45, 41, 25, 44, 24, 15, 13]
# epoch: 202, bulyan: at our-agr n_at 10 e 202 | val loss 2.0314 val acc 20.3328 best val_acc 21.428571
# discarded index [20, 23, 35, 45, 41, 25, 44, 24, 15, 13]
# epoch: 203, bulyan: at our-agr n_at 10 e 203 | val loss 2.1173 val acc 15.7265 best val_acc 21.428571
# discarded index [20, 23, 35, 45, 41, 25, 44, 24, 13, 15]
# epoch: 204, bulyan: at our-agr n_at 10 e 204 | val loss 2.7876 val acc 16.6599 best val_acc 21.428571
# discarded index [20, 23, 35, 45, 41, 25, 44, 24, 13, 15]
# epoch: 205, bulyan: at our-agr n_at 10 e 205 | val loss 3.0625 val acc 13.6364 best val_acc 21.428571
# discarded index [20, 23, 35, 45, 41, 25, 44, 24, 13, 15]
# epoch: 206, bulyan: at our-agr n_at 10 e 206 | val loss 4.5225 val acc 10.5722 best val_acc 21.428571
# discarded index [20, 45, 35, 23, 41, 25, 24, 15, 13, 26]
# epoch: 207, bulyan: at our-agr n_at 10 e 207 | val loss 2.7650 val acc 10.9578 best val_acc 21.428571
# discarded index [20, 45, 35, 23, 41, 25, 24, 15, 13, 26]
# epoch: 208, bulyan: at our-agr n_at 10 e 208 | val loss 2.5982 val acc 17.6948 best val_acc 21.428571
# discarded index [20, 45, 35, 23, 41, 25, 24, 15, 13, 26]
# epoch: 209, bulyan: at our-agr n_at 10 e 209 | val loss 3.2857 val acc 10.7752 best val_acc 21.428571
# discarded index [20, 45, 35, 23, 41, 25, 24, 15, 13, 26]
# epoch: 210, bulyan: at our-agr n_at 10 e 210 | val loss 10.4826 val acc 10.1461 best val_acc 21.428571
# discarded index [20, 44, 35, 45, 23, 41, 25, 13, 15, 26]
# epoch: 211, bulyan: at our-agr n_at 10 e 211 | val loss 4.6513 val acc 9.8620 best val_acc 21.428571
# discarded index [20, 44, 35, 45, 23, 41, 25, 13, 15, 26]
# epoch: 212, bulyan: at our-agr n_at 10 e 212 | val loss 111.3004 val acc 10.3084 best val_acc 21.428571
# discarded index [20, 15, 45, 35, 13, 14, 44, 24, 41, 25]
# epoch: 213, bulyan: at our-agr n_at 10 e 213 | val loss 13.0147 val acc 10.8766 best val_acc 21.428571
# discarded index [20, 15, 13, 45, 35, 14, 44, 41, 24, 25]
# epoch: 214, bulyan: at our-agr n_at 10 e 214 | val loss 337.5277 val acc 10.2273 best val_acc 21.428571
# discarded index [20, 13, 24, 17, 48, 37, 29, 15, 32, 35]
# epoch: 215, bulyan: at our-agr n_at 10 e 215 | val loss 130406.8371 val acc 9.6997 best val_acc 21.428571
# val loss 130406.837054 too high

# %%
import matplotlib.pyplot as plt
import numpy as np

ne =  nepochs + 1

for j in range(10):
  plt.figure(figsize=(10, 6))
  x = np.arange(ne)
  for i in range(40):
      y = history[i+10]
      plt.plot(x, y, color='green')

  y = history[j]
  plt.plot(x, y, color='red')


  plt.title('history')
  plt.xlabel('epoch')
  plt.ylabel('mean')
  plt.legend()
  plt.grid(True)
  plt.savefig('./history_malicious_'+str(j)+'.png')
  plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 11
#       9 for i in range(40):
#      10     y = history[i+10]
# ---> 11     plt.plot(x, y, color='green')
#      13 y = history[j]
#      14 plt.plot(x, y, color='red')
#
# File c:\Users\Hizan\.conda\envs\cpen333\lib\site-packages\matplotlib\pyplot.py:3575, in plot(scalex, scaley, data, *args, **kwargs)
#    3567 @_copy_docstring_and_deprecators(Axes.plot)
#    3568 def plot(
#    3569     *args: float | ArrayLike | str,
#    (...)
#    3573     **kwargs,
#    3574 ) -> list[Line2D]:
# -> 3575     return gca().plot(
#    3576         *args,
#    3577         scalex=scalex,
#    3578         scaley=scaley,
#    3579         **({"data": data} if data is not None else {}),
#    3580         **kwargs,
#    3581     )
#
# File c:\Users\Hizan\.conda\envs\cpen333\lib\site-packages\matplotlib\axes\_axes.py:1723, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1721 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722 for line in lines:
# -> 1723     self.add_line(line)
#    1724 if scalex:
#    1725     self._request_autoscale_view("x")
#
# File c:\Users\Hizan\.conda\envs\cpen333\lib\site-packages\matplotlib\axes\_base.py:2309, in _AxesBase.add_line(self, line)
#    2306 if line.get_clip_path() is None:
#    2307     line.set_clip_path(self.patch)
# -> 2309 self._update_line_limits(line)
#    2310 if not line.get_label():
#    2311     line.set_label(f'_child{len(self._children)}')
#
# File c:\Users\Hizan\.conda\envs\cpen333\lib\site-packages\matplotlib\axes\_base.py:2332, in _AxesBase._update_line_limits(self, line)
#    2328 def _update_line_limits(self, line):
#    2329     """
#    2330     Figures out the data limit of the given line, updating self.dataLim.
#    2331     """
# -> 2332     path = line.get_path()
#    2333     if path.vertices.size == 0:
#    2334         return
#
# File c:\Users\Hizan\.conda\envs\cpen333\lib\site-packages\matplotlib\lines.py:1032, in Line2D.get_path(self)
#    1030 """Return the `~matplotlib.path.Path` associated with this line."""
#    1031 if self._invalidy or self._invalidx:
# -> 1032     self.recache()
#    1033 return self._path
#
# File c:\Users\Hizan\.conda\envs\cpen333\lib\site-packages\matplotlib\lines.py:674, in Line2D.recache(self, always)
#     672 if always or self._invalidy:
#     673     yconv = self.convert_yunits(self._yorig)
# --> 674     y = _to_unmasked_float_array(yconv).ravel()
#     675 else:
#     676     y = self._y
#
# File c:\Users\Hizan\.conda\envs\cpen333\lib\site-packages\matplotlib\cbook.py:1345, in _to_unmasked_float_array(x)
#    1343     return np.ma.asarray(x, float).filled(np.nan)
#    1344 else:
# -> 1345     return np.asarray(x, float)
#
# File c:\Users\Hizan\.conda\envs\cpen333\lib\site-packages\torch\_tensor.py:1064, in Tensor.__array__(self, dtype)
#    1062     return self.numpy()
#    1063 else:
# -> 1064     return self.numpy().astype(dtype, copy=False)
#
# TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.

# %%
ne = nepochs + 1

plt.figure(figsize=(10, 6))
x = np.arange(ne)
for i in range(40):
    y = history[i+10]
    plt.plot(x, y, color='green')

for i in range(10):
    y = history[i]
    plt.plot(x, y, color='red')

plt.title('history')
plt.xlabel('epoch')
plt.ylabel('mean')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Plotting the data
for col in ['loss', 'validation accuracy', 'best validation accuracy']:
    plt.plot(df['epoch'].tolist(), df[col].tolist())
    plt.title("our attack + 10 attacker + our defense_"+col)
    plt.savefig('./our attack + 10 attacker + our defense ' + col + '.png')
    plt.show()
